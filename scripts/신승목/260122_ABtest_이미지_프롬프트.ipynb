# %% [markdown]
# # A/B Test: 이미지 생성 프롬프트 비교
#
# ## 목적
# - **대조군 A**: 일반적인 OpenAI API를 활용해 단순히 생성한 이미지 생성용 영어 프롬프트
# - **실험군 B**: 업종별 분류(18개 하위 그룹)를 통해 특화된 이미지 생성용 영어 프롬프트
#
# ## 가설
# 업종별 특화 프롬프트 시스템(B)이 일반 프롬프트 생성(A)보다 더 구체적이고 업종 특성에 맞는 프롬프트를 생성한다.
#
# ## 테스트 구성
# - 18개 하위 그룹별 10개의 한글 예시 문장
# - 총 180개의 테스트 케이스
# - 4개의 셀로 구성: S등급, A등급, B+C등급, D+E등급

# %% [markdown]
# ## 0. 환경 설정 및 모듈 로드

# %%
import os
import sys
import json
from typing import Dict, List
from dotenv import load_dotenv
from openai import OpenAI

# 프로젝트 루트 경로 설정
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# 환경변수 로드
load_dotenv()

# 실험군 B용 모듈 import
from src.generation.image_generation.prompt.prompt_manager import PromptTemplateManager

print(f"프로젝트 경로: {PROJECT_ROOT}")
print("모듈 로드 완료!")
# Out:
# 프로젝트 경로: c:\Users\USER\_codeit\_final_project\codeit_ad_smallbiz
# 모듈 로드 완료!

# %% [markdown]
# ## 1. A/B 테스트 함수 정의

# %%
# OpenAI 클라이언트 초기화
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# 실험군 B용 프롬프트 매니저 초기화
prompt_manager_b = PromptTemplateManager()


def generate_prompt_control_a(korean_input: str) -> str:
    """
    대조군 A: 일반적인 OpenAI API를 사용한 프롬프트 생성
    
    특징:
    - 업종 분류 없이 단순 번역 및 프롬프트 변환
    - 일반적인 이미지 생성 지시문 사용
    - 실험군 B와 비슷한 길이(80-250 단어)로 생성
    """
    system_prompt = """You are an image prompt generator. Convert Korean advertising text into English image generation prompts.

Rules:
1. Create a detailed prompt (80-250 words) for AI image generation
2. Include subject, setting, lighting, atmosphere, and visual details
3. Write in natural flowing sentences
4. Focus on visual elements that can be photographed or illustrated
5. Do NOT include any text or typography in the image description

Output format:
{"positive": "your detailed prompt here"}
"""
    
    user_prompt = f"""Convert this Korean advertising text into an image generation prompt:

{korean_input}

Generate a detailed, visually descriptive prompt."""
    
    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            temperature=0.7
        )
        
        result = response.choices[0].message.content.strip()
        
        # JSON 파싱
        if "```json" in result:
            result = result.split("```json")[1].split("```")[0].strip()
        elif "```" in result:
            result = result.split("```")[1].split("```")[0].strip()
        
        data = json.loads(result)
        return data.get("positive", result)
        
    except Exception as e:
        return f"[Error] {str(e)}"


def generate_prompt_experiment_b(korean_input: str, style: str = "realistic") -> str:
    """
    실험군 B: 업종별 분류를 통한 특화 프롬프트 생성
    
    특징:
    - 한글 입력에서 자동 업종 감지
    - 18개 하위 그룹별 최적화된 프롬프트 템플릿 적용
    - 업종별 키워드, 조명, 구도, 색감 등 반영
    """
    try:
        result = prompt_manager_b.generate_detailed_prompt(korean_input, style)
        return result.get("positive", "")
    except Exception as e:
        return f"[Error] {str(e)}"


def run_ab_test(test_cases: List[Dict], group_name: str):
    """
    A/B 테스트 실행 및 결과 출력
    
    Args:
        test_cases: 테스트 케이스 리스트 [{"group": "S-1", "input": "한글 입력"}]
        group_name: 그룹명 (예: "S등급")
    """
    print(f"\n{'='*100}")
    print(f"📊 {group_name} A/B 테스트 결과")
    print(f"{'='*100}\n")
    
    results = []
    
    for i, case in enumerate(test_cases, 1):
        group = case.get("group", "")
        korean_input = case.get("input", "")
        
        print(f"\n[{i}/{len(test_cases)}] {group}")
        print(f"-" * 80)
        
        # A/B 프롬프트 생성
        prompt_a = generate_prompt_control_a(korean_input)
        prompt_b = generate_prompt_experiment_b(korean_input)
        
        # 결과 출력
        print(f'한글 입력: "{korean_input}"')
        print(f'\n대조군 A: "{prompt_a[:500]}..."' if len(prompt_a) > 500 else f'\n대조군 A: "{prompt_a}"')
        print(f'\n실험군 B: "{prompt_b[:500]}..."' if len(prompt_b) > 500 else f'\n실험군 B: "{prompt_b}"')
        print(f"\n📏 길이 비교: A={len(prompt_a.split())}단어, B={len(prompt_b.split())}단어")
        
        results.append({
            "group": group,
            "korean_input": korean_input,
            "prompt_a": prompt_a,
            "prompt_b": prompt_b,
            "len_a": len(prompt_a.split()),
            "len_b": len(prompt_b.split())
        })
    
    # 요약 통계
    avg_len_a = sum(r["len_a"] for r in results) / len(results)
    avg_len_b = sum(r["len_b"] for r in results) / len(results)
    
    print(f"\n\n{'='*100}")
    print(f"📈 {group_name} 요약 통계")
    print(f"{'='*100}")
    print(f"테스트 케이스 수: {len(results)}")
    print(f"대조군 A 평균 길이: {avg_len_a:.1f} 단어")
    print(f"실험군 B 평균 길이: {avg_len_b:.1f} 단어")
    
    return results

# %% [markdown]
# ## 2. 테스트 데이터 정의
#
# ### 18개 하위 그룹별 10개의 한글 예시 문장

# %%
# ============================================
# S등급: 감성 및 미각 자극 그룹 (4개 그룹)
# ============================================

# S-1: 고온 조리 및 육즙 강조 (19개 업종)
S1_HOT_COOKING = [
    {"group": "S-1", "input": "숯불에 구운 삼겹살, 육즙이 뚝뚝 떨어지는 모습"},
    {"group": "S-1", "input": "치킨 전문점 홍보, 갓 튀긴 바삭한 치킨"},
    {"group": "S-1", "input": "피자 가게 신메뉴, 치즈가 늘어나는 장면"},
    {"group": "S-1", "input": "마라탕 전문점, 얼얼하게 매운 국물과 재료들"},
    {"group": "S-1", "input": "스테이크 레스토랑, 미디엄 레어로 구운 안심"},
    {"group": "S-1", "input": "중국집 짜장면, 윤기 나는 면발과 춘장 소스"},
    {"group": "S-1", "input": "버거 전문점, 육즙 가득한 수제버거"},
    {"group": "S-1", "input": "곱창 구이, 불판 위에서 지글지글 익는 모습"},
    {"group": "S-1", "input": "일식 라멘집, 김이 모락모락 나는 돈코츠 라멘"},
    {"group": "S-1", "input": "생맥주 전문점, 시원한 맥주와 안주 플래터"},
]

# S-2: 신선도 및 색감 강조 (8개 업종)
S2_FRESHNESS = [
    {"group": "S-2", "input": "횟집 홍보, 신선한 모둠회와 싱싱한 해산물"},
    {"group": "S-2", "input": "초밥 전문점, 장인이 만든 프리미엄 오마카세"},
    {"group": "S-2", "input": "해산물 찜, 게와 새우가 가득한 해물찜"},
    {"group": "S-2", "input": "수산시장 홍보, 싱싱한 활어와 조개류"},
    {"group": "S-2", "input": "복어 요리 전문점, 복어회와 복어탕 코스"},
    {"group": "S-2", "input": "정육점 홍보, 마블링이 좋은 한우 투플러스"},
    {"group": "S-2", "input": "과일 전문점, 제철 딸기와 샤인머스캣"},
    {"group": "S-2", "input": "채소 가게, 유기농 신선 채소 모음"},
    {"group": "S-2", "input": "연어 전문점, 노르웨이산 생연어 사시미"},
    {"group": "S-2", "input": "젓갈 가게, 전통 방식으로 담근 명란젓"},
]

# S-3: 감성 및 부드러운 질감 (21개 업종)
S3_EMOTIONAL = [
    {"group": "S-3", "input": "카페 신메뉴, 딸기 라떼와 크루아상"},
    {"group": "S-3", "input": "베이커리 홍보, 갓 구운 소금빵과 크림빵"},
    {"group": "S-3", "input": "아이스크림 가게, 파스텔 톤 젤라또 3종"},
    {"group": "S-3", "input": "떡카페, 예쁜 화과자와 전통차 세트"},
    {"group": "S-3", "input": "샌드위치 전문점, 건강한 샐러드 샌드위치"},
    {"group": "S-3", "input": "서점 카페, 책과 함께하는 커피 타임"},
    {"group": "S-3", "input": "화장품 매장, 봄 시즌 신제품 립스틱"},
    {"group": "S-3", "input": "약국 건강기능식품, 비타민과 유산균"},
    {"group": "S-3", "input": "문구점 홍보, 예쁜 다이어리와 펜 세트"},
    {"group": "S-3", "input": "기념품샵, 여행 기념 엽서와 마그넷"},
]

# S-4: 정갈함과 다채로움 (22개 업종)
S4_NEAT_VARIETY = [
    {"group": "S-4", "input": "한정식 홍보, 정갈한 반찬과 된장찌개 상차림"},
    {"group": "S-4", "input": "김밥 전문점, 다양한 김밥과 라면 세트"},
    {"group": "S-4", "input": "백반집 점심 메뉴, 오늘의 집밥 정식"},
    {"group": "S-4", "input": "국밥집 홍보, 뜨끈한 돼지국밥 한 그릇"},
    {"group": "S-4", "input": "냉면 전문점, 시원한 물냉면과 비빔냉면"},
    {"group": "S-4", "input": "반찬 가게, 정성 가득 수제 반찬 10종"},
    {"group": "S-4", "input": "분식집, 떡볶이와 순대 세트 메뉴"},
    {"group": "S-4", "input": "칼국수집, 손칼국수와 왕만두"},
    {"group": "S-4", "input": "전문점 홍보, 바삭한 해물파전과 막걸리"},
    {"group": "S-4", "input": "족발/보쌈 전문점, 쫄깃한 족발과 보쌈"},
]

# S등급 전체 테스트 케이스
S_GRADE_TEST_CASES = S1_HOT_COOKING + S2_FRESHNESS + S3_EMOTIONAL + S4_NEAT_VARIETY

print(f"S등급 테스트 케이스 수: {len(S_GRADE_TEST_CASES)}개")
# Out:
# S등급 테스트 케이스 수: 40개

# %%
# ============================================
# A등급: 비주얼 변화 및 자기관리 그룹 (4개 그룹)
# ============================================

# A-1: 인물 중심 뷰티 및 에스테틱 (5개 업종)
A1_BEAUTY = [
    {"group": "A-1", "input": "미용실 봄 헤어 스타일, 웨이브 펌 시술 결과"},
    {"group": "A-1", "input": "피부관리실 홍보, 맑고 깨끗한 피부 관리"},
    {"group": "A-1", "input": "네일샵 신상 디자인, 봄 꽃 네일 아트"},
    {"group": "A-1", "input": "성형외과 상담 안내, 자연스러운 코 성형"},
    {"group": "A-1", "input": "피부과 레이저 시술, 잡티 제거 전후 비교"},
    {"group": "A-1", "input": "미용실 염색 이벤트, 트렌디한 발레아주"},
    {"group": "A-1", "input": "에스테틱 페이셜 케어, 광채 나는 피부"},
    {"group": "A-1", "input": "네일샵 젤네일, 고급스러운 글리터 디자인"},
    {"group": "A-1", "input": "헤어샵 남성 커트, 깔끔한 투블럭 스타일"},
    {"group": "A-1", "input": "속눈썹 연장 전문, 자연스러운 볼륨 래쉬"},
]

# A-2: 신체 변화 및 웰니스 (6개 업종)
A2_WELLNESS = [
    {"group": "A-2", "input": "헬스장 PT 프로그램, 1:1 개인 트레이닝"},
    {"group": "A-2", "input": "요가 스튜디오, 아침 명상 요가 클래스"},
    {"group": "A-2", "input": "필라테스 센터, 체형 교정 프로그램"},
    {"group": "A-2", "input": "태권도 학원, 어린이 품새 수업"},
    {"group": "A-2", "input": "다이어트 클리닉, 3개월 체중 감량 성공"},
    {"group": "A-2", "input": "마사지샵 홍보, 타이 마사지 전신 케어"},
    {"group": "A-2", "input": "크로스핏 박스, 고강도 인터벌 트레이닝"},
    {"group": "A-2", "input": "복싱 체육관, 다이어트 복싱 프로그램"},
    {"group": "A-2", "input": "스피닝 센터, 신나는 그룹 사이클링"},
    {"group": "A-2", "input": "스파 웰니스, 아로마 테라피 힐링"},
]

# A-3: 패션 및 스타일 아이템 (23개 업종)
A3_FASHION = [
    {"group": "A-3", "input": "여성 의류 매장, 봄 신상 원피스 컬렉션"},
    {"group": "A-3", "input": "남성 정장 전문점, 맞춤 수트 제작"},
    {"group": "A-3", "input": "아동복 가게, 귀여운 봄 키즈 패션"},
    {"group": "A-3", "input": "신발 매장, 트렌디한 스니커즈 신상"},
    {"group": "A-3", "input": "가방 브랜드, 가죽 토트백 신제품"},
    {"group": "A-3", "input": "시계/주얼리샵, 프리미엄 시계 컬렉션"},
    {"group": "A-3", "input": "안경점 신상, 트렌드 뿔테 안경"},
    {"group": "A-3", "input": "사진관 홍보, 가족 기념사진 촬영"},
    {"group": "A-3", "input": "웨딩샵 드레스, 우아한 레이스 웨딩드레스"},
    {"group": "A-3", "input": "한복 대여점, 설날 전통 한복 렌탈"},
]

# A-4: 섬세한 케어 및 감성 소품 (16개 업종)
A4_DELICATE_CARE = [
    {"group": "A-4", "input": "꽃집 홍보, 발렌타인 장미 꽃다발"},
    {"group": "A-4", "input": "반려동물 용품점, 강아지 봄 옷 신상"},
    {"group": "A-4", "input": "동물병원 안내, 반려견 건강검진 패키지"},
    {"group": "A-4", "input": "장난감 가게, 레고 신제품 출시"},
    {"group": "A-4", "input": "가구점 홍보, 미니멀 원목 책상 세트"},
    {"group": "A-4", "input": "세탁소 서비스, 명품 가방 클리닝"},
    {"group": "A-4", "input": "피아노 학원, 어린이 피아노 레슨"},
    {"group": "A-4", "input": "미술학원 홍보, 수채화 클래스 작품전"},
    {"group": "A-4", "input": "자전거 매장, 접이식 미니벨로 신상"},
    {"group": "A-4", "input": "인테리어 소품샵, 북유럽 감성 조명"},
]

# A등급 전체 테스트 케이스
A_GRADE_TEST_CASES = A1_BEAUTY + A2_WELLNESS + A3_FASHION + A4_DELICATE_CARE

print(f"A등급 테스트 케이스 수: {len(A_GRADE_TEST_CASES)}개")
# Out:
# A등급 테스트 케이스 수: 40개

# %%
# ============================================
# B등급: 공간 체험 및 교육 그룹 (3개 그룹)
# ============================================

# B-1: 학습 및 몰입 (16개 업종)
B1_LEARNING = [
    {"group": "B-1", "input": "입시학원 홍보, 소수정예 수학 클래스"},
    {"group": "B-1", "input": "외국어 학원, 원어민 영어 회화 수업"},
    {"group": "B-1", "input": "코딩 학원, 어린이 프로그래밍 교육"},
    {"group": "B-1", "input": "스터디카페 홍보, 조용하고 쾌적한 학습 공간"},
    {"group": "B-1", "input": "운전학원 안내, 친절한 1:1 운전 교육"},
    {"group": "B-1", "input": "공무원 학원, 합격자 수기와 커리큘럼"},
    {"group": "B-1", "input": "독서실 오픈, 24시간 개인 학습 부스"},
    {"group": "B-1", "input": "유학원 상담, 미국 대학 입학 컨설팅"},
    {"group": "B-1", "input": "취업 학원, 면접 스피치 특강"},
    {"group": "B-1", "input": "자격증 학원, 바리스타 자격증 과정"},
]

# B-2: 여가 및 숙박 (19개 업종)
B2_LEISURE = [
    {"group": "B-2", "input": "호텔 프로모션, 오션뷰 스위트룸 패키지"},
    {"group": "B-2", "input": "펜션 홍보, 가족 단위 바베큐 독채"},
    {"group": "B-2", "input": "PC방 이벤트, 최신 사양 게이밍 좌석"},
    {"group": "B-2", "input": "노래방 시설, 프리미엄 코인 노래방"},
    {"group": "B-2", "input": "글램핑장 오픈, 자연 속 럭셔리 캠핑"},
    {"group": "B-2", "input": "여행사 패키지, 제주도 3박 4일 투어"},
    {"group": "B-2", "input": "찜질방 홍보, 힐링 스파 시설 안내"},
    {"group": "B-2", "input": "만화카페, 아늑한 독서 공간"},
    {"group": "B-2", "input": "보드게임 카페, 친구들과 즐기는 게임"},
    {"group": "B-2", "input": "리조트 워터파크, 신나는 물놀이 시설"},
]

# B-3: 스포츠 및 활동 (10개 업종)
B3_SPORTS = [
    {"group": "B-3", "input": "수영장 회원 모집, 성인 수영 강습"},
    {"group": "B-3", "input": "골프 연습장, 실내 스크린 골프 시설"},
    {"group": "B-3", "input": "볼링장 이벤트, 단체 볼링 대회"},
    {"group": "B-3", "input": "당구장 홍보, 프로 당구 레슨"},
    {"group": "B-3", "input": "테니스장 오픈, 실내 테니스 코트"},
    {"group": "B-3", "input": "탁구장 클럽, 동호인 리그전"},
    {"group": "B-3", "input": "풋살장 대관, 최신 인조잔디 구장"},
    {"group": "B-3", "input": "배드민턴장, 동호회 대관 안내"},
    {"group": "B-3", "input": "클라이밍 센터, 초보자 볼더링 체험"},
    {"group": "B-3", "input": "스쿼시장 신규 오픈, 1:1 레슨"},
]

# ============================================
# C등급: 신뢰 기반 전문 서비스 그룹 (3개 그룹)
# ============================================

# C-1: 전문 사무 (18개 업종)
C1_PROFESSIONAL = [
    {"group": "C-1", "input": "부동산 중개소, 역세권 신축 오피스텔 매물"},
    {"group": "C-1", "input": "법무법인 홍보, 기업 법률 자문 서비스"},
    {"group": "C-1", "input": "세무사 사무소, 종합소득세 신고 대행"},
    {"group": "C-1", "input": "회계사 상담, 스타트업 재무 컨설팅"},
    {"group": "C-1", "input": "특허 사무소, 상표권 등록 안내"},
    {"group": "C-1", "input": "노무사 사무실, 근로계약서 검토 서비스"},
    {"group": "C-1", "input": "광고 대행사, 브랜드 마케팅 캠페인"},
    {"group": "C-1", "input": "경영 컨설팅, 중소기업 성장 전략"},
    {"group": "C-1", "input": "행정사 사무소, 인허가 대행 서비스"},
    {"group": "C-1", "input": "번역 사무소, 법률 문서 번역 전문"},
]

# C-2: 의료 및 케어 (16개 업종)
C2_MEDICAL = [
    {"group": "C-2", "input": "내과 의원, 건강검진 패키지 안내"},
    {"group": "C-2", "input": "치과 클리닉, 임플란트 상담 이벤트"},
    {"group": "C-2", "input": "한의원 홍보, 비만 한방 다이어트"},
    {"group": "C-2", "input": "정형외과, 척추 비수술 치료 프로그램"},
    {"group": "C-2", "input": "안과 라식 센터, 시력교정술 상담"},
    {"group": "C-2", "input": "이비인후과, 수면무호흡 검사 안내"},
    {"group": "C-2", "input": "소아과 의원, 영유아 예방접종"},
    {"group": "C-2", "input": "산부인과, 임신 초기 검사 프로그램"},
    {"group": "C-2", "input": "정신건강의학과, 스트레스 상담 클리닉"},
    {"group": "C-2", "input": "요양원 안내, 어르신 전문 케어 시설"},
]

# C-3: 기술 및 시공 (16개 업종)
C3_TECHNICAL = [
    {"group": "C-3", "input": "자동차 정비소, 엔진오일 교환 이벤트"},
    {"group": "C-3", "input": "세차장 홍보, 프리미엄 손세차 서비스"},
    {"group": "C-3", "input": "인테리어 업체, 아파트 리모델링 시공"},
    {"group": "C-3", "input": "이사업체 안내, 원룸 포장이사 서비스"},
    {"group": "C-3", "input": "에어컨 청소, 분해 완전 세척 서비스"},
    {"group": "C-3", "input": "방역 소독 업체, 바퀴벌레 퇴치 서비스"},
    {"group": "C-3", "input": "조경 관리, 아파트 단지 정원 가꾸기"},
    {"group": "C-3", "input": "간판 제작소, LED 채널 간판 시공"},
    {"group": "C-3", "input": "타일 시공 전문, 욕실 리모델링"},
    {"group": "C-3", "input": "도배/장판 업체, 벽지 시공 견적 안내"},
]

# B+C등급 전체 테스트 케이스
BC_GRADE_TEST_CASES = B1_LEARNING + B2_LEISURE + B3_SPORTS + C1_PROFESSIONAL + C2_MEDICAL + C3_TECHNICAL

print(f"B+C등급 테스트 케이스 수: {len(BC_GRADE_TEST_CASES)}개")
# Out:
# B+C등급 테스트 케이스 수: 60개

# %%
# ============================================
# D등급: 목적형 소매 및 장비 그룹 (2개 그룹)
# ============================================

# D-1: 중장비 및 부품 (16개 업종)
D1_HEAVY_EQUIPMENT = [
    {"group": "D-1", "input": "타이어 전문점, 사계절 타이어 할인"},
    {"group": "D-1", "input": "자동차 부품점, 순정 브레이크 패드"},
    {"group": "D-1", "input": "철물점 홍보, 공구 세트 특가 판매"},
    {"group": "D-1", "input": "건축자재 판매, 시멘트/벽돌 도매"},
    {"group": "D-1", "input": "전기용품 가게, LED 조명 설치"},
    {"group": "D-1", "input": "중장비 대여, 굴삭기 렌탈 서비스"},
    {"group": "D-1", "input": "바닥재 전문, 마루/장판 시공"},
    {"group": "D-1", "input": "의료기기 판매, 혈압계/체온계 세트"},
    {"group": "D-1", "input": "중고 물품점, 가전제품 매입/판매"},
    {"group": "D-1", "input": "사료 전문점, 반려동물 사료 할인"},
]

# D-2: 일반 기기 (14개 업종)
D2_GENERAL_EQUIPMENT = [
    {"group": "D-2", "input": "핸드폰 매장, 최신 스마트폰 개통"},
    {"group": "D-2", "input": "컴퓨터 수리점, 노트북 SSD 업그레이드"},
    {"group": "D-2", "input": "가전제품 매장, 에어컨 여름 특가"},
    {"group": "D-2", "input": "복합기 임대, 사무실 프린터 렌탈"},
    {"group": "D-2", "input": "폰 수리 전문, 액정 교체 당일 수리"},
    {"group": "D-2", "input": "렌터카 업체, 장기 렌트 프로모션"},
    {"group": "D-2", "input": "인력사무소, 단기 아르바이트 모집"},
    {"group": "D-2", "input": "냉장고 수리, 컴프레서 교체 서비스"},
    {"group": "D-2", "input": "노트북 판매, 학생 할인 프로모션"},
    {"group": "D-2", "input": "TV 수리점, 대형 TV 출장 서비스"},
]

# ============================================
# E등급: 인프라 및 특수 목적 그룹 (2개 그룹)
# ============================================

# E-1: 편의 및 인프라 (2개 업종)
E1_INFRASTRUCTURE = [
    {"group": "E-1", "input": "주유소 홍보, 리터당 할인 이벤트"},
    {"group": "E-1", "input": "LPG 충전소, 자동차 가스 충전"},
    {"group": "E-1", "input": "셀프 주유소, 24시간 야간 운영"},
    {"group": "E-1", "input": "세차장 겸 주유소, 셀프 세차 시설"},
    {"group": "E-1", "input": "전기차 충전소, 급속 충전 스테이션"},
]

# E-2: 예절 및 의례 (2개 업종)
E2_CEREMONY = [
    {"group": "E-2", "input": "장례식장 안내, 엄숙한 추모 공간"},
    {"group": "E-2", "input": "납골당 분양, 평화로운 영면 장소"},
    {"group": "E-2", "input": "상조 서비스, 장례 종합 패키지"},
    {"group": "E-2", "input": "수목장 안내, 자연과 함께하는 추모"},
    {"group": "E-2", "input": "추모관 홍보, 차분한 추모 시설"},
]

# D+E등급 전체 테스트 케이스
DE_GRADE_TEST_CASES = D1_HEAVY_EQUIPMENT + D2_GENERAL_EQUIPMENT + E1_INFRASTRUCTURE + E2_CEREMONY

print(f"D+E등급 테스트 케이스 수: {len(DE_GRADE_TEST_CASES)}개")
# Out:
# D+E등급 테스트 케이스 수: 30개

# %% [markdown]
# ## 3. A/B 테스트 실행

# %% [markdown]
# ### 3.1 S등급 테스트 (감성 및 미각 자극)

# %%
# S등급 A/B 테스트 실행
s_grade_results = run_ab_test(S_GRADE_TEST_CASES, "S등급 (감성 및 미각 자극)")
# Out:
# ====================================================================================================
# 📊 S등급 (감성 및 미각 자극) A/B 테스트 결과
# ====================================================================================================
#
#
# [1/40] S-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 숯불에 구운 삼겹살, 육즙이 뚝뚝 떨어지는 모습
# ================================================================================
#    감지된 업종: s1_hot_cooking
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1040 chars (~162 words)
# ================================================================================
#
# 한글 입력: "숯불에 구운 삼겹살, 육즙이 뚝뚝 떨어지는 모습"
#
# 대조군 A: "A close-up scene of mouthwatering, grilled pork belly sizzling over charcoal flames. The pork belly is perfectly cooked, glistening with a golden-brown crust, with juices dripping down onto the hot grill, creating a slight steam. The charcoal is glowing with embers, adding a warm, inviting light to the scene. Surrounding the grill, a rustic wooden table is set with fresh ingredients like vibrant green lettuce leaves, spicy red chili peppers, and a small bowl of dipping sauce. The atmosphere is l..."
#
# 실험군 B: "Charcoal-grilled pork belly (samgyeopsal) with juices dripping, captured mid-sizzle as clear beads of meat juice fall from a glistening edge. Shot like a professional food photograph on a Canon EOS R5 with a 100mm macro lens at f/2.8 to isolate the subject, using a fast shutter to freeze droplets and a low ISO for clean detail. The scene is a close 45-degree macro composition over a rustic charcoal grill, showing deep sear lines and slightly charred edges, layers of translucent rendered fat, and..."
#
# 📏 길이 비교: A=118단어, B=162단어
#
# [2/40] S-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 치킨 전문점 홍보, 갓 튀긴 바삭한 치킨
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1075 chars (~171 words)
#    Text Overlay: {'product_name': '갓 튀긴 바삭한 치킨', 'tagline': '치킨 전문점 홍보'}
# ================================================================================
#
# 한글 입력: "치킨 전문점 홍보, 갓 튀긴 바삭한 치킨"
#
# 대조군 A: "Imagine a vibrant and inviting scene at a chicken specialty restaurant. The focus is on a large, golden-brown fried chicken, perfectly crispy and glistening with a light sheen of oil. The chicken is presented on a rustic wooden table, surrounded by an array of colorful side dishes, including fresh coleslaw, crispy fries, and dipping sauces in small bowls. The setting is warmly lit with soft, natural light filtering through a nearby window, casting gentle shadows that enhance the textures of the ..."
#
# 실험군 B: "Crispy freshly-fried chicken presented in an open woven basket at the center of a top-down flat lay, a few pieces torn open to reveal steaming, juicy white meat inside and flaky, golden-brown crust falling in crisp shards. Shot like a commercial food photograph on a Canon EOS R5 with a 35mm lens from directly overhead, warm overhead softbox light mimics home-style restaurant lighting while a subtle side window fill adds natural daylight highlights. The scene is on a warm wooden dining table with..."
#
# 📏 길이 비교: A=138단어, B=171단어
#
# [3/40] S-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 피자 가게 신메뉴, 치즈가 늘어나는 장면
# ================================================================================
#    감지된 업종: s1_hot_cooking
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1017 chars (~161 words)
#    Text Overlay: {'tagline': '신메뉴'}
# ================================================================================
#
# 한글 입력: "피자 가게 신메뉴, 치즈가 늘어나는 장면"
#
# 대조군 A: "A mouth-watering scene showcasing a freshly baked pizza being pulled apart, with gooey, melted cheese stretching tantalizingly between two slices. The setting is a cozy, warmly lit pizzeria with rustic wooden tables and a brick oven in the background, giving an inviting atmosphere. The pizza is topped with vibrant ingredients such as bright red tomatoes, fresh green basil, and a sprinkle of golden-brown crust. The lighting casts a warm glow on the pizza, highlighting the rich textures of the che..."
#
# 실험군 B: "New menu pizza from a neighborhood pizzeria with a single slice being lifted so long, molten cheese stretches in glossy, elastic strands from the pie. Shot like high-end commercial food photography on a full-frame camera with an 85mm lens at a shallow aperture to isolate the foreground, the composition sits at a 45-degree macro close-up showing the lifted slice and the remaining pie on a rustic wooden board. Warm overhead cinematic light combined with a soft natural window rim light creates gold..."
#
# 📏 길이 비교: A=117단어, B=161단어
#
# [4/40] S-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 마라탕 전문점, 얼얼하게 매운 국물과 재료들
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1276 chars (~193 words)
# ================================================================================
#
# 한글 입력: "마라탕 전문점, 얼얼하게 매운 국물과 재료들"
#
# 대조군 A: "A vibrant and enticing scene of a traditional mala tang restaurant, showcasing a steaming pot filled with a rich, spicy broth. The broth is a deep red color, bubbling energetically, with visible spices and herbs floating on the surface, creating an aromatic allure. Surrounding the hot pot, an array of fresh, colorful ingredients is beautifully arranged on a wooden table. There are bright green leafy vegetables, plump mushrooms, and various meats sliced thinly, all glistening with freshness. The ..."
#
# 실험군 B: "Mala tang hot pot spread with a numbing, tongue-tingling spicy broth and neatly arranged fresh ingredients, presented in a top-down flat lay across a wooden dining table. Shot on a professional full-frame camera with a 35mm prime lens mounted overhead to capture the entire composition, aperture around f/5.6 for crisp detail across the frame. Warm overhead restaurant lighting mixes with soft natural daylight from a nearby window, creating warm highlights on the chili oil surface and gentle shadow..."
#
# 📏 길이 비교: A=157단어, B=193단어
#
# [5/40] S-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 스테이크 레스토랑, 미디엄 레어로 구운 안심
# ================================================================================
#    감지된 업종: s1_hot_cooking
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1111 chars (~180 words)
# ================================================================================
#
# 한글 입력: "스테이크 레스토랑, 미디엄 레어로 구운 안심"
#
# 대조군 A: "A beautifully arranged steak restaurant setting, featuring a centerpiece of a perfectly cooked medium-rare tenderloin steak. The steak is glistening with a rich, caramelized crust, showcasing juicy, pink meat at the center, garnished with a sprig of fresh rosemary and a drizzle of herb-infused olive oil. Surrounding the steak are elegant plates with colorful sides, such as roasted seasonal vegetables and creamy mashed potatoes. The table is set with polished cutlery, wine glasses filled with a d..."
#
# 실험군 B: "Filet mignon steak cooked to medium-rare, sliced open to reveal a warm pink center with juices gently pooling, presented on a rustic wooden board in an upscale steak restaurant. Shot as a 45-degree macro close-up to emphasize the interior texture and charred crust, the camera focuses on the cut surface while the rest of the plate and background fall into creamy bokeh. Photographic direction: shot on a full-frame mirrorless camera with a 100mm macro lens at f/2.8, 1/160s, ISO 200 to capture fine ..."
#
# 📏 길이 비교: A=127단어, B=180단어
#
# [6/40] S-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 중국집 짜장면, 윤기 나는 면발과 춘장 소스
# ================================================================================
#    감지된 업종: s1_hot_cooking
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1119 chars (~186 words)
# ================================================================================
#
# 한글 입력: "중국집 짜장면, 윤기 나는 면발과 춘장 소스"
#
# 대조군 A: "A beautifully composed still life featuring a bowl of Chinese Jajangmyeon, showcasing glossy, perfectly cooked noodles glistening under soft, warm lighting. The rich, dark Jajang sauce is generously drizzled over the noodles, with chunks of savory vegetables peeking through, adding vibrant colors of green and red. Surrounding the bowl, traditional Chinese chopsticks rest casually, while a small dish of pickled radish adds a pop of white to the scene. The background is softly blurred, evoking a c..."
#
# 실험군 B: "Jjajangmyeon in a deep rustic ceramic bowl, glossy black-bean sauce clinging to springy wheat noodles as a pair of black chopsticks lifts a generous tangle, steam rising in soft ribbons and catching the light. Shot as a 45-degree macro close-up to emphasize noodle texture and sauce viscosity, with the lifted strands framed slightly off-center so the bowl rim and a few caramelized pork and diced onion pieces remain in view. Shot on a Canon EOS R5 with a 100mm f/2.8 macro lens using a shallow dept..."
#
# 📏 길이 비교: A=103단어, B=186단어
#
# [7/40] S-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 버거 전문점, 육즙 가득한 수제버거
# ================================================================================
#    감지된 업종: s1_hot_cooking
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1167 chars (~185 words)
# ================================================================================
#
# 한글 입력: "버거 전문점, 육즙 가득한 수제버거"
#
# 대조군 A: "Imagine a bustling burger restaurant with a warm and inviting atmosphere. The focal point is a beautifully crafted gourmet burger, showcasing a thick, juicy beef patty that glistens with savory juices. The burger is artfully stacked with fresh, crisp lettuce, ripe tomato slices, and melted cheddar cheese, all nestled between a lightly toasted, sesame-seed bun. Surrounding the burger, there are vibrant side dishes like golden, crispy French fries and a small bowl of tangy dipping sauce. The setti..."
#
# 실험군 B: "Handcrafted juicy beef burger cut in cross-section with glossy melted cheese stretching from the patty, juices pooling and delicate steam rising, presented on a toasted brioche bun sprinkled with sesame seeds. Shot like a commercial food photograph on a Canon EOS R5 with a 100mm macro lens at f/2.8, shallow depth of field to keep the frontmost patty edge and bun sharply detailed while the background melts into creamy bokeh. The composition is a 45-degree macro close-up slightly above the plate t..."
#
# 📏 길이 비교: A=142단어, B=185단어
#
# [8/40] S-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 곱창 구이, 불판 위에서 지글지글 익는 모습
# ================================================================================
#    감지된 업종: s1_hot_cooking
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1062 chars (~170 words)
# ================================================================================
#
# 한글 입력: "곱창 구이, 불판 위에서 지글지글 익는 모습"
#
# 대조군 A: "A sizzling plate of grilled gopchang (beef intestines) is the focal point of the scene, arranged artistically on a traditional Korean barbecue grill. The gopchang is perfectly charred, with crispy edges and a glossy sheen reflecting the golden glow of the flames below. Surrounding the grill, vibrant side dishes like kimchi, pickled radish, and a fresh salad add color and contrast to the image. The setting is a cozy, rustic Korean barbecue restaurant, with wooden tables and warm ambient lighting ..."
#
# 실험군 B: "Gopchang sizzling on a hotplate, cut into bite-sized twists and curling as hot oil pops and steam rises in delicate ribbons. Capture the moment of active cooking from a 45-degree macro perspective so the irregular coils, charred grill marks and glistening fat occupy the foreground while the cast-iron griddle and faint ember glow blur softly in the background. Direct a warm overhead key light to create golden highlights on the surface oil and a soft side fill from a nearby window to reveal the po..."
#
# 📏 길이 비교: A=146단어, B=170단어
#
# [9/40] S-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 일식 라멘집, 김이 모락모락 나는 돈코츠 라멘
# ================================================================================
#    감지된 업종: s1_hot_cooking
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1069 chars (~171 words)
# ================================================================================
#
# 한글 입력: "일식 라멘집, 김이 모락모락 나는 돈코츠 라멘"
#
# 대조군 A: "A cozy Japanese ramen shop, featuring a steaming bowl of tonkotsu ramen at the center of the composition. The bowl is filled with rich, creamy broth, topped with tender slices of chashu pork, vibrant green onions, and a perfectly cooked soft-boiled egg with a runny yolk. The steam rises from the bowl, creating an inviting atmosphere that suggests warmth and comfort. The shop's interior is adorned with traditional Japanese decor, including wooden beams, paper lanterns softly glowing with warm lig..."
#
# 실험군 B: "Tonkotsu ramen steaming in a deep ceramic bowl, a close-up 45-degree macro composition that captures steam curling up from the silky, milky pork-bone broth as thin noodles are gently lifted and coil with glossy sheen. Shot on a Canon EOS R5 with a 100mm f/2.8 macro lens, shallow depth of field at f/2.8 isolates the bowl against a softly blurred wooden counter and warm restaurant interior. Overhead soft warm key light from a diffused softbox highlights the creamy emulsified broth and glistening o..."
#
# 📏 길이 비교: A=143단어, B=171단어
#
# [10/40] S-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 생맥주 전문점, 시원한 맥주와 안주 플래터
# ================================================================================
#    감지된 업종: s1_hot_cooking
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1097 chars (~178 words)
# ================================================================================
#
# 한글 입력: "생맥주 전문점, 시원한 맥주와 안주 플래터"
#
# 대조군 A: "A cozy and inviting craft beer pub setting, featuring a beautifully arranged platter of assorted appetizers including crispy fried calamari, spicy chicken wings, and fresh vegetable sticks with creamy dips. In the foreground, tall chilled glasses of golden, frothy beer catch the soft, warm glow of pendant lights hanging from the ceiling. The atmosphere is lively yet relaxed, with patrons enjoying their drinks and food at wooden tables, surrounded by rustic brick walls adorned with vintage beer m..."
#
# 실험군 B: "A chilled pint of draft beer and an appetizer platter arranged on a rustic wooden table in a bustling craft beer pub. Shot like a professional food photographer, the composition is a 45-degree macro close-up focusing on the frothy beer head and the nearest savory bite, with a shallow depth of field to render the background into creamy bokeh. Use a full-frame camera with a 50mm–85mm lens and an aperture around f/1.8 to capture fine foam bubbles and condensation beads clinging to the glass. Warm o..."
#
# 📏 길이 비교: A=125단어, B=178단어
#
# [11/40] S-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 횟집 홍보, 신선한 모둠회와 싱싱한 해산물
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1106 chars (~173 words)
# ================================================================================
#
# 한글 입력: "횟집 홍보, 신선한 모둠회와 싱싱한 해산물"
#
# 대조군 A: "Create an inviting and vibrant seafood restaurant scene, showcasing a beautifully arranged platter of fresh sashimi and assorted seafood. The table is set with an elegant wooden surface reflecting warm, ambient lighting that creates a cozy atmosphere. In the foreground, display a colorful variety of sashimi including salmon, tuna, and yellowtail, artfully garnished with thinly sliced radishes, vibrant green herbs, and a sprinkling of sesame seeds. Surrounding the sashimi, include a selection of ..."
#
# 실험군 B: "Assorted sashimi and fresh chilled seafood arranged as a premium overhead flat-lay, thinly sliced tuna, salmon, yellowtail and translucent white fish fanned on a large wooden platter surrounded by glistening prawns, scallops, mussels and thinly shaved octopus on a bed of crushed ice. Shot like a commercial food photography setup on a Canon EOS R5 with a 35mm lens at f/8 to keep the entire composition sharp, bright studio daylight from a softbox above and a subtle cool fill from the left to enhan..."
#
# 📏 길이 비교: A=139단어, B=173단어
#
# [12/40] S-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 초밥 전문점, 장인이 만든 프리미엄 오마카세
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1045 chars (~158 words)
# ================================================================================
#
# 한글 입력: "초밥 전문점, 장인이 만든 프리미엄 오마카세"
#
# 대조군 A: "An elegant sushi restaurant setting, showcasing a premium omakase experience prepared by skilled artisans. The scene features a beautifully arranged wooden sushi counter, with a master sushi chef dressed in traditional attire, expertly crafting sushi with meticulous precision. Various types of sushi are displayed on pristine ceramic plates, highlighting vibrant colors and delicate garnishes, such as fresh wasabi and pickled ginger. Soft, warm lighting bathes the space, creating a cozy and inviti..."
#
# 실험군 B: "Premium omakase sushi platter made by a master sushi chef, laid out in an elegant overhead flat lay on a clean white surface, each nigiri and sashimi piece meticulously arranged to show individual craftsmanship. Shot as commercial food photography on a Canon EOS R5 with a 50mm lens, top-down composition, f/8 for sharpness across the frame, 1/125s, ISO 100. Bright cool studio and natural daylight combined at about 5600K create a chilled, high-clarity atmosphere with soft, crisp shadows. Emphasize..."
#
# 📏 길이 비교: A=126단어, B=158단어
#
# [13/40] S-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 해산물 찜, 게와 새우가 가득한 해물찜
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1136 chars (~176 words)
# ================================================================================
#
# 한글 입력: "해산물 찜, 게와 새우가 가득한 해물찜"
#
# 대조군 A: "Create a vibrant and appetizing scene of a seafood steam pot brimming with an assortment of fresh ingredients. The focal point is a large, steaming pot filled with plump, bright red crabs, succulent pink shrimp, and an array of colorful vegetables like green bell peppers and vibrant orange carrots. The pot is placed on a rustic wooden table, surrounded by fresh herbs and lemon slices for garnish. Soft, warm lighting illuminates the scene, casting a golden glow on the shiny shells of the seafood,..."
#
# 실험군 B: "A large steaming seafood 찜 piled high with whole crabs and plump shrimp is the central focus, photographed from a clean overhead flat‑lay perspective. The platter shows cracked crab shells exposing glossy white meat and translucent shrimp with natural pink and orange tones, each shell glistening with tiny water droplets and a faint wisp of steam to convey freshly prepared freshness. Shot on a high‑resolution camera in a studio with bright natural daylight balance around 5500K, two softboxes crea..."
#
# 📏 길이 비교: A=138단어, B=176단어
#
# [14/40] S-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 수산시장 홍보, 싱싱한 활어와 조개류
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1169 chars (~173 words)
# ================================================================================
#
# 한글 입력: "수산시장 홍보, 싱싱한 활어와 조개류"
#
# 대조군 A: "Imagine a vibrant seafood market bustling with activity, showcasing a stunning array of fresh fish and shellfish. The scene is set under a bright, natural light filtering through the open stalls, illuminating the glossy scales of live fish splashing in large tanks. Nearby, heaps of colorful shellfish, including clams, oysters, and shrimp, are artistically arranged on ice, glistening with moisture and showcasing their natural textures. The atmosphere is lively and inviting, with vendors energetic..."
#
# 실험군 B: "A top-down overhead flat-lay of freshly caught live fish and an assortment of shellfish arranged on crushed ice at a coastal fish market, the fish positioned in dynamic, slightly angled rows and clams and scallops nested in small clusters to emphasize variety and abundance. Shot on a Canon EOS R5 with a 50mm lens set to f/11 for edge-to-edge sharpness, bright studio lights softened with large diffusers replicate natural daylight from the upper-left, creating crisp highlights and cool soft shadow..."
#
# 📏 길이 비교: A=145단어, B=173단어
#
# [15/40] S-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 복어 요리 전문점, 복어회와 복어탕 코스
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1156 chars (~180 words)
#    Text Overlay: {'product_name': '복어회와 복어탕 코스', 'tagline': '복어 요리 전문점'}
# ================================================================================
#
# 한글 입력: "복어 요리 전문점, 복어회와 복어탕 코스"
#
# 대조군 A: "A beautifully arranged dining table showcasing an exquisite fugu (pufferfish) cuisine experience. The setting is a traditional Korean restaurant with wooden furnishings, warm ambient lighting casting a soft glow over the table. In the center, a large, elegant platter displays thinly sliced fugu sashimi, delicately garnished with vibrant green herbs and thinly sliced radishes, glistening with freshness. Surrounding the sashimi are smaller bowls of dipping sauces, their rich colors contrasting aga..."
#
# 실험군 B: "A premium course of pufferfish sashimi and steaming pufferfish hot pot presented as a refined meal at a fugu specialty restaurant, captured in a clean overhead flat lay composition. Shot on a Canon EOS R5 with a 35mm lens, bright studio lighting simulating cool natural daylight from top-left with a soft fill from the right to eliminate harsh shadows. The chilled sashimi is arranged on crushed ice in a shallow porcelain platter, each translucent slice showing delicate striations and a faint pink ..."
#
# 📏 길이 비교: A=141단어, B=180단어
#
# [16/40] S-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 정육점 홍보, 마블링이 좋은 한우 투플러스
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1080 chars (~164 words)
#    Text Overlay: {'product_name': '한우 투플러스', 'tagline': '마블링이 좋은'}
# ================================================================================
#
# 한글 입력: "정육점 홍보, 마블링이 좋은 한우 투플러스"
#
# 대조군 A: "A vibrant and inviting butcher shop display, showcasing a selection of high-quality Hanwoo beef with exceptional marbling. The setting is a rustic yet modern butcher shop, with wooden shelves filled with various cuts of meat. Soft, warm lighting highlights the rich red tones of the beef, accentuating the intricate white marbling that signifies its premium quality. The atmosphere is bustling yet friendly, with a skilled butcher in a white apron carefully preparing the meat in the background. Fres..."
#
# 실험군 B: "Hanwoo Two-Plus sirloin steak with exceptional marbling is centered in an overhead flat-lay composition, a single thick cut laid on a chilled stainless steel tray with a clean white studio background. Shot as high-end commercial food photography on a full-frame camera with a 100mm macro-style lens to capture fat veins and muscle fibers in razor-sharp detail. Bright, cool daylight-balanced studio lighting from above with softfill from the side creates crisp specular highlights on the fat and a su..."
#
# 📏 길이 비교: A=132단어, B=164단어
#
# [17/40] S-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 과일 전문점, 제철 딸기와 샤인머스캣
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1280 chars (~197 words)
# ================================================================================
#
# 한글 입력: "과일 전문점, 제철 딸기와 샤인머스캣"
#
# 대조군 A: "A vibrant fruit shop interior showcasing an abundant selection of seasonal strawberries and Shine Muscat grapes. The shop is filled with wooden crates overflowing with plump, ripe strawberries, their bright red color contrasting beautifully with the deep green leaves. Nearby, glistening clusters of Shine Muscat grapes hang elegantly, their translucent skin reflecting soft light, giving them an almost ethereal glow. The setting is warmly lit, with natural sunlight streaming through large windows,..."
#
# 실험군 B: "Seasonal strawberries and Shine Muscat grapes arranged in a clean overhead flat-lay, the strawberries whole and halved to reveal glossy red flesh while clusters of translucent pale green Shine Muscat grapes sit beside them, one grape sliced to show the juicy interior. Photographed from a top-down perspective on a matte white marble countertop with minimalist negative space, the composition feels spacious and premium. Shot on a Canon EOS R5 with a 100mm macro lens from directly above, bright soft..."
#
# 📏 길이 비교: A=136단어, B=197단어
#
# [18/40] S-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 채소 가게, 유기농 신선 채소 모음
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1071 chars (~163 words)
# ================================================================================
#
# 한글 입력: "채소 가게, 유기농 신선 채소 모음"
#
# 대조군 A: "A vibrant organic vegetable shop brimming with a colorful assortment of fresh produce. The setting features rustic wooden shelves and crates overflowing with a variety of vegetables, including leafy greens, bright red tomatoes, and golden carrots. The shop is bathed in warm, natural sunlight streaming through large windows, creating a welcoming and inviting atmosphere. The walls are adorned with green plants and earthy decor, enhancing the organic feel. In the foreground, a wooden table displays..."
#
# 실험군 B: "An assortment of organic fresh vegetables arranged for an overhead flat-lay, featuring bunches of leafy greens, glossy cherry tomatoes, crisp radishes with feathery tops, tender baby carrots with soil-speckled roots, purple eggplants, firm bell peppers, and bundles of herbs placed in small wicker baskets and ceramic bowls on a clean white surface. Shot on a full-frame camera from a strict top-down perspective to emphasize variety and composition, using a 35mm lens at f/8 for sharp detail across ..."
#
# 📏 길이 비교: A=117단어, B=163단어
#
# [19/40] S-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 연어 전문점, 노르웨이산 생연어 사시미
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1197 chars (~187 words)
# ================================================================================
#
# 한글 입력: "연어 전문점, 노르웨이산 생연어 사시미"
#
# 대조군 A: "A beautifully arranged platter of fresh Norwegian salmon sashimi, showcasing the vibrant pink and orange hues of the fish. The sashimi is artfully sliced and elegantly placed on a dark wooden board, surrounded by garnishes of delicate edible flowers, thinly sliced radishes, and a small bowl of soy sauce. The setting is a cozy, upscale sushi restaurant with warm, ambient lighting that casts a soft glow on the food, enhancing its freshness. In the background, the blurred outlines of traditional Ja..."
#
# 실험군 B: "Norwegian fresh salmon sashimi presented in a premium salmon specialty restaurant, thin translucent slices fanned neatly on a simple white porcelain plate seen in a clean overhead flat lay, top-down composition. Shot like a commercial food photograph on a full-frame camera with a 50mm lens, bright soft studio lighting supplemented by natural daylight from a nearby window to create crisp, cool illumination at roughly 5600K. The scene emphasizes a chilled freshness with tiny beads of water and fin..."
#
# 📏 길이 비교: A=124단어, B=187단어
#
# [20/40] S-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 젓갈 가게, 전통 방식으로 담근 명란젓
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1109 chars (~173 words)
#    Text Overlay: {'product_name': '명란젓', 'tagline': '전통 방식으로 담근'}
# ================================================================================
#
# 한글 입력: "젓갈 가게, 전통 방식으로 담근 명란젓"
#
# 대조군 A: "Visualize a quaint, traditional Korean fish sauce shop, showcasing an array of beautifully crafted jars filled with vibrant, red-orange seasoned roe. The scene is set in a rustic wooden interior, with warm, golden lighting filtering through paper lanterns, casting soft shadows on the wooden shelves. Each jar is carefully labeled with handwritten tags, and the texture of the roe glistens under the light, highlighting its freshness. Surrounding the jars are traditional Korean utensils, such as woo..."
#
# 실험군 B: "명란젓 presented as the main subject in a top-down overhead flat lay, a shallow traditional ceramic bowl filled with translucent, glossy pollock roe placed on a clean white surface in a minimalist jeotgal shop setting. Shot like commercial food photography on a full-frame camera with a 90mm macro lens, bright cool-key studio lighting combined with soft natural daylight from the side creates crisp highlights and gentle shadows that emphasize freshness and a chilled feeling. The roe shows individual ..."
#
# 📏 길이 비교: A=133단어, B=173단어
#
# [21/40] S-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 카페 신메뉴, 딸기 라떼와 크루아상
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1081 chars (~185 words)
#    Text Overlay: {'product_name': '딸기 라떼 & 크루아상', 'tagline': '신메뉴 출시'}
# ================================================================================
#
# 한글 입력: "카페 신메뉴, 딸기 라떼와 크루아상"
#
# 대조군 A: "A cozy café setting featuring a beautifully styled table with a delicious new menu item: a frothy strawberry latte in a clear glass, showcasing layers of pink and creamy white, topped with a sprinkle of crushed strawberries. Next to the latte, a freshly baked croissant, golden brown and flaky, rests on a delicate white plate, with a few crumbs scattered around. The background is softly blurred, capturing the warm ambiance of the café with wooden shelves lined with jars of coffee beans and pastri..."
#
# 실험군 B: "A freshly prepared strawberry latte and a golden, flaky croissant arranged on a small wooden café table beside a sunlit window. The strawberry latte sits in a tall clear glass showing soft gradient layers of pale pink milk and creamy foam with a delicate swirl of strawberry syrup on top, tiny micro-bubbles visible on the foam and a faint wisp of steam rising. The croissant rests on a natural wooden board with visible buttery layers, crisp edges and a few scattered crumbs and a subtle sheen of gl..."
#
# 📏 길이 비교: A=122단어, B=185단어
#
# [22/40] S-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 베이커리 홍보, 갓 구운 소금빵과 크림빵
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 990 chars (~165 words)
#    Text Overlay: {'product_name': '갓 구운 소금빵, 크림빵'}
# ================================================================================
#
# 한글 입력: "베이커리 홍보, 갓 구운 소금빵과 크림빵"
#
# 대조군 A: "A warm and inviting bakery scene showcasing freshly baked goods. In the foreground, there are two types of bread: a golden crusted salt bread, glistening with a sprinkle of coarse sea salt, and a fluffy cream bread, slightly dusted with powdered sugar, revealing a creamy filling peeking out from the sides. The background features rustic wooden shelves filled with assorted breads and pastries, all bathed in soft, warm lighting that creates a cozy atmosphere. The bakery's interior has exposed bric..."
#
# 실험군 B: "Freshly baked salted roll and a cream-filled bun arranged for a bakery promotional shot, one roll whole and the cream bun gently torn open to reveal velvety custard oozing from the center. Photograph this scene on a light wooden table next to a sunlit window in a cozy morning bakery, styled with a soft linen napkin and a ceramic plate in muted beige-pink tones. Shot on a Canon EOS R5 with a 50mm f/1.4 lens, wide aperture to create a shallow depth of field and creamy bokeh in the background. Use ..."
#
# 📏 길이 비교: A=137단어, B=165단어
#
# [23/40] S-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 아이스크림 가게, 파스텔 톤 젤라또 3종
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1114 chars (~182 words)
# ================================================================================
#
# 한글 입력: "아이스크림 가게, 파스텔 톤 젤라또 3종"
#
# 대조군 A: "Imagine a charming ice cream shop that exudes a whimsical atmosphere, nestled in a sunlit corner of a bustling street. The shop features an inviting exterior painted in soft pastel colors, with a large window showcasing three exquisite gelato flavors elegantly arranged in a gleaming display case. Each gelato flavor is a vibrant pastel hue: a creamy lavender, a delicate mint green, and a soft peach, each adorned with a sprinkling of edible glitter. Inside, the shop is adorned with vintage decor, ..."
#
# 실험군 B: "Three pastel-toned gelato scoops arranged in an elegant overhead flat lay, each scoop a distinct flavor — soft strawberry pink, pale mint green, and light peach-orange — placed in shallow metal gelato pans and a small ceramic bowl on a clean white marble counter. Shot from a top-down perspective with a focus on chilled freshness, the scene is lit by bright daylight-balanced studio lighting from the left with a soft fill from above, creating crisp highlights on glossy gelato ridges and soft, natu..."
#
# 📏 길이 비교: A=150단어, B=182단어
#
# [24/40] S-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 떡카페, 예쁜 화과자와 전통차 세트
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1055 chars (~170 words)
# ================================================================================
#
# 한글 입력: "떡카페, 예쁜 화과자와 전통차 세트"
#
# 대조군 A: "A beautifully arranged table setting in a cozy tea cafe, showcasing an elegant selection of traditional Korean sweets, known as 'hwagwaja', alongside delicate porcelain cups filled with steaming traditional tea. The sweets are intricately crafted, featuring vibrant colors and floral designs, displayed on a polished wooden platter. Soft, natural light filters through a nearby window, creating a warm and inviting atmosphere. Surrounding the table, lush green plants add a touch of nature, while tra..."
#
# 실험군 B: "A set of pretty 화과자 (delicate rice confections) paired with a traditional Korean tea set arranged on a low wooden table inside a cozy tteok cafe. Shot on a Canon EOS R5 with a 50mm f/1.4 lens at wide aperture to create a shallow depth of field, the composition is a lifestyle overhead-tilted flat lay that captures the front wagashi in crisp focus while the rest of the table falls into creamy bokeh. Soft morning window light streams gently from the left through sheer curtains, producing diffused h..."
#
# 📏 길이 비교: A=110단어, B=170단어
#
# [25/40] S-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 샌드위치 전문점, 건강한 샐러드 샌드위치
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 981 chars (~153 words)
# ================================================================================
#
# 한글 입력: "샌드위치 전문점, 건강한 샐러드 샌드위치"
#
# 대조군 A: "A vibrant and inviting sandwich shop interior, showcasing a health-focused theme. The setting features a rustic wooden counter adorned with fresh ingredients, including colorful vegetables like ripe tomatoes, crisp lettuce, and sliced avocados. Behind the counter, shelves are stocked with jars of homemade dressings and grains. A chef, wearing a clean apron, is skillfully assembling a salad sandwich, layering greens, grilled chicken, and a drizzle of olive oil on whole grain bread. Sunlight strea..."
#
# 실험군 B: "A healthy salad sandwich placed slightly off-center on a ceramic plate, the sandwich cut in half to reveal layers of crisp romaine and butter lettuce, thinly sliced heirloom tomatoes, ripe avocado, crunchy toasted multigrain bread with visible seeds, and a glossy herb-yogurt dressing seeping into the crumb. Shot like a lifestyle food photograph on a Canon EOS R5 with a 50mm f/1.4 lens at wide aperture to produce soft bokeh in the background. Natural morning window light streams from the left, cr..."
#
# 📏 길이 비교: A=130단어, B=153단어
#
# [26/40] S-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 서점 카페, 책과 함께하는 커피 타임
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1069 chars (~186 words)
# ================================================================================
#
# 한글 입력: "서점 카페, 책과 함께하는 커피 타임"
#
# 대조군 A: "A cozy bookstore cafe scene, filled with shelves of colorful books that reach from the floor to the ceiling. In the foreground, a rustic wooden table holds a steaming cup of coffee, its rich aroma wafting through the air. Surrounding the table are plush, inviting chairs with soft cushions, creating a perfect nook for reading. Warm, ambient lighting spills from vintage-style lamps, casting a soft glow over the pages of an open book resting on the table. The walls are adorned with framed literary ..."
#
# 실험군 B: "A steaming cup of coffee resting next to an open book on a small wooden table inside a cozy bookstore café, photographed as a calm morning coffee moment. Shot on a Canon EOS R5 with a 50mm f/1.4 lens, framed from a slightly overhead 30-degree angle to show the cup's delicate foam art and the book's visible paper fibers while keeping a shallow depth of field for creamy bokeh. Natural window light streams softly from the left, diffused through a thin curtain to create gentle highlights on the cera..."
#
# 📏 길이 비교: A=130단어, B=186단어
#
# [27/40] S-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 화장품 매장, 봄 시즌 신제품 립스틱
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1136 chars (~181 words)
# ================================================================================
#
# 한글 입력: "화장품 매장, 봄 시즌 신제품 립스틱"
#
# 대조군 A: "Imagine a vibrant cosmetics store showcasing a stunning display of new spring season lipsticks. The setting is bright and inviting, with pastel-colored walls adorned with floral motifs that evoke a sense of freshness and renewal. The lighting is soft and warm, creating a welcoming atmosphere that highlights the rich colors of the lipsticks. Each lipstick tube is elegantly arranged on sleek glass shelves, reflecting the sunlight streaming in through large windows. In the foreground, a makeup arti..."
#
# 실험군 B: "Spring collection lipsticks displayed in a boutique cosmetics store, three tubes arranged on a low wooden counter with one cap removed and the creamy bullet slightly twisted up to reveal its smooth surface while a small swatch of color is freshly smeared on a matte ceramic tile beside them. Describe the scene as a lifestyle product shot with natural, gentle morning sunlight filtering through a frosted storefront window, creating soft, warm rim light and delicate circular highlights in the backgr..."
#
# 📏 길이 비교: A=123단어, B=181단어
#
# [28/40] S-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 약국 건강기능식품, 비타민과 유산균
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1257 chars (~202 words)
# ================================================================================
#
# 한글 입력: "약국 건강기능식품, 비타민과 유산균"
#
# 대조군 A: "A bright and inviting pharmacy interior, showcasing a well-organized shelf filled with an array of health supplements, including colorful bottles of vitamins and probiotic capsules. The setting is well-lit with soft, natural light streaming through large windows, creating a warm and welcoming atmosphere. The shelves are made of light wood, giving a clean and modern look. In the foreground, a friendly pharmacist in a white coat is assisting a customer, pointing out a particular vitamin with a smi..."
#
# 실험군 B: "A pharmacy display of health supplements featuring neatly arranged amber vitamin bottles, a small clear glass jar filled with probiotic capsules, and a blister pack placed on a light wooden counter to evoke a calm morning wellness ritual. Shot on a Canon EOS R5 with an 85mm f/1.4 lens at wide aperture to create a shallow depth of field, the scene focuses on an open vitamin bottle with a few glossy capsules spilling onto a small ceramic dish while a gentle hand reaches in to pick one up, adding a..."
#
# 📏 길이 비교: A=115단어, B=202단어
#
# [29/40] S-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 문구점 홍보, 예쁜 다이어리와 펜 세트
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1099 chars (~180 words)
# ================================================================================
#
# 한글 입력: "문구점 홍보, 예쁜 다이어리와 펜 세트"
#
# 대조군 A: "A beautifully arranged display of a stylish diary and a matching pen set, set in a cozy, inviting stationery shop. The diary, with a soft leather cover in pastel pink, features intricate gold embossing and is slightly open to reveal elegant, lined pages with delicate floral borders. The pen, a sleek, gold-accented fountain pen, lies gracefully beside the diary, glinting in the soft, warm light of the shop. The interior of the shop is adorned with shelves filled with colorful notebooks, art suppl..."
#
# 실험군 B: "A pretty diary and matching pen set arranged as the central subject in an inviting promotional overhead flat lay. The leatherette diary sits slightly angled with its elastic band and ribbon bookmark visible, pages gently fanned to reveal creamy, textured paper; a slim brushed-metal pen rests across the cover catching a warm highlight. Shot like a lifestyle product image on a full-frame camera with a 50mm f/1.4 lens, the scene is lit by soft morning window light from the left that creates delicat..."
#
# 📏 길이 비교: A=134단어, B=180단어
#
# [30/40] S-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 기념품샵, 여행 기념 엽서와 마그넷
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1050 chars (~170 words)
# ================================================================================
#
# 한글 입력: "기념품샵, 여행 기념 엽서와 마그넷"
#
# 대조군 A: "A charming souvenir shop filled with an array of travel memorabilia. The scene showcases a vibrant display of colorful postcards featuring iconic landmarks and scenic views from around the world, neatly arranged on rustic wooden shelves. Beside the postcards, an assortment of whimsical magnets, each uniquely designed with various travel themes, catches the eye. The shop is warmly lit with soft, ambient lighting that creates a cozy atmosphere, inviting travelers to explore. The walls are adorned ..."
#
# ...
#
# 실험군 B: "Hanjeongsik table setting featuring neatly arranged banchan and a steaming pot of doenjang jjigae, captured in a clean overhead flat-lay composition. Shot like a professional food photograph on a Canon EOS R5 with a 35mm prime lens at f/4 to keep the entire arrangement crisply detailed while retaining gentle separation between elements. The scene is lit by warm overhead home-style lighting blended with soft natural daylight from a window, producing gentle highlights on porcelain rims and a warm,..."
#
# 📏 길이 비교: A=147단어, B=202단어
#
# [32/40] S-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 김밥 전문점, 다양한 김밥과 라면 세트
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1083 chars (~169 words)
# ================================================================================
#
# 한글 입력: "김밥 전문점, 다양한 김밥과 라면 세트"
#
# 대조군 A: "A vibrant and inviting scene inside a Korean gimbap specialty restaurant, showcasing a variety of colorful gimbap rolls beautifully arranged on a traditional wooden table. Each gimbap is filled with a medley of ingredients such as bright yellow pickled radish, fresh green lettuce, savory marinated beef, and vibrant orange carrot strips, all wrapped in glossy seaweed. On the side, steaming bowls of rich, steaming ramen, garnished with green onions and a soft-boiled egg, add warmth to the composit..."
#
# 실험군 B: "A top-down overhead view of a gimbap specialty shop meal set featuring an assorted variety of gimbap rolls and a steaming bowl of ramen arranged neatly on a wooden table. Shot as a flat-lay on a full-frame camera with a 35mm lens from directly above, aperture f/8 to keep the entire spread crisply detailed, natural daylight from a nearby window mixed with a warm overhead pendant creating soft highlights and gentle shadows. The gimbap rolls are sliced and fanned in tidy rows showing glossy seaweed..."
#
# 📏 길이 비교: A=134단어, B=169단어
#
# [33/40] S-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 백반집 점심 메뉴, 오늘의 집밥 정식
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1095 chars (~176 words)
#    Text Overlay: {'product_name': '오늘의 집밥 정식', 'tagline': '백반집 점심 메뉴'}
# ================================================================================
#
# 한글 입력: "백반집 점심 메뉴, 오늘의 집밥 정식"
#
# 대조군 A: "A cozy and inviting Korean 백반집 (lunch restaurant) setting, featuring a wooden table adorned with a traditional Korean table setting. The scene is filled with an array of colorful dishes, showcasing a well-balanced 집밥 (home-cooked meal) 정식 (set menu). Each dish is presented beautifully: a steaming bowl of rice, vibrant side dishes like kimchi, pickled radishes, and seasoned vegetables, as well as a savory stew bubbling in a stone pot. The lighting is warm and soft, creating a welcoming atmosphere..."
#
# 실험군 B: "Traditional Korean home-style lunch set arranged as a top-down flat lay on a warm wooden table, featuring a steaming bowl of short-grain rice, a stone bowl of clear soup, a grilled mackerel fillet with glossy glaze, a vibrant mound of kimchi, several small side-dish bowls of seasoned vegetables and pickles, and brass chopsticks and a spoon neatly placed. Shot on a full-frame camera with a 35mm lens mounted overhead to capture the full spread, aperture around f/5.6 for moderate depth of field so ..."
#
# 📏 길이 비교: A=142단어, B=176단어
#
# [34/40] S-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 국밥집 홍보, 뜨끈한 돼지국밥 한 그릇
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1131 chars (~181 words)
#    Text Overlay: {'product_name': '돼지국밥', 'tagline': '뜨끈한 한 그릇'}
# ================================================================================
#
# 한글 입력: "국밥집 홍보, 뜨끈한 돼지국밥 한 그릇"
#
# 대조군 A: "Imagine a cozy, inviting Korean restaurant specializing in traditional pork soup, known as 'dwaeji-gukbap.' The scene features a steaming bowl of rich, savory pork soup placed at the center of a rustic wooden table. The soup is brimming with tender chunks of pork, vibrant green onions, and a sprinkle of sesame seeds, while wisps of steam rise gently from the surface, creating a warm and comforting atmosphere. Surrounding the bowl are traditional Korean side dishes like kimchi and pickled vegetab..."
#
# 실험군 B: "A steaming bowl of pork gukbap (돼지국밥) sits centered in a top-down flat lay, steam curling up from the hot amber broth while tender slices of simmered pork and plump white rice are clearly visible beneath the surface. Shot on a Canon EOS R5 with a 35mm lens in overhead orientation, soft natural daylight from a nearby window combines with warm pendant restaurant lighting to create golden highlights on the broth and gentle shadows around the bowl. The scene feels like an authentic neighborhood eate..."
#
# 📏 길이 비교: A=144단어, B=181단어
#
# [35/40] S-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 냉면 전문점, 시원한 물냉면과 비빔냉면
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1078 chars (~160 words)
#    Text Overlay: {'product_name': '물냉면, 비빔냉면'}
# ================================================================================
#
# 한글 입력: "냉면 전문점, 시원한 물냉면과 비빔냉면"
#
# 대조군 A: "A vibrant and inviting scene set in a traditional Korean cold noodle restaurant, showcasing two exquisite bowls of cold noodles prominently displayed on a wooden table. One bowl features mul naengmyeon, with ice floating in a clear, chilled beef broth, garnished with slices of cucumber, radish, and a perfectly boiled egg, all under soft, natural lighting that highlights the freshness of the ingredients. The other bowl presents bibim naengmyeon, with a colorful mix of spicy gochujang sauce, toppe..."
#
# 실험군 B: "A cold noodle restaurant scene featuring a chilled mul-naengmyeon in a clear icy broth and a vibrant bibim-naengmyeon tossed in spicy red sauce, presented in a neat overhead flat-lay arrangement on a warm wooden table. Shot like commercial food photography on a Canon EOS R5 with a 50mm lens from directly above, combining soft natural daylight from a nearby window with warm overhead restaurant lighting to create gentle highlights and soft shadow falloff. The mul-naengmyeon shows glassy ice crysta..."
#
# 📏 길이 비교: A=138단어, B=160단어
#
# [36/40] S-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 반찬 가게, 정성 가득 수제 반찬 10종
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1106 chars (~169 words)
#    Text Overlay: {'product_name': '수제 반찬 10종', 'tagline': '정성 가득'}
# ================================================================================
#
# 한글 입력: "반찬 가게, 정성 가득 수제 반찬 10종"
#
# 대조군 A: "A cozy, inviting Korean banchan shop filled with an array of homemade side dishes. The scene showcases a wooden display counter laden with ten different vibrant and colorful banchan, each beautifully arranged in traditional ceramic bowls. The side dishes include kimchi, pickled vegetables, marinated fish, and savory pancakes, all glistening under soft, warm lighting. The shop has a rustic charm, with wooden shelves lined with jars of ingredients and herbs, adding a homely atmosphere. A friendly ..."
#
# 실험군 B: "Ten handmade Korean side dishes (수제 반찬 10종) arranged in a neat overhead flat lay, each dish presented in simple white and earthenware bowls on a warm wooden counter inside a small, tidy banchan shop. Shot as a top-down composition showing the full variety — glossy kimchi with visible chili threads and sesame seeds, bright green seasoned vegetables with visible scallion slices, golden pan-fried jeon with crisp edges, braised soy-glazed root vegetables with shiny sauce, and other colorful traditio..."
#
# 📏 길이 비교: A=142단어, B=169단어
#
# [37/40] S-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 분식집, 떡볶이와 순대 세트 메뉴
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1144 chars (~180 words)
#    Text Overlay: {'product_name': '떡볶이와 순대 세트'}
# ================================================================================
#
# 한글 입력: "분식집, 떡볶이와 순대 세트 메뉴"
#
# 대조군 A: "A cozy and inviting Korean street food restaurant interior, showcasing a vibrant food display featuring a set menu of spicy tteokbokki and savory sundae. The tteokbokki, with its bright red sauce glistening, is served in a traditional earthenware bowl, garnished with sliced green onions and sesame seeds. Beside it, a plate of sundae, rich and dark, is artfully arranged, accompanied by a small dish of spicy dipping sauce. The setting is lively, with warm, ambient lighting that casts a golden hue ..."
#
# 실험군 B: "Tteokbokki and sundae set meal captured in a clean top-down flat lay, the main subject centered and arranged with side dishes and utensils for a traditional Korean snack bar presentation. Shot on a Canon EOS R5 with a 35mm lens mounted directly overhead, medium aperture to keep the whole spread in sharp focus while preserving soft background separation. Warm overhead restaurant light mixes with natural daylight from a nearby window to create cozy highlights on glossy red chili sauce and subtle r..."
#
# 📏 길이 비교: A=136단어, B=180단어
#
# [38/40] S-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 칼국수집, 손칼국수와 왕만두
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1022 chars (~157 words)
# ================================================================================
#
# 한글 입력: "칼국수집, 손칼국수와 왕만두"
#
# 대조군 A: "A cozy, inviting Korean noodle shop interior featuring a rustic wooden table set with bowls of fresh hand-cut kalguksu (noodle soup) and large, steaming king dumplings (wang mandu). The scene is illuminated by warm, soft light filtering through traditional paper lanterns, creating an intimate atmosphere. In the background, a chef skillfully prepares noodles by hand, showcasing the art of making kalguksu. The walls are adorned with traditional Korean decor, including wooden shelves filled with ja..."
#
# 실험군 B: "Hand-cut kalguksu noodles in a steaming ceramic bowl and a platter of oversized wang-mandu dumplings take center stage in a cozy Korean noodle house overhead spread. Shot as a top-down flat lay on a warm wooden table, the scene shows a single bowl of amber broth with irregular, hand-pulled noodle strands curling through the soup and a glossy surface dotted with scallion slices and sesame oil sheen, while the large dumplings display visible pleats, flour dust, and slightly translucent dough revea..."
#
# 📏 길이 비교: A=133단어, B=157단어
#
# [39/40] S-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 전문점 홍보, 바삭한 해물파전과 막걸리
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1139 chars (~178 words)
#    Text Overlay: {'product_name': '바삭한 해물파전 & 막걸리', 'tagline': '전문점 홍보'}
# ================================================================================
#
# 한글 입력: "전문점 홍보, 바삭한 해물파전과 막걸리"
#
# 대조군 A: "A cozy, traditional Korean restaurant setting featuring a beautifully arranged table displaying a large, golden-brown seafood pancake (haemul pajeon) with crispy edges. The pancake is garnished with vibrant green scallions and served on a rustic wooden platter, with small bowls of dipping sauce on the side. Beside it, a tall, frosty glass of makgeolli, the traditional Korean rice wine, is filled to the brim, showcasing its milky white color. The ambiance is warm and inviting, with soft, ambient ..."
#
# 실험군 B: "Crispy seafood pancake and makgeolli presented as a restaurant promotion, captured in a warm overhead flat-lay that highlights texture and authenticity. Shot on a Canon EOS R5 with a 35mm lens at f/5.6 for even sharpness across the spread, natural window light from the left provides a soft key fill while a warm overhead diffuser creates gentle highlights on the pancake crust. A large golden-brown haemul pajeon sits centered, cut into triangular slices to reveal visible shrimp, squid rings, and b..."
#
# 📏 길이 비교: A=137단어, B=178단어
#
# [40/40] S-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 족발/보쌈 전문점, 쫄깃한 족발과 보쌈
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1107 chars (~175 words)
#    Text Overlay: {'product_name': '족발 / 보쌈', 'tagline': '쫄깃한 족발과 보쌈'}
# ================================================================================
#
# 한글 입력: "족발/보쌈 전문점, 쫄깃한 족발과 보쌈"
#
# 대조군 A: "A cozy, inviting Korean restaurant specializing in jokbal (pork trotters) and bossam (wrapped pork). The interior is warmly lit with soft golden hues, highlighting wooden tables set with traditional Korean tableware. In the foreground, a beautifully arranged platter of glistening jokbal, showcasing the tender, gelatinous texture of the meat, is surrounded by fresh green lettuce leaves, garlic cloves, and sliced chili peppers. Beside it, a bowl of steaming white rice and a vibrant kimchi dish add..."
#
# 실험군 B: "A top-down overhead shot of a freshly prepared spread featuring a glistening, chewy plate of jokbal (braised pig's trotters) alongside a neatly arranged platter of bossam (sliced boiled pork) presented for sharing. Shot on a full-frame camera with a 35mm lens, the scene is arranged as a flat-lay on a warm wooden dining table with clean ceramic bowls and metal tongs, capturing the rich mahogany glaze on the pork skin, visible collagen sheen, and thin, even slices of meat. Warm overhead home-style..."
#
# 📏 길이 비교: A=128단어, B=175단어
#
#
# ====================================================================================================
# 📈 S등급 (감성 및 미각 자극) 요약 통계
# ====================================================================================================
# 테스트 케이스 수: 40
# 대조군 A 평균 길이: 132.6 단어
# 실험군 B 평균 길이: 175.6 단어

# %% [markdown]
# ### 3.2 A등급 테스트 (비주얼 변화 및 자기관리)

# %%
# A등급 A/B 테스트 실행
a_grade_results = run_ab_test(A_GRADE_TEST_CASES, "A등급 (비주얼 변화 및 자기관리)")
# Out:
# ====================================================================================================
# 📊 A등급 (비주얼 변화 및 자기관리) A/B 테스트 결과
# ====================================================================================================
#
#
# [1/40] A-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 미용실 봄 헤어 스타일, 웨이브 펌 시술 결과
# ================================================================================
#    감지된 업종: a1_beauty
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1094 chars (~173 words)
# ================================================================================
#
# 한글 입력: "미용실 봄 헤어 스타일, 웨이브 펌 시술 결과"
#
# 대조군 A: "Create an image of a stylish hair salon during spring, showcasing a beautiful model with elegant, soft wave perm hair. The setting is bright and inviting, with large windows allowing natural sunlight to pour in, illuminating the space. The interior is decorated with fresh flowers and pastel colors, giving a vibrant and refreshing atmosphere. The model is smiling confidently, her hair cascading in loose, bouncy waves that frame her face perfectly. The stylist, a professional with a keen eye for d..."
#
# 실험군 B: "A young woman showcasing a fresh spring wave perm hairstyle after a salon treatment, posed in a three-quarter close-up portrait with her head slightly tilted and a confident, relaxed expression. Shot on a full-frame camera with an 85mm f/1.4 lens to create a shallow depth of field that keeps the face and hair waves razor sharp while softly blurring the upscale salon background. Use professional three-point beauty lighting with a soft key light and beauty dish for even, flattering illumination, a..."
#
# 📏 길이 비교: A=128단어, B=173단어
#
# [2/40] A-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 피부관리실 홍보, 맑고 깨끗한 피부 관리
# ================================================================================
#    감지된 업종: a1_beauty
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1014 chars (~164 words)
#    Text Overlay: {'event_name': '피부관리실 홍보', 'tagline': '맑고 깨끗한 피부 관리'}
# ================================================================================
#
# 한글 입력: "피부관리실 홍보, 맑고 깨끗한 피부 관리"
#
# 대조군 A: "A serene skincare clinic interior, showcasing a tranquil and inviting atmosphere. The room is filled with soft, natural light filtering through large windows, illuminating a pristine treatment area equipped with elegant skincare products. A plush treatment bed is positioned in the center, adorned with crisp white linens and surrounded by potted plants that add a touch of greenery. On a nearby shelf, neatly arranged bottles of serums and creams reflect the essence of clean beauty. The walls are p..."
#
# 실험군 B: "A close-up portrait of a young adult woman receiving a professional facial treatment, her face turned three-quarters to camera with a calm, confident expression as an esthetician’s gloved hand gently applies a clear serum to her cheek. Shot like high-end beauty photography on a full-frame camera with an 85mm lens and shallow depth of field, the composition focuses tightly on the skin texture and the microdetail of the serum droplet. Use a flattering three-point studio setup with a softbox key li..."
#
# 📏 길이 비교: A=118단어, B=164단어
#
# [3/40] A-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 네일샵 신상 디자인, 봄 꽃 네일 아트
# ================================================================================
#    감지된 업종: a1_beauty
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1124 chars (~188 words)
# ================================================================================
#
# 한글 입력: "네일샵 신상 디자인, 봄 꽃 네일 아트"
#
# 대조군 A: "A vibrant nail salon setting showcasing a new spring floral nail art design. The scene is filled with soft pastel colors, featuring a variety of blooming flowers like cherry blossoms, daisies, and tulips intricately painted on long, elegant nails. The background is softly illuminated with natural light filtering through large windows, creating a warm and inviting atmosphere. Various nail polish bottles in a rainbow of colors are displayed on a sleek, modern manicure table, adding to the aestheti..."
#
# 실험군 B: "Hands showcasing a nail salon's new spring floral nail art, fingers slightly splayed and gently resting on a soft white linen and pale marble surface so the manicure is the sole focus. Shot on a Canon EOS R5 with a 100mm macro lens at f/2.8, 1/160s, ISO 100, portrait orientation with a tight macro crop that centers on the nails and fingertips. Use a professional three-point lighting setup with a softbox key light overhead, a warm fill reflector in front to soften shadows, and a subtle cool rim l..."
#
# 📏 길이 비교: A=136단어, B=188단어
#
# [4/40] A-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 성형외과 상담 안내, 자연스러운 코 성형
# ================================================================================
#    감지된 업종: a1_beauty
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1051 chars (~167 words)
# ================================================================================
#
# 한글 입력: "성형외과 상담 안내, 자연스러운 코 성형"
#
# 대조군 A: "Create an image of a serene and inviting plastic surgery consultation room. The setting features modern yet warm decor with soft, neutral colors, including light beige and soft white tones. A comfortable consultation chair is placed next to a sleek, wooden desk, which holds an elegant vase of fresh flowers. Natural light streams through large windows adorned with sheer curtains, casting gentle shadows on the polished wooden floor. On the walls, there are tasteful framed photographs of natural-lo..."
#
# 실험군 B: "A close-up portrait of a young woman seated in a modern plastic surgery consultation room showing the natural result of a rhinoplasty, her head turned three-quarters to display the refined nasal bridge and softly contoured tip while she wears a calm, confident expression. Shot on a full-frame camera with an 85mm focal length and wide aperture to create a shallow depth of field, the composition is vertical with tight framing from the forehead to the upper lip, placing sharp focus on the nose and ..."
#
# 📏 길이 비교: A=129단어, B=167단어
#
# [5/40] A-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 피부과 레이저 시술, 잡티 제거 전후 비교
# ================================================================================
#    감지된 업종: a1_beauty
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1178 chars (~175 words)
# ================================================================================
#
# 한글 입력: "피부과 레이저 시술, 잡티 제거 전후 비교"
#
# 대조군 A: "Create a split-image comparison showcasing the effects of dermatological laser treatment for blemish removal. On the left side, depict a close-up of a woman's face before the treatment, highlighting various skin imperfections such as dark spots and uneven tone. The lighting should be soft and slightly dim, emphasizing the texture of the skin and the visible blemishes. On the right side, illustrate the same woman after the treatment, with a radiant and clear complexion, glowing under bright, natu..."
#
# 실험군 B: "Close-up split portrait of a woman's mid-face showing a dermatology laser treatment comparison with the left side showing the skin condition before treatment and the right side showing the clear, healed result. Shot on a high-resolution full-frame camera with a 100mm macro lens using portrait orientation, the composition focuses tightly on cheeks, nose and jawline so skin texture is clearly visible. Professional studio three-point beauty lighting with a soft key light and gentle rim light sculpt..."
#
# 📏 길이 비교: A=126단어, B=175단어
#
# [6/40] A-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 미용실 염색 이벤트, 트렌디한 발레아주
# ================================================================================
#    감지된 업종: a1_beauty
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1305 chars (~197 words)
#    Text Overlay: {'event_name': '미용실 염색 이벤트', 'tagline': '트렌디한 발레아주'}
# ================================================================================
#
# 한글 입력: "미용실 염색 이벤트, 트렌디한 발레아주"
#
# 대조군 A: "An upscale hair salon interior showcasing a vibrant hair dye event focused on trendy balayage techniques. The setting is bright and inviting, with large windows allowing natural light to flood in, illuminating the sleek, modern decor. Stylish salon chairs are arranged around elegant mirrors, where clients are seen getting their hair styled by professional stylists. The atmosphere is lively and energetic, filled with the sounds of laughter and conversation. Various hair dye products in an array o..."
#
# 실험군 B: "A female model showcasing a trendy balayage hair color in a close-up beauty portrait, slightly turned three-quarter profile with one hand gently lifting a lock to reveal the seamless root-to-tip gradient. Shot like high-end salon editorial photography on a Canon EOS R5 with an 85mm f/1.4 equivalent lens, shallow depth of field at wide aperture to isolate hair detail and soften the background. Use a professional three-point lighting setup: a softbox key light at 45 degrees for even, flattering il..."
#
# 📏 길이 비교: A=129단어, B=197단어
#
# [7/40] A-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 에스테틱 페이셜 케어, 광채 나는 피부
# ================================================================================
#    감지된 업종: a1_beauty
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1137 chars (~181 words)
# ================================================================================
#
# 한글 입력: "에스테틱 페이셜 케어, 광채 나는 피부"
#
# 대조군 A: "A serene spa environment showcasing an aesthetic facial care treatment in progress. The setting features a softly lit room with neutral-toned walls and natural wooden accents, creating a tranquil and inviting atmosphere. A client reclines comfortably on a plush treatment bed, covered with a white towel, while a skilled aesthetician gently applies a luxurious facial mask, giving off a subtle glow. Natural light filters in through sheer curtains, illuminating the client's radiant skin that shines ..."
#
# 실험군 B: "Close-up portrait of a woman after an aesthetic facial treatment, presenting luminous, dewy skin and a calm, confident expression as she slightly tilts her head toward the camera. Shot like a high-end salon editorial on a Canon EOS R5 with an 85mm f/1.4 lens, tightly framed in portrait orientation with macro-level focus on the cheek, nose and eye area. Use professional three-point beauty lighting: a large softbox key creating even soft shadows, a subtle fill reflector to preserve natural skin to..."
#
# 📏 길이 비교: A=135단어, B=181단어
#
# [8/40] A-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 네일샵 젤네일, 고급스러운 글리터 디자인
# ================================================================================
#    감지된 업종: a1_beauty
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1068 chars (~170 words)
# ================================================================================
#
# 한글 입력: "네일샵 젤네일, 고급스러운 글리터 디자인"
#
# 대조군 A: "Imagine an upscale nail salon interior, elegantly designed with a modern aesthetic. The setting features plush seating in soft pastel colors, with ambient lighting that casts a warm glow throughout the space. The focal point is a beautifully arranged display of gel nail polishes, showcasing an array of luxurious glitter designs. Each nail design sparkles under the soft lighting, reflecting various colors and creating a dazzling effect. The nail technician, focused and skilled, is delicately appl..."
#
# 실험군 B: "Manicured hand showcasing gel nails with a luxurious glitter design, posed elegantly with fingers slightly curved to emphasize nail length and glossy surfaces. Shot on a full-frame camera with a 100mm macro lens in portrait orientation, the composition is a close-up beauty shot focused on the nail bed and tips with shallow depth of field. Use professional three-point studio lighting with a soft key light, gentle fill light to reveal skin texture, and a cool rim light to produce subtle highlights..."
#
# 📏 길이 비교: A=131단어, B=170단어
#
# [9/40] A-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 헤어샵 남성 커트, 깔끔한 투블럭 스타일
# ================================================================================
#    감지된 업종: a1_beauty
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1139 chars (~181 words)
# ================================================================================
#
# 한글 입력: "헤어샵 남성 커트, 깔끔한 투블럭 스타일"
#
# 대조군 A: "A modern barbershop interior featuring a stylish, contemporary design. In the foreground, a male model sits in a sleek, black barber chair, showcasing a fresh two-block haircut, characterized by short sides and a longer top styled with a slight wave. The barber, a skilled professional with an attentive expression, is carefully using scissors and a comb to refine the hairstyle. Soft, warm lighting illuminates the space, creating an inviting atmosphere, while large mirrors reflect the stylish deco..."
#
# 실험군 B: "A young male client showcasing a clean two-block haircut, captured in a tight head-and-shoulders portrait that emphasizes the precise contrast between the short sides and the longer textured top. Shot on a Canon EOS R5 with an 85mm f/1.4 lens, the composition is a close-up beauty shot in portrait orientation with shallow depth of field so individual hair strands and the razor-sharp fade lines remain crisp while the background melts into creamy bokeh. Use a professional three-point studio lightin..."
#
# 📏 길이 비교: A=132단어, B=181단어
#
# [10/40] A-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 속눈썹 연장 전문, 자연스러운 볼륨 래쉬
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1178 chars (~178 words)
# ================================================================================
#
# 한글 입력: "속눈썹 연장 전문, 자연스러운 볼륨 래쉬"
#
# 대조군 A: "A serene beauty salon interior focusing on eyelash extensions, featuring a cozy and inviting atmosphere. Soft, natural light filters through large windows adorned with sheer curtains, casting gentle shadows across the room. In the foreground, a skilled technician meticulously applies natural-looking volume lashes to a client's eyelashes, showcasing the delicate artistry involved. The client reclines comfortably in a plush, padded chair, her eyes closed in relaxation, with soft pastel colors surr..."
#
# 실험군 B: "A close-up of a woman's eye with freshly applied natural-volume eyelash extensions, the eye gently closed to showcase soft, seamless fanning along the lash line and a natural, lightweight silhouette. Shot on a Canon EOS R5 with a 100mm macro lens using a shallow depth of field so each tapered synthetic lash fiber and the delicate base attachment are crisply rendered while the surroundings dissolve into creamy bokeh. Soft warm overhead salon lighting is balanced with cool window daylight to revea..."
#
# 📏 길이 비교: A=123단어, B=178단어
#
# [11/40] A-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 헬스장 PT 프로그램, 1:1 개인 트레이닝
# ================================================================================
#    감지된 업종: a2_wellness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1126 chars (~175 words)
# ================================================================================
#
# 한글 입력: "헬스장 PT 프로그램, 1:1 개인 트레이닝"
#
# 대조군 A: "A vibrant and dynamic personal training session in a modern gym setting. The scene captures a dedicated personal trainer, a fit individual in athletic wear, guiding a client through a rigorous workout. The gym is equipped with various state-of-the-art fitness equipment, including weights, resistance bands, and cardio machines, all surrounded by large mirrors reflecting the energetic atmosphere. Soft, natural light streams through the large windows, illuminating the space and creating a motivatio..."
#
# 실험군 B: "A one-on-one personal training session in a bright modern gym, the trainer guiding a client through a weighted lunge while supporting form, captured mid-motion with both figures in a full-body athletic pose. Shot as professional sports photography on a Canon EOS R5 with a 50mm lens, high shutter speed to freeze movement and a shallow depth of field to softly blur the background gym equipment. Natural daylight pours through tall windows from the far side while a strong cool rim light from camera-..."
#
# 📏 길이 비교: A=126단어, B=175단어
#
# [12/40] A-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 요가 스튜디오, 아침 명상 요가 클래스
# ================================================================================
#    감지된 업종: a2_wellness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1177 chars (~185 words)
# ================================================================================
#
# 한글 입력: "요가 스튜디오, 아침 명상 요가 클래스"
#
# 대조군 A: "A serene and tranquil yoga studio bathed in the soft light of dawn. The room is spacious and filled with natural elements, featuring wooden floors and large windows that allow golden sunlight to stream in, illuminating the space. In the center, a group of diverse individuals is engaged in a morning meditation yoga class, each person gracefully transitioning into poses. They are surrounded by potted plants and calming decor, creating a peaceful atmosphere. The soft colors of their yoga mats contr..."
#
# 실험군 B: "A single yoga practitioner seated cross-legged at the front of a sunlit studio, leading a calm morning meditation yoga class while other students sit softly blurred in the background. Shot on a Canon EOS R5 with a 35mm f/1.8 lens to capture full-body posture with a natural perspective, the camera is positioned slightly below eye level to emphasize stable grounded posture and presence. Warm golden morning light pours through large floor-to-ceiling windows from the left, creating soft rim lighting..."
#
# 📏 길이 비교: A=128단어, B=185단어
#
# [13/40] A-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 필라테스 센터, 체형 교정 프로그램
# ================================================================================
#    감지된 업종: a2_wellness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1088 chars (~164 words)
# ================================================================================
#
# 한글 입력: "필라테스 센터, 체형 교정 프로그램"
#
# 대조군 A: "A serene and modern Pilates studio, featuring large floor-to-ceiling windows that let in soft, natural light, creating an inviting atmosphere. The room is adorned with polished wooden floors and minimalist decor, including plants in the corners for a touch of nature. In the center, there are several Pilates reformers and mats arranged neatly, showcasing an organized and peaceful space for exercise. A diverse group of individuals, wearing comfortable athletic wear, are engaged in various Pilates ..."
#
# 실험군 B: "A Pilates instructor adjusting a client's alignment as the client holds a dynamic full-body Pilates exercise, captured mid-movement to emphasize posture correction and muscle engagement in a polished studio. Shot on a Canon EOS R5 with a 35mm lens, high shutter speed to freeze motion and f/4 for a moderately shallow depth of field that keeps the whole body sharp while softly blurring the background. The scene takes place in a bright, airy Pilates center with large windows letting in natural soft..."
#
# 📏 길이 비교: A=116단어, B=164단어
#
# [14/40] A-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 태권도 학원, 어린이 품새 수업
# ================================================================================
#    감지된 업종: a2_wellness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1154 chars (~178 words)
# ================================================================================
#
# 한글 입력: "태권도 학원, 어린이 품새 수업"
#
# 대조군 A: "An energetic scene depicting a taekwondo academy specifically for children, showcasing a vibrant and dynamic atmosphere. The setting is an indoor training hall, with bright, colorful mats covering the floor. Children, aged around 7 to 10, are dressed in traditional white taekwondo uniforms, practicing their forms (poomsae) with focused expressions. The room is well-lit with natural sunlight streaming through large windows, illuminating their movements. In the background, there are motivational p..."
#
# 실험군 B: "Children performing Taekwondo poomsae in a bright training hall, captured mid-movement as a group executes synchronized forms with focused, determined expressions. Shot like professional sports photography on a Canon EOS R5 with a 35mm f/1.8 lens at a fast shutter speed to freeze kicks and hand motions while retaining slight motion blur on extremities to convey energy. The spacious dojang has high windows flooding soft natural light from one side complemented by bright overhead gym lighting, cre..."
#
# 📏 길이 비교: A=149단어, B=178단어
#
# [15/40] A-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 다이어트 클리닉, 3개월 체중 감량 성공
# ================================================================================
#    감지된 업종: a2_wellness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1108 chars (~174 words)
#    Text Overlay: {'product_name': '다이어트 클리닉', 'tagline': '3개월 체중 감량 성공'}
# ================================================================================
#
# 한글 입력: "다이어트 클리닉, 3개월 체중 감량 성공"
#
# 대조군 A: "A serene and modern diet clinic interior, featuring a bright and airy consultation room with large windows letting in warm, natural light. The room is adorned with soothing colors, such as soft greens and whites, creating a calming atmosphere. In the foreground, a diverse group of three individuals—one woman and two men, each representing different ethnic backgrounds—are celebrating their weight loss success with joyful expressions. They are gathered around a sleek table filled with healthy meal..."
#
# 실험군 B: "A confident woman in her early 30s, lean and visibly toned, celebrating after completing a three-month weight loss program stands in the bright reception area of a modern diet clinic with her arms raised in a victorious pose. Shot on a Canon EOS R5 with a 35mm f/1.8 lens, the scene is framed as a full-body editorial portrait with the subject in sharp focus and the clinic staff and equipment softly blurred in the background. Natural daylight pours through large windows from the left while a cool ..."
#
# 📏 길이 비교: A=135단어, B=174단어
#
# [16/40] A-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 마사지샵 홍보, 타이 마사지 전신 케어
# ================================================================================
#    감지된 업종: a2_wellness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1120 chars (~183 words)
# ================================================================================
#
# 한글 입력: "마사지샵 홍보, 타이 마사지 전신 케어"
#
# 대조군 A: "A serene and inviting massage therapy room designed for a Thai massage experience. The setting is softly lit with warm, ambient lighting that creates a calming atmosphere. The room features traditional Thai decor, including intricate wooden carvings and lush green plants that add a touch of nature. In the center, there is a comfortable massage table adorned with soft, colorful linens. Aromatherapy candles flicker gently on a nearby shelf, filling the air with a soothing scent. A small water foun..."
#
# 실험군 B: "A professional Thai massage therapist performing a full-body traditional Thai massage, gently stretching a client's leg while using firm, precise palm and forearm pressure along the hips and back. Shot on a Canon EOS R5 with a 35mm f/1.8 lens, the frame captures the full body interaction on a low wooden mat in a bright, airy spa studio. Natural window light from the left filtered through rice-paper screens provides soft, warm illumination while a subtle golden rim light from the right sculpts th..."
#
# 📏 길이 비교: A=125단어, B=183단어
#
# [17/40] A-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 크로스핏 박스, 고강도 인터벌 트레이닝
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1133 chars (~174 words)
# ================================================================================
#
# 한글 입력: "크로스핏 박스, 고강도 인터벌 트레이닝"
#
# 대조군 A: "A vibrant CrossFit box filled with energetic athletes engaged in high-intensity interval training. The setting is an industrial-style gym with exposed brick walls and large windows letting in bright natural light. In the foreground, a diverse group of individuals is performing various exercises, such as kettlebell swings, burpees, and box jumps, showcasing their determination and strength. The atmosphere is electrifying, with sweat glistening on their skin and expressions of focus and camaraderi..."
#
# 실험군 B: "CrossFit box during a high-intensity interval training session, captured from an elevated overhead perspective that shows multiple workout stations and athletes in mid-movement. Shot on a Canon EOS R5 with a 35mm lens, high shutter speed to freeze dynamic motion and a slightly shallow depth of field to isolate central athletes while keeping the overall layout readable. The scene is lit by diffused daylight pouring through large industrial windows combined with warm overhead pendant lights, creat..."
#
# 📏 길이 비교: A=117단어, B=174단어
#
# [18/40] A-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 복싱 체육관, 다이어트 복싱 프로그램
# ================================================================================
#    감지된 업종: a2_wellness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1027 chars (~165 words)
# ================================================================================
#
# 한글 입력: "복싱 체육관, 다이어트 복싱 프로그램"
#
# 대조군 A: "A vibrant boxing gym filled with energy and motivation, featuring a diverse group of individuals engaged in a dynamic boxing workout. The setting showcases a spacious interior with high ceilings, walls adorned with motivational posters, and an array of boxing equipment including heavy bags, speed bags, and gloves. The lighting is bright and energetic, casting a natural glow that highlights the determination on the participants' faces. In the foreground, a woman with a focused expression is pract..."
#
# 실험군 B: "A fit athletic woman throwing a powerful hook at a worn leather heavy bag in a boxing gym, captured mid-motion with her full body in frame and muscles visibly engaged. Shot like professional sports photography on a Canon EOS R5 with a 35mm lens, fast shutter speed to freeze action and a shallow aperture for subject separation. Warm side strobes highlight the muscle definition and catch sweat droplets on her skin while cooler natural light streams through high industrial windows creating rim ligh..."
#
# 📏 길이 비교: A=150단어, B=165단어
#
# [19/40] A-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 스피닝 센터, 신나는 그룹 사이클링
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1151 chars (~172 words)
# ================================================================================
#
# 한글 입력: "스피닝 센터, 신나는 그룹 사이클링"
#
# 대조군 A: "Imagine a vibrant spinning center filled with energy and excitement, where a diverse group of enthusiastic individuals is engaged in a dynamic group cycling session. The setting is a spacious, well-lit room with large windows that let in natural light, enhancing the lively atmosphere. The walls are adorned with colorful, motivational artwork that inspires movement and determination. The cyclists, dressed in bright, sporty attire, are on stationary bikes, pedaling vigorously in sync with an upbea..."
#
# 실험군 B: "A dynamic spinning center group cycling class with a confident instructor leading a packed studio, riders pedaling intensely in staggered rows and leaning forward in powerful, synchronized motion. Shot on a full-frame mirrorless camera with a 24mm wide-angle lens from a slightly elevated 45-degree vantage to include the instructor and several rows of cyclists, using a moderate aperture around f/4 to keep multiple subjects reasonably sharp while allowing gentle background separation. Warm overhea..."
#
# 📏 길이 비교: A=144단어, B=172단어
#
# [20/40] A-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 스파 웰니스, 아로마 테라피 힐링
# ================================================================================
#    감지된 업종: a2_wellness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1109 chars (~174 words)
# ================================================================================
#
# 한글 입력: "스파 웰니스, 아로마 테라피 힐링"
#
# 대조군 A: "An inviting spa wellness scene featuring a serene aromatherapy therapy room. The room is softly illuminated by warm, dim lighting, creating a tranquil atmosphere. In the foreground, a wooden massage table is dressed with plush white linens and surrounded by an array of essential oils in elegant glass bottles, each labeled with names like lavender, eucalyptus, and chamomile. The walls are adorned with soothing nature-inspired artwork, and soft, flowing curtains filter gentle sunlight, casting del..."
#
# 실험군 B: "A relaxed spa client receiving an aromatherapy healing massage, therapist’s hands gently applying warmed essential oil to the client’s shoulders and temples while wisps of steam rise from a nearby ceramic bowl of lavender and eucalyptus. Shot like a professional wellness editorial on a Canon EOS R5 with an 85mm f/1.4 lens, shallow depth of field at f/1.8 to softly blur the background while keeping skin texture and oil sheen razor-sharp. Soft natural daylight from a frosted window fills the room ..."
#
# 📏 길이 비교: A=139단어, B=174단어
#
# [21/40] A-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 여성 의류 매장, 봄 신상 원피스 컬렉션
# ================================================================================
#    감지된 업종: a3_fashion
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1080 chars (~169 words)
# ================================================================================
#
# 한글 입력: "여성 의류 매장, 봄 신상 원피스 컬렉션"
#
# 대조군 A: "A vibrant women's clothing store showcasing a spring collection of dresses. The interior is filled with soft pastel colors, with floral patterns adorning the walls and delicate greenery hanging from the ceiling. Sunlight streams through large windows, casting a warm glow over the neatly arranged displays of dresses in various styles and colors; flowing maxi dresses, chic midi dresses, and playful sundresses. Each dress features unique details like lace trims, ruffled sleeves, and vibrant prints,..."
#
# 실험군 B: "Female model wearing a spring new dress from a women's clothing store stands in a relaxed three-quarter pose on an urban sidewalk, one hand lightly touching the dress waist and the other holding a small neutral clutch, conveying effortless editorial confidence. Shot on a Canon EOS R5 with a 50mm f/1.8 lens to capture full body while preserving natural proportions, the scene uses warm golden hour sunlight as a rim backlight combined with a large softbox fill to softly illuminate the face and garm..."
#
# 📏 길이 비교: A=131단어, B=169단어
#
# [22/40] A-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 남성 정장 전문점, 맞춤 수트 제작
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1143 chars (~180 words)
# ================================================================================
#
# 한글 입력: "남성 정장 전문점, 맞춤 수트 제작"
#
# 대조군 A: "A sophisticated tailor shop specializing in men's suits, showcasing a luxurious interior filled with rich mahogany wood and elegant furnishings. In the foreground, a skilled tailor, dressed in a classic black apron, meticulously measures a well-dressed male client in a tailored suit. The walls are adorned with various fabrics and suit samples, displaying a range of textures and colors from deep navy to charcoal gray. Soft, warm lighting enhances the inviting atmosphere, casting gentle shadows th..."
#
# 실험군 B: "A bespoke men's suit on a tailor's mannequin being meticulously adjusted by a craftsman's hands, the tailor smoothing the sleeve and checking the shoulder line in a small high-end tailoring studio. Shot on a Canon EOS R5 with a 85mm f/1.4 lens to capture a shallow depth of field that isolates the lapel and hand-stitching while allowing the workshop to softly blur into the background. Warm overhead pendant lights cast soft highlights on the deep navy wool, while natural daylight from a left-side ..."
#
# 📏 길이 비교: A=128단어, B=180단어
#
# [23/40] A-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 아동복 가게, 귀여운 봄 키즈 패션
# ================================================================================
#    감지된 업종: a3_fashion
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1174 chars (~182 words)
# ================================================================================
#
# 한글 입력: "아동복 가게, 귀여운 봄 키즈 패션"
#
# 대조군 A: "Imagine a charming children's clothing store filled with a delightful array of spring fashion for kids. The setting features a bright and airy interior, illuminated by soft natural light streaming through large windows adorned with pastel-colored curtains. Shelves are lined with playful outfits in vibrant hues, including floral dresses, light jackets, and colorful accessories. A cheerful display of matching hats and shoes adds to the whimsical atmosphere. In one corner, a small play area with pl..."
#
# 실험군 B: "A young child model around four to six years old poses in a playful three-quarter stance wearing a coordinated spring outfit from a boutique kids' collection, the focus on the full body styling and fabric detail. Shot on a Canon EOS R5 with a 50mm lens set around f/2.8 to create a shallow but realistic depth of field, the child stands on a sunlit urban sidewalk framed by soft flowering trees and a tasteful storefront in the background. Natural golden hour sunlight provides warm rim light while a..."
#
# 📏 길이 비교: A=122단어, B=182단어
#
# [24/40] A-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 신발 매장, 트렌디한 스니커즈 신상
# ================================================================================
#    감지된 업종: a3_fashion
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1052 chars (~163 words)
# ================================================================================
#
# 한글 입력: "신발 매장, 트렌디한 스니커즈 신상"
#
# 대조군 A: "A modern shoe store interior that showcases a collection of trendy new sneakers. The setting is vibrant and lively, with sleek wooden shelves displaying an array of colorful sneakers in various styles and designs. Spotlights illuminate the shoes, creating a warm and inviting atmosphere. The walls are adorned with contemporary artwork and large mirrors reflecting the stylish footwear. A few stylish mannequins are positioned throughout the space, wearing fashionable outfits that complement the sne..."
#
# 실험군 B: "Trendy new sneakers modeled in a modern urban shoe store, a model wearing the sneakers standing in a three-quarter pose with one foot slightly forward to emphasize the side profile and sole. Shot as high-end fashion photography on a Canon EOS R5 with an 85mm f/1.4 lens, using shallow depth of field to isolate the footwear while keeping the boutique interior softly readable. Natural diffused sunlight from large storefront windows provides soft wraparound illumination while a warm golden-hour rim ..."
#
# 📏 길이 비교: A=117단어, B=163단어
#
# [25/40] A-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 가방 브랜드, 가죽 토트백 신제품
# ================================================================================
#    감지된 업종: a3_fashion
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 976 chars (~155 words)
# ================================================================================
#
# 한글 입력: "가방 브랜드, 가죽 토트백 신제품"
#
# 대조군 A: "A luxurious leather tote bag displayed elegantly in a modern, chic setting. The tote bag features a rich, deep brown color with a smooth finish, showcasing its high-quality craftsmanship. Surrounding the bag, a stylish boutique interior with minimalist decor enhances its appeal, characterized by soft, neutral tones and warm wooden accents. The lighting is soft and inviting, casting gentle shadows that highlight the bag's contours and textures. A few elegant accessories, like a silk scarf and a s..."
#
# 실험군 B: "Leather tote bag carried by a female model in a three-quarter full-body fashion pose on a quiet city sidewalk, the bag slightly angled toward the camera to reveal its silhouette and open top. Shot on a Canon EOS R5 with a 50mm f/1.8 lens, shallow depth of field isolates the bag while keeping the model and urban storefront softly readable. Warm golden-hour sunlight creates a gentle rim light on the bag's edges while a large soft diffuser fills shadows to reveal fine leather grain, tight stitching..."
#
# 📏 길이 비교: A=108단어, B=155단어
#
# [26/40] A-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 시계/주얼리샵, 프리미엄 시계 컬렉션
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1141 chars (~167 words)
#    Text Overlay: {'product_name': '프리미엄 시계 컬렉션', 'tagline': '시계/주얼리샵'}
# ================================================================================
#
# 한글 입력: "시계/주얼리샵, 프리미엄 시계 컬렉션"
#
# 대조군 A: "Imagine a luxurious watch and jewelry shop interior, elegantly designed with polished wooden displays and soft velvet drapes. The walls are adorned with tasteful artwork and mirrors that reflect the shimmering lights from the crystal chandeliers above. In the center, a striking premium watch collection is showcased, featuring a variety of exquisite timepieces, each with intricate details and unique designs. Some watches have sparkling diamonds embedded in their faces, while others boast sleek me..."
#
# 실험군 B: "Premium wristwatch collection arranged in an overhead flat-lay, three luxury watches shown from a top-down perspective — a brushed stainless steel chronograph, a rose-gold dress watch with fine leather strap, and a matte ceramic diver — each angled slightly to reveal dial detail and bracelet texture. Shot like a high-end commercial on a Canon EOS R5 with a 90mm macro lens, f/5.6 to keep crisp detail across faces, high-resolution product photography aesthetic. Bright softbox directly above combin..."
#
# 📏 길이 비교: A=127단어, B=167단어
#
# [27/40] A-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 안경점 신상, 트렌드 뿔테 안경
# ================================================================================
#    감지된 업종: a3_fashion
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1076 chars (~163 words)
#    Text Overlay: {'product_name': '안경점 신상', 'tagline': '트렌드 뿔테 안경'}
# ================================================================================
#
# 한글 입력: "안경점 신상, 트렌드 뿔테 안경"
#
# 대조군 A: "A stylish eyewear store display showcasing the latest trendy horn-rimmed glasses. The setting is a chic boutique with modern decor, featuring sleek wooden shelves lined with various pairs of glasses. Soft, natural lighting filters through large windows, casting gentle shadows that highlight the unique shapes and colors of the frames. Each pair of horn-rimmed glasses is elegantly placed on a minimalist stand, emphasizing their craftsmanship and design. The atmosphere is inviting and sophisticated..."
#
# 실험군 B: "A fashionable model wearing trendy horn-rimmed eyeglasses poses in a three-quarter full body fashion shot, standing confidently against a softly blurred urban rooftop street scene. Shot like a commercial lookbook image on a Canon EOS R5 with a 50mm lens at f/2.0 to achieve a shallow depth of field and creamy bokeh. Natural golden hour sunlight from behind creates a warm rim light while a large softbox from camera left provides gentle, diffused fill on the face and fabric. The outfit is a sophist..."
#
# 📏 길이 비교: A=134단어, B=163단어
#
# [28/40] A-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 사진관 홍보, 가족 기념사진 촬영
# ================================================================================
#    감지된 업종: a3_fashion
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1189 chars (~180 words)
# ================================================================================
#
# 한글 입력: "사진관 홍보, 가족 기념사진 촬영"
#
# 대조군 A: "A warm and inviting family photography studio setting, filled with soft, natural light filtering through large windows. The room is decorated with charming, rustic elements, such as wooden frames showcasing family portraits and delicate floral arrangements on a vintage table. In the foreground, a joyful family of four, with parents and two children, is posing together, their expressions filled with love and happiness. The children are playfully interacting, one holding a small bouquet of wildflo..."
#
# 실험군 B: "Family of four posing for a promotional family portrait at a professional photo studio, arranged in a relaxed, fashion-forward composition with parents seated on a low bench and two children standing in three-quarter poses, gently interacting and holding hands to convey warmth and connection. Shot on a full-frame mirrorless camera with a 35mm lens at f/4 to capture full-body detail while keeping a softly blurred background, using a large south-facing window and a softbox as the key lights to pro..."
#
# 📏 길이 비교: A=128단어, B=180단어
#
# [29/40] A-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 웨딩샵 드레스, 우아한 레이스 웨딩드레스
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1117 chars (~169 words)
# ================================================================================
#
# 한글 입력: "웨딩샵 드레스, 우아한 레이스 웨딩드레스"
#
# 대조군 A: "A stunning wedding dress displayed in an elegant bridal shop, showcasing intricate lace detailing that flows beautifully. The dress is adorned with delicate embroidery and sparkling embellishments, capturing the light in a soft, ethereal glow. Surrounding the dress, the boutique is tastefully decorated with soft pastel colors and elegant furnishings, giving a sense of luxury and romance. Natural light filters through large windows, casting gentle shadows and highlighting the textures of the lace..."
#
# 실험군 B: "Elegant lace wedding dress on a mannequin displayed prominently in a refined bridal boutique, the camera focused on the intricate bodice as the dress gently cascades into layered tulle and satin. Shot on a Canon EOS R5 with a 50mm f/1.4 lens using a shallow depth of field to isolate lace details, natural morning window light from the left bathes the fabric in soft diffuse daylight while warm overhead pendant lights add gentle golden highlights and subtle rim light that makes the tulle translucen..."
#
# 📏 길이 비교: A=106단어, B=169단어
#
# [30/40] A-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 한복 대여점, 설날 전통 한복 렌탈
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1314 chars (~197 words)
# ================================================================================
#
# 한글 입력: "한복 대여점, 설날 전통 한복 렌탈"
#
# 대조군 A: "A beautifully arranged Hanbok rental shop showcasing a vibrant collection of traditional Korean Hanboks for the Lunar New Year celebration. The setting is warm and inviting, with wooden shelves lined with an array of colorful Hanboks, each adorned with intricate embroidery and patterns. Soft, ambient lighting bathes the shop in a golden hue, highlighting the rich textures of the fabrics. In one corner, a traditional wooden mirror reflects the elegant attire, while delicate decorations such as pa..."
#
# 실험군 B: "Seollal traditional hanbok rental display in a boutique shop, three mannequins arranged in a gentle arc wearing a vibrant women’s chima-jeogori, a dignified men’s durumagi and a colorful child’s hanbok, posed as if ready for fittings. Shot like a commercial interior photograph on a Canon EOS R5 with a 50mm lens at f/2.2 to create a shallow depth of field that keeps the foreground details crisp while softly blurring the boutique background. Warm natural daylight streams through a large front wind..."
#
# 📏 길이 비교: A=130단어, B=197단어
#
# [31/40] A-4
# --------------------------------------------------------------------------------
#
# ...
#    감지된 업종: a4_delicate_care
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1099 chars (~174 words)
#    Text Overlay: {'product_name': '발렌타인 장미 꽃다발', 'tagline': '꽃집 홍보'}
# ================================================================================
#
# 한글 입력: "꽃집 홍보, 발렌타인 장미 꽃다발"
#
# 대조군 A: "A charming flower shop interior, bursting with vibrant colors and the scent of fresh blooms. In the center, a stunning bouquet of red roses, beautifully arranged with delicate green foliage, symbolizes romance and love for Valentine's Day. The bouquet is elegantly wrapped in soft, sheer fabric, adorned with a subtle ribbon. Surrounding the centerpiece, various other flowers in pastel shades, like pink tulips and white lilies, create a harmonious contrast. The shop is warmly lit, with golden hour..."
#
# 실험군 B: "Valentine's rose bouquet for a florist promotional shoot, tightly framed as an extreme macro product portrait showing a hand-tied cluster of deep red roses with delicate rosebud centers and layered petals. Shot like commercial floral photography on a Canon EOS R5 with a 100mm macro lens at f/2.8, very shallow depth of field and subtle focus stacking to retain crisp petal edges. Soft diffused window light from the left provides gentle, natural highlights while a warm rim backlight emphasizes the ..."
#
# 📏 길이 비교: A=131단어, B=174단어
#
# [32/40] A-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 반려동물 용품점, 강아지 봄 옷 신상
# ================================================================================
#    감지된 업종: a4_delicate_care
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1164 chars (~177 words)
# ================================================================================
#
# 한글 입력: "반려동물 용품점, 강아지 봄 옷 신상"
#
# 대조군 A: "Imagine a vibrant pet supply store filled with an array of colorful spring dog clothing. The shop is adorned with cheerful decorations, featuring pastel hues of pink, blue, and yellow that evoke a sense of warmth and joy. Sunlight streams in through large windows, casting a soft glow over the neatly arranged racks of adorable dog outfits. Each outfit showcases playful patterns like flowers, polka dots, and stripes, made from lightweight, breathable fabrics ideal for spring. In one corner, a frie..."
#
# 실험군 B: "New spring dog clothes showcased in a boutique pet supply store with a small beagle model wearing a pastel floral lightweight raincoat while a miniature mannequin nearby displays a matching knitted sweater, the scene focused on the garments and craftsmanship. Shot on a Canon EOS R5 with a 100mm macro lens at f/2.8 to capture intricate fabric detail and stitching, soft natural diffused window light from the left provides gentle highlights while a subtle fill reflector from the right removes harsh..."
#
# 📏 길이 비교: A=145단어, B=177단어
#
# [33/40] A-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 동물병원 안내, 반려견 건강검진 패키지
# ================================================================================
#    감지된 업종: a4_delicate_care
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1132 chars (~174 words)
#    Text Overlay: {'product_name': '반려견 건강검진 패키지', 'tagline': '동물병원 안내'}
# ================================================================================
#
# 한글 입력: "동물병원 안내, 반려견 건강검진 패키지"
#
# 대조군 A: "A warm and inviting animal hospital reception area designed for pet owners, featuring a friendly veterinarian and a playful dog. The setting is bright and cheerful, with soft natural light streaming through large windows adorned with colorful pet-themed decorations. In the foreground, a golden retriever puppy is happily wagging its tail, surrounded by vibrant potted plants. The veterinarian, a kind-looking woman in a white lab coat, kneels beside the puppy, holding a stethoscope with a caring sm..."
#
# 실험군 B: "A calm adult dog sitting on an examination table receiving a comprehensive health checkup package at a modern veterinary clinic, the scene staged as a promotional service photograph that emphasizes trust and attentive care. Shot on a Canon EOS R5 with an 85mm f/1.4 lens using a close-up portrait and selective macro details to capture fur and instrument textures, shallow depth of field isolates the dog and vet interaction. Soft natural window light from the left combined with diffused overhead cl..."
#
# 📏 길이 비교: A=143단어, B=174단어
#
# [34/40] A-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 장난감 가게, 레고 신제품 출시
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1129 chars (~173 words)
# ================================================================================
#
# 한글 입력: "장난감 가게, 레고 신제품 출시"
#
# 대조군 A: "A vibrant and inviting toy store filled with colorful shelves brimming with a variety of LEGO sets. The scene is set during the day, with sunlight streaming through large display windows, casting warm, golden light across the store. Children of different ages are happily exploring the aisles, their faces lit up with excitement as they discover new LEGO products. One child is seated on the floor, deeply engrossed in building a detailed LEGO castle, while another is showing a friend a new space-th..."
#
# 실험군 B: "New LEGO set displayed as the central subject for a product launch, arranged in a clean toy store launch scene from a top-down flat lay perspective. Shot like premium commercial product photography on a Canon EOS R5 with a 35mm lens mounted overhead, bright daylight-balanced softbox directly above for even, cool studio lighting and gentle, realistic shadows. The boxed new set sits slightly angled on a pristine white surface with unboxed bricks, translucent pieces, and two posed minifigures fanne..."
#
# 📏 길이 비교: A=146단어, B=173단어
#
# [35/40] A-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 가구점 홍보, 미니멀 원목 책상 세트
# ================================================================================
#    감지된 업종: a4_delicate_care
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1095 chars (~172 words)
#    Text Overlay: {'product_name': '미니멀 원목 책상 세트', 'tagline': '가구점 홍보'}
# ================================================================================
#
# 한글 입력: "가구점 홍보, 미니멀 원목 책상 세트"
#
# 대조군 A: "A beautifully arranged minimalist wood desk set showcased in a modern furniture store. The scene features a sleek, natural wood desk with clean lines and a matching wooden chair, placed against a softly lit backdrop. The setting has large windows allowing warm, natural sunlight to filter in, casting gentle shadows on the polished wooden floor. Surrounding the desk are tasteful decorative elements such as a small potted plant, a stylish desk lamp with a soft glow, and a few neatly stacked books. ..."
#
# 실험군 B: "Minimal solid wood desk set displayed as a premium furniture store promotional product, a clean three-quarter view of the desk with a matching stool tucked underneath and a single small ceramic mug and an open notebook to suggest everyday use. Shot like high-end commercial furniture photography on a full-frame camera with a 50mm lens for the main composition and a 100mm macro for a separate close-detail read, using shallow depth of field to isolate the desk while keeping the silhouette crisp. So..."
#
# 📏 길이 비교: A=136단어, B=172단어
#
# [36/40] A-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 세탁소 서비스, 명품 가방 클리닝
# ================================================================================
#    감지된 업종: a4_delicate_care
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1084 chars (~161 words)
# ================================================================================
#
# 한글 입력: "세탁소 서비스, 명품 가방 클리닝"
#
# 대조군 A: "A luxurious dry cleaning service setting, showcasing an elegant boutique interior with soft, ambient lighting that creates a sophisticated atmosphere. The focal point of the scene is a pristine, high-end designer handbag being carefully cleaned by a skilled attendant in stylish attire. Surrounding the handbag are plush velvet display cases filled with various other exquisite bags, all meticulously arranged. The walls feature tasteful art pieces that reflect a chic, upscale vibe. In the backgroun..."
#
# 실험군 B: "Luxury handbag being professionally cleaned by a specialist technician in a high-end laundry atelier, shown in an extreme macro close-up that emphasizes the meticulous restoration process. Shot on a Canon EOS R5 with a 100mm macro lens, the frame captures gloved hands gently applying a delicate cleaning foam with a soft-bristle brush to the leather surface while another hand carefully polishes the metal clasp with a microfiber cloth. Soft diffused window light from the left combines with a clean..."
#
# 📏 길이 비교: A=112단어, B=161단어
#
# [37/40] A-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 피아노 학원, 어린이 피아노 레슨
# ================================================================================
#    감지된 업종: b1_learning
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1122 chars (~175 words)
# ================================================================================
#
# 한글 입력: "피아노 학원, 어린이 피아노 레슨"
#
# 대조군 A: "A bright and cheerful piano academy, filled with the sounds of children learning to play the piano. The setting showcases a spacious, sunlit classroom with large windows that let in warm, golden light. Inside, vibrant posters of musical notes and famous composers adorn the walls, creating an inspiring atmosphere. Several young children, around 6 to 10 years old, are seated at black and white pianos, their fingers dancing over the keys with concentration and joy. A friendly instructor, smiling an..."
#
# 실험군 B: "Children's piano lesson in a bright, organized teaching studio with a young child seated at an upright piano and a teacher gently guiding the child's hand on the keys. Shot as a wide-angle interior architectural image on a Canon EOS R5 with a 24mm lens to capture the full room overview and leading lines of wooden flooring and practice desks. Natural daylight pours through large windows, supplemented by soft, even overhead panel lighting to create a warm, airy study atmosphere. The composition sh..."
#
# 📏 길이 비교: A=131단어, B=175단어
#
# [38/40] A-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 미술학원 홍보, 수채화 클래스 작품전
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1176 chars (~181 words)
# ================================================================================
#
# 한글 입력: "미술학원 홍보, 수채화 클래스 작품전"
#
# 대조군 A: "A vibrant art exhibition showcasing watercolor paintings created by students at an art academy. The setting is a bright and airy gallery space filled with natural light streaming in through large windows. The walls are adorned with an array of stunning watercolor artworks, each displaying different techniques and styles, from delicate florals to abstract landscapes. In the foreground, a small group of enthusiastic art students engages in conversation, their faces illuminated with excitement and ..."
#
# 실험군 B: "Watercolor class exhibition pieces arranged on a large light oak table, photographed from above in an inviting art studio setting. Shot on a Canon EOS R5 with a 35mm lens at f/5.6 for even sharpness, natural daylight streaming from a tall north-facing window on the left and a warm pendant overhead providing soft fill light to create gentle highlights and soft shadows. Several student watercolors are laid out in a slightly staggered grid—some unframed works taped at the corners, a few small mount..."
#
# 📏 길이 비교: A=148단어, B=181단어
#
# [39/40] A-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 자전거 매장, 접이식 미니벨로 신상
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1135 chars (~162 words)
# ================================================================================
#
# 한글 입력: "자전거 매장, 접이식 미니벨로 신상"
#
# 대조군 A: "A vibrant bicycle store interior showcasing a range of sleek, foldable mini bikes. The setting is bright and inviting, with large windows allowing natural light to stream in, illuminating the colorful bicycles on display. The walls are adorned with bicycle-themed art and accessories, creating an engaging atmosphere for cycling enthusiasts. In the foreground, a shiny new foldable mini bike is prominently featured, its compact design and modern features highlighted. The background includes shelves..."
#
# 실험군 B: "Foldable mini velo bicycles arranged in a clean, modern bicycle shop showroom, displayed from a slightly elevated top-down three-quarter angle so each folding mechanism and compact silhouette is clearly visible. Shot on a high-resolution full-frame camera with a 35mm lens at f/5.6 to keep sharp detail across the scene, warm overhead LED panels mix with soft natural daylight streaming through a storefront window to create gentle highlights on metal and subtle shadows beneath the frames. The compo..."
#
# 📏 길이 비교: A=120단어, B=162단어
#
# [40/40] A-4
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 인테리어 소품샵, 북유럽 감성 조명
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1077 chars (~168 words)
# ================================================================================
#
# 한글 입력: "인테리어 소품샵, 북유럽 감성 조명"
#
# 대조군 A: "An inviting interior decor shop showcasing a cozy Scandinavian aesthetic. The shop is filled with an array of stylish decorative items, including minimalist furniture, elegant vases, and unique wall art. Soft, warm lighting creates a welcoming atmosphere, highlighting the textures of natural materials like wood and wool. Large windows allow natural light to filter in, casting gentle shadows across the room. The walls are painted in serene pastel colors, adorned with tasteful decorations that ref..."
#
# 실험군 B: "Scandinavian-style interior decor shop display focusing on Nordic lighting fixtures arranged on a low oak display table and floating shelves, pendant lamps and small table lamps casting a warm, gentle glow. Shot like a commercial interior photograph on a Canon EOS R5 with a 50mm f/1.8 lens, wide aperture for shallow depth of field, natural window light streaming from the left early morning, diffused through a sheer curtain to create soft, long shadows and creamy bokeh in the background. The scen..."
#
# 📏 길이 비교: A=121단어, B=168단어
#
#
# ====================================================================================================
# 📈 A등급 (비주얼 변화 및 자기관리) 요약 통계
# ====================================================================================================
# 테스트 케이스 수: 40
# 대조군 A 평균 길이: 129.5 단어
# 실험군 B 평균 길이: 174.0 단어

# %% [markdown]
# ### 3.3 B+C등급 테스트 (공간 체험/교육 + 신뢰 기반 서비스)

# %%
# B+C등급 A/B 테스트 실행
bc_grade_results = run_ab_test(BC_GRADE_TEST_CASES, "B+C등급 (공간 체험/교육 + 신뢰 기반 서비스)")
# Out:
# ====================================================================================================
# 📊 B+C등급 (공간 체험/교육 + 신뢰 기반 서비스) A/B 테스트 결과
# ====================================================================================================
#
#
# [1/60] B-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 입시학원 홍보, 소수정예 수학 클래스
# ================================================================================
#    감지된 업종: b1_learning
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1260 chars (~189 words)
#    Text Overlay: {'product_name': '소수정예 수학 클래스', 'tagline': '입시학원 홍보'}
# ================================================================================
#
# 한글 입력: "입시학원 홍보, 소수정예 수학 클래스"
#
# 대조군 A: "A cozy and modern classroom setting designed for an exclusive small group of students engaged in a mathematics class. The room is filled with natural light streaming through large windows, casting soft shadows on the walls adorned with colorful educational posters and mathematical formulas. In the foreground, a diverse group of five students, focused and enthusiastic, are seated around a round table, each with their own set of books, notebooks, and tablets. Their expressions reflect curiosity an..."
#
# 실험군 B: "A professional entrance exam tutoring academy classroom showcasing a small elite math class in session. The scene shows a focused tutor leaning slightly over a student’s desk explaining a concept while four attentive students sit at neatly arranged wooden desks in a compact, organized layout. Shot on a Canon EOS R5 with a 16–35mm f/2.8 lens, wide-angle interior perspective taken from a slightly elevated three-quarter view to capture the overall room architecture and seating arrangement. Natural ..."
#
# 📏 길이 비교: A=128단어, B=189단어
#
# [2/60] B-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 외국어 학원, 원어민 영어 회화 수업
# ================================================================================
#    감지된 업종: b1_learning
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1461 chars (~216 words)
# ================================================================================
#
# 한글 입력: "외국어 학원, 원어민 영어 회화 수업"
#
# 대조군 A: "A vibrant and engaging scene inside a modern foreign language academy, showcasing a diverse group of students in a dynamic English conversation class. The setting is a bright, airy classroom adorned with colorful world maps and language posters. Sunlight streams through large windows, casting warm light across the room. In the foreground, a friendly native English speaker, an enthusiastic young woman, is animatedly interacting with the students, who are a mix of ages and ethnicities, all engaged..."
#
# 실험군 B: "A modern foreign language academy classroom during a native English conversation lesson, a native English-speaking teacher seated at the front guiding a small group of adult students in an engaged discussion; students lean forward, speak, listen attentively, take notes on notebooks and laptops, and one student gestures as they practice pronunciation. Shot like professional architectural interior photography on a Canon EOS R5 with a 24mm wide-angle lens at f/5.6, ISO 200, daylight white balance, ..."
#
# 📏 길이 비교: A=124단어, B=216단어
#
# [3/60] B-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 코딩 학원, 어린이 프로그래밍 교육
# ================================================================================
#    감지된 업종: b1_learning
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1159 chars (~165 words)
# ================================================================================
#
# 한글 입력: "코딩 학원, 어린이 프로그래밍 교육"
#
# 대조군 A: "A vibrant and engaging coding academy designed for children, showcasing a lively classroom filled with young students eagerly participating in programming lessons. The room is bright and colorful, with walls adorned with educational posters of coding languages and fun graphics related to technology. Each child is seated at a modern computer workstation, their faces illuminated by the screens as they focus on their coding tasks. The atmosphere is buzzing with excitement and curiosity, with a frie..."
#
# 실험군 B: "A bright modern children's coding classroom featuring elementary-age students actively learning programming on laptops and tablets, with one teacher kneeling beside a child to offer guidance. Shot on a Canon EOS R5 with a 16-35mm f/2.8 wide-angle lens, composed as an interior architectural overview that captures the full room from a slightly elevated corner perspective. Large floor-to-ceiling windows on the left pour soft natural daylight across wooden desks, while warm overhead LED panels provi..."
#
# 📏 길이 비교: A=123단어, B=165단어
#
# [4/60] B-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 스터디카페 홍보, 조용하고 쾌적한 학습 공간
# ================================================================================
#    감지된 업종: b1_learning
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1120 chars (~160 words)
# ================================================================================
#
# 한글 입력: "스터디카페 홍보, 조용하고 쾌적한 학습 공간"
#
# 대조군 A: "A serene and comfortable study cafe designed for focused learning. The interior features soft, muted colors with warm wood accents, creating a cozy atmosphere. Large windows allow natural light to flood in, illuminating individual study pods and communal tables scattered throughout the space. Each study pod is equipped with plush chairs, small desks, and personal lighting to promote concentration. Potted plants are strategically placed, adding a touch of greenery and freshness. The cafe is adorn..."
#
# 실험군 B: "Study cafe interior showing a quiet, comfortable learning space with neatly organized individual desks and a few students working calmly with laptops and notebooks. Shot on a Canon EOS R5 with a 24mm wide-angle lens from a low slightly diagonal vantage point to capture a room overview and architectural perspective, deep focus so both foreground desks and background study booths remain sharp. Natural daylight pours through large floor-to-ceiling windows on the left, supplemented by soft, diffused..."
#
# 📏 길이 비교: A=131단어, B=160단어
#
# [5/60] B-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 운전학원 안내, 친절한 1:1 운전 교육
# ================================================================================
#    감지된 업종: b1_learning
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1116 chars (~173 words)
#    Text Overlay: {'product_name': '운전학원 안내', 'tagline': '친절한 1:1 운전 교육'}
# ================================================================================
#
# 한글 입력: "운전학원 안내, 친절한 1:1 운전 교육"
#
# 대조군 A: "Create an inviting scene inside a modern driving school, featuring a friendly driving instructor and a student engaged in a one-on-one driving lesson. The interior of the car should be well-lit, showcasing a clean and organized dashboard with instructional materials visible. Outside the car window, depict a sunny day with clear blue skies and a picturesque road lined with trees. The atmosphere should feel supportive and encouraging, highlighting the personal connection between the instructor and..."
#
# 실험군 B: "Driving school interior with a friendly one-to-one driving lesson between an instructor and a student in the foreground, the instructor leaning slightly toward the seated student pointing at a route map on a tablet while maintaining warm, encouraging eye contact. Shot on a full-frame camera with a 24mm wide-angle lens at f/8 to keep the whole room in sharp focus, natural daylight pouring through large windows complemented by soft overhead lighting to create a bright, airy atmosphere. Compose the..."
#
# 📏 길이 비교: A=129단어, B=173단어
#
# [6/60] B-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 공무원 학원, 합격자 수기와 커리큘럼
# ================================================================================
#    감지된 업종: b1_learning
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1242 chars (~183 words)
# ================================================================================
#
# 한글 입력: "공무원 학원, 합격자 수기와 커리큘럼"
#
# 대조군 A: "A vibrant and dynamic scene inside a public service academy classroom, showcasing a diverse group of students deeply engaged in their studies. The room is filled with large windows that let in warm, natural light, creating an inviting atmosphere. On one side, a dedicated instructor stands at a whiteboard, passionately explaining concepts, while students of various backgrounds, including a young woman with glasses, a middle-aged man taking notes, and a college-age student with a laptop, are activ..."
#
# 실험군 B: "Public servant academy classroom showing a bright, organized study environment with success story displays and curriculum materials arranged for review. Shot on a full-frame camera with a wide 16mm lens to capture the interior perspective, the composition frames rows of wood-grain desks leading toward a feature wall with framed graduate portraits and a corkboard of pinned testimonials and curriculum charts rendered softly to avoid legible text. Natural daylight pours through large floor-to-ceili..."
#
# 📏 길이 비교: A=129단어, B=183단어
#
# [7/60] B-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 독서실 오픈, 24시간 개인 학습 부스
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1212 chars (~188 words)
#    Text Overlay: {'event_name': '독서실 오픈', 'tagline': '24시간 개인 학습 부스'}
# ================================================================================
#
# 한글 입력: "독서실 오픈, 24시간 개인 학습 부스"
#
# 대조군 A: "Visualize a modern, inviting study room designed for individual learning, featuring multiple personal study booths. The setting is a spacious, well-lit environment with large windows that allow natural light to flood in, creating a warm and welcoming atmosphere. Each booth is equipped with comfortable seating, a sleek desk, and contemporary design elements, such as soundproof walls for privacy. The color palette is calming, with soft blues and greens, accentuated by warm wooden tones. In the bac..."
#
# 실험군 B: "A modern study room showcasing 24시간 개인 학습 부스 arranged in clean parallel rows, seen from a slightly elevated top-down angle that reveals the overall layout and individual booth intimacy. The foreground features one student quietly studying with an open laptop and notebook, a small desk lamp casting a warm pool of light, while other booths remain tidy and unoccupied to emphasize privacy and availability. Shot as a high-end interior photograph on a Canon EOS R5 with a 35mm lens at f/3.5 to capture ..."
#
# 📏 길이 비교: A=139단어, B=188단어
#
# [8/60] B-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 유학원 상담, 미국 대학 입학 컨설팅
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1408 chars (~216 words)
# ================================================================================
#
# 한글 입력: "유학원 상담, 미국 대학 입학 컨설팅"
#
# 대조군 A: "A warm and inviting office environment designed for educational consulting, featuring a sleek modern desk with a laptop open, displaying a vibrant university website. In the background, a large world map is pinned with colorful markers indicating various countries, symbolizing global education opportunities. Soft, natural light filters through large windows, casting gentle shadows across the room filled with bookshelves lined with academic guides and brochures. A comfortable seating area with pl..."
#
# 실험군 B: "Study abroad consultation for U.S. college admissions captured as an inviting overhead flat-lay of a counselor and prospective student actively reviewing application materials. The scene is shot like a professional editorial photograph on a Canon EOS R5 with a 35mm lens, gentle top-down composition with a slight angle to reveal faces and hands, shallow depth of field to keep focus on the documents and gestures. Warm overhead home-style lighting mixes with soft natural daylight from a nearby wind..."
#
# 📏 길이 비교: A=122단어, B=216단어
#
# [9/60] B-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 취업 학원, 면접 스피치 특강
# ================================================================================
#    감지된 업종: b1_learning
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1161 chars (~182 words)
# ================================================================================
#
# 한글 입력: "취업 학원, 면접 스피치 특강"
#
# 대조군 A: "A dynamic scene set inside a modern classroom designed for professional development, filled with eager students participating in an interactive interview speech workshop. The room is well-lit with large windows allowing natural sunlight to flood in, creating a bright and inviting atmosphere. Students of diverse backgrounds are seated at sleek desks, attentively listening to an enthusiastic instructor standing at the front. The instructor, a middle-aged professional wearing smart attire, gestures..."
#
# 실험군 B: "A career academy interview speech workshop in progress with a professional coach standing at the front demonstrating posture and hand gestures while a small group of adult students listens and practices in turns. Shot on a full-frame camera with a wide 24mm lens from a slightly elevated rear corner to show the entire interior perspective, the composition captures the trainer, a semicircle of desks, and students mid-practice, some speaking into a discreet lapel microphone and others taking notes...."
#
# 📏 길이 비교: A=141단어, B=182단어
#
# [10/60] B-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 자격증 학원, 바리스타 자격증 과정
# ================================================================================
#    감지된 업종: b1_learning
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1365 chars (~191 words)
# ================================================================================
#
# 한글 입력: "자격증 학원, 바리스타 자격증 과정"
#
# 대조군 A: "A vibrant and inviting coffee shop interior, showcasing a barista training academy environment. The scene is bustling with students engaged in a barista certification course. A diverse group of individuals, including young adults and middle-aged men and women, are gathered around a sleek espresso machine, attentively following a skilled instructor demonstrating latte art. The setting is filled with warm, ambient lighting that creates a cozy atmosphere, with natural light streaming through large ..."
#
# 실험군 B: "Barista certification course in progress with an instructor demonstrating espresso extraction at the front while a small group of trainees practice at individual workstations. Shot on a Canon EOS R5 with a 24mm wide-angle lens to capture the full interior perspective, the image shows a bright, airy training studio with large floor-to-ceiling windows letting in abundant natural daylight complemented by soft warm overhead lighting. The composition is a wide-angle architectural overview that emphas..."
#
# 📏 길이 비교: A=142단어, B=191단어
#
# [11/60] B-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 호텔 프로모션, 오션뷰 스위트룸 패키지
# ================================================================================
#    감지된 업종: b2_leisure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1060 chars (~165 words)
#    Text Overlay: {'product_name': '오션뷰 스위트룸 패키지', 'tagline': '호텔 프로모션'}
# ================================================================================
#
# 한글 입력: "호텔 프로모션, 오션뷰 스위트룸 패키지"
#
# 대조군 A: "Create a captivating image of a luxurious oceanview suite in a high-end hotel. The suite features floor-to-ceiling windows that showcase a breathtaking view of the sparkling blue ocean, with gentle waves lapping at the shore. Inside, the decor is elegant and modern, with soft neutral tones accented by plush furnishings. A king-sized bed adorned with fluffy white pillows is positioned to face the ocean, allowing guests to wake up to stunning sunrises. Include a cozy sitting area with a stylish so..."
#
# 실험군 B: "Ocean-view suite in a luxury hotel, photographed as a cinematic wide-angle interior to showcase the high ceiling and a panoramic ocean vista through floor-to-ceiling windows. Shot on a full-frame camera with a 24mm lens from a slightly elevated corner to emphasize space and scale, using shallow foreground focus but deep clarity on the balcony and horizon. Golden hour sunlight pours across the room creating warm shafts and long soft shadows, complemented by warm recessed ambient lighting and a be..."
#
# 📏 길이 비교: A=174단어, B=165단어
#
# [12/60] B-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 펜션 홍보, 가족 단위 바베큐 독채
# ================================================================================
#    감지된 업종: b2_leisure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1296 chars (~197 words)
# ================================================================================
#
# 한글 입력: "펜션 홍보, 가족 단위 바베큐 독채"
#
# 대조군 A: "A cozy, inviting vacation rental cabin surrounded by lush greenery, designed for family gatherings. The setting features a spacious outdoor barbecue area with a grill, picnic tables, and colorful string lights creating a warm ambiance. A family of four, including two children, is joyfully preparing a barbecue feast, with fresh vegetables and meats laid out on the tables. The sun is setting in the background, casting a golden hue over the scene, enhancing the inviting atmosphere. In the backgroun..."
#
# 실험군 B: "A detached private vacation cottage prepared for a family barbecue, showing a wide cinematic view that includes the open-plan living room flowing directly onto a private wooden deck where a family of four laughs around a premium built-in grill. Shot on a full-frame camera with a 24mm lens to capture the high ceiling and panoramic sightlines, the scene is framed as a cinematic wide shot from a slightly elevated angle to reveal both interior and exterior in one composition. Golden hour sunlight po..."
#
# 📏 길이 비교: A=117단어, B=197단어
#
# [13/60] B-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: PC방 이벤트, 최신 사양 게이밍 좌석
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1221 chars (~183 words)
#    Text Overlay: {'product_name': '최신 사양 게이밍 좌석', 'event_name': 'PC방 이벤트'}
# ================================================================================
#
# 한글 입력: "PC방 이벤트, 최신 사양 게이밍 좌석"
#
# 대조군 A: "Imagine a vibrant PC gaming lounge filled with the latest high-spec gaming seats. The setting is a modern, stylish room with sleek, illuminated gaming setups featuring powerful computers and large, ultra-high-definition monitors displaying stunning graphics from popular games. Each gaming station is adorned with RGB lighting that casts colorful reflections across the space. The atmosphere is energized and inviting, with gamers intensely focused on their screens, wearing headsets and immersed in ..."
#
# 실험군 B: "Latest-spec gaming seats arranged in a premium PC bang event setting, each ergonomic chair paired with a high-end gaming PC tower and curved monitor, the seats slightly angled to invite a player and showing stitching and contour lines clearly. Shot like a commercial interior photograph on a full-frame camera with a 24mm wide lens, moderate aperture to keep the row in crisp focus while gently softening the background. Bright cool studio lights mixed with natural daylight from a high window create..."
#
# 📏 길이 비교: A=143단어, B=183단어
#
# [14/60] B-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 노래방 시설, 프리미엄 코인 노래방
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1254 chars (~178 words)
# ================================================================================
#
# 한글 입력: "노래방 시설, 프리미엄 코인 노래방"
#
# 대조군 A: "Imagine a luxurious karaoke room designed for an upscale experience. The setting is a modern, private karaoke lounge with plush velvet seating in deep shades of royal blue and gold accents. Soft, ambient lighting casts a warm glow throughout the room, creating an inviting and intimate atmosphere. The walls are adorned with soundproof panels featuring artistic designs, enhancing both aesthetics and acoustics. A sleek touch-screen interface is embedded in the table, allowing guests to effortlessly..."
#
# 실험군 B: "Premium coin karaoke facility interior captured in an overhead flat-lay top-down composition, showing one private booth, the coin-operated kiosk, and a tidy tabletop with a microphone, headphones, and a chilled drink. Shot like a commercial interior photograph on a full-frame camera mounted above with a 35mm equivalent lens, f/8 for crisp detail across the scene, low ISO for clean noise-free rendering, and studio strobes balanced with daylight at 5600K. Bright, cool lighting from softboxes produ..."
#
# 📏 길이 비교: A=155단어, B=178단어
#
# [15/60] B-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 글램핑장 오픈, 자연 속 럭셔리 캠핑
# ================================================================================
#    감지된 업종: b2_leisure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1226 chars (~188 words)
# ================================================================================
#
# 한글 입력: "글램핑장 오픈, 자연 속 럭셔리 캠핑"
#
# 대조군 A: "A luxurious glamping site nestled in the heart of nature, surrounded by lush greenery and towering trees. The scene captures elegantly furnished tents with large, cozy beds draped in soft linens, inviting guests to relax. A wooden deck extends from the tents, adorned with stylish outdoor furniture and soft cushions, perfect for lounging. The setting is illuminated by warm, golden hour sunlight filtering through the leaves, creating a magical atmosphere. In the background, a serene lake reflects ..."
#
# 실험군 B: "Luxury glamping suite revealed at golden hour, a spacious canvas-and-timber tent standing open to a panoramic woodland and lake view, inviting guests into a refined nature retreat. Shot on a Canon EOS R5 with a 24mm wide-angle lens, composed as a cinematic wide shot that emphasizes the tall vaulted ceiling and the seamless indoor-outdoor connection. Warm golden sunlight pours through the open entrance and large windows while soft ambient lamps and a low fireplace cast layered cinematic interior ..."
#
# 📏 길이 비교: A=141단어, B=188단어
#
# [16/60] B-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 여행사 패키지, 제주도 3박 4일 투어
# ================================================================================
#    감지된 업종: b2_leisure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1190 chars (~176 words)
#    Text Overlay: {'product_name': '제주도 3박 4일 투어', 'tagline': '여행사 패키지'}
# ================================================================================
#
# 한글 입력: "여행사 패키지, 제주도 3박 4일 투어"
#
# 대조군 A: "A breathtaking landscape showcasing a 3-night, 4-day tour in Jeju Island, South Korea. The scene features a vibrant sunrise over the iconic Hallasan Mountain, with lush greenery and blooming wildflowers in the foreground. In the distance, a serene beach with crystal-clear turquoise waters and soft white sand completes the picturesque view. A couple is seen exploring the coastal cliffs, capturing the moment with a camera, while a local vendor sells fresh tropical fruits nearby. The atmosphere is ..."
#
# 실험군 B: "Jeju Island 3박 4일 투어 package portrayed as a cinematic luxury hotel suite scene with a panoramic ocean view. A well-dressed couple stands near floor-to-ceiling windows, one person pointing toward the distant coastline while the other leans on a suitcase, conveying relaxed anticipation and exploration. Shot on a Canon EOS R5 with a 24mm f/1.4 lens in a wide-angle cinematic composition that emphasizes the high ceiling and expansive view. Warm golden-hour sunlight pours through the windows, casting ..."
#
# 📏 길이 비교: A=146단어, B=176단어
#
# [17/60] B-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 찜질방 홍보, 힐링 스파 시설 안내
# ================================================================================
#    감지된 업종: b2_leisure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1136 chars (~173 words)
# ================================================================================
#
# 한글 입력: "찜질방 홍보, 힐링 스파 시설 안내"
#
# 대조군 A: "Imagine a serene and inviting jjimjilbang (Korean sauna) with a variety of cozy, softly-lit spaces designed for relaxation and healing. The interior features smooth wooden floors and warm stone walls, with gentle steam rising from heated stone beds surrounded by lush indoor plants. The lighting is warm and atmospheric, casting a soothing glow that enhances the tranquil vibe. In one corner, a traditional Korean clay oven emits soft, warm light, while nearby, a bubbling hot spring invites guests t..."
#
# 실험군 B: "A luxurious Korean jjimjilbang healing spa interior presented as a cinematic wide shot from a slightly elevated, high-ceiling perspective that reveals a panoramic layout of multiple therapy zones. The composition shows a heated stone ondol relaxation area with low wooden daybeds, a tiled mineral salt chamber, and steaming hot pools edged in polished dark stone, arranged to feel spacious and calming. Shot on a Canon EOS R5 with a 24mm lens to emphasize expansive scale, warm golden-hour sunlight s..."
#
# 📏 길이 비교: A=160단어, B=173단어
#
# [18/60] B-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 만화카페, 아늑한 독서 공간
# ================================================================================
#    감지된 업종: s3_emotional
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 983 chars (~162 words)
# ================================================================================
#
# 한글 입력: "만화카페, 아늑한 독서 공간"
#
# 대조군 A: "Imagine a cozy comic cafe, designed to be a perfect reading space. The interior is adorned with warm wooden furniture, including plush armchairs and small tables for individual readers. Shelves lined with vibrant comic books reach up to the ceiling, showcasing a colorful array of genres. Soft, ambient lighting casts a gentle glow throughout the room, creating a relaxed atmosphere ideal for immersing oneself in a story. A large window allows natural light to filter in, illuminating a corner with ..."
#
# 실험군 B: "A cozy manga café reading nook captured in the soft glow of early morning light, a single low wooden table beside a plush beige armchair and a built-in shelf densely packed with colorful comic volumes. Shot on a full-frame camera with a 35mm f/1.8 lens at wide aperture to create creamy shallow depth of field and gentle bokeh, the scene shows a reader's hands holding an open comic with visible paper grain and slightly curled edges while a small ceramic cup with delicate foam art and faint steam r..."
#
# 📏 길이 비교: A=152단어, B=162단어
#
# [19/60] B-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 보드게임 카페, 친구들과 즐기는 게임
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1196 chars (~194 words)
# ================================================================================
#
# 한글 입력: "보드게임 카페, 친구들과 즐기는 게임"
#
# 대조군 A: "A cozy board game café filled with warm, inviting colors and soft lighting. The scene features a group of friends gathered around a large wooden table, deeply engaged in playing various board games. Laughter and excitement fill the atmosphere as they share snacks and drinks, creating a lively and joyful environment. The walls are adorned with colorful game posters and shelves lined with an array of board games, from classic to modern. In the background, a barista is preparing beverages, adding t..."
#
# 실험군 B: "A group of four friends gathered around a board game in a modern board game cafe, leaning in and laughing as hands reach to move colorful tokens and roll dice, captured from a clean top-down overhead perspective. Shot on a Canon EOS R5 with a 35mm lens mounted directly above the table, aperture around f/5.6 for sharp detail across the scene, natural daylight from large windows on the left paired with soft cool studio fill to emphasize a fresh, airy mood. The light creates crisp highlights on glo..."
#
# 📏 길이 비교: A=119단어, B=194단어
#
# [20/60] B-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 리조트 워터파크, 신나는 물놀이 시설
# ================================================================================
#    감지된 업종: b2_leisure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1182 chars (~174 words)
# ================================================================================
#
# 한글 입력: "리조트 워터파크, 신나는 물놀이 시설"
#
# 대조군 A: "Imagine a vibrant resort water park filled with excitement and joy. The scene is set under a bright blue sky with fluffy white clouds, casting playful shadows on the glistening water. In the foreground, a large, colorful water slide spirals down into a sparkling pool where families and children splash joyfully. Surrounding the pool, lush tropical palm trees sway gently in the warm breeze, adding to the vacation vibe. Children are seen laughing and playing with inflatable toys, and a group of fri..."
#
# 실험군 B: "Resort waterpark filled with guests enjoying exciting water-play attractions, captured as a cinematic wide-angle interior scene that emphasizes scale and motion. Shot on a full-frame camera with a 24mm lens from a slightly elevated low angle to show the high vaulted ceiling and sweeping panoramic layout, the frame features twisting water slides, splash pads, a lazy river, and multi-level play structures with children and adults mid-action, laughing and splashing. Warm golden-hour sunlight stream..."
#
# 📏 길이 비교: A=149단어, B=174단어
#
# [21/60] B-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 수영장 회원 모집, 성인 수영 강습
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1117 chars (~171 words)
#    Text Overlay: {'product_name': '수영장 회원 모집', 'tagline': '성인 수영 강습'}
# ================================================================================
#
# 한글 입력: "수영장 회원 모집, 성인 수영 강습"
#
# 대조군 A: "A vibrant and inviting scene at a modern swimming pool, showcasing a diverse group of adults engaged in a swimming lesson. The setting is a bright, sunny day with sunlight streaming through large glass windows, casting shimmering reflections on the water's surface. The pool is surrounded by lush greenery and colorful poolside loungers, creating a relaxed atmosphere. In the foreground, an enthusiastic instructor demonstrates swimming techniques to attentive students in the water, while others pra..."
#
# 실험군 B: "Adult swimming lesson class with a diverse group of adults practicing technique under a focused instructor, captured mid-action as a swimmer executes a clean freestyle stroke and droplets arc from the hand. Shot like a commercial sports photograph on a Canon EOS R5 with a 35mm f/1.8 lens, high shutter speed to freeze splash detail and a moderate aperture to separate the foreground swimmer from a softly blurred background. Bright natural daylight filters through high windows and overhead studio f..."
#
# 📏 길이 비교: A=125단어, B=171단어
#
# [22/60] B-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 골프 연습장, 실내 스크린 골프 시설
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1124 chars (~173 words)
# ================================================================================
#
# 한글 입력: "골프 연습장, 실내 스크린 골프 시설"
#
# 대조군 A: "A modern indoor golf practice facility, featuring state-of-the-art screen golf technology. The scene showcases a spacious, well-lit area with multiple golf simulators, where players are engaged in practice swings. The walls are adorned with large screens displaying picturesque golf courses and vibrant green landscapes. Soft, ambient lighting creates a welcoming atmosphere, while spotlights highlight each simulator. The flooring is sleek and polished, reflecting the light and enhancing the contem..."
#
# 실험군 B: "Indoor screen golf practice facility composed as a wide-angle interior scene showing three training bays receding into depth, one bay occupied by a single golfer mid-swing. Shot on a full-frame camera with a 16–35mm f/2.8 lens from a slightly elevated three-quarter angle to emphasize the layout and depth, using fast shutter speed to freeze the club and a small amount of motion blur on the ball. Natural daylight from high clerestory windows mixes with warm 3000–4000K overhead pendant lights and s..."
#
# 📏 길이 비교: A=128단어, B=173단어
#
# [23/60] B-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 볼링장 이벤트, 단체 볼링 대회
# ================================================================================
#    감지된 업종: b3_sports
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1163 chars (~173 words)
#    Text Overlay: {'event_name': '단체 볼링 대회', 'tagline': '볼링장 이벤트'}
# ================================================================================
#
# 한글 입력: "볼링장 이벤트, 단체 볼링 대회"
#
# 대조군 A: "A vibrant bowling alley filled with energy, showcasing a group bowling tournament. The scene is bustling with participants of various ages and backgrounds, all wearing colorful team shirts, cheering and celebrating each other's strikes and spares. The wooden lanes gleam under the bright neon lights that illuminate the space, creating a lively and festive atmosphere. In the background, we see a large digital scoreboard displaying scores, while spectators gather near the sides, clapping and enjoyi..."
#
# 실험군 B: "A group bowling tournament event with multiple teams competing, captured as a wide, dynamic venue shot showing players in mid-action delivering shots down several lanes. Shot on a full-frame mirrorless camera with a 24mm wide-angle lens to emphasize depth and leading lines of the polished maple lanes, moderate aperture to keep foreground action sharp and background context readable. Bright, even overhead sports lighting fills the arena with clear, neutral tones while soft directional fill light ..."
#
# 📏 길이 비교: A=118단어, B=173단어
#
# [24/60] B-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 당구장 홍보, 프로 당구 레슨
# ================================================================================
#    감지된 업종: b3_sports
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1256 chars (~193 words)
#    Text Overlay: {'product_name': '프로 당구 레슨', 'tagline': '당구장 홍보'}
# ================================================================================
#
# 한글 입력: "당구장 홍보, 프로 당구 레슨"
#
# 대조군 A: "An inviting interior of a professional billiard hall, featuring several well-maintained pool tables with vibrant green felt. The setting is warmly lit with a mix of soft overhead lights and ambient light coming from stylish lamps hanging above each table. The walls are adorned with framed photographs of famous billiard players in action, adding a touch of history and prestige to the atmosphere. In the foreground, a skilled instructor is demonstrating a technique to an eager student, both focused..."
#
# 실험군 B: "Professional billiards instructor giving a hands-on lesson to a focused student beside a single pool table in a spacious, immaculate billiards hall. Shot on a Canon EOS R5 with a 24-70mm f/2.8 lens at a slightly wide 28mm focal length to capture both the coach and the depth of the facility, framed in a low three-quarter angle along the table rails to create strong leading lines. Bright even overhead sports lighting fills the room with neutral white tones while a soft side fill from LED panels sc..."
#
# 📏 길이 비교: A=157단어, B=193단어
#
# [25/60] B-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 테니스장 오픈, 실내 테니스 코트
# ================================================================================
#    감지된 업종: b3_sports
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1138 chars (~179 words)
# ================================================================================
#
# 한글 입력: "테니스장 오픈, 실내 테니스 코트"
#
# 대조군 A: "A vibrant indoor tennis court, showcasing a fresh and inviting atmosphere. The court is surrounded by bright white walls with large windows allowing natural light to pour in, illuminating the polished wooden floor. In the foreground, two tennis players are engaged in an enthusiastic match, their movements dynamic and full of energy. One player, wearing a bright blue sports outfit, serves the ball with precision, while the other, dressed in a contrasting red outfit, prepares to return the shot. N..."
#
# 실험군 B: "Brand-new indoor tennis court at a grand opening, shown in a wide, dynamic overview with one court in the foreground and additional courts receding into the background. Shot like a professional sports venue photograph on a Canon EOS R5 with a 24mm lens from a slightly elevated baseline angle to emphasize depth and leading lines. Even overhead LED sports lighting bathes the scene in bright, neutral light with soft, minimal shadows and crisp highlights on the playing surface. The court surface is ..."
#
# 📏 길이 비교: A=161단어, B=179단어
#
# [26/60] B-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 탁구장 클럽, 동호인 리그전
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1162 chars (~180 words)
# ================================================================================
#
# 한글 입력: "탁구장 클럽, 동호인 리그전"
#
# 대조군 A: "Imagine a vibrant indoor table tennis club bustling with energy, where players of all ages and skill levels are engaged in a friendly league competition. The scene is filled with dynamic movement as players in colorful sports attire are mid-swing, their expressions a mix of focus and determination. The tables are arranged in a spacious hall, illuminated by bright overhead lights that create a lively and competitive atmosphere. The walls are adorned with motivational sports posters, and the sound..."
#
# 실험군 B: "An indoor table tennis club hosting an amateur league match viewed from a high overhead angle, several tables arranged in neat rows with players engaged in mid-play. Shot like a professional sports photograph on a full-frame camera with a wide 24mm lens, natural daylight from high windows mixes with warm overhead gym lights to create soft highlights and gentle shadows across the scene. The central table is crisply focused with the white ball frozen mid-air above the glossy blue surface while pad..."
#
# 📏 길이 비교: A=147단어, B=180단어
#
# [27/60] B-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 풋살장 대관, 최신 인조잔디 구장
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1092 chars (~171 words)
# ================================================================================
#
# 한글 입력: "풋살장 대관, 최신 인조잔디 구장"
#
# 대조군 A: "A vibrant futsal court set in an outdoor environment, showcasing the latest artificial turf technology. The scene depicts a well-maintained, bright green playing surface with realistic texture, surrounded by a modern perimeter fence. In the background, there are tall, leafy trees and a clear blue sky, creating a lively atmosphere. The sunlight casts gentle shadows on the turf, emphasizing its pristine condition. Players in colorful sports gear can be seen practicing, their movements dynamic and ..."
#
# 실험군 B: "Modern futsal field with brand-new artificial turf seen from a slightly elevated wide-angle perspective, showcasing the full rectangular pitch, crisp white lines, goal areas and corner arcs, ready for rental use. Shot like a professional facility photo on a Canon EOS R5 with a 16-35mm f/2.8 lens at around 24mm from roughly 6 meters above the center, daylight with soft cloud diffusion to avoid harsh shadows. The image emphasizes texture and cleanliness: individual synthetic grass blades and dark ..."
#
# 📏 길이 비교: A=119단어, B=171단어
#
# [28/60] B-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 배드민턴장, 동호회 대관 안내
# ================================================================================
#    감지된 업종: s2_freshness
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1042 chars (~158 words)
#    Text Overlay: {'product_name': '배드민턴장', 'event_name': '동호회 대관 안내'}
# ================================================================================
#
# 한글 입력: "배드민턴장, 동호회 대관 안내"
#
# 대조군 A: "A vibrant indoor badminton court bustling with energy, featuring bright fluorescent lighting that casts a clear glow over the polished wooden floor. In the foreground, a diverse group of enthusiastic players, both men and women of various ages, are engaged in a lively game of badminton, their athletic wear colorful and dynamic. The players are caught mid-action, with shuttlecocks flying through the air, and expressions of concentration and joy on their faces. In the background, large windows all..."
#
# 실험군 B: "Badminton court prepared for a community club reservation, seen from a top-down overhead perspective showing two adjacent courts and a central aisle. Shot like a high-resolution commercial photograph on a Sony A7R IV with a wide 24mm lens mounted overhead, even sharp focus across the frame and deep depth of field. Natural daylight streams through high windows combined with bright studio fill lights to create cool, fresh color temperature and crisp soft shadows. The polished maple wood floor show..."
#
# 📏 길이 비교: A=149단어, B=158단어
#
# [29/60] B-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 클라이밍 센터, 초보자 볼더링 체험
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1042 chars (~164 words)
# ================================================================================
#
# 한글 입력: "클라이밍 센터, 초보자 볼더링 체험"
#
# 대조군 A: "A vibrant indoor climbing center bustling with activity, featuring a variety of colorful bouldering walls designed for beginners. The setting is filled with bright, ambient lighting that highlights the textured surfaces of the climbing walls, showcasing a range of grips in various shapes and sizes. In the foreground, a group of enthusiastic newcomers, dressed in comfortable athletic wear, are engaged in a bouldering session, some attempting to scale the walls while others cheer them on from belo..."
#
# 실험군 B: "A beginner bouldering class at an indoor climbing center, an instructor crouched on a crash pad demonstrating precise foot placement while a novice climber reaches for a brightly colored hold a few feet above, two other beginners watching and preparing their chalk. Shot on a full-frame camera with a 24mm wide lens to capture the airy interior, natural daylight streaming from high windows on the left mixed with warm overhead LEDs to create soft directional highlights and gentle shadows. The scene..."
#
# 📏 길이 비교: A=146단어, B=164단어
#
# [30/60] B-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 스쿼시장 신규 오픈, 1:1 레슨
# ================================================================================
#    감지된 업종: b3_sports
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1275 chars (~196 words)
#    Text Overlay: {'event_name': '스쿼시장 신규 오픈', 'tagline': '1:1 레슨'}
# ================================================================================
#
# 한글 입력: "스쿼시장 신규 오픈, 1:1 레슨"
#
# 대조군 A: "An inviting, modern squash court interior bustling with energy, showcasing a newly opened facility. The setting features sleek glass walls and polished wooden floors, reflecting bright overhead lights that create a vibrant atmosphere. In the foreground, a dedicated instructor is engaging with a student during a one-on-one lesson, demonstrating the correct grip of the squash racket. The instructor is wearing a sporty outfit, exuding enthusiasm and expertise, while the student, dressed in comforta..."
#
# ...
#    감지된 업종: b3_sports
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1129 chars (~176 words)
#    Text Overlay: {'product_name': '자동차 정비소', 'event_name': '엔진오일 교환 이벤트'}
# ================================================================================
#
# 한글 입력: "자동차 정비소, 엔진오일 교환 이벤트"
#
# 대조군 A: "A bustling automobile repair shop during a bright and sunny day, showcasing a vibrant scene of mechanics at work. In the foreground, a skilled mechanic is focused on changing the engine oil of a sleek, modern car, with oil cans and tools neatly arranged around him. The shop is filled with various vehicles in different stages of repair, highlighting the busy atmosphere. Sunlight streams through the large windows, casting warm, inviting light onto the shiny surfaces of the cars and the organized c..."
#
# 실험군 B: "A modern automotive repair shop hosting an engine oil change event, captured from a dynamic wide-angle viewpoint that emphasizes spaciousness and activity. Shot on a full-frame camera with a 24mm lens at f/4 to keep the service bays in clear focus, the composition shows two hydraulic lifts, a technician pouring fresh engine oil from a clean plastic jug into an open engine bay while another mechanic drains oil into a catch pan. Bright overhead LED panels provide even, clinical illumination with s..."
#
# 📏 길이 비교: A=148단어, B=176단어
#
# [52/60] C-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 세차장 홍보, 프리미엄 손세차 서비스
# ================================================================================
#    감지된 업종: c3_technical
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1226 chars (~189 words)
#    Text Overlay: {'product_name': '세차장', 'tagline': '프리미엄 손세차 서비스'}
# ================================================================================
#
# 한글 입력: "세차장 홍보, 프리미엄 손세차 서비스"
#
# 대조군 A: "A luxurious car wash setting showcasing a premium hand car wash service. The scene features a sleek, shiny sports car parked in the foreground, droplets of water glistening on its surface under bright, natural sunlight. Surrounding the car, skilled attendants in crisp uniforms are meticulously washing and detailing the vehicle, using high-quality cleaning products and tools. The backdrop is a modern car wash facility with large glass windows, allowing sunlight to flood the space, creating a warm..."
#
# 실험군 B: "Premium hand car wash service scene showing a uniformed technician performing a meticulous hand wash on a dark blue luxury sedan, captured in a three-quarter front view with a subtle split composition for before-and-after comparison. The left side of the frame shows the car before cleaning with light water spots and dull finish, while the right side reveals a mirror-like glossy finish as the technician gently buffs the panel with a plush microfiber towel and soft foam mitt. Shot like professiona..."
#
# 📏 길이 비교: A=114단어, B=189단어
#
# [53/60] C-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 인테리어 업체, 아파트 리모델링 시공
# ================================================================================
#    감지된 업종: a3_fashion
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1214 chars (~173 words)
# ================================================================================
#
# 한글 입력: "인테리어 업체, 아파트 리모델링 시공"
#
# 대조군 A: "A beautifully remodeled apartment interior showcasing modern design elements. The scene captures a spacious living room with large windows allowing natural light to flood in, highlighting the sleek, minimalist furniture arrangement. The walls are painted in soft, neutral tones, complemented by accent pieces in vibrant colors. A stylish, contemporary sofa is positioned around a chic coffee table, adorned with decorative items such as candles and a small plant. To the left, a cozy reading nook fea..."
#
# 실험군 B: "Newly remodeled apartment living room and open kitchen staged by an interior renovation company, photographed to highlight craftsmanship and material quality. Shot on a full-frame camera with a wide 24mm lens at f/4 to capture a three-quarter view of the space, the composition centers on a handcrafted oak kitchen island and a mid-century modern sofa where a designer casually reviews blueprints, giving human scale. Natural daylight pours through large floor-to-ceiling windows from the left, compl..."
#
# 📏 길이 비교: A=150단어, B=173단어
#
# [54/60] C-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 이사업체 안내, 원룸 포장이사 서비스
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1220 chars (~181 words)
#    Text Overlay: {'product_name': '원룸 포장이사 서비스', 'tagline': '이사업체 안내'}
# ================================================================================
#
# 한글 입력: "이사업체 안내, 원룸 포장이사 서비스"
#
# 대조군 A: "A cozy, well-decorated one-room apartment in the process of being packed for a move. The room is filled with various moving boxes, some stacked neatly while others are partially open, revealing items like clothes, books, and kitchenware. A friendly moving team, dressed in uniforms, is carefully wrapping a delicate lamp in bubble wrap, showcasing their professionalism. Soft, warm lighting filters through a window, casting gentle shadows and creating a welcoming atmosphere. The walls are adorned w..."
#
# 실험군 B: "Studio one-room apartment packing and moving service in action, professional movers carefully packing and organizing a small urban apartment for relocation. Shot like a commercial documentary photograph on a Canon EOS R5 with a 35mm f/1.4 lens, slightly elevated three-quarter angle to show both people and neatly arranged boxes across the living area. Warm overhead home lighting mixes with natural daylight spilling from a nearby window to create soft directional highlights and gentle shadows. The..."
#
# 📏 길이 비교: A=135단어, B=181단어
#
# [55/60] C-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 에어컨 청소, 분해 완전 세척 서비스
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1157 chars (~179 words)
# ================================================================================
#
# 한글 입력: "에어컨 청소, 분해 완전 세척 서비스"
#
# 대조군 A: "An indoor scene showcasing a professional air conditioning cleaning service in action. The focus is on a technician wearing a clean uniform, carefully disassembling an air conditioning unit. The setting is a modern living room with bright, natural light streaming in through a large window, illuminating the dust particles in the air. The air conditioner parts are neatly arranged on a clean, white cloth, revealing the intricate components such as the coils and filters. The technician has a focused..."
#
# 실험군 B: "Disassembled air conditioner components for a professional complete-clean service, neatly arranged in a top-down flat lay on a bright white tiled countertop to emphasize cleanliness. Shot on a Canon EOS R5 with a 50mm lens from directly above, medium depth of field so the central filter and coil are razor sharp while the edges have soft falloff. Warm overhead household light mixes with cool daylight from a nearby window to create natural, soft highlights and gentle shadows. The scene shows one s..."
#
# 📏 길이 비교: A=124단어, B=179단어
#
# [56/60] C-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 방역 소독 업체, 바퀴벌레 퇴치 서비스
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1295 chars (~198 words)
# ================================================================================
#
# 한글 입력: "방역 소독 업체, 바퀴벌레 퇴치 서비스"
#
# 대조군 A: "A professional pest control service in action, showcasing a technician in a clean, white uniform using a high-tech spray device to eliminate cockroaches in a modern kitchen. The setting is a bright, well-lit kitchen with stainless steel appliances and a tiled backsplash, emphasizing cleanliness and hygiene. The technician, wearing gloves and a mask, is focused and determined, highlighting the seriousness of the pest problem. Sunlight streams in through a window, casting soft shadows and creating..."
#
# 실험군 B: "A professional pest control technician in a white protective coverall and full-face respirator kneels at the baseboard of a modern residential kitchen, carefully applying cockroach treatment with a stainless steel handheld pump sprayer. Shot on a Canon EOS R5 with a 35mm f/1.8 lens from a low three-quarter angle, natural daylight streaming through a nearby window is balanced by warm overhead kitchen lighting to create soft highlights and gentle shadows. The composition centers on the action: a c..."
#
# 📏 길이 비교: A=111단어, B=198단어
#
# [57/60] C-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 조경 관리, 아파트 단지 정원 가꾸기
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1264 chars (~185 words)
# ================================================================================
#
# 한글 입력: "조경 관리, 아파트 단지 정원 가꾸기"
#
# 대조군 A: "A serene apartment complex garden meticulously maintained, showcasing a vibrant landscape filled with colorful flowers, lush green shrubs, and neatly manicured grass. The scene is set during a sunny day with soft, golden sunlight filtering through the leaves of tall trees, casting gentle shadows on the ground. Pathways made of smooth stones wind through the garden, bordered by blooming flower beds that burst with colors of red, yellow, and purple. In the background, the modern architecture of th..."
#
# 실험군 B: "Apartment complex garden maintenance team tending and pruning raised flower beds and container gardens, workers in breathable workwear kneeling and using hand pruners and a wheelbarrow while one operator trims hedges with a cordless hedge trimmer; composition is an overhead to slightly oblique view that captures the geometric arrangement of pathways, raised planters, decorative gravel, and small lawn patches. Shot like a professional environmental photograph with a DJI Mavic 3 style high-resolut..."
#
# 📏 길이 비교: A=148단어, B=185단어
#
# [58/60] C-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 간판 제작소, LED 채널 간판 시공
# ================================================================================
#    감지된 업종: c3_technical
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1383 chars (~206 words)
# ================================================================================
#
# 한글 입력: "간판 제작소, LED 채널 간판 시공"
#
# 대조군 A: "A bustling sign-making workshop showcasing a variety of LED channel signs in various shapes and sizes. The setting is filled with bright, vibrant colors, with several signs glowing dynamically in the warm light of the workshop. A skilled technician is meticulously assembling a large LED channel sign, surrounded by tools and materials like metal frames, colorful acrylic sheets, and illuminated components. The atmosphere is lively and energetic, with beams of natural light streaming through large ..."
#
# 실험군 B: "A LED channel sign installation in progress inside a professional sign-making workshop, a skilled technician in protective gloves is fastening LED modules into an aluminum channel letter while a completed, unbranded channel sign with frosted acrylic face is mounted on a neutral wall for a clear before-and-after comparison. Shot on a Canon EOS R5 with a 50mm macro lens at f/8 for crisp detail across the frame, balanced exposure and high resolution suited for technical documentation. Bright overhe..."
#
# 📏 길이 비교: A=115단어, B=206단어
#
# [59/60] C-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 타일 시공 전문, 욕실 리모델링
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1166 chars (~172 words)
# ================================================================================
#
# 한글 입력: "타일 시공 전문, 욕실 리모델링"
#
# 대조군 A: "A beautifully renovated bathroom showcasing expert tile installation. The scene features elegant, glossy ceramic tiles in shades of soft blue and white, creating a serene and modern atmosphere. Natural light streams in through a frosted glass window, casting gentle reflections on the tiled surfaces. The focal point is a luxurious freestanding bathtub, surrounded by stylish potted plants that add a touch of greenery. A sleek, contemporary vanity with a large mirror reflects the harmonious design,..."
#
# 실험군 B: "Bathroom remodeling showcasing professional tile installation in a freshly renovated bathroom, captured in a slightly elevated three-quarter view that emphasizes the newly laid wall and floor tiles. Shot on a Canon EOS R5 with a 24-70mm f/2.8 lens at 35mm, aperture f/4 to keep foreground details crisp while creating a gentle background separation. Warm overhead pendant light softly illuminates the space while natural daylight filters through a frosted window, producing soft ambient shadows and r..."
#
# 📏 길이 비교: A=121단어, B=172단어
#
# [60/60] C-3
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 도배/장판 업체, 벽지 시공 견적 안내
# ================================================================================
#    감지된 업종: d1_equipment
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1175 chars (~170 words)
# ================================================================================
#
# 한글 입력: "도배/장판 업체, 벽지 시공 견적 안내"
#
# 대조군 A: "A modern interior scene showcasing a professional wallpaper and flooring installation company at work. The setting is a bright, well-lit living room featuring freshly painted walls adorned with elegant wallpaper patterns, showcasing various textures and colors. To one side, a skilled installer is meticulously applying the wallpaper, using a smoothing tool to ensure a seamless finish. The floor features a stylish laminate or vinyl flooring that complements the wallpaper, reflecting natural light ..."
#
# 실험군 B: "A professional wallpaper and flooring contractor arranging wallpaper sample boards and vinyl plank samples on a clean wooden workbench for a client estimate, hands positioning a textured wallpaper sample over a coordinating vinyl plank to compare patterns and colors. Shot on a Canon EOS R5 with a 50mm macro lens at f/4, 1/125s, ISO 100, tripod-stable commercial product photography style. Bright warehouse fluorescent overhead combined with a softbox fill from the left creates crisp high-contrast ..."
#
# 📏 길이 비교: A=114단어, B=170단어
#
#
# ====================================================================================================
# 📈 B+C등급 (공간 체험/교육 + 신뢰 기반 서비스) 요약 통계
# ====================================================================================================
# 테스트 케이스 수: 60
# 대조군 A 평균 길이: 134.2 단어
# 실험군 B 평균 길이: 182.5 단어

# %% [markdown]
# ### 3.4 D+E등급 테스트 (목적형 소매 + 인프라)

# %%
# D+E등급 A/B 테스트 실행
de_grade_results = run_ab_test(DE_GRADE_TEST_CASES, "D+E등급 (목적형 소매 + 인프라)")
# Out:
# ====================================================================================================
# 📊 D+E등급 (목적형 소매 + 인프라) A/B 테스트 결과
# ====================================================================================================
#
#
# [1/30] D-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 타이어 전문점, 사계절 타이어 할인
# ================================================================================
#    감지된 업종: d1_equipment
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1178 chars (~179 words)
#    Text Overlay: {'product_name': '사계절 타이어', 'event_name': '사계절 타이어 할인'}
# ================================================================================
#
# 한글 입력: "타이어 전문점, 사계절 타이어 할인"
#
# 대조군 A: "A bustling tire specialty shop during a vibrant autumn day, showcasing a wide variety of all-season tires prominently displayed around the entrance. The shop is adorned with colorful banners indicating seasonal discounts, and the bright sunlight filters through the trees, casting playful shadows on the pavement. In the foreground, a friendly salesperson, wearing a branded uniform, is demonstrating the features of a tire to an interested customer who is examining it closely. Surrounding the shop ..."
#
# 실험군 B: "All-season tires arranged on industrial steel racks and on a low display platform, a three-quarter view with one tire in the foreground turned slightly to show detailed tread pattern and sidewall curvature. Shot as a commercial product catalog image on a Canon EOS R5 with a 100mm macro lens at f/8, ISO 100, tripod-mounted for razor-sharp detail and even focus across the rack. Bright overhead fluorescent warehouse lighting combined with focused softbox fill from the side creates high-contrast hig..."
#
# 📏 길이 비교: A=131단어, B=179단어
#
# [2/30] D-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 자동차 부품점, 순정 브레이크 패드
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1075 chars (~174 words)
#    Text Overlay: {'product_name': '순정 브레이크 패드'}
# ================================================================================
#
# 한글 입력: "자동차 부품점, 순정 브레이크 패드"
#
# 대조군 A: "A bustling auto parts store filled with an array of automotive components, prominently featuring an organized display of genuine brake pads. The setting is well-lit with bright overhead lights that illuminate the shiny surfaces of the parts. Shelves are stocked with various car parts, creating a sense of depth and variety. In the foreground, a close-up view showcases a selection of high-quality brake pads, each with distinct textures and colors, placed on a polished wooden counter. The atmospher..."
#
# 실험군 B: "OEM brake pads displayed in a tidy automotive parts store, top-down flat lay showing multiple sets neatly arranged in rows on a clean wooden workbench. The central composition features one open plain cardboard box with two new brake pads facing each other, a single pad rotated to reveal the granular friction surface and chamfered edge, and a backing plate showing matte painted texture and subtle machining marks. Shot on a Canon EOS R5 with a 50mm f/2.8 macro lens, soft overhead warm LED and diff..."
#
# 📏 길이 비교: A=134단어, B=174단어
#
# [3/30] D-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 철물점 홍보, 공구 세트 특가 판매
# ================================================================================
#    감지된 업종: d1_equipment
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1118 chars (~174 words)
#    Text Overlay: {'product_name': '공구 세트', 'tagline': '특가 판매', 'event_name': '철물점 홍보'}
# ================================================================================
#
# 한글 입력: "철물점 홍보, 공구 세트 특가 판매"
#
# 대조군 A: "A vibrant hardware store interior showcasing a special sale on a wide variety of tool sets. The scene is bustling with customers exploring the aisles filled with bright and colorful tool displays. The lighting is warm and inviting, casting soft shadows that highlight the metallic surfaces of various tools. On the shelves, there are neatly arranged tool sets, featuring wrenches, screwdrivers, and power tools, all gleaming under the spotlight. In the background, a friendly store clerk is assisting..."
#
# 실험군 B: "A professional tool set displayed in an open foam-lined case on a sturdy wooden workbench, positioned front and center to showcase each piece clearly. Shot on a Canon EOS R5 with a 50mm macro lens at f/8 for sharp product detail and even depth of field, the composition resembles a commercial catalog image with the case angled slightly to reveal organized rows of wrenches, sockets, pliers, screwdrivers, and a compact cordless drill. Bright warehouse fluorescent overhead light is combined with two..."
#
# 📏 길이 비교: A=123단어, B=174단어
#
# [4/30] D-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 건축자재 판매, 시멘트/벽돌 도매
# ================================================================================
#    감지된 업종: c3_technical
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1313 chars (~192 words)
# ================================================================================
#
# 한글 입력: "건축자재 판매, 시멘트/벽돌 도매"
#
# 대조군 A: "Imagine a bustling construction supply warehouse filled with various building materials. The scene includes towering stacks of bags of cement, neatly arranged bricks in vibrant colors, and a variety of tools and equipment scattered throughout the space. Sunlight streams through large windows, casting warm, golden rays that illuminate the dust particles dancing in the air, creating a dynamic atmosphere. On one side, a team of workers in hard hats and safety vests are discussing plans, surrounded ..."
#
# 실험군 B: "Wholesale construction materials warehouse featuring stacked bags of cement and neatly palletized red clay bricks being inspected and loaded by workers, a sales representative gesturing toward product specs while a forklift carefully places a pallet in the background. Shot on a Canon EOS R5 with a 35mm f/1.4 for a wide documentary frame and an 85mm f/1.8 for close-up detail shots, commercial photographic style with high resolution and crisp clarity. Bright, even industrial LED overhead lighting ..."
#
# 📏 길이 비교: A=147단어, B=192단어
#
# [5/30] D-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 전기용품 가게, LED 조명 설치
# ================================================================================
#    감지된 업종: d1_equipment
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1098 chars (~162 words)
# ================================================================================
#
# 한글 입력: "전기용품 가게, LED 조명 설치"
#
# 대조군 A: "A modern electric appliance store interior, showcasing a variety of LED lighting installations. The setting features sleek, contemporary shelves filled with different types of LED bulbs, strips, and fixtures, all glowing softly with vibrant colors. Bright white light illuminates the space, creating a clean and inviting atmosphere. Customers are seen examining the products, with some engaging with friendly staff members who are demonstrating the latest lighting technology. The walls are adorned w..."
#
# 실험군 B: "A store electrician on a ladder installing a slim rectangular LED panel in the ceiling of a well-organized electrical appliance shop, captured as a commercial documentation shot. Shot on a Canon EOS R5 with a 24mm lens at f/5.6, ISO 200, 1/125s, HDR merge to preserve bright LED highlights and deep shelf shadows. The scene shows the installer in mid-action tightening a metal bracket while the newly installed LED emits cool, even white light that contrasts with the existing warmer showroom fixture..."
#
# 📏 길이 비교: A=121단어, B=162단어
#
# [6/30] D-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 중장비 대여, 굴삭기 렌탈 서비스
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1211 chars (~179 words)
# ================================================================================
#
# 한글 입력: "중장비 대여, 굴삭기 렌탈 서비스"
#
# 대조군 A: "A vibrant construction site bustling with activity, showcasing a variety of heavy machinery for rent. In the foreground, a large, bright yellow excavator is digging into the earth, its arm raised high, with dirt flying around as it works. Surrounding the excavator are other types of machinery, such as bulldozers and cranes, all gleaming under the afternoon sun. The setting includes a backdrop of tall construction fences and scattered piles of gravel and materials. Soft shadows are cast by the ma..."
#
# 실험군 B: "Aerial top-down view of multiple excavators neatly arranged in a rental equipment yard, each machine facing the same direction as if prepared for immediate dispatch, a technician in a high-visibility vest walking between them for scale and action. Shot like a professional commercial photograph from a high-resolution drone with a wide 24mm-equivalent perspective and a slightly tilted top-down angle to reveal profiles and footprints, the scene captured in warm early-morning sunlight with soft, dif..."
#
# 📏 길이 비교: A=138단어, B=179단어
#
# [7/30] D-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 바닥재 전문, 마루/장판 시공
# ================================================================================
#    감지된 업종: d1_equipment
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1242 chars (~177 words)
# ================================================================================
#
# 한글 입력: "바닥재 전문, 마루/장판 시공"
#
# 대조군 A: "A cozy interior scene showcasing a beautifully finished wooden floor installation in a modern living room. The room is bathed in warm, natural light streaming through large windows, highlighting the rich textures and grains of the wooden floor. A plush area rug is strategically placed, complementing the floor while adding a touch of comfort. Stylish furniture, including a sleek sofa and a contemporary coffee table, is arranged invitingly around the space. Potted plants add a touch of greenery, e..."
#
# 실험군 B: "Flooring installation scene showing skilled craftsmen fitting engineered wood planks and luxury vinyl tiles across a clean commercial showroom floor, captured as a single composed product-focused shot. Shot on a Canon EOS R5 with a 50mm lens, medium aperture for a balanced depth of field so the foreground plank details are razor-sharp while the mid-ground installers remain clear, tripod-mounted for precise framing. Bright overhead LED panel and softbox fill light create crisp directional highlig..."
#
# 📏 길이 비교: A=134단어, B=177단어
#
# [8/30] D-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 의료기기 판매, 혈압계/체온계 세트
# ================================================================================
#    감지된 업종: d1_equipment
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1211 chars (~180 words)
# ================================================================================
#
# 한글 입력: "의료기기 판매, 혈압계/체온계 세트"
#
# 대조군 A: "A modern medical device showroom featuring a sleek display of a blood pressure monitor and a digital thermometer set. The setting is well-lit, with bright, soft lighting that enhances the clean, clinical atmosphere. The blood pressure monitor is elegantly designed, showcasing a large, easy-to-read digital screen and a stylish cuff, while the thermometer is compact and high-tech, with a smooth, ergonomic shape. The background includes polished wooden shelves filled with various other medical gadg..."
#
# 실험군 B: "Blood pressure monitor and digital thermometer set arranged as a professional product catalog composition, the blood pressure unit placed frontal three-quarter with cuff neatly coiled to the side and the compact digital thermometer angled slightly forward. Shot on a Canon EOS R5 with a 100mm macro lens at f/11 to keep both devices razor-sharp, studio strobes with softboxes above and a focused rim light from the left create crisp highlights on plastic and brushed metal surfaces, while subtle fill..."
#
# 📏 길이 비교: A=134단어, B=180단어
#
# [9/30] D-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 중고 물품점, 가전제품 매입/판매
# ================================================================================
#    감지된 업종: d2_appliances
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1123 chars (~169 words)
# ================================================================================
#
# 한글 입력: "중고 물품점, 가전제품 매입/판매"
#
# 대조군 A: "An inviting second-hand store filled with a variety of used electronics. The scene is set inside a cozy, well-lit shop with warm wooden shelves displaying an array of appliances, including vintage radios, modern televisions, and kitchen gadgets. Sunlight filters through large windows, casting soft shadows and creating a friendly atmosphere. There are colorful price tags dangling from each item, adding a touch of vibrancy to the space. A friendly shopkeeper, dressed in casual attire, stands behin..."
#
# 실험군 B: "A clean, professional product display of gently used household appliances arranged for buy-and-sell evaluation, front-facing and slightly staggered to show depth and different silhouettes. Shot on a Canon EOS R5 with an 85mm lens set around f/8, low ISO 100 and 1/125s to achieve crisp commercial clarity. The scene is a high-key studio setup on seamless white paper with a large softbox overhead and two soft side fill lights creating even, bright illumination and soft, controlled reflections on gl..."
#
# 📏 길이 비교: A=158단어, B=169단어
#
# [10/30] D-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 사료 전문점, 반려동물 사료 할인
# ================================================================================
#    감지된 업종: d1_equipment
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1191 chars (~173 words)
#    Text Overlay: {'product_name': '반려동물 사료', 'tagline': '사료 전문점', 'discount': '할인'}
# ================================================================================
#
# 한글 입력: "사료 전문점, 반려동물 사료 할인"
#
# 대조군 A: "A cozy pet food store interior, filled with colorful bags of various pet foods lining the wooden shelves. The setting is warmly lit with soft, ambient lights creating a welcoming atmosphere. In the foreground, a friendly store clerk is happily assisting a customer, who is holding a bag of dog food, while a cheerful golden retriever eagerly waits beside them. The walls are decorated with playful pet-themed artwork and promotional posters showcasing discounts on pet food. Near the entrance, a vibr..."
#
# 실험군 B: "A neatly organized display of pet food bags and cans on industrial metal shelving in a specialty pet food store, photographed as a commercial catalog-style shot to emphasize a promotional discount. Shot on a Canon EOS R5 with a 50mm lens at moderate aperture to keep the entire shelf plane crisp, camera slightly below eye level for a confident retail perspective. Bright overhead fluorescent warehouse lighting combined with clean commercial display spotlights creates high contrast highlights on me..."
#
# 📏 길이 비교: A=114단어, B=173단어
#
# [11/30] D-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 핸드폰 매장, 최신 스마트폰 개통
# ================================================================================
#    감지된 업종: d2_appliances
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1176 chars (~170 words)
# ================================================================================
#
# 한글 입력: "핸드폰 매장, 최신 스마트폰 개통"
#
# 대조군 A: "A modern mobile phone store interior, showcasing the latest smartphones on sleek display tables. The setting is vibrant and bustling with activity, featuring a diverse group of customers exploring various high-tech devices. Bright, overhead LED lights illuminate the space, casting a warm glow on the polished surfaces of the phones. The walls are adorned with colorful posters of new smartphone models, emphasizing their cutting-edge features. In one corner, a friendly sales associate is engaging w..."
#
# 실험군 B: "A mobile phone store salesperson handing a newly activated latest smartphone to a customer at a sleek service counter, front-facing product emphasis with the device slightly angled to reveal its thin metal frame and glass display. Shot as professional retail product photography on a Canon EOS R5 with 50mm lens, bright studio lighting from softboxes above and two LED rim lights creating crisp specular highlights on the glass and brushed metal edges. The scene is set against a seamless white backg..."
#
# 📏 길이 비교: A=130단어, B=170단어
#
# [12/30] D-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 컴퓨터 수리점, 노트북 SSD 업그레이드
# ================================================================================
#    감지된 업종: d2_appliances
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1110 chars (~171 words)
# ================================================================================
#
# 한글 입력: "컴퓨터 수리점, 노트북 SSD 업그레이드"
#
# 대조군 A: "A modern computer repair shop featuring a sleek, organized workspace. In the foreground, a technician is focused on upgrading a laptop's SSD, surrounded by an array of high-tech tools and components. The technician, a young Asian woman with glasses, has her hair tied back, showcasing a look of concentration as she carefully works with precision tools. The setting is illuminated by soft, warm lighting that gives the space a welcoming atmosphere. Behind her, shelves are filled with various compute..."
#
# 실험군 B: "Laptop undergoing an SSD upgrade at a professional computer repair workstation, shown in a clean, front-facing close-up where a technician's gloved hands are gently sliding an M.2 NVMe SSD into the open slot. Shot like commercial electronics photography on a Canon EOS R5 with an 85mm f/1.8 lens, the scene is framed three-quarter front so the laptop keyboard, open chassis, and SSD are all clearly visible. Bright, even studio lighting from a large softbox overhead with subtle side fill creates sof..."
#
# 📏 길이 비교: A=123단어, B=171단어
#
# [13/30] D-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 가전제품 매장, 에어컨 여름 특가
# ================================================================================
#    감지된 업종: d2_appliances
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1189 chars (~182 words)
#    Text Overlay: {'product_name': '에어컨', 'tagline': '여름 특가'}
# ================================================================================
#
# 한글 입력: "가전제품 매장, 에어컨 여름 특가"
#
# 대조군 A: "A bustling electronics store showcasing a summer promotion on air conditioning units. The scene is filled with various models of sleek, modern air conditioners displayed prominently on polished shelves. Bright, vibrant summer colors adorn the store, with banners and posters highlighting special offers and discounts. The interior is well-lit, with large windows allowing natural sunlight to stream in, creating a warm and inviting atmosphere. Customers of diverse backgrounds are seen interacting wi..."
#
# 실험군 B: "Air conditioner displayed as the main subject in a clean appliance store showroom, presented in a front-facing, slightly three-quarter angle on a white glossy pedestal to emphasize its form and vents. Shot like professional commercial product photography on a Canon EOS R5 with a 50mm lens, even bright studio lighting with large softboxes overhead and two rim lights to create crisp highlights along the edges and gentle soft shadows beneath the unit. The scene has a minimalist monochrome palette w..."
#
# 📏 길이 비교: A=150단어, B=182단어
#
# [14/30] D-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 복합기 임대, 사무실 프린터 렌탈
# ================================================================================
#    감지된 업종: d2_appliances
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1020 chars (~162 words)
# ================================================================================
#
# 한글 입력: "복합기 임대, 사무실 프린터 렌탈"
#
# 대조군 A: "A modern office setting showcasing a sleek multifunction printer in a well-organized workspace. The printer, with its glossy black and silver finish, is placed on a light wooden desk surrounded by essential office supplies like notepads, pens, and a laptop. The room is filled with natural light streaming in through large windows, casting soft shadows on the floor. In the background, there are shelves neatly lined with books and decorative plants that bring a touch of greenery to the environment...."
#
# 실험군 B: "A front-facing multifunction office printer placed centrally on a seamless white backdrop, photographed as a clean commercial product shot. The device is shown upright with the paper tray slightly open and a single crisp page emerging to reveal fine paper fiber texture but no printed words. Shot on a Canon EOS R5 with a 50mm lens at f/8 for full-device sharpness, the camera is positioned at chest height for a natural straight-on perspective. Bright, even three-point studio lighting with large so..."
#
# 📏 길이 비교: A=110단어, B=162단어
#
# [15/30] D-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 폰 수리 전문, 액정 교체 당일 수리
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1170 chars (~180 words)
#    Text Overlay: {'product_name': '폰 수리 전문', 'tagline': '액정 교체 당일 수리'}
# ================================================================================
#
# 한글 입력: "폰 수리 전문, 액정 교체 당일 수리"
#
# 대조군 A: "A modern smartphone repair shop bustling with activity, showcasing a technician working diligently on a sleek smartphone with a cracked screen. The setting is bright and welcoming, with large windows allowing natural light to flood in, illuminating the workspace filled with high-tech tools and colorful phone accessories. The technician, a young adult with focused expression, is wearing a professional uniform and using specialized equipment to carefully replace the phone's screen. On a nearby wor..."
#
# 실험군 B: "Phone repair specialist replacing a cracked smartphone screen for same-day service, captured in a clean, professional repair workstation with the technician's hands carefully removing the broken glass from the phone frame. Shot on a Canon EOS R5 with a 90mm macro lens, slightly overhead three-quarter angle to show both the device surface and the technician's focused movements, using a shallow depth of field to keep the phone and hands razor-sharp while the background tools gently fall into soft ..."
#
# 📏 길이 비교: A=126단어, B=180단어
#
# [16/30] D-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 렌터카 업체, 장기 렌트 프로모션
# ================================================================================
#    감지된 업종: b2_leisure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1211 chars (~184 words)
# ================================================================================
#
# 한글 입력: "렌터카 업체, 장기 렌트 프로모션"
#
# 대조군 A: "A sleek, modern rental car parked in a picturesque setting, showcasing the concept of long-term car rental. The car, a shiny silver sedan, is positioned on a scenic coastal road with gentle waves lapping against the shore in the background. The sun is setting, casting a warm golden hue over the landscape, creating a serene and inviting atmosphere. Lush green hills rise in the distance, while a few fluffy clouds drift across the vibrant sky. The scene conveys a sense of adventure and freedom, wit..."
#
# 실험군 B: "A premium car rental showroom scene focused on a long-term rental promotion, showing a lineup of three mid-size luxury SUVs angled toward the camera while a professional rental agent hands car keys to a smiling couple at a modern consultation desk. Shot on a full-frame camera with a 24mm lens for a cinematic wide interior perspective, the composition emphasizes the high ceiling and expansive glass walls that reveal a warm city skyline at golden hour. Soft overhead diffused lighting combines with..."
#
# 📏 길이 비교: A=131단어, B=184단어
#
# [17/30] D-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 인력사무소, 단기 아르바이트 모집
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1111 chars (~180 words)
# ================================================================================
#
# 한글 입력: "인력사무소, 단기 아르바이트 모집"
#
# 대조군 A: "A bustling urban scene depicting a modern job recruitment agency specializing in short-term part-time job placements. The setting features a sleek glass building with a bright, welcoming entrance adorned with greenery. Inside, a diverse group of young adults is engaged in conversations with friendly staff members, some sitting at a round table filled with colorful brochures about job opportunities. Sunlight streams through large windows, creating a warm and inviting atmosphere. On the walls, the..."
#
# 실험군 B: "An employment agency receptionist handing a clipboard with a short-term part-time job application form to a prospective applicant across a neat wooden desk, captured in a warm, welcoming moment. Shot on a Canon EOS R5 with a 35mm f/1.8 lens at f/2.2 to create a shallow depth of field that keeps the clipboard and hands sharply in focus while softly blurring the background. Overhead warm softbox light provides gentle, even illumination and natural daylight from a window at the left adds subtle sid..."
#
# 📏 길이 비교: A=122단어, B=180단어
#
# [18/30] D-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 냉장고 수리, 컴프레서 교체 서비스
# ================================================================================
#    감지된 업종: d2_appliances
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1151 chars (~173 words)
#    Text Overlay: {'product_name': '냉장고 수리', 'tagline': '컴프레서 교체 서비스'}
# ================================================================================
#
# 한글 입력: "냉장고 수리, 컴프레서 교체 서비스"
#
# 대조군 A: "A close-up view of a modern kitchen featuring a refrigerator being repaired. The scene captures a technician, wearing a blue uniform and safety gloves, focused on replacing a compressor. The refrigerator is sleek and stainless steel, with the door slightly ajar, revealing organized shelves filled with fresh produce and drinks. Soft, natural light filters in through a nearby window, illuminating the workspace and creating a warm, inviting atmosphere. Tools are neatly arranged on the counter, incl..."
#
# 실험군 B: "A refrigerator technician replacing a compressor in a clean commercial service scene, hands in blue nitrile gloves carefully aligning a new compact compressor into the rear compartment of a modern white refrigerator with the back panel removed. Shot on a Canon EOS R5 with a 50mm lens at f/8 to keep the appliance and compressor sharply rendered, studio softboxes placed at 45-degree angles and a large overhead diffuser provide bright, even illumination that eliminates harsh shadows while preservin..."
#
# 📏 길이 비교: A=126단어, B=173단어
#
# [19/30] D-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 노트북 판매, 학생 할인 프로모션
# ================================================================================
#    감지된 업종: d1_equipment
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1163 chars (~173 words)
#    Text Overlay: {'product_name': '노트북', 'tagline': '학생 할인 프로모션'}
# ================================================================================
#
# 한글 입력: "노트북 판매, 학생 할인 프로모션"
#
# 대조군 A: "A vibrant and modern electronics store showcasing a wide array of sleek laptops arranged neatly on wooden tables. The setting is bright and inviting, illuminated by warm overhead lights that highlight the shiny surfaces of the devices. In the background, large windows allow natural light to pour in, casting soft shadows across the room. Students of diverse backgrounds, dressed in casual but trendy attire, are engaged in examining the laptops, their expressions filled with excitement and curiosit..."
#
# 실험군 B: "A modern slim laptop displayed in a commercial catalog-style product shot, placed at a three-quarter angle on a low matte-gray pedestal with the lid slightly open to reveal the keyboard and hinge details. Shot on a Canon EOS R5 with an 85mm lens set to f/5.6 for crisp detail across the device, neutral white balance and low ISO to preserve texture. Bright cool overhead fluorescent light combined with focused softbox highlights creates strong, controlled specular reflections on the brushed aluminu..."
#
# 📏 길이 비교: A=147단어, B=173단어
#
# [20/30] D-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: TV 수리점, 대형 TV 출장 서비스
# ================================================================================
#    감지된 업종: d2_appliances
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1229 chars (~188 words)
# ================================================================================
#
# 한글 입력: "TV 수리점, 대형 TV 출장 서비스"
#
# 대조군 A: "A bustling TV repair shop filled with various models of televisions, both large and small, displayed on shelves and tables. The setting is bright and inviting, with warm ambient lighting that highlights the shiny screens. Technicians in blue uniforms are actively working on different TV sets, some are disassembled with circuit boards and tools scattered around. In the background, a large, high-definition television is mounted on the wall, showcasing vibrant colors from a nature documentary. The ..."
#
# 실험군 B: "A professional TV repair technician carrying a large 65‑inch flat‑screen TV during an on‑site service call in a modern, minimalist living room, captured mid‑step as he carefully aligns the TV to a wall mount in a front‑facing, editorial composition. Shot on a Canon EOS R5 with a 35mm f/1.8 lens, moderate aperture to keep the technician and screen sharply detailed while gently softening the background, with careful camera height at chest level to emphasize scale. Softbox key light from the left a..."
#
# 📏 길이 비교: A=134단어, B=188단어
#
# [21/30] E-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 주유소 홍보, 리터당 할인 이벤트
# ================================================================================
#    감지된 업종: e1_infrastructure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1171 chars (~169 words)
#    Text Overlay: {'event_name': '리터당 할인 이벤트', 'tagline': '주유소 홍보'}
# ================================================================================
#
# 한글 입력: "주유소 홍보, 리터당 할인 이벤트"
#
# 대조군 A: "A vibrant gas station scene during the golden hour, showcasing a bustling atmosphere with cars lining up to fuel up. The foreground features a modern gas pump, gleaming under the warm sunlight, with a colorful promotional banner fluttering gently in the breeze, hinting at a discount event. Nearby, a friendly attendant assists a customer, both smiling as they engage in conversation. The background reveals a picturesque landscape of rolling hills and trees, bathed in the soft glow of the setting s..."
#
# 실험군 B: "A modern gas station forecourt photographed from a wide, slightly elevated perspective showing the full facility layout, pumps, canopy, convenience store entrance and parked car near a pump, composed for a commercial promotion about a per-liter discount campaign. Shot on a high-resolution full-frame camera with a 24mm wide-angle lens to emphasize the breadth of the site, natural bright daytime sunlight from the left creating crisp shadows and a clear blue sky overhead. The scene is clean and org..."
#
# 📏 길이 비교: A=132단어, B=169단어
#
# [22/30] E-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: LPG 충전소, 자동차 가스 충전
# ================================================================================
#    감지된 업종: e1_infrastructure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1116 chars (~169 words)
# ================================================================================
#
# 한글 입력: "LPG 충전소, 자동차 가스 충전"
#
# 대조군 A: "A bustling LPG filling station set in an urban environment during golden hour, with the warm glow of the setting sun casting long shadows. The scene features a modern gas pump designed for LPG, with sleek lines and a shiny metallic finish, surrounded by a couple of vehicles waiting in line to refuel. One car, a vibrant red sedan, is positioned at the pump, with a visible hose connecting to its fuel inlet. The atmosphere is lively, with a few customers chatting near the convenience store adjacent..."
#
# 실험군 B: "LPG filling station with a passenger car actively refueling at a pump, the driver standing beside the vehicle while the nozzle is inserted into the car's LPG inlet. Shot on a Canon EOS R5 with a 24mm lens at f/8 to capture a wide perspective and deep focus across the entire facility, natural bright daytime sunlight from a clear blue sky casting crisp shadows under the canopy. The scene is composed like documentary infrastructure photography, a straightforward low-to-mid angle that shows multiple..."
#
# 📏 길이 비교: A=126단어, B=169단어
#
# [23/30] E-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 셀프 주유소, 24시간 야간 운영
# ================================================================================
#    감지된 업종: e1_infrastructure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1138 chars (~170 words)
#    Text Overlay: {'product_name': '셀프 주유소', 'tagline': '24시간 야간 운영'}
# ================================================================================
#
# 한글 입력: "셀프 주유소, 24시간 야간 운영"
#
# 대조군 A: "A bustling self-service gas station at night, illuminated by bright neon lights that reflect off the shiny surfaces of cars. The scene is lively, with a few vehicles parked at the fuel pumps, their drivers filling up their tanks. The gas station features modern design elements, with sleek fuel dispensers and a well-maintained convenience store visible in the background. The night sky is deep blue, dotted with twinkling stars, enhancing the vibrant atmosphere. A soft glow emanates from the statio..."
#
# 실험군 B: "Self-service gas station operating overnight under bright canopy lighting, captured in a wide-angle documentary photograph that clearly shows the full facility and pump layout. Shot on a Canon EOS R5 with a 24mm lens on a tripod, slow shutter to capture crisp light and subtle movement, aperture around f/8 for deep sharpness and low ISO to preserve detail. The scene is illuminated by cool white LED canopy lights and warmer convenience-store interior lighting, creating contrasting blue and amber t..."
#
# 📏 길이 비교: A=124단어, B=170단어
#
# [24/30] E-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 세차장 겸 주유소, 셀프 세차 시설
# ================================================================================
#    감지된 업종: e1_infrastructure
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1233 chars (~186 words)
# ================================================================================
#
# 한글 입력: "세차장 겸 주유소, 셀프 세차 시설"
#
# 대조군 A: "Imagine a modern car wash and gas station hybrid, bustling with activity. The setting is bright and clean, showcasing a sleek, contemporary design. In the foreground, a row of shiny cars are lined up at the self-service car wash area, where individuals are actively spraying water and applying foam to their vehicles. The sunlight reflects off the wet surfaces, creating a glistening effect. To the side, a cluster of gas pumps stands ready, with colorful fuel nozzles glimmering in the daylight. The..."
#
# 실험군 B: "A combined gas station and self-service car wash facility captured in a wide, documentary-style daytime photograph. Shot on a Canon EOS R5 with a 24mm lens, tripod-mounted for precise framing, aperture f/8 to keep the entire scene in sharp focus and natural daylight color balance. The composition shows the full facility from a low wide-angle perspective, with the fuel canopy and pumps to the left and multiple self-service wash bays to the right, guiding lanes and marked parking visible in the fo..."
#
# 📏 길이 비교: A=145단어, B=186단어
#
# [25/30] E-1
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 전기차 충전소, 급속 충전 스테이션
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1150 chars (~173 words)
# ================================================================================
#
# 한글 입력: "전기차 충전소, 급속 충전 스테이션"
#
# 대조군 A: "A modern electric vehicle charging station set in a vibrant urban environment. The scene features sleek, futuristic charging units with glowing indicators, showcasing the latest in electric vehicle technology. Surrounding the station, there are a variety of electric cars in different colors, parked and charging, reflecting the diversity of electric mobility. The setting is illuminated by soft, ambient lighting from nearby street lamps and the charging units themselves, creating a welcoming atmos..."
#
# 실험군 B: "A modern electric vehicle fast charging station photographed from a slightly elevated top-down angle, focusing on one active rapid charger in the foreground and a neat row of charging bays receding into the background. Shot on a full-frame camera (Canon EOS R5) with a 35mm lens at f/5.6 to maintain moderate depth of field and crisp detail across the scene. Natural daylight from a clear morning sky is supplemented by warm canopy lights that create soft pools of illumination and subtle reflections..."
#
# 📏 길이 비교: A=143단어, B=173단어
#
# [26/30] E-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 장례식장 안내, 엄숙한 추모 공간
# ================================================================================
#    감지된 업종: e2_ceremony
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1161 chars (~176 words)
# ================================================================================
#
# 한글 입력: "장례식장 안내, 엄숙한 추모 공간"
#
# 대조군 A: "A solemn funeral home setting, characterized by an atmosphere of deep reverence and tranquility. The interior features soft, muted colors, primarily shades of gray and white, with elegant wooden furnishings that evoke a sense of warmth. Delicate floral arrangements, including white lilies and pale roses, are placed strategically throughout the room, adding a touch of natural beauty. Soft, diffused lighting filters through sheer curtains, creating gentle shadows that enhance the serene environmen..."
#
# 실험군 B: "A funeral chapel interior where a funeral director in dark formal attire gently guides a small family down a central aisle toward a solemn memorial area, posed respectfully and composed to convey quiet guidance and dignity. Shot on a Canon EOS R5 with a 24mm f/1.8 lens, tripod-mounted to preserve perfect symmetry, medium aperture to keep the central figures and altar in crisp focus while rendering the background with gentle falloff. The space is captured with soft, muted natural light streaming ..."
#
# 📏 길이 비교: A=108단어, B=176단어
#
# [27/30] E-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 납골당 분양, 평화로운 영면 장소
# ================================================================================
#    감지된 업종: e2_ceremony
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1004 chars (~155 words)
# ================================================================================
#
# 한글 입력: "납골당 분양, 평화로운 영면 장소"
#
# 대조군 A: "Create a serene and peaceful scene of a modern columbarium, surrounded by a tranquil garden. The setting features elegant stone structures with intricate carvings and soft, natural colors that blend seamlessly with the lush greenery. Gentle sunlight filters through the leaves of nearby trees, casting dappled shadows on the ground. In the foreground, a small, beautifully arranged altar is adorned with fresh flowers and candles, symbolizing remembrance and peace. The atmosphere is calm and reflect..."
#
# 실험군 B: "A serene columbarium interior presented as a peaceful final resting place, photographed to showcase available niches and a dignified atmosphere. Shot on a full-frame camera with a 24mm lens at f/8 to achieve a deep, even focus, careful symmetrical composition with the central aisle and niches receding to a gentle vanishing point. Soft diffused daylight filters through frosted skylights while warm recessed LED strips behind each niche provide a gentle halo, creating a calm, respectful glow. The s..."
#
# 📏 길이 비교: A=103단어, B=155단어
#
# [28/30] E-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 상조 서비스, 장례 종합 패키지
# ================================================================================
#    감지된 업종: e2_ceremony
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1170 chars (~176 words)
#    Text Overlay: {'product_name': '상조 서비스', 'tagline': '장례 종합 패키지'}
# ================================================================================
#
# 한글 입력: "상조 서비스, 장례 종합 패키지"
#
# 대조군 A: "Create a serene and respectful scene representing a comprehensive funeral service package. The setting is a tranquil funeral home with soft, warm lighting that creates a comforting atmosphere. In the foreground, an elegant casket is adorned with beautiful white flowers, symbolizing peace and remembrance. Surrounding the casket, there are tasteful arrangements of candles casting a gentle glow, enhancing the solemn ambiance. In the background, a peaceful garden can be seen through large window pan..."
#
# 실험군 B: "A dignified funeral service package presentation in an elegant funeral parlor arranged to convey a comprehensive 장례 종합 패키지. Shot as a professional interior photograph on a full-frame camera with a 35mm lens at moderate aperture to keep the entire arrangement in clear, respectful focus. The scene shows a symmetrical, carefully composed altar area and a low central display table holding an elegant closed package box, a folded linen brochure, a simple framed photo placeholder, and a tasteful white ..."
#
# 📏 길이 비교: A=130단어, B=176단어
#
# [29/30] E-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 수목장 안내, 자연과 함께하는 추모
# ================================================================================
#    감지된 업종: s4_neat_variety
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1050 chars (~168 words)
# ================================================================================
#
# 한글 입력: "수목장 안내, 자연과 함께하는 추모"
#
# 대조군 A: "A serene and tranquil woodland setting, showcasing a beautifully designed natural burial ground. The scene is bathed in soft, dappled sunlight filtering through the lush green leaves of tall trees, creating a peaceful and respectful atmosphere. In the foreground, a gentle stream flows, reflecting the vibrant colors of nature. Delicate wildflowers in various shades of purple, yellow, and white bloom along the banks, adding a touch of color to the earthy tones of the soil and fallen leaves. Small,..."
#
# 실험군 B: "A serene woodland natural burial site photographed as a respectful informational scene: a small family stands quietly by a modest stone memorial and a biodegradable urn partially nestled into the forest floor, the composition focused on human connection with nature. Shot on a Canon EOS R5 with a 35mm lens at golden hour, warm sunlight filters through tall tree canopies creating soft shafts of light and gentle rim illumination on the figures. The setting is a tidy clearing edged by ferns, moss-co..."
#
# 📏 길이 비교: A=116단어, B=168단어
#
# [30/30] E-2
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🎨 Z-Image Turbo 프롬프트 생성 중...
#    입력: 추모관 홍보, 차분한 추모 시설
# ================================================================================
#    감지된 업종: e2_ceremony
#
# ✅ 프롬프트 생성 완료!
#    Style: realistic
#    Positive: 1105 chars (~163 words)
# ================================================================================
#
# 한글 입력: "추모관 홍보, 차분한 추모 시설"
#
# 대조군 A: "A serene memorial hall setting, designed for peaceful remembrance. The interior features soft, muted colors, with elegant wooden furnishings and gentle lighting that creates a calming atmosphere. Ornate floral arrangements in subtle hues are placed thoughtfully throughout the room, complementing the tranquil ambiance. Natural light filters through large, softly draped windows, casting a warm glow across the space. There are comfortable seating areas with plush cushions, inviting visitors to sit ..."
#
# 실험군 B: "A calm, dignified memorial hall interior with a symmetrical central aisle leading the eye to a simple, respectfully designed altar, captured as a promotional photograph conveying quiet solace. Shot on a Canon EOS R5 with a 24mm tilt-shift lens at f/8 to maintain crisp focus from foreground to background, using a slow shutter to gently integrate ambient light. Soft muted natural light filters through high frosted windows, forming gentle shafts across the space while low warm uplights recessed int..."
#
# 📏 길이 비교: A=128단어, B=163단어
#
#
# ====================================================================================================
# 📈 D+E등급 (목적형 소매 + 인프라) 요약 통계
# ====================================================================================================
# 테스트 케이스 수: 30
# 대조군 A 평균 길이: 129.6 단어
# 실험군 B 평균 길이: 174.2 단어

# %% [markdown]
# ## 4. 종합 분석 및 결과 저장

# %%
import pandas as pd
from datetime import datetime

# 모든 결과 합치기
all_results = s_grade_results + a_grade_results + bc_grade_results + de_grade_results

# DataFrame으로 변환
df = pd.DataFrame(all_results)

# 기본 통계
print("\n" + "="*100)
print("📊 전체 A/B 테스트 종합 결과")
print("="*100)

print(f"\n총 테스트 케이스: {len(all_results)}개")
print(f"\n대조군 A 평균 길이: {df['len_a'].mean():.1f} 단어")
print(f"실험군 B 평균 길이: {df['len_b'].mean():.1f} 단어")
print(f"\n대조군 A 길이 범위: {df['len_a'].min()} ~ {df['len_a'].max()} 단어")
print(f"실험군 B 길이 범위: {df['len_b'].min()} ~ {df['len_b'].max()} 단어")

# 그룹별 통계
print("\n" + "-"*50)
print("그룹별 평균 길이 비교")
print("-"*50)
group_stats = df.groupby('group').agg({
    'len_a': 'mean',
    'len_b': 'mean'
}).round(1)
group_stats.columns = ['대조군 A 평균', '실험군 B 평균']
print(group_stats)

# 결과 저장
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_path = f"ab_test_results_{timestamp}.csv"
df.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\n💾 결과 저장 완료: {output_path}")
# Out:
# ====================================================================================================
# 📊 전체 A/B 테스트 종합 결과
# ====================================================================================================
#
# 총 테스트 케이스: 170개
#
# 대조군 A 평균 길이: 131.9 단어
# 실험군 B 평균 길이: 177.4 단어
#
# 대조군 A 길이 범위: 103 ~ 174 단어
# 실험군 B 길이 범위: 153 ~ 216 단어
#
# --------------------------------------------------
# 그룹별 평균 길이 비교
# --------------------------------------------------
#        대조군 A 평균  실험군 B 평균
# group
# A-1       128.7     177.4
# A-2       132.9     174.4
# A-3       123.1     172.5
# A-4       133.3     171.7
# B-1       130.8     186.3
# B-2       145.6     179.0
# B-3       139.2     175.8
# C-1       128.0     190.9
# C-2       133.7     179.9
# C-3       128.0     182.9
# D-1       133.4     175.9
# D-2       129.9     176.3
# E-1       134.0     173.4
# E-2       117.0     167.6
# S-1       131.6     175.7
# S-2       133.1     174.4
# S-3       127.7     177.4
# S-4       138.1     174.7
#
# 💾 결과 저장 완료: ab_test_results_20260122_114110.csv

# %% [markdown]
# ## 5. 샘플 비교 (상세 분석용)

# %%
def display_comparison(results, n_samples=3):
    """
    A/B 비교 결과를 보기 좋게 출력
    """
    import random
    samples = random.sample(results, min(n_samples, len(results)))
    
    for i, sample in enumerate(samples, 1):
        print(f"\n{'='*100}")
        print(f"샘플 {i}: {sample['group']}")
        print(f"{'='*100}")
        print(f"\n📝 한글 입력:")
        print(f"   \"{sample['korean_input']}\"")
        
        print(f"\n🔵 대조군 A ({sample['len_a']}단어):")
        print(f"   \"{sample['prompt_a']}\"")
        
        print(f"\n🟢 실험군 B ({sample['len_b']}단어):")
        print(f"   \"{sample['prompt_b']}\"")

# 각 등급에서 샘플 추출
print("\n" + "#"*100)
print("# S등급 샘플 비교")
print("#"*100)
display_comparison(s_grade_results, 2)

print("\n" + "#"*100)
print("# A등급 샘플 비교")
print("#"*100)
display_comparison(a_grade_results, 2)

print("\n" + "#"*100)
print("# B+C등급 샘플 비교")
print("#"*100)
display_comparison(bc_grade_results, 2)

print("\n" + "#"*100)
print("# D+E등급 샘플 비교")
print("#"*100)
display_comparison(de_grade_results, 2)
# Out:
# ####################################################################################################
# # S등급 샘플 비교
# ####################################################################################################
#
# ====================================================================================================
# 샘플 1: S-3
# ====================================================================================================
#
# 📝 한글 입력:
#    "서점 카페, 책과 함께하는 커피 타임"
#
# 🔵 대조군 A (130단어):
#    "A cozy bookstore cafe scene, filled with shelves of colorful books that reach from the floor to the ceiling. In the foreground, a rustic wooden table holds a steaming cup of coffee, its rich aroma wafting through the air. Surrounding the table are plush, inviting chairs with soft cushions, creating a perfect nook for reading. Warm, ambient lighting spills from vintage-style lamps, casting a soft glow over the pages of an open book resting on the table. The walls are adorned with framed literary quotes and artwork, enhancing the intellectual atmosphere. Outside the large, sunlit windows, lush greenery peeks through, adding a touch of nature to the scene. The overall mood is tranquil and inspiring, inviting patrons to relax, sip their coffee, and get lost in the world of books."
#
# 🟢 실험군 B (186단어):
#    "A steaming cup of coffee resting next to an open book on a small wooden table inside a cozy bookstore café, photographed as a calm morning coffee moment. Shot on a Canon EOS R5 with a 50mm f/1.4 lens, framed from a slightly overhead 30-degree angle to show the cup's delicate foam art and the book's visible paper fibers while keeping a shallow depth of field for creamy bokeh. Natural window light streams softly from the left, diffused through a thin curtain to create gentle highlights on the ceramic glaze, warm rim light on the pages, and soft, long shadows across the table. The scene feels intimate and quiet with muted warm earth tones and subtle pastel accents in a linen napkin and a small vase of dried flowers. Include tactile details like the linen weave, wood grain, microbubbles in the foam, faint steam swirl above the cup, and soft corner creases on the book. Color grade to a warm, slightly desaturated lifestyle aesthetic with natural skin tones for a human hand reaching in, low ISO and gentle film-like grain for an Instagram-worthy cozy café mood."
#
# ====================================================================================================
# 샘플 2: S-1
# ====================================================================================================
#
# 📝 한글 입력:
#    "스테이크 레스토랑, 미디엄 레어로 구운 안심"
#
# 🔵 대조군 A (127단어):
#    "A beautifully arranged steak restaurant setting, featuring a centerpiece of a perfectly cooked medium-rare tenderloin steak. The steak is glistening with a rich, caramelized crust, showcasing juicy, pink meat at the center, garnished with a sprig of fresh rosemary and a drizzle of herb-infused olive oil. Surrounding the steak are elegant plates with colorful sides, such as roasted seasonal vegetables and creamy mashed potatoes. The table is set with polished cutlery, wine glasses filled with a deep red wine, and soft linen napkins. The lighting is warm and inviting, casting a golden glow over the table, enhancing the rich colors of the food. In the background, the restaurant ambiance is cozy and sophisticated, with dark wood accents, soft leather seating, and subtle candlelight creating an intimate atmosphere."
#
# 🟢 실험군 B (180단어):
#    "Filet mignon steak cooked to medium-rare, sliced open to reveal a warm pink center with juices gently pooling, presented on a rustic wooden board in an upscale steak restaurant. Shot as a 45-degree macro close-up to emphasize the interior texture and charred crust, the camera focuses on the cut surface while the rest of the plate and background fall into creamy bokeh. Photographic direction: shot on a full-frame mirrorless camera with a 100mm macro lens at f/2.8, 1/160s, ISO 200 to capture fine detail and shallow depth of field. Warm cinematic overhead light and a soft spotlight from above create golden highlights on the meat while subtle natural window light from the side adds a warm glow and gentle rim light. The atmosphere is intimate and appetizing with delicate steam rising, a glossy butter sheen on the surface, visible charcoal grill marks, coarse salt crystals and cracked pepper, and taut meat fibers. Textures are emphasized — crisp seared crust, tender moist interior, glistening oil drops — with rich saturated brown and red tones for a professional commercial food photography aesthetic."
#
# ####################################################################################################
# # A등급 샘플 비교
# ####################################################################################################
#
# ====================================================================================================
# 샘플 1: A-2
# ====================================================================================================
#
# 📝 한글 입력:
#    "헬스장 PT 프로그램, 1:1 개인 트레이닝"
#
# 🔵 대조군 A (126단어):
#    "A vibrant and dynamic personal training session in a modern gym setting. The scene captures a dedicated personal trainer, a fit individual in athletic wear, guiding a client through a rigorous workout. The gym is equipped with various state-of-the-art fitness equipment, including weights, resistance bands, and cardio machines, all surrounded by large mirrors reflecting the energetic atmosphere. Soft, natural light streams through the large windows, illuminating the space and creating a motivational environment. The trainer, with a focused and encouraging expression, demonstrates an exercise while the client, looking determined, follows closely. The walls are adorned with motivational fitness posters, and the floor is covered with colorful gym mats. The overall atmosphere is one of energy, commitment, and personal growth, showcasing the essence of one-on-one personal training."
#
# 🟢 실험군 B (175단어):
#    "A one-on-one personal training session in a bright modern gym, the trainer guiding a client through a weighted lunge while supporting form, captured mid-motion with both figures in a full-body athletic pose. Shot as professional sports photography on a Canon EOS R5 with a 50mm lens, high shutter speed to freeze movement and a shallow depth of field to softly blur the background gym equipment. Natural daylight pours through tall windows from the far side while a strong cool rim light from camera-left sculpts muscle contours and highlights sweat beads. The mood is focused and determined, editorial fitness aesthetic with energetic, saturated colors against neutral concrete and rubber flooring. Close attention to textures: visible skin pores and defined muscle striations, tiny droplets of sweat catching the rim light, the woven weave of the training shirt, rubber grip texture of the dumbbell, and subtle chalk dust in the air. Low-angle three-quarter composition emphasizes power and motion, crisp sharpness on faces and hands, warm color grading with punchy contrast and minimal grain for a polished commercial look."
#
# ====================================================================================================
# 샘플 2: A-3
# ====================================================================================================
#
# 📝 한글 입력:
#    "가방 브랜드, 가죽 토트백 신제품"
#
# 🔵 대조군 A (108단어):
#    "A luxurious leather tote bag displayed elegantly in a modern, chic setting. The tote bag features a rich, deep brown color with a smooth finish, showcasing its high-quality craftsmanship. Surrounding the bag, a stylish boutique interior with minimalist decor enhances its appeal, characterized by soft, neutral tones and warm wooden accents. The lighting is soft and inviting, casting gentle shadows that highlight the bag's contours and textures. A few elegant accessories, like a silk scarf and a small potted plant, are placed nearby, adding a touch of sophistication. The overall atmosphere is one of luxury and style, inviting the viewer to imagine owning and using this exquisite accessory."
#
# 🟢 실험군 B (155단어):
#    "Leather tote bag carried by a female model in a three-quarter full-body fashion pose on a quiet city sidewalk, the bag slightly angled toward the camera to reveal its silhouette and open top. Shot on a Canon EOS R5 with a 50mm f/1.8 lens, shallow depth of field isolates the bag while keeping the model and urban storefront softly readable. Warm golden-hour sunlight creates a gentle rim light on the bag's edges while a large soft diffuser fills shadows to reveal fine leather grain, tight stitching, hand-painted edge detail, and polished brass hardware. The model wears a tailored neutral trench and minimalist accessories, light breeze lifting the coat to add motion. Color grading is muted and sophisticated with warm highlights and cool midtones to emphasize material quality. Close-up clarity on texture shows subtle sheen, soft matte finish, interior woven lining glimpsed through the slightly open top, and precise tailoring for an editorial, commercial fashion look."
#
# ####################################################################################################
# # B+C등급 샘플 비교
# ####################################################################################################
#
# ====================================================================================================
# 샘플 1: C-1
# ====================================================================================================
#
# 📝 한글 입력:
#    "세무사 사무소, 종합소득세 신고 대행"
#
# 🔵 대조군 A (135단어):
#    "A modern tax office interior, showcasing a professional environment dedicated to comprehensive income tax filing services. The scene features a sleek reception area with a polished wooden desk, where a friendly receptionist greets clients. Behind her, a wall adorned with framed certificates and accolades highlights the expertise of the tax professionals. The office is well-lit with large windows allowing natural light to flood the space, creating a warm and inviting atmosphere. In the background, several tax consultants are engaged with clients at stylish glass-top desks, discussing paperwork and tax documents. The color palette includes soft blues and whites, enhancing the serene and trustworthy ambiance. Potted plants add a touch of greenery, while a digital screen displays informative visuals about tax services. The overall composition conveys professionalism, trust, and a commitment to providing exceptional financial guidance."
#
# 🟢 실험군 B (198단어):
#    "Tax accounting office assisting a client with comprehensive income tax filing, an experienced tax accountant in a navy suit seated across a polished white conference table while pointing at printed tax forms as the client follows with a pen; both focused on the documents and a laptop screen showing spreadsheets. Shot like a corporate commercial photograph on a Canon EOS R5 with a 35mm lens, medium focal length to capture the meeting and interior context, shallow to moderate depth of field to keep the paperwork and hands sharp while gently softening the background. Bright, clean office lighting combines natural daylight streaming through large side windows with professional white overhead lights to create even, neutral illumination and soft, realistic shadows. The scene uses cool, trustworthy blue accent colors against a white and light grey palette, with visible textures such as fine paper fibers on forms, matte metal of a calculator, subtle leather grain on chairs, and the woven fabric of a blazer. Composition emphasizes an organized, uncluttered workspace with neat blue binders on shelves, a minimal potted plant, and clear surfaces; color grading is neutral-cool, high-key, low noise, and crisp commercial clarity suitable for corporate documentation and marketing imagery."
#
# ====================================================================================================
# 샘플 2: C-1
# ====================================================================================================
#
# 📝 한글 입력:
#    "행정사 사무소, 인허가 대행 서비스"
#
# 🔵 대조군 A (132단어):
#    "A modern administrative office setting, featuring a sleek reception area with contemporary furniture. The walls are adorned with abstract art and inspirational quotes, creating a welcoming atmosphere. In the foreground, a professional-looking administrative officer, wearing formal attire, is engaged in a discussion with a client at a polished wooden desk. Sunlight streams through large windows, casting soft shadows on the floor, enhancing the bright and optimistic mood of the space. On the desk, there are neatly organized files, a laptop displaying graphs, and a cup of coffee, reflecting a busy yet efficient work environment. In the background, a bulletin board displays various licenses and permits, showcasing the office's dedication to handling administrative services. The overall ambiance is one of professionalism, trust, and clarity, inviting viewers to feel confident in the services provided."
#
# 🟢 실험군 B (178단어):
#    "Administrative services office providing licensing and permit application services, a professional consultation scene with an administrative officer in a navy suit explaining a stamped permit to a seated client across a tidy wooden desk. Shot on a Canon EOS R5 with a 24mm lens, medium-wide interior composition from a slightly elevated three-quarter angle that captures both people and the organized office layout. Bright natural daylight streams through large windows on the left while clean overhead LED panels provide even, soft white illumination, creating a high-key, trustworthy atmosphere. Textures are clear and realistic: warm matte wood grain on the desk, soft woven fabric on chairs, slight leather sheen on folders, subtle gloss on stacked document sleeves, and tempered glass reflections on a nearby partition. The laptop screen and documents are intentionally out of focus so no text is legible. Color palette emphasizes professional whites and light greys with trustworthy blue accents in folders and wall décor, moderate depth of field at f/4 to keep subjects crisp and background softly receding, neutral-warm color grading for a polished corporate photography look."
#
# ####################################################################################################
# # D+E등급 샘플 비교
# ####################################################################################################
#
# ====================================================================================================
# 샘플 1: D-2
# ====================================================================================================
#
# 📝 한글 입력:
#    "폰 수리 전문, 액정 교체 당일 수리"
#
# 🔵 대조군 A (126단어):
#    "A modern smartphone repair shop bustling with activity, showcasing a technician working diligently on a sleek smartphone with a cracked screen. The setting is bright and welcoming, with large windows allowing natural light to flood in, illuminating the workspace filled with high-tech tools and colorful phone accessories. The technician, a young adult with focused expression, is wearing a professional uniform and using specialized equipment to carefully replace the phone's screen. On a nearby workbench, there are various smartphones in different states of repair, showcasing the process of fixing devices. The atmosphere is lively yet precise, with a sense of urgency reflecting the 'same-day repair' service. The background features a clean, organized space with posters of different smartphone models hanging on the walls, highlighting the shop's expertise."
#
# 🟢 실험군 B (180단어):
#    "Phone repair specialist replacing a cracked smartphone screen for same-day service, captured in a clean, professional repair workstation with the technician's hands carefully removing the broken glass from the phone frame. Shot on a Canon EOS R5 with a 90mm macro lens, slightly overhead three-quarter angle to show both the device surface and the technician's focused movements, using a shallow depth of field to keep the phone and hands razor-sharp while the background tools gently fall into soft bokeh. Warm overhead LED light mixed with soft natural daylight from a nearby window creates a balanced, trustworthy atmosphere with subtle rim highlights on metal tools. Emphasize tactile details like the fine skin pores and tiny cuticle lines on the technician's fingers, the micro-scratches on the phone bezel, the glossy edge of the replacement glass reflecting a cool blue, the woven texture of a microfiber cloth, and the matte rubber of an anti-static mat. Arrange small plastic trays with neatly sorted screws, precision screwdrivers, adhesive strips, and a magnifying loupe in an organized, inviting composition that conveys speed, cleanliness, and expert care."
#
# ====================================================================================================
# 샘플 2: D-2
# ====================================================================================================
#
# 📝 한글 입력:
#    "복합기 임대, 사무실 프린터 렌탈"
#
# 🔵 대조군 A (110단어):
#    "A modern office setting showcasing a sleek multifunction printer in a well-organized workspace. The printer, with its glossy black and silver finish, is placed on a light wooden desk surrounded by essential office supplies like notepads, pens, and a laptop. The room is filled with natural light streaming in through large windows, casting soft shadows on the floor. In the background, there are shelves neatly lined with books and decorative plants that bring a touch of greenery to the environment. The atmosphere is professional yet inviting, conveying a sense of productivity and efficiency. The overall color palette features calming blues, whites, and earthy tones, creating a harmonious and focused ambiance."
#
# 🟢 실험군 B (162단어):
#    "A front-facing multifunction office printer placed centrally on a seamless white backdrop, photographed as a clean commercial product shot. The device is shown upright with the paper tray slightly open and a single crisp page emerging to reveal fine paper fiber texture but no printed words. Shot on a Canon EOS R5 with a 50mm lens at f/8 for full-device sharpness, the camera is positioned at chest height for a natural straight-on perspective. Bright, even three-point studio lighting with large softboxes creates soft highlights on the matte plastic casing and subtle specular reflections on the glossy touchscreen, while a faint shadow beneath the unit grounds it against the white surface. Color palette is modern white and charcoal with cool blue LED accents; surface textures include visible plastic grain, metal hinges, and smooth glass on the control panel. The mood is professional and high-tech, minimal and clinical, with neutral color grading, crisp detail, and no text or logos visible on screens or paper."

# %% [markdown]
# ## 6. GPT 기반 프롬프트 품질 평가
#
# ### 6.1 평가 기준 정의 (업종별 분류 문서 기반)

# %%
# ============================================
# GPT 기반 프롬프트 품질 평가 시스템
# ============================================

# 등급별 평가 기준 (업종별_분류_및_광고전략.md 기반)
EVALUATION_CRITERIA = {
    "S": {
        "name": "S등급 - 감성 및 미각 자극",
        "criteria": """
## S등급 평가 기준 (감성 및 미각 자극)

### 핵심 원칙
- 이성적인 판단보다 '시각적 자극'에 의한 즉각적 반응 유도
- 사진/영상 한 장의 퀄리티가 광고 성과의 80% 이상 결정

### 세부 평가 항목 (각 20점, 총 100점)

1. **질감 표현 (Texture)** - 20점
   - 음식의 육즙, 윤기, 바삭함 등 질감이 구체적으로 묘사되었는가
   - S-1: 육즙(juicy), 지글거림(sizzling), 숯불 자국(grill marks)
   - S-2: 신선함(fresh), 투명한 색감(translucent), 물방울(water droplets)
   - S-3: 부드러운 질감(creamy), 촉촉함(moist), 파스텔 톤
   - S-4: 정갈함(neat), 다채로움(colorful), 균형잡힌 배치

2. **조명 설정 (Lighting)** - 20점
   - 업종에 맞는 조명 설정이 명시되었는가
   - 따뜻한 조명, 자연광, 스튜디오 조명 등 구체적 명시

3. **색감/분위기 (Color/Mood)** - 20점
   - 식욕을 자극하는 색감 또는 감성적 분위기가 표현되었는가
   - 따뜻한 톤, 선명한 색상, 부드러운 파스텔 등

4. **구도/앵글 (Composition)** - 20점
   - 클로즈업, 45도 앵글, 탑다운 뷰 등 구도가 명시되었는가
   - 음식 중심 배치, 보케 효과 등

5. **업종 특화 키워드 (Industry-Specific)** - 20점
   - 해당 업종에 특화된 전문 용어나 키워드가 포함되었는가
"""
    },
    "A": {
        "name": "A등급 - 비주얼 변화 및 자기관리",
        "criteria": """
## A등급 평가 기준 (비주얼 변화 및 자기관리)

### 핵심 원칙
- '변화'와 '결과'를 시각적으로 증명
- 피부결, 머릿결, 근육 선명도 등 디테일 강조

### 세부 평가 항목 (각 20점, 총 100점)

1. **변화/결과 표현 (Transformation)** - 20점
   - A-1: 피부결 윤기, 머릿결 광택, 아름다운 네일 디자인
   - A-2: 근육 선명도, 역동적 자세, 건강한 체형
   - A-3: 원단 질감, 스타일링, 트렌디한 코디
   - A-4: 꽃의 생생함, 반려동물 털 질감, 섬세한 디테일

2. **조명 설정 (Lighting)** - 20점
   - A-1: 스튜디오 림 라이팅, 얕은 피사계 심도
   - A-2: 시네마틱 헬스장 조명, 높은 대비
   - A-3: 자연광, 패션 룩북 스타일
   - A-4: 부드러운 자연광, 매크로 촬영

3. **인물/제품 중심성 (Subject Focus)** - 20점
   - 주요 피사체가 명확히 부각되었는가
   - 배경과의 적절한 분리

4. **전문성/신뢰감 (Professionalism)** - 20점
   - 전문적인 느낌이 전달되는가
   - 고급스러운 분위기

5. **업종 특화 키워드 (Industry-Specific)** - 20점
   - 해당 업종에 특화된 전문 용어나 키워드가 포함되었는가
"""
    },
    "BC": {
        "name": "B+C등급 - 공간 체험/신뢰 기반 서비스",
        "criteria": """
## B+C등급 평가 기준 (공간 체험 + 신뢰 기반 서비스)

### B등급 핵심 원칙
- 단일 제품이 아닌 '머무는 경험'과 '성취'를 판매
- 광각 렌즈를 활용한 공간감 표현

### C등급 핵심 원칙
- 화려함보다는 '실패 없는 선택'임을 증명하는 신뢰성
- 전문적인 블루톤 배색, 정돈된 레이아웃

### 세부 평가 항목 (각 20점, 총 100점)

1. **공간감/시설 표현 (Space/Facility)** - 20점
   - B-1: 밝고 쾌적한 학습 공간, 정돈된 책상
   - B-2: 시네마틱 인테리어, 럭셔리한 숙박 시설
   - B-3: 넓은 시설, 전문 장비, 현대적 느낌
   - C등급: 미니멀 기업 스타일, 청결한 의료 공간

2. **조명 설정 (Lighting)** - 20점
   - B등급: 광각, 시네마틱 조명, 무드 조명
   - C등급: 밝고 균일한 조명, 전문적 분위기

3. **신뢰감/전문성 (Trust/Expertise)** - 20점
   - 전문적이고 믿을 수 있는 느낌이 전달되는가
   - C등급: 블루 계열 액센트, 깨끗한 환경

4. **구도/앵글 (Composition)** - 20점
   - 광각 렌즈, 파노라마 뷰, 시설 전경 등

5. **업종 특화 키워드 (Industry-Specific)** - 20점
   - 해당 업종에 특화된 전문 용어나 키워드가 포함되었는가
"""
    },
    "DE": {
        "name": "D+E등급 - 목적형 소매/인프라",
        "criteria": """
## D+E등급 평가 기준 (목적형 소매 + 인프라)

### D등급 핵심 원칙
- 견고함, 실용성, 기능성 강조
- 산업적 미학, 높은 대비, 금속 질감

### E등급 핵심 원칙
- 접근성, 편의성, 품위
- 직관적 사진, 명확한 간판, 차분한 분위기

### 세부 평가 항목 (각 20점, 총 100점)

1. **제품/시설 명확성 (Clarity)** - 20점
   - D-1: 금속 질감, 내구성, 산업적 미학
   - D-2: 깨끗한 제품 촬영, 첨단 느낌
   - E-1: 직관적 사진, 명확한 간판
   - E-2: 차분한 분위기, 절제된 색상, 대칭 구도

2. **조명 설정 (Lighting)** - 20점
   - D등급: 밝은 조명, 스튜디오 조명, 높은 대비
   - E등급: 주간 자연광, 차분한 조명

3. **실용성/기능성 (Functionality)** - 20점
   - 제품의 실용성과 기능이 잘 전달되는가

4. **정돈된 구성 (Organization)** - 20점
   - 정리된 선반, 깔끔한 배치, 명확한 구성

5. **업종 특화 키워드 (Industry-Specific)** - 20점
   - 해당 업종에 특화된 전문 용어나 키워드가 포함되었는가
"""
    }
}

print("평가 기준 로드 완료!")
# Out:
# 평가 기준 로드 완료!

# %% [markdown]
# ### 6.2 GPT 평가 함수 정의

# %%
def evaluate_prompts_with_gpt(
    korean_input: str,
    prompt_a: str,
    prompt_b: str,
    group: str
) -> Dict:
    """
    GPT를 사용하여 두 프롬프트를 비교 평가

    Args:
        korean_input: 원본 한글 입력
        prompt_a: 대조군 A 프롬프트
        prompt_b: 실험군 B 프롬프트
        group: 그룹 코드 (S-1, A-2 등)

    Returns:
        Dict: 평가 결과
    """
    # 등급 결정
    if group.startswith("S"):
        grade = "S"
    elif group.startswith("A"):
        grade = "A"
    elif group.startswith("B") or group.startswith("C"):
        grade = "BC"
    else:
        grade = "DE"

    criteria = EVALUATION_CRITERIA[grade]["criteria"]
    grade_name = EVALUATION_CRITERIA[grade]["name"]

    system_prompt = f"""당신은 광고용 이미지 생성 프롬프트 품질을 평가하는 전문가입니다.
소상공인 광고 이미지 생성을 위한 프롬프트의 적합성을 평가합니다.

{criteria}

## 평가 방법
1. 각 항목별로 0-20점 척도로 평가
2. 두 프롬프트(A와 B)를 동일한 기준으로 평가
3. 어떤 프롬프트가 해당 업종의 광고 이미지 생성에 더 적합한지 판단
4. 반드시 JSON 형식으로 출력

## 출력 형식 (JSON)
{{
    "grade": "{grade_name}",
    "evaluation_a": {{
        "texture_or_subject": <0-20>,
        "lighting": <0-20>,
        "color_mood": <0-20>,
        "composition": <0-20>,
        "industry_specific": <0-20>,
        "total": <0-100>,
        "strengths": "강점 설명",
        "weaknesses": "약점 설명"
    }},
    "evaluation_b": {{
        "texture_or_subject": <0-20>,
        "lighting": <0-20>,
        "color_mood": <0-20>,
        "composition": <0-20>,
        "industry_specific": <0-20>,
        "total": <0-100>,
        "strengths": "강점 설명",
        "weaknesses": "약점 설명"
    }},
    "winner": "A" 또는 "B" 또는 "TIE",
    "winner_reason": "선택 이유 (2-3문장)",
    "detailed_comparison": "두 프롬프트의 상세 비교 분석 (3-4문장)"
}}
"""

    user_prompt = f"""## 평가 대상

### 원본 한글 입력 (광고 요청)
"{korean_input}"

### 업종 그룹
{group}

### 대조군 A 프롬프트
"{prompt_a}"

### 실험군 B 프롬프트
"{prompt_b}"

위 두 프롬프트를 평가 기준에 따라 비교 분석하고, 어떤 프롬프트가 해당 업종의 광고 이미지 생성에 더 적합한지 판단해주세요.
반드시 JSON 형식으로만 응답해주세요."""

    try:
        response = client.chat.completions.create(
            model="gpt-4o",  # 더 정확한 평가를 위해 gpt-4o 사용
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            temperature=0.3,  # 일관된 평가를 위해 낮은 temperature
            response_format={"type": "json_object"}
        )

        result = json.loads(response.choices[0].message.content)
        return result

    except Exception as e:
        return {"error": str(e)}


def evaluate_existing_results(existing_results: List[Dict], group_name: str, sample_size: int = None):
    """
    이미 생성된 A/B 테스트 결과를 사용하여 GPT 평가만 수행
    
    Args:
        existing_results: 섹션 3에서 생성된 A/B 테스트 결과 리스트
        group_name: 그룹명
        sample_size: 평가할 샘플 수 (None이면 전체 평가)
    
    Returns:
        평가 결과 리스트, 승패 통계
    """
    import random
    import time
    
    print(f"\n{'='*100}")
    print(f"📊 {group_name} GPT 평가 (기존 A/B 결과 활용)")
    print(f"{'='*100}\n")
    
    # 샘플 선택 (None이면 전체)
    if sample_size and sample_size < len(existing_results):
        samples = random.sample(existing_results, sample_size)
        print(f"📌 전체 {len(existing_results)}개 중 {sample_size}개 샘플 평가")
    else:
        samples = existing_results
        print(f"📌 전체 {len(existing_results)}개 평가")
    
    results = []
    wins = {"A": 0, "B": 0, "TIE": 0}
    total_scores = {"A": [], "B": []}
    
    for i, case in enumerate(samples, 1):
        group = case.get("group", "")
        korean_input = case.get("korean_input", "")
        prompt_a = case.get("prompt_a", "")
        prompt_b = case.get("prompt_b", "")
        
        print(f"\n[{i}/{len(samples)}] {group}")
        print(f"-" * 80)
        print(f'한글 입력: "{korean_input}"')
        print(f'\n대조군 A: "{prompt_a[:200]}..."' if len(prompt_a) > 200 else f'\n대조군 A: "{prompt_a}"')
        print(f'\n실험군 B: "{prompt_b[:200]}..."' if len(prompt_b) > 200 else f'\n실험군 B: "{prompt_b}"')
        
        # GPT 평가
        print("\n🔍 GPT 평가 중...")
        evaluation = evaluate_prompts_with_gpt(korean_input, prompt_a, prompt_b, group)
        
        if "error" not in evaluation:
            eval_a = evaluation.get("evaluation_a", {})
            eval_b = evaluation.get("evaluation_b", {})
            winner = evaluation.get("winner", "TIE")
            
            print(f"\n📊 평가 결과:")
            print(f"   대조군 A 점수: {eval_a.get('total', 'N/A')}점")
            print(f"   실험군 B 점수: {eval_b.get('total', 'N/A')}점")
            print(f"   🏆 승자: {'대조군 A' if winner == 'A' else '실험군 B' if winner == 'B' else '무승부'}")
            print(f"   📝 이유: {evaluation.get('winner_reason', 'N/A')}")
            
            wins[winner] += 1
            if eval_a.get('total'):
                total_scores["A"].append(eval_a.get('total'))
            if eval_b.get('total'):
                total_scores["B"].append(eval_b.get('total'))
            
            results.append({
                "group": group,
                "korean_input": korean_input,
                "prompt_a": prompt_a,
                "prompt_b": prompt_b,
                "len_a": case.get("len_a", len(prompt_a.split())),
                "len_b": case.get("len_b", len(prompt_b.split())),
                "score_a": eval_a.get('total'),
                "score_b": eval_b.get('total'),
                "winner": winner,
                "evaluation": evaluation
            })
        else:
            print(f"   ❌ 평가 오류: {evaluation['error']}")
            # 오류가 나도 결과에 포함 (평가 없이)
            results.append({
                "group": group,
                "korean_input": korean_input,
                "prompt_a": prompt_a,
                "prompt_b": prompt_b,
                "len_a": case.get("len_a", len(prompt_a.split())),
                "len_b": case.get("len_b", len(prompt_b.split())),
                "score_a": None,
                "score_b": None,
                "winner": None,
                "evaluation": evaluation
            })
        
        # API 레이트 리밋 방지를 위한 딜레이
        if i < len(samples):
            time.sleep(0.5)
    
    # 요약 통계
    valid_results = [r for r in results if r.get("winner")]
    
    print(f"\n\n{'='*100}")
    print(f"📈 {group_name} 평가 요약")
    print(f"{'='*100}")
    print(f"평가 케이스 수: {len(valid_results)}/{len(samples)}")
    
    if valid_results:
        print(f"\n🏆 승패 현황:")
        print(f"   대조군 A 승: {wins['A']}회 ({wins['A']/len(valid_results)*100:.1f}%)")
        print(f"   실험군 B 승: {wins['B']}회 ({wins['B']/len(valid_results)*100:.1f}%)")
        print(f"   무승부: {wins['TIE']}회 ({wins['TIE']/len(valid_results)*100:.1f}%)")
    
    if total_scores["A"] and total_scores["B"]:
        print(f"\n📊 평균 점수:")
        print(f"   대조군 A: {sum(total_scores['A'])/len(total_scores['A']):.1f}점")
        print(f"   실험군 B: {sum(total_scores['B'])/len(total_scores['B']):.1f}점")
    
    return results, wins


# 기존 run_ab_test_with_evaluation 함수는 유지 (필요시 사용)
def run_ab_test_with_evaluation(test_cases: List[Dict], group_name: str, sample_size: int = 5):
    """
    A/B 테스트 실행 + GPT 평가 (새로 생성하면서 평가)
    - 주의: 이 함수는 A/B 결과를 새로 생성합니다.
    - 기존 결과를 활용하려면 evaluate_existing_results()를 사용하세요.
    """
    import random

    print(f"\n{'='*100}")
    print(f"📊 {group_name} A/B 테스트 + GPT 평가 (새로 생성)")
    print(f"{'='*100}\n")

    samples = random.sample(test_cases, min(sample_size, len(test_cases)))

    results = []
    wins = {"A": 0, "B": 0, "TIE": 0}
    total_scores = {"A": [], "B": []}

    for i, case in enumerate(samples, 1):
        group = case.get("group", "")
        korean_input = case.get("input", "")

        print(f"\n[{i}/{len(samples)}] {group}")
        print(f"-" * 80)
        print(f'한글 입력: "{korean_input}"')

        # A/B 프롬프트 생성
        prompt_a = generate_prompt_control_a(korean_input)
        prompt_b = generate_prompt_experiment_b(korean_input)

        print(f'\n대조군 A: "{prompt_a[:200]}..."' if len(prompt_a) > 200 else f'\n대조군 A: "{prompt_a}"')
        print(f'\n실험군 B: "{prompt_b[:200]}..."' if len(prompt_b) > 200 else f'\n실험군 B: "{prompt_b}"')

        # GPT 평가
        print("\n🔍 GPT 평가 중...")
        evaluation = evaluate_prompts_with_gpt(korean_input, prompt_a, prompt_b, group)

        if "error" not in evaluation:
            eval_a = evaluation.get("evaluation_a", {})
            eval_b = evaluation.get("evaluation_b", {})
            winner = evaluation.get("winner", "TIE")

            print(f"\n📊 평가 결과:")
            print(f"   대조군 A 점수: {eval_a.get('total', 'N/A')}점")
            print(f"   실험군 B 점수: {eval_b.get('total', 'N/A')}점")
            print(f"   🏆 승자: {'대조군 A' if winner == 'A' else '실험군 B' if winner == 'B' else '무승부'}")

            wins[winner] += 1
            if eval_a.get('total'):
                total_scores["A"].append(eval_a.get('total'))
            if eval_b.get('total'):
                total_scores["B"].append(eval_b.get('total'))

            results.append({
                "group": group,
                "korean_input": korean_input,
                "prompt_a": prompt_a,
                "prompt_b": prompt_b,
                "score_a": eval_a.get('total'),
                "score_b": eval_b.get('total'),
                "winner": winner,
                "evaluation": evaluation
            })
        else:
            print(f"   ❌ 평가 오류: {evaluation['error']}")

    return results, wins

# %% [markdown]
# ### 6.3 S등급 GPT 평가 실행

# %%
# S등급 GPT 평가 - 섹션 3에서 생성된 s_grade_results 활용
# sample_size=None 으로 설정하면 전체 40개 평가 (API 비용 주의)
# sample_size=10 으로 설정하면 10개만 샘플링하여 평가

s_eval_results, s_wins = evaluate_existing_results(
    s_grade_results,  # 섹션 3에서 생성된 결과 사용
    "S등급 (감성 및 미각 자극)",
    sample_size=None  # 전체 평가 (또는 원하는 샘플 수로 변경)
)
# Out:
# ====================================================================================================
# 📊 S등급 (감성 및 미각 자극) GPT 평가 (기존 A/B 결과 활용)
# ====================================================================================================
#
# 📌 전체 40개 평가
#
# [1/40] S-1
# --------------------------------------------------------------------------------
# 한글 입력: "숯불에 구운 삼겹살, 육즙이 뚝뚝 떨어지는 모습"
#
# 대조군 A: "A close-up scene of mouthwatering, grilled pork belly sizzling over charcoal flames. The pork belly is perfectly cooked, glistening with a golden-brown crust, with juices dripping down onto the hot gr..."
#
# 실험군 B: "Charcoal-grilled pork belly (samgyeopsal) with juices dripping, captured mid-sizzle as clear beads of meat juice fall from a glistening edge. Shot like a professional food photograph on a Canon EOS R5..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 촬영 장비와 기술적 요소를 상세히 설명하여 삼겹살의 질감과 분위기를 더욱 생생하게 표현할 수 있음.
#
# [2/40] S-1
# --------------------------------------------------------------------------------
# 한글 입력: "치킨 전문점 홍보, 갓 튀긴 바삭한 치킨"
#
# 대조군 A: "Imagine a vibrant and inviting scene at a chicken specialty restaurant. The focus is on a large, golden-brown fried chicken, perfectly crispy and glistening with a light sheen of oil. The chicken is p..."
#
# 실험군 B: "Crispy freshly-fried chicken presented in an open woven basket at the center of a top-down flat lay, a few pieces torn open to reveal steaming, juicy white meat inside and flaky, golden-brown crust fa..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 치킨의 질감과 조명을 매우 구체적으로 설명하며, 카메라 세팅과 촬영 각도까지 명확히 제시하여 전문성을 높입니다.
#
# [3/40] S-1
# --------------------------------------------------------------------------------
# 한글 입력: "피자 가게 신메뉴, 치즈가 늘어나는 장면"
#
# 대조군 A: "A mouth-watering scene showcasing a freshly baked pizza being pulled apart, with gooey, melted cheese stretching tantalizingly between two slices. The setting is a cozy, warmly lit pizzeria with rusti..."
#
# 실험군 B: "New menu pizza from a neighborhood pizzeria with a single slice being lifted so long, molten cheese stretches in glossy, elastic strands from the pie. Shot like high-end commercial food photography on..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도 등 모든 면에서 더 구체적이고 전문적인 설명을 제공하여 시각적 자극을 극대화합니다.
#
# [4/40] S-1
# --------------------------------------------------------------------------------
# 한글 입력: "마라탕 전문점, 얼얼하게 매운 국물과 재료들"
#
# 대조군 A: "A vibrant and enticing scene of a traditional mala tang restaurant, showcasing a steaming pot filled with a rich, spicy broth. The broth is a deep red color, bubbling energetically, with visible spice..."
#
# 실험군 B: "Mala tang hot pot spread with a numbing, tongue-tingling spicy broth and neatly arranged fresh ingredients, presented in a top-down flat lay across a wooden dining table. Shot on a professional full-f..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 89점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 촬영 기법과 질감 표현에서 더 높은 점수를 받았으며, 업종에 특화된 키워드 사용이 뛰어나다.
#
# [5/40] S-1
# --------------------------------------------------------------------------------
# 한글 입력: "스테이크 레스토랑, 미디엄 레어로 구운 안심"
#
# 대조군 A: "A beautifully arranged steak restaurant setting, featuring a centerpiece of a perfectly cooked medium-rare tenderloin steak. The steak is glistening with a rich, caramelized crust, showcasing juicy, p..."
#
# 실험군 B: "Filet mignon steak cooked to medium-rare, sliced open to reveal a warm pink center with juices gently pooling, presented on a rustic wooden board in an upscale steak restaurant. Shot as a 45-degree ma..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 스테이크의 질감과 조명, 색감을 매우 세밀하게 묘사하며, 촬영 기법과 앵글에 대한 구체적인 지시가 포함되어 있어 광고 이미지 생성에 더 적합합니다.
#
# [6/40] S-1
# --------------------------------------------------------------------------------
# 한글 입력: "중국집 짜장면, 윤기 나는 면발과 춘장 소스"
#
# 대조군 A: "A beautifully composed still life featuring a bowl of Chinese Jajangmyeon, showcasing glossy, perfectly cooked noodles glistening under soft, warm lighting. The rich, dark Jajang sauce is generously d..."
#
# 실험군 B: "Jjajangmyeon in a deep rustic ceramic bowl, glossy black-bean sauce clinging to springy wheat noodles as a pair of black chopsticks lifts a generous tangle, steam rising in soft ribbons and catching t..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 구도에서 매우 구체적이고 전문적인 설명을 제공하여 고급스러운 이미지를 생성할 수 있는 잠재력이 높습니다.
#
# [7/40] S-1
# --------------------------------------------------------------------------------
# 한글 입력: "버거 전문점, 육즙 가득한 수제버거"
#
# 대조군 A: "Imagine a bustling burger restaurant with a warm and inviting atmosphere. The focal point is a beautifully crafted gourmet burger, showcasing a thick, juicy beef patty that glistens with savory juices..."
#
# 실험군 B: "Handcrafted juicy beef burger cut in cross-section with glossy melted cheese stretching from the patty, juices pooling and delicate steam rising, presented on a toasted brioche bun sprinkled with sesa..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 99점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 질감, 조명, 구도에 대한 구체적이고 전문적인 설명을 통해 더욱 매력적이고 식욕을 자극하는 이미지를 생성할 수 있습니다.
#
# [8/40] S-1
# --------------------------------------------------------------------------------
# 한글 입력: "곱창 구이, 불판 위에서 지글지글 익는 모습"
#
# 대조군 A: "A sizzling plate of grilled gopchang (beef intestines) is the focal point of the scene, arranged artistically on a traditional Korean barbecue grill. The gopchang is perfectly charred, with crispy edg..."
#
# 실험군 B: "Gopchang sizzling on a hotplate, cut into bite-sized twists and curling as hot oil pops and steam rises in delicate ribbons. Capture the moment of active cooking from a 45-degree macro perspective so ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 100점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 음식의 질감과 조명, 색감, 구도에서 모두 뛰어난 디테일을 제공하며, 전문적인 사진 촬영 기법까지 포함하여 완벽한 광고 이미지를 생성할 수 있다.
#
# [9/40] S-1
# --------------------------------------------------------------------------------
# 한글 입력: "일식 라멘집, 김이 모락모락 나는 돈코츠 라멘"
#
# 대조군 A: "A cozy Japanese ramen shop, featuring a steaming bowl of tonkotsu ramen at the center of the composition. The bowl is filled with rich, creamy broth, topped with tender slices of chashu pork, vibrant ..."
#
# 실험군 B: "Tonkotsu ramen steaming in a deep ceramic bowl, a close-up 45-degree macro composition that captures steam curling up from the silky, milky pork-bone broth as thin noodles are gently lifted and coil w..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 사진 촬영 기법과 구체적인 장비 설명을 통해 라멘의 질감과 색감을 극대화하여 시각적 자극을 극대화합니다.
#
# [10/40] S-1
# --------------------------------------------------------------------------------
# 한글 입력: "생맥주 전문점, 시원한 맥주와 안주 플래터"
#
# 대조군 A: "A cozy and inviting craft beer pub setting, featuring a beautifully arranged platter of assorted appetizers including crispy fried calamari, spicy chicken wings, and fresh vegetable sticks with creamy..."
#
# 실험군 B: "A chilled pint of draft beer and an appetizer platter arranged on a rustic wooden table in a bustling craft beer pub. Shot like a professional food photographer, the composition is a 45-degree macro c..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 89점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도에서 모두 뛰어난 세부 묘사를 제공하여 시각적 자극을 극대화합니다.
#
# [11/40] S-2
# --------------------------------------------------------------------------------
# 한글 입력: "횟집 홍보, 신선한 모둠회와 싱싱한 해산물"
#
# 대조군 A: "Create an inviting and vibrant seafood restaurant scene, showcasing a beautifully arranged platter of fresh sashimi and assorted seafood. The table is set with an elegant wooden surface reflecting war..."
#
# 실험군 B: "Assorted sashimi and fresh chilled seafood arranged as a premium overhead flat-lay, thinly sliced tuna, salmon, yellowtail and translucent white fish fanned on a large wooden platter surrounded by gli..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 97점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 촬영 세팅과 세부적인 질감 표현을 통해 매우 고품질의 광고 이미지를 생성할 수 있습니다.
#
# [12/40] S-2
# --------------------------------------------------------------------------------
# 한글 입력: "초밥 전문점, 장인이 만든 프리미엄 오마카세"
#
# 대조군 A: "An elegant sushi restaurant setting, showcasing a premium omakase experience prepared by skilled artisans. The scene features a beautifully arranged wooden sushi counter, with a master sushi chef dres..."
#
# 실험군 B: "Premium omakase sushi platter made by a master sushi chef, laid out in an elegant overhead flat lay on a clean white surface, each nigiri and sashimi piece meticulously arranged to show individual cra..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 97점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감과 색감의 세부 표현이 뛰어나고, 촬영 기술과 구도가 명확하게 제시되어 있어 고급스러움과 신선함을 강조합니다.
#
# [13/40] S-2
# --------------------------------------------------------------------------------
# 한글 입력: "해산물 찜, 게와 새우가 가득한 해물찜"
#
# 대조군 A: "Create a vibrant and appetizing scene of a seafood steam pot brimming with an assortment of fresh ingredients. The focal point is a large, steaming pot filled with plump, bright red crabs, succulent p..."
#
# 실험군 B: "A large steaming seafood 찜 piled high with whole crabs and plump shrimp is the central focus, photographed from a clean overhead flat‑lay perspective. The platter shows cracked crab shells exposing gl..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 97점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도에서 모두 높은 점수를 받았으며, 특히 촬영 각도와 조명 설정이 명확하여 고급스러운 이미지를 생성하는 데 적합합니다.
#
# [14/40] S-2
# --------------------------------------------------------------------------------
# 한글 입력: "수산시장 홍보, 싱싱한 활어와 조개류"
#
# 대조군 A: "Imagine a vibrant seafood market bustling with activity, showcasing a stunning array of fresh fish and shellfish. The scene is set under a bright, natural light filtering through the open stalls, illu..."
#
# 실험군 B: "A top-down overhead flat-lay of freshly caught live fish and an assortment of shellfish arranged on crushed ice at a coastal fish market, the fish positioned in dynamic, slightly angled rows and clams..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 세부적인 질감과 조명 설정을 통해 고급스러운 상업적 품질을 강조하며, 해산물의 신선함을 효과적으로 전달합니다.
#
# [15/40] S-2
# --------------------------------------------------------------------------------
# 한글 입력: "복어 요리 전문점, 복어회와 복어탕 코스"
#
# 대조군 A: "A beautifully arranged dining table showcasing an exquisite fugu (pufferfish) cuisine experience. The setting is a traditional Korean restaurant with wooden furnishings, warm ambient lighting casting ..."
#
# 실험군 B: "A premium course of pufferfish sashimi and steaming pufferfish hot pot presented as a refined meal at a fugu specialty restaurant, captured in a clean overhead flat lay composition. Shot on a Canon EO..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 음식의 질감과 조명, 색감, 구도에 대한 구체적인 설명이 뛰어나며, 카메라 설정까지 포함하여 시각적 디테일을 극대화합니다.
#
# [16/40] S-2
# --------------------------------------------------------------------------------
# 한글 입력: "정육점 홍보, 마블링이 좋은 한우 투플러스"
#
# 대조군 A: "A vibrant and inviting butcher shop display, showcasing a selection of high-quality Hanwoo beef with exceptional marbling. The setting is a rustic yet modern butcher shop, with wooden shelves filled w..."
#
# 실험군 B: "Hanwoo Two-Plus sirloin steak with exceptional marbling is centered in an overhead flat-lay composition, a single thick cut laid on a chilled stainless steel tray with a clean white studio background...."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 질감과 조명, 색감에서 매우 구체적이고 세밀한 표현을 통해 한우의 고급스러움과 신선함을 극대화합니다.
#
# [17/40] S-2
# --------------------------------------------------------------------------------
# 한글 입력: "과일 전문점, 제철 딸기와 샤인머스캣"
#
# 대조군 A: "A vibrant fruit shop interior showcasing an abundant selection of seasonal strawberries and Shine Muscat grapes. The shop is filled with wooden crates overflowing with plump, ripe strawberries, their ..."
#
# 실험군 B: "Seasonal strawberries and Shine Muscat grapes arranged in a clean overhead flat-lay, the strawberries whole and halved to reveal glossy red flesh while clusters of translucent pale green Shine Muscat ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 97점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 과일의 질감과 조명을 세밀하게 표현하고, 전문적인 촬영 기법을 활용하여 고급스러운 이미지를 제공한다. 이는 광고 이미지의 품질을 높이는 데 큰 장점이 된다.
#
# [18/40] S-2
# --------------------------------------------------------------------------------
# 한글 입력: "채소 가게, 유기농 신선 채소 모음"
#
# 대조군 A: "A vibrant organic vegetable shop brimming with a colorful assortment of fresh produce. The setting features rustic wooden shelves and crates overflowing with a variety of vegetables, including leafy g..."
#
# 실험군 B: "An assortment of organic fresh vegetables arranged for an overhead flat-lay, featuring bunches of leafy greens, glossy cherry tomatoes, crisp radishes with feathery tops, tender baby carrots with soil..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 채소의 질감, 조명, 색감, 구도 등 모든 측면에서 매우 구체적이고 전문적인 표현을 통해 신선함과 유기농의 매력을 극대화하여 전달합니다.
#
# [19/40] S-2
# --------------------------------------------------------------------------------
# 한글 입력: "연어 전문점, 노르웨이산 생연어 사시미"
#
# 대조군 A: "A beautifully arranged platter of fresh Norwegian salmon sashimi, showcasing the vibrant pink and orange hues of the fish. The sashimi is artfully sliced and elegantly placed on a dark wooden board, s..."
#
# 실험군 B: "Norwegian fresh salmon sashimi presented in a premium salmon specialty restaurant, thin translucent slices fanned neatly on a simple white porcelain plate seen in a clean overhead flat lay, top-down c..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 97점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 연어의 질감과 신선함을 매우 세밀하게 묘사하며, 조명과 구도를 통해 연어의 디테일을 극대화하여 광고 이미지 생성에 더 적합합니다.
#
# [20/40] S-2
# --------------------------------------------------------------------------------
# 한글 입력: "젓갈 가게, 전통 방식으로 담근 명란젓"
#
# 대조군 A: "Visualize a quaint, traditional Korean fish sauce shop, showcasing an array of beautifully crafted jars filled with vibrant, red-orange seasoned roe. The scene is set in a rustic wooden interior, with..."
#
# 실험군 B: "명란젓 presented as the main subject in a top-down overhead flat lay, a shallow traditional ceramic bowl filled with translucent, glossy pollock roe placed on a clean white surface in a minimalist jeotga..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 명란젓의 질감과 신선함을 극대화하는 데 초점을 맞추어 시각적 자극이 매우 강하며, 조명과 구도 설정이 명확하여 광고 이미지로서의 효과가 뛰어나다.
#
# [21/40] S-3
# --------------------------------------------------------------------------------
# 한글 입력: "카페 신메뉴, 딸기 라떼와 크루아상"
#
# 대조군 A: "A cozy café setting featuring a beautifully styled table with a delicious new menu item: a frothy strawberry latte in a clear glass, showcasing layers of pink and creamy white, topped with a sprinkle ..."
#
# 실험군 B: "A freshly prepared strawberry latte and a golden, flaky croissant arranged on a small wooden café table beside a sunlit window. The strawberry latte sits in a tall clear glass showing soft gradient la..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 질감, 조명, 색감, 구도, 업종 특화 키워드 모두에서 높은 점수를 받았으며, 특히 카메라 세팅과 구도에 대한 구체적인 설명이 전문성을 더해줍니다.
#
# [22/40] S-3
# --------------------------------------------------------------------------------
# 한글 입력: "베이커리 홍보, 갓 구운 소금빵과 크림빵"
#
# 대조군 A: "A warm and inviting bakery scene showcasing freshly baked goods. In the foreground, there are two types of bread: a golden crusted salt bread, glistening with a sprinkle of coarse sea salt, and a fluf..."
#
# 실험군 B: "Freshly baked salted roll and a cream-filled bun arranged for a bakery promotional shot, one roll whole and the cream bun gently torn open to reveal velvety custard oozing from the center. Photograph ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감 및 구도에 대한 구체적이고 전문적인 설명을 통해 고품질의 광고 이미지를 생성할 가능성이 높습니다.
#
# [23/40] S-3
# --------------------------------------------------------------------------------
# 한글 입력: "아이스크림 가게, 파스텔 톤 젤라또 3종"
#
# 대조군 A: "Imagine a charming ice cream shop that exudes a whimsical atmosphere, nestled in a sunlit corner of a bustling street. The shop features an inviting exterior painted in soft pastel colors, with a larg..."
#
# 실험군 B: "Three pastel-toned gelato scoops arranged in an elegant overhead flat lay, each scoop a distinct flavor — soft strawberry pink, pale mint green, and light peach-orange — placed in shallow metal gelato..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도 등 모든 평가 항목에서 높은 점수를 받았으며, 업종에 특화된 키워드도 잘 포함되어 있습니다.
#
# [24/40] S-3
# --------------------------------------------------------------------------------
# 한글 입력: "떡카페, 예쁜 화과자와 전통차 세트"
#
# 대조군 A: "A beautifully arranged table setting in a cozy tea cafe, showcasing an elegant selection of traditional Korean sweets, known as 'hwagwaja', alongside delicate porcelain cups filled with steaming tradi..."
#
# 실험군 B: "A set of pretty 화과자 (delicate rice confections) paired with a traditional Korean tea set arranged on a low wooden table inside a cozy tteok cafe. Shot on a Canon EOS R5 with a 50mm f/1.4 lens at wide ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 99점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도에 대한 구체적인 설명이 뛰어나며, 시각적 자극을 극대화하여 광고 이미지 생성에 매우 적합하다.
#
# [25/40] S-3
# --------------------------------------------------------------------------------
# 한글 입력: "샌드위치 전문점, 건강한 샐러드 샌드위치"
#
# 대조군 A: "A vibrant and inviting sandwich shop interior, showcasing a health-focused theme. The setting features a rustic wooden counter adorned with fresh ingredients, including colorful vegetables like ripe t..."
#
# 실험군 B: "A healthy salad sandwich placed slightly off-center on a ceramic plate, the sandwich cut in half to reveal layers of crisp romaine and butter lettuce, thinly sliced heirloom tomatoes, ripe avocado, cr..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 음식의 질감과 디테일을 매우 구체적으로 묘사하고, 조명과 구도를 명확하게 설정하여 시각적 자극을 극대화함.
#
# [26/40] S-3
# --------------------------------------------------------------------------------
# 한글 입력: "서점 카페, 책과 함께하는 커피 타임"
#
# 대조군 A: "A cozy bookstore cafe scene, filled with shelves of colorful books that reach from the floor to the ceiling. In the foreground, a rustic wooden table holds a steaming cup of coffee, its rich aroma waf..."
#
# 실험군 B: "A steaming cup of coffee resting next to an open book on a small wooden table inside a cozy bookstore café, photographed as a calm morning coffee moment. Shot on a Canon EOS R5 with a 50mm f/1.4 lens,..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 커피와 책의 질감을 세밀하게 묘사하고, 조명과 색감을 통해 감성적인 분위기를 잘 표현하여 광고 이미지 생성에 더 적합합니다.
#
# [27/40] S-3
# --------------------------------------------------------------------------------
# 한글 입력: "화장품 매장, 봄 시즌 신제품 립스틱"
#
# 대조군 A: "Imagine a vibrant cosmetics store showcasing a stunning display of new spring season lipsticks. The setting is bright and inviting, with pastel-colored walls adorned with floral motifs that evoke a se..."
#
# 실험군 B: "Spring collection lipsticks displayed in a boutique cosmetics store, three tubes arranged on a low wooden counter with one cap removed and the creamy bullet slightly twisted up to reveal its smooth su..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 립스틱의 질감과 디테일을 매우 세밀하게 묘사하며, 조명과 색감 설정이 업종에 적합합니다.
#
# [28/40] S-3
# --------------------------------------------------------------------------------
# 한글 입력: "약국 건강기능식품, 비타민과 유산균"
#
# 대조군 A: "A bright and inviting pharmacy interior, showcasing a well-organized shelf filled with an array of health supplements, including colorful bottles of vitamins and probiotic capsules. The setting is wel..."
#
# 실험군 B: "A pharmacy display of health supplements featuring neatly arranged amber vitamin bottles, a small clear glass jar filled with probiotic capsules, and a blister pack placed on a light wooden counter to..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도 등 모든 항목에서 매우 구체적이고 감성적으로 표현되어 있으며, 업종에 특화된 요소들이 잘 반영되어 있다.
#
# [29/40] S-3
# --------------------------------------------------------------------------------
# 한글 입력: "문구점 홍보, 예쁜 다이어리와 펜 세트"
#
# 대조군 A: "A beautifully arranged display of a stylish diary and a matching pen set, set in a cozy, inviting stationery shop. The diary, with a soft leather cover in pastel pink, features intricate gold embossin..."
#
# 실험군 B: "A pretty diary and matching pen set arranged as the central subject in an inviting promotional overhead flat lay. The leatherette diary sits slightly angled with its elastic band and ribbon bookmark v..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 89점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도, 업종 특화 키워드 모든 면에서 매우 구체적이고 세부적인 설명을 제공하여 광고 이미지 생성에 더 적합하다.
#
# [30/40] S-3
# --------------------------------------------------------------------------------
# 한글 입력: "기념품샵, 여행 기념 엽서와 마그넷"
#
# 대조군 A: "A charming souvenir shop filled with an array of travel memorabilia. The scene showcases a vibrant display of colorful postcards featuring iconic landmarks and scenic views from around the world, neat..."
#
# 실험군 B: "A cozy souvenir shop countertop filled with travel postcards and colorful enamel magnets, a gentle scene of a customer’s hand reaching to lift a fanned postcard from a neat stack. Shot on a Canon EOS ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 83점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도 등 모든 면에서 구체적이고 감성적인 표현이 뛰어나다. 업종 특화 키워드도 잘 반영되어 있어 광고 이미지 생성에 더 적합하다.
#
# [31/40] S-4
# --------------------------------------------------------------------------------
# 한글 입력: "한정식 홍보, 정갈한 반찬과 된장찌개 상차림"
#
# 대조군 A: "A beautifully arranged traditional Korean table setting featuring a variety of side dishes, known as banchan, alongside a steaming bowl of doenjang jjigae, a rich soybean paste stew. The table is made..."
#
# 실험군 B: "Hanjeongsik table setting featuring neatly arranged banchan and a steaming pot of doenjang jjigae, captured in a clean overhead flat-lay composition. Shot like a professional food photograph on a Cano..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 99점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도 및 업종 특화 요소를 매우 상세하고 전문적으로 설명하여 고품질의 광고 이미지를 생성할 수 있습니다.
#
# [32/40] S-4
# --------------------------------------------------------------------------------
# 한글 입력: "김밥 전문점, 다양한 김밥과 라면 세트"
#
# 대조군 A: "A vibrant and inviting scene inside a Korean gimbap specialty restaurant, showcasing a variety of colorful gimbap rolls beautifully arranged on a traditional wooden table. Each gimbap is filled with a..."
#
# 실험군 B: "A top-down overhead view of a gimbap specialty shop meal set featuring an assorted variety of gimbap rolls and a steaming bowl of ramen arranged neatly on a wooden table. Shot as a flat-lay on a full-..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 구체적인 카메라 설정과 촬영 각도를 통해 전문적인 사진 촬영의 디테일을 제공하며, 음식의 질감과 색감을 매우 구체적으로 표현하여 시각적 자극을 극대화합니다.
#
# [33/40] S-4
# --------------------------------------------------------------------------------
# 한글 입력: "백반집 점심 메뉴, 오늘의 집밥 정식"
#
# 대조군 A: "A cozy and inviting Korean 백반집 (lunch restaurant) setting, featuring a wooden table adorned with a traditional Korean table setting. The scene is filled with an array of colorful dishes, showcasing a ..."
#
# 실험군 B: "Traditional Korean home-style lunch set arranged as a top-down flat lay on a warm wooden table, featuring a steaming bowl of short-grain rice, a stone bowl of clear soup, a grilled mackerel fillet wit..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 음식의 질감과 디테일을 구체적으로 표현하며, 조명과 색감이 잘 조화되어 감성적이고 미각을 자극하는 이미지를 생성할 수 있음.
#
# [34/40] S-4
# --------------------------------------------------------------------------------
# 한글 입력: "국밥집 홍보, 뜨끈한 돼지국밥 한 그릇"
#
# 대조군 A: "Imagine a cozy, inviting Korean restaurant specializing in traditional pork soup, known as 'dwaeji-gukbap.' The scene features a steaming bowl of rich, savory pork soup placed at the center of a rusti..."
#
# 실험군 B: "A steaming bowl of pork gukbap (돼지국밥) sits centered in a top-down flat lay, steam curling up from the hot amber broth while tender slices of simmered pork and plump white rice are clearly visible bene..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 촬영 기법과 장비에 대한 구체적인 설명을 통해 시각적 디테일을 극대화하며, 음식의 질감과 분위기를 매우 효과적으로 전달합니다.
#
# [35/40] S-4
# --------------------------------------------------------------------------------
# 한글 입력: "냉면 전문점, 시원한 물냉면과 비빔냉면"
#
# 대조군 A: "A vibrant and inviting scene set in a traditional Korean cold noodle restaurant, showcasing two exquisite bowls of cold noodles prominently displayed on a wooden table. One bowl features mul naengmyeo..."
#
# 실험군 B: "A cold noodle restaurant scene featuring a chilled mul-naengmyeon in a clear icy broth and a vibrant bibim-naengmyeon tossed in spicy red sauce, presented in a neat overhead flat-lay arrangement on a ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 구도 등 모든 항목에서 매우 구체적이고 전문적인 설명을 제공하여 광고 이미지 생성에 더 적합하다.
#
# [36/40] S-4
# --------------------------------------------------------------------------------
# 한글 입력: "반찬 가게, 정성 가득 수제 반찬 10종"
#
# 대조군 A: "A cozy, inviting Korean banchan shop filled with an array of homemade side dishes. The scene showcases a wooden display counter laden with ten different vibrant and colorful banchan, each beautifully ..."
#
# 실험군 B: "Ten handmade Korean side dishes (수제 반찬 10종) arranged in a neat overhead flat lay, each dish presented in simple white and earthenware bowls on a warm wooden counter inside a small, tidy banchan shop. ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 99점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도, 업종 특화 키워드 모든 면에서 매우 세밀하고 구체적으로 표현되어 있어 광고 이미지 생성에 더 적합합니다.
#
# [37/40] S-4
# --------------------------------------------------------------------------------
# 한글 입력: "분식집, 떡볶이와 순대 세트 메뉴"
#
# 대조군 A: "A cozy and inviting Korean street food restaurant interior, showcasing a vibrant food display featuring a set menu of spicy tteokbokki and savory sundae. The tteokbokki, with its bright red sauce glis..."
#
# 실험군 B: "Tteokbokki and sundae set meal captured in a clean top-down flat lay, the main subject centered and arranged with side dishes and utensils for a traditional Korean snack bar presentation. Shot on a Ca..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 89점
#    실험군 B 점수: 97점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 촬영 기법과 장비에 대한 구체적인 설명을 통해 전문성을 높였으며, 음식의 질감과 색감을 매우 세밀하게 묘사하여 시각적 자극을 극대화했습니다.
#
# [38/40] S-4
# --------------------------------------------------------------------------------
# 한글 입력: "칼국수집, 손칼국수와 왕만두"
#
# 대조군 A: "A cozy, inviting Korean noodle shop interior featuring a rustic wooden table set with bowls of fresh hand-cut kalguksu (noodle soup) and large, steaming king dumplings (wang mandu). The scene is illum..."
#
# 실험군 B: "Hand-cut kalguksu noodles in a steaming ceramic bowl and a platter of oversized wang-mandu dumplings take center stage in a cozy Korean noodle house overhead spread. Shot as a top-down flat lay on a w..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 음식의 질감과 디테일을 세밀하게 표현하고, 조명과 구도에 대한 명확한 설명을 제공하여 광고 이미지 생성에 더 적합하다.
#
# [39/40] S-4
# --------------------------------------------------------------------------------
# 한글 입력: "전문점 홍보, 바삭한 해물파전과 막걸리"
#
# 대조군 A: "A cozy, traditional Korean restaurant setting featuring a beautifully arranged table displaying a large, golden-brown seafood pancake (haemul pajeon) with crispy edges. The pancake is garnished with v..."
#
# 실험군 B: "Crispy seafood pancake and makgeolli presented as a restaurant promotion, captured in a warm overhead flat-lay that highlights texture and authenticity. Shot on a Canon EOS R5 with a 35mm lens at f/5...."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감과 조명 설정에 대한 세부적인 묘사가 뛰어나며, 전문적인 촬영 기법을 활용하여 음식의 매력을 극대화할 수 있는 요소를 잘 설명하고 있다.
#
# [40/40] S-4
# --------------------------------------------------------------------------------
# 한글 입력: "족발/보쌈 전문점, 쫄깃한 족발과 보쌈"
#
# 대조군 A: "A cozy, inviting Korean restaurant specializing in jokbal (pork trotters) and bossam (wrapped pork). The interior is warmly lit with soft golden hues, highlighting wooden tables set with traditional K..."
#
# 실험군 B: "A top-down overhead shot of a freshly prepared spread featuring a glistening, chewy plate of jokbal (braised pig's trotters) alongside a neatly arranged platter of bossam (sliced boiled pork) presente..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감, 구도 모든 면에서 매우 구체적이고 전문적인 표현을 사용하여 시각적 자극을 극대화하고 있습니다.
#
#
# ====================================================================================================
# 📈 S등급 (감성 및 미각 자극) 평가 요약
# ====================================================================================================
# 평가 케이스 수: 40/40
#
# 🏆 승패 현황:
#    대조군 A 승: 0회 (0.0%)
#    실험군 B 승: 40회 (100.0%)
#    무승부: 0회 (0.0%)
#
# 📊 평균 점수:
#    대조군 A: 87.0점
#    실험군 B: 96.6점

# %% [markdown]
# ### 6.4 A등급 GPT 평가 실행

# %%
# A등급 GPT 평가 - 섹션 3에서 생성된 a_grade_results 활용
a_eval_results, a_wins = evaluate_existing_results(
    a_grade_results,  # 섹션 3에서 생성된 결과 사용
    "A등급 (비주얼 변화 및 자기관리)",
    sample_size=None  # 전체 평가
)
# Out:
# ====================================================================================================
# 📊 A등급 (비주얼 변화 및 자기관리) GPT 평가 (기존 A/B 결과 활용)
# ====================================================================================================
#
# 📌 전체 40개 평가
#
# [1/40] A-1
# --------------------------------------------------------------------------------
# 한글 입력: "미용실 봄 헤어 스타일, 웨이브 펌 시술 결과"
#
# 대조군 A: "Create an image of a stylish hair salon during spring, showcasing a beautiful model with elegant, soft wave perm hair. The setting is bright and inviting, with large windows allowing natural sunlight ..."
#
# 실험군 B: "A young woman showcasing a fresh spring wave perm hairstyle after a salon treatment, posed in a three-quarter close-up portrait with her head slightly tilted and a confident, relaxed expression. Shot ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 조명과 세밀한 디테일을 강조하여 고급스러운 살롱의 분위기와 헤어 스타일의 질감을 효과적으로 표현합니다.
#
# [2/40] A-1
# --------------------------------------------------------------------------------
# 한글 입력: "피부관리실 홍보, 맑고 깨끗한 피부 관리"
#
# 대조군 A: "A serene skincare clinic interior, showcasing a tranquil and inviting atmosphere. The room is filled with soft, natural light filtering through large windows, illuminating a pristine treatment area eq..."
#
# 실험군 B: "A close-up portrait of a young adult woman receiving a professional facial treatment, her face turned three-quarters to camera with a calm, confident expression as an esthetician’s gloved hand gently ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 피부결과 세럼의 미세 디테일을 강조하여 변화와 결과를 시각적으로 잘 표현하고, 전문적인 조명 설정을 통해 고급스러운 분위기를 제공합니다.
#
# [3/40] A-1
# --------------------------------------------------------------------------------
# 한글 입력: "네일샵 신상 디자인, 봄 꽃 네일 아트"
#
# 대조군 A: "A vibrant nail salon setting showcasing a new spring floral nail art design. The scene is filled with soft pastel colors, featuring a variety of blooming flowers like cherry blossoms, daisies, and tul..."
#
# 실험군 B: "Hands showcasing a nail salon's new spring floral nail art, fingers slightly splayed and gently resting on a soft white linen and pale marble surface so the manicure is the sole focus. Shot on a Canon..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 97점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 네일 아트의 디테일과 질감을 극대화하여 전문적이고 고급스러운 이미지를 제공하며, 업종 특화에 매우 적합합니다.
#
# [4/40] A-1
# --------------------------------------------------------------------------------
# 한글 입력: "성형외과 상담 안내, 자연스러운 코 성형"
#
# 대조군 A: "Create an image of a serene and inviting plastic surgery consultation room. The setting features modern yet warm decor with soft, neutral colors, including light beige and soft white tones. A comforta..."
#
# 실험군 B: "A close-up portrait of a young woman seated in a modern plastic surgery consultation room showing the natural result of a rhinoplasty, her head turned three-quarters to display the refined nasal bridg..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 코 성형의 디테일한 결과를 직접적으로 강조하며, 전문적인 조명과 촬영 기법을 사용하여 고급스러운 분위기를 잘 전달합니다.
#
# [5/40] A-1
# --------------------------------------------------------------------------------
# 한글 입력: "피부과 레이저 시술, 잡티 제거 전후 비교"
#
# 대조군 A: "Create a split-image comparison showcasing the effects of dermatological laser treatment for blemish removal. On the left side, depict a close-up of a woman's face before the treatment, highlighting v..."
#
# 실험군 B: "Close-up split portrait of a woman's mid-face showing a dermatology laser treatment comparison with the left side showing the skin condition before treatment and the right side showing the clear, heal..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 피부의 디테일을 강조하는 데 있어 더 높은 수준의 전문성과 신뢰감을 제공합니다. 고해상도 촬영과 조명 설정이 피부의 변화를 더 명확하게 전달합니다.
#
# [6/40] A-1
# --------------------------------------------------------------------------------
# 한글 입력: "미용실 염색 이벤트, 트렌디한 발레아주"
#
# 대조군 A: "An upscale hair salon interior showcasing a vibrant hair dye event focused on trendy balayage techniques. The setting is bright and inviting, with large windows allowing natural light to flood in, ill..."
#
# 실험군 B: "A female model showcasing a trendy balayage hair color in a close-up beauty portrait, slightly turned three-quarter profile with one hand gently lifting a lock to reveal the seamless root-to-tip gradi..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 97점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 발레아주 염색의 디테일과 결과를 고급스럽고 전문적으로 표현하여, 미용실 광고에 적합한 이미지를 생성할 수 있습니다.
#
# [7/40] A-1
# --------------------------------------------------------------------------------
# 한글 입력: "에스테틱 페이셜 케어, 광채 나는 피부"
#
# 대조군 A: "A serene spa environment showcasing an aesthetic facial care treatment in progress. The setting features a softly lit room with neutral-toned walls and natural wooden accents, creating a tranquil and ..."
#
# 실험군 B: "Close-up portrait of a woman after an aesthetic facial treatment, presenting luminous, dewy skin and a calm, confident expression as she slightly tilts her head toward the camera. Shot like a high-end..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 피부의 세부 질감과 광채를 강조하며, 조명 및 색조 설정이 매우 전문적입니다. 이는 에스테틱 페이셜 케어의 광고 이미지에 적합한 고급스러운 느낌을 잘 전달합니다.
#
# [8/40] A-1
# --------------------------------------------------------------------------------
# 한글 입력: "네일샵 젤네일, 고급스러운 글리터 디자인"
#
# 대조군 A: "Imagine an upscale nail salon interior, elegantly designed with a modern aesthetic. The setting features plush seating in soft pastel colors, with ambient lighting that casts a warm glow throughout th..."
#
# 실험군 B: "Manicured hand showcasing gel nails with a luxurious glitter design, posed elegantly with fingers slightly curved to emphasize nail length and glossy surfaces. Shot on a full-frame camera with a 100mm..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 네일 디자인의 디테일과 질감을 강조하여 고급스러움을 극대화하고, 조명 설정을 통해 시각적 효과를 극대화함으로써 광고 이미지 생성에 더 적합함.
#
# [9/40] A-1
# --------------------------------------------------------------------------------
# 한글 입력: "헤어샵 남성 커트, 깔끔한 투블럭 스타일"
#
# 대조군 A: "A modern barbershop interior featuring a stylish, contemporary design. In the foreground, a male model sits in a sleek, black barber chair, showcasing a fresh two-block haircut, characterized by short..."
#
# 실험군 B: "A young male client showcasing a clean two-block haircut, captured in a tight head-and-shoulders portrait that emphasizes the precise contrast between the short sides and the longer textured top. Shot..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 헤어스타일의 디테일한 질감과 조명 설정을 매우 구체적으로 설명하며, 전문적인 사진 촬영 기법을 통해 고급스러운 이미지를 잘 전달합니다.
#
# [10/40] A-1
# --------------------------------------------------------------------------------
# 한글 입력: "속눈썹 연장 전문, 자연스러운 볼륨 래쉬"
#
# 대조군 A: "A serene beauty salon interior focusing on eyelash extensions, featuring a cozy and inviting atmosphere. Soft, natural light filters through large windows adorned with sheer curtains, casting gentle s..."
#
# 실험군 B: "A close-up of a woman's eye with freshly applied natural-volume eyelash extensions, the eye gently closed to showcase soft, seamless fanning along the lash line and a natural, lightweight silhouette. ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 속눈썹 연장의 정밀한 디테일과 질감을 강조하여 전문성과 신뢰감을 높이며, 업종에 특화된 이미지를 잘 전달합니다.
#
# [11/40] A-2
# --------------------------------------------------------------------------------
# 한글 입력: "헬스장 PT 프로그램, 1:1 개인 트레이닝"
#
# 대조군 A: "A vibrant and dynamic personal training session in a modern gym setting. The scene captures a dedicated personal trainer, a fit individual in athletic wear, guiding a client through a rigorous workout..."
#
# 실험군 B: "A one-on-one personal training session in a bright modern gym, the trainer guiding a client through a weighted lunge while supporting form, captured mid-motion with both figures in a full-body athleti..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 텍스처와 조명에 대한 세밀한 묘사를 통해 헬스장 PT 프로그램의 역동성과 전문성을 더욱 효과적으로 전달합니다.
#
# [12/40] A-2
# --------------------------------------------------------------------------------
# 한글 입력: "요가 스튜디오, 아침 명상 요가 클래스"
#
# 대조군 A: "A serene and tranquil yoga studio bathed in the soft light of dawn. The room is spacious and filled with natural elements, featuring wooden floors and large windows that allow golden sunlight to strea..."
#
# 실험군 B: "A single yoga practitioner seated cross-legged at the front of a sunlit studio, leading a calm morning meditation yoga class while other students sit softly blurred in the background. Shot on a Canon ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 사진 촬영 기법과 디테일한 묘사를 통해 고급스러운 분위기를 잘 전달합니다. 특히, 피부결과 근육 선명도를 강조하여 시각적 변화를 효과적으로 보여줍니다.
#
# [13/40] A-2
# --------------------------------------------------------------------------------
# 한글 입력: "필라테스 센터, 체형 교정 프로그램"
#
# 대조군 A: "A serene and modern Pilates studio, featuring large floor-to-ceiling windows that let in soft, natural light, creating an inviting atmosphere. The room is adorned with polished wooden floors and minim..."
#
# 실험군 B: "A Pilates instructor adjusting a client's alignment as the client holds a dynamic full-body Pilates exercise, captured mid-movement to emphasize posture correction and muscle engagement in a polished ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 81점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 체형 교정과 근육 참여를 강조하는 디테일한 시각적 요소를 잘 표현하여 업종의 특성을 더 잘 반영합니다.
#
# [14/40] A-2
# --------------------------------------------------------------------------------
# 한글 입력: "태권도 학원, 어린이 품새 수업"
#
# 대조군 A: "An energetic scene depicting a taekwondo academy specifically for children, showcasing a vibrant and dynamic atmosphere. The setting is an indoor training hall, with bright, colorful mats covering the..."
#
# 실험군 B: "Children performing Taekwondo poomsae in a bright training hall, captured mid-movement as a group executes synchronized forms with focused, determined expressions. Shot like professional sports photog..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 사진 촬영 기법과 조명 설정을 통해 태권도 품새의 역동성과 에너지를 더욱 효과적으로 전달합니다.
#
# [15/40] A-2
# --------------------------------------------------------------------------------
# 한글 입력: "다이어트 클리닉, 3개월 체중 감량 성공"
#
# 대조군 A: "A serene and modern diet clinic interior, featuring a bright and airy consultation room with large windows letting in warm, natural light. The room is adorned with soothing colors, such as soft greens..."
#
# 실험군 B: "A confident woman in her early 30s, lean and visibly toned, celebrating after completing a three-month weight loss program stands in the bright reception area of a modern diet clinic with her arms rai..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 78점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 체중 감량의 결과를 시각적으로 명확하게 표현하며, 전문적이고 고급스러운 분위기를 잘 전달합니다.
#
# [16/40] A-2
# --------------------------------------------------------------------------------
# 한글 입력: "마사지샵 홍보, 타이 마사지 전신 케어"
#
# 대조군 A: "A serene and inviting massage therapy room designed for a Thai massage experience. The setting is softly lit with warm, ambient lighting that creates a calming atmosphere. The room features traditiona..."
#
# 실험군 B: "A professional Thai massage therapist performing a full-body traditional Thai massage, gently stretching a client's leg while using firm, precise palm and forearm pressure along the hips and back. Sho..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 80점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 마사지의 실제적인 디테일과 변화를 강조하여, 고객에게 마사지의 효과를 시각적으로 전달하는 데 더 적합합니다.
#
# [17/40] A-2
# --------------------------------------------------------------------------------
# 한글 입력: "크로스핏 박스, 고강도 인터벌 트레이닝"
#
# 대조군 A: "A vibrant CrossFit box filled with energetic athletes engaged in high-intensity interval training. The setting is an industrial-style gym with exposed brick walls and large windows letting in bright n..."
#
# 실험군 B: "CrossFit box during a high-intensity interval training session, captured from an elevated overhead perspective that shows multiple workout stations and athletes in mid-movement. Shot on a Canon EOS R5..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 조명, 질감, 색감 등 세부적인 요소를 상세히 설명하여 시각적 디테일이 뛰어나고, 전문적인 장비와 촬영 기법을 언급하여 신뢰감을 준다.
#
# [18/40] A-2
# --------------------------------------------------------------------------------
# 한글 입력: "복싱 체육관, 다이어트 복싱 프로그램"
#
# 대조군 A: "A vibrant boxing gym filled with energy and motivation, featuring a diverse group of individuals engaged in a dynamic boxing workout. The setting showcases a spacious interior with high ceilings, wall..."
#
# 실험군 B: "A fit athletic woman throwing a powerful hook at a worn leather heavy bag in a boxing gym, captured mid-motion with her full body in frame and muscles visibly engaged. Shot like professional sports ph..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 85점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 인물의 근육과 운동의 역동성을 강조하며, 전문적인 사진 촬영 기법을 통해 고급스러운 이미지를 생성할 수 있습니다.
#
# [19/40] A-2
# --------------------------------------------------------------------------------
# 한글 입력: "스피닝 센터, 신나는 그룹 사이클링"
#
# 대조군 A: "Imagine a vibrant spinning center filled with energy and excitement, where a diverse group of enthusiastic individuals is engaged in a dynamic group cycling session. The setting is a spacious, well-li..."
#
# 실험군 B: "A dynamic spinning center group cycling class with a confident instructor leading a packed studio, riders pedaling intensely in staggered rows and leaning forward in powerful, synchronized motion. Sho..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 전문적인 촬영 기법과 세부적인 텍스처 표현이 뛰어나며, 조명과 색감의 조화가 잘 이루어져 있어 광고 이미지 생성에 더욱 적합합니다.
#
# [20/40] A-2
# --------------------------------------------------------------------------------
# 한글 입력: "스파 웰니스, 아로마 테라피 힐링"
#
# 대조군 A: "An inviting spa wellness scene featuring a serene aromatherapy therapy room. The room is softly illuminated by warm, dim lighting, creating a tranquil atmosphere. In the foreground, a wooden massage t..."
#
# 실험군 B: "A relaxed spa client receiving an aromatherapy healing massage, therapist’s hands gently applying warmed essential oil to the client’s shoulders and temples while wisps of steam rise from a nearby cer..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 아로마 테라피의 디테일과 촉각적인 요소를 강조하여 시각적 임팩트가 강하며, 전문적인 촬영 장비를 언급하여 신뢰감을 줍니다.
#
# [21/40] A-3
# --------------------------------------------------------------------------------
# 한글 입력: "여성 의류 매장, 봄 신상 원피스 컬렉션"
#
# 대조군 A: "A vibrant women's clothing store showcasing a spring collection of dresses. The interior is filled with soft pastel colors, with floral patterns adorning the walls and delicate greenery hanging from t..."
#
# 실험군 B: "Female model wearing a spring new dress from a women's clothing store stands in a relaxed three-quarter pose on an urban sidewalk, one hand lightly touching the dress waist and the other holding a sma..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 의류의 디테일과 촬영 기술을 강조하여 제품의 고급스러움과 전문성을 잘 전달합니다. 이는 광고 이미지 생성에 있어 더 높은 품질의 결과물을 기대할 수 있습니다.
#
# [22/40] A-3
# --------------------------------------------------------------------------------
# 한글 입력: "남성 정장 전문점, 맞춤 수트 제작"
#
# 대조군 A: "A sophisticated tailor shop specializing in men's suits, showcasing a luxurious interior filled with rich mahogany wood and elegant furnishings. In the foreground, a skilled tailor, dressed in a class..."
#
# 실험군 B: "A bespoke men's suit on a tailor's mannequin being meticulously adjusted by a craftsman's hands, the tailor smoothing the sleeve and checking the shoulder line in a small high-end tailoring studio. Sh..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 맞춤 수트의 디테일과 전문성을 더욱 강조하며, 조명과 색조의 활용이 뛰어납니다. 이는 고급스러운 브랜드 이미지를 효과적으로 전달합니다.
#
# [23/40] A-3
# --------------------------------------------------------------------------------
# 한글 입력: "아동복 가게, 귀여운 봄 키즈 패션"
#
# 대조군 A: "Imagine a charming children's clothing store filled with a delightful array of spring fashion for kids. The setting features a bright and airy interior, illuminated by soft natural light streaming thr..."
#
# 실험군 B: "A young child model around four to six years old poses in a playful three-quarter stance wearing a coordinated spring outfit from a boutique kids' collection, the focus on the full body styling and fa..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 81점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 아동복의 질감과 스타일링을 세밀하게 강조하며, 전문적인 조명과 촬영 기법을 활용하여 고급스러운 광고 이미지를 생성할 수 있습니다.
#
# [24/40] A-3
# --------------------------------------------------------------------------------
# 한글 입력: "신발 매장, 트렌디한 스니커즈 신상"
#
# 대조군 A: "A modern shoe store interior that showcases a collection of trendy new sneakers. The setting is vibrant and lively, with sleek wooden shelves displaying an array of colorful sneakers in various styles..."
#
# 실험군 B: "Trendy new sneakers modeled in a modern urban shoe store, a model wearing the sneakers standing in a three-quarter pose with one foot slightly forward to emphasize the side profile and sole. Shot as h..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 신발의 디테일한 질감과 구조를 강조하며, 고급스러운 패션 사진 촬영 기법을 통해 제품의 고급스러움을 효과적으로 부각시켰습니다.
#
# [25/40] A-3
# --------------------------------------------------------------------------------
# 한글 입력: "가방 브랜드, 가죽 토트백 신제품"
#
# 대조군 A: "A luxurious leather tote bag displayed elegantly in a modern, chic setting. The tote bag features a rich, deep brown color with a smooth finish, showcasing its high-quality craftsmanship. Surrounding ..."
#
# 실험군 B: "Leather tote bag carried by a female model in a three-quarter full-body fashion pose on a quiet city sidewalk, the bag slightly angled toward the camera to reveal its silhouette and open top. Shot on ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 가방의 질감과 디테일을 더 세밀하게 설명하며, 전문적인 촬영 기법을 강조하여 광고 이미지 생성에 더 적합합니다.
#
# [26/40] A-3
# --------------------------------------------------------------------------------
# 한글 입력: "시계/주얼리샵, 프리미엄 시계 컬렉션"
#
# 대조군 A: "Imagine a luxurious watch and jewelry shop interior, elegantly designed with polished wooden displays and soft velvet drapes. The walls are adorned with tasteful artwork and mirrors that reflect the s..."
#
# 실험군 B: "Premium wristwatch collection arranged in an overhead flat-lay, three luxury watches shown from a top-down perspective — a brushed stainless steel chronograph, a rose-gold dress watch with fine leathe..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 시계의 질감과 디테일을 강조하여 고급스러운 제품의 특성을 잘 드러냄으로써 광고 이미지 생성에 더 적합합니다.
#
# [27/40] A-3
# --------------------------------------------------------------------------------
# 한글 입력: "안경점 신상, 트렌드 뿔테 안경"
#
# 대조군 A: "A stylish eyewear store display showcasing the latest trendy horn-rimmed glasses. The setting is a chic boutique with modern decor, featuring sleek wooden shelves lined with various pairs of glasses. ..."
#
# 실험군 B: "A fashionable model wearing trendy horn-rimmed eyeglasses poses in a three-quarter full body fashion shot, standing confidently against a softly blurred urban rooftop street scene. Shot like a commerc..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 안경의 디테일과 패션 요소를 강조하여 고급스러운 이미지를 잘 전달합니다. 조명과 색감의 활용이 뛰어나며, 제품의 질감과 디자인을 세밀하게 표현합니다.
#
# [28/40] A-3
# --------------------------------------------------------------------------------
# 한글 입력: "사진관 홍보, 가족 기념사진 촬영"
#
# 대조군 A: "A warm and inviting family photography studio setting, filled with soft, natural light filtering through large windows. The room is decorated with charming, rustic elements, such as wooden frames show..."
#
# 실험군 B: "Family of four posing for a promotional family portrait at a professional photo studio, arranged in a relaxed, fashion-forward composition with parents seated on a low bench and two children standing ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 조명, 스타일링, 카메라 설정 등에서 전문성과 디테일이 뛰어나며, 고급스러운 분위기를 잘 전달합니다.
#
# [29/40] A-3
# --------------------------------------------------------------------------------
# 한글 입력: "웨딩샵 드레스, 우아한 레이스 웨딩드레스"
#
# 대조군 A: "A stunning wedding dress displayed in an elegant bridal shop, showcasing intricate lace detailing that flows beautifully. The dress is adorned with delicate embroidery and sparkling embellishments, ca..."
#
# 실험군 B: "Elegant lace wedding dress on a mannequin displayed prominently in a refined bridal boutique, the camera focused on the intricate bodice as the dress gently cascades into layered tulle and satin. Shot..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 89점
#    실험군 B 점수: 98점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 촬영 기술과 조명 조건을 구체적으로 설명하여 고급스러운 분위기를 잘 전달한다. 이는 웨딩샵 드레스 광고에 적합하다.
#
# [30/40] A-3
# --------------------------------------------------------------------------------
# 한글 입력: "한복 대여점, 설날 전통 한복 렌탈"
#
# 대조군 A: "A beautifully arranged Hanbok rental shop showcasing a vibrant collection of traditional Korean Hanboks for the Lunar New Year celebration. The setting is warm and inviting, with wooden shelves lined ..."
#
# 실험군 B: "Seollal traditional hanbok rental display in a boutique shop, three mannequins arranged in a gentle arc wearing a vibrant women’s chima-jeogori, a dignified men’s durumagi and a colorful child’s hanbo..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 한복의 질감과 색상을 강조하는 동시에 전문적인 촬영 기법을 활용하여 고급스러운 이미지를 생성할 수 있는 가능성을 높입니다.
#
# [31/40] A-4
# --------------------------------------------------------------------------------
# 한글 입력: "꽃집 홍보, 발렌타인 장미 꽃다발"
#
# 대조군 A: "A charming flower shop interior, bursting with vibrant colors and the scent of fresh blooms. In the center, a stunning bouquet of red roses, beautifully arranged with delicate green foliage, symbolize..."
#
# 실험군 B: "Valentine's rose bouquet for a florist promotional shoot, tightly framed as an extreme macro product portrait showing a hand-tied cluster of deep red roses with delicate rosebud centers and layered pe..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 매크로 촬영을 통해 꽃의 디테일을 극대화하여 고급스러운 느낌을 주며, 전문적인 조명과 색감 설정으로 발렌타인 데이의 로맨틱한 분위기를 효과적으로 전달합니다.
#
# [32/40] A-4
# --------------------------------------------------------------------------------
# 한글 입력: "반려동물 용품점, 강아지 봄 옷 신상"
#
# 대조군 A: "Imagine a vibrant pet supply store filled with an array of colorful spring dog clothing. The shop is adorned with cheerful decorations, featuring pastel hues of pink, blue, and yellow that evoke a sen..."
#
# 실험군 B: "New spring dog clothes showcased in a boutique pet supply store with a small beagle model wearing a pastel floral lightweight raincoat while a miniature mannequin nearby displays a matching knitted sw..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 제품의 질감과 디테일을 강조하며, 전문적인 촬영 기법을 통해 고급스러운 이미지를 생성할 수 있습니다.
#
# [33/40] A-4
# --------------------------------------------------------------------------------
# 한글 입력: "동물병원 안내, 반려견 건강검진 패키지"
#
# 대조군 A: "A warm and inviting animal hospital reception area designed for pet owners, featuring a friendly veterinarian and a playful dog. The setting is bright and cheerful, with soft natural light streaming t..."
#
# 실험군 B: "A calm adult dog sitting on an examination table receiving a comprehensive health checkup package at a modern veterinary clinic, the scene staged as a promotional service photograph that emphasizes tr..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 89점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 세부적인 질감 표현과 전문적인 조명 설정을 통해 더 높은 수준의 전문성과 신뢰감을 제공합니다. 이는 동물병원 광고에 적합한 요소입니다.
#
# [34/40] A-4
# --------------------------------------------------------------------------------
# 한글 입력: "장난감 가게, 레고 신제품 출시"
#
# 대조군 A: "A vibrant and inviting toy store filled with colorful shelves brimming with a variety of LEGO sets. The scene is set during the day, with sunlight streaming through large display windows, casting warm..."
#
# 실험군 B: "New LEGO set displayed as the central subject for a product launch, arranged in a clean toy store launch scene from a top-down flat lay perspective. Shot like premium commercial product photography on..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 레고 신제품의 디테일과 고급스러운 제품 이미지를 강조하여, 광고 이미지 생성에 더 적합합니다. 제품의 질감과 조명에 대한 세부적인 설명이 뛰어나며, 전문적인 느낌을 잘 전달합니다.
#
# [35/40] A-4
# --------------------------------------------------------------------------------
# 한글 입력: "가구점 홍보, 미니멀 원목 책상 세트"
#
# 대조군 A: "A beautifully arranged minimalist wood desk set showcased in a modern furniture store. The scene features a sleek, natural wood desk with clean lines and a matching wooden chair, placed against a soft..."
#
# 실험군 B: "Minimal solid wood desk set displayed as a premium furniture store promotional product, a clean three-quarter view of the desk with a matching stool tucked underneath and a single small ceramic mug an..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 가구의 질감과 디테일을 강조하며, 고급스러운 상업 사진 촬영 기법을 통해 전문성과 신뢰감을 잘 전달합니다.
#
# [36/40] A-4
# --------------------------------------------------------------------------------
# 한글 입력: "세탁소 서비스, 명품 가방 클리닝"
#
# 대조군 A: "A luxurious dry cleaning service setting, showcasing an elegant boutique interior with soft, ambient lighting that creates a sophisticated atmosphere. The focal point of the scene is a pristine, high-..."
#
# 실험군 B: "Luxury handbag being professionally cleaned by a specialist technician in a high-end laundry atelier, shown in an extreme macro close-up that emphasizes the meticulous restoration process. Shot on a C..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 클리닝 과정의 세부사항을 매크로 촬영으로 강조하여, 세탁소 서비스의 전문성과 신뢰성을 효과적으로 전달합니다.
#
# [37/40] A-4
# --------------------------------------------------------------------------------
# 한글 입력: "피아노 학원, 어린이 피아노 레슨"
#
# 대조군 A: "A bright and cheerful piano academy, filled with the sounds of children learning to play the piano. The setting showcases a spacious, sunlit classroom with large windows that let in warm, golden light..."
#
# 실험군 B: "Children's piano lesson in a bright, organized teaching studio with a young child seated at an upright piano and a teacher gently guiding the child's hand on the keys. Shot as a wide-angle interior ar..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 전문적인 사진 촬영 기법과 세부적인 질감 표현을 통해 고급스러운 학습 환경을 잘 나타내며, 교육 시설의 구조적 배치를 강조합니다.
#
# [38/40] A-4
# --------------------------------------------------------------------------------
# 한글 입력: "미술학원 홍보, 수채화 클래스 작품전"
#
# 대조군 A: "A vibrant art exhibition showcasing watercolor paintings created by students at an art academy. The setting is a bright and airy gallery space filled with natural light streaming in through large wind..."
#
# 실험군 B: "Watercolor class exhibition pieces arranged on a large light oak table, photographed from above in an inviting art studio setting. Shot on a Canon EOS R5 with a 35mm lens at f/5.6 for even sharpness, ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 작품의 질감과 세부 요소를 더 잘 강조하여 미술학원의 전문성을 부각시키며, 광고 이미지 생성에 적합합니다.
#
# [39/40] A-4
# --------------------------------------------------------------------------------
# 한글 입력: "자전거 매장, 접이식 미니벨로 신상"
#
# 대조군 A: "A vibrant bicycle store interior showcasing a range of sleek, foldable mini bikes. The setting is bright and inviting, with large windows allowing natural light to stream in, illuminating the colorful..."
#
# 실험군 B: "Foldable mini velo bicycles arranged in a clean, modern bicycle shop showroom, displayed from a slightly elevated top-down three-quarter angle so each folding mechanism and compact silhouette is clear..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 실험군 B는 제품의 디테일과 전문성을 강조하여 고급스러운 광고 이미지를 생성하는 데 더 적합하다. 특히, 자전거의 접이식 메커니즘과 질감이 잘 드러나 있어 소비자에게 제품의 장점을 직접적으로 전달할 수 있다.
#
# [40/40] A-4
# --------------------------------------------------------------------------------
# 한글 입력: "인테리어 소품샵, 북유럽 감성 조명"
#
# 대조군 A: "An inviting interior decor shop showcasing a cozy Scandinavian aesthetic. The shop is filled with an array of stylish decorative items, including minimalist furniture, elegant vases, and unique wall a..."
#
# 실험군 B: "Scandinavian-style interior decor shop display focusing on Nordic lighting fixtures arranged on a low oak display table and floating shelves, pendant lamps and small table lamps casting a warm, gentle..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 조명과 질감의 디테일을 구체적으로 설명하고, 전문적인 촬영 기법을 언급하여 더 높은 신뢰감을 줍니다.
#
#
# ====================================================================================================
# 📈 A등급 (비주얼 변화 및 자기관리) 평가 요약
# ====================================================================================================
# 평가 케이스 수: 40/40
#
# 🏆 승패 현황:
#    대조군 A 승: 0회 (0.0%)
#    실험군 B 승: 40회 (100.0%)
#    무승부: 0회 (0.0%)
#
# 📊 평균 점수:
#    대조군 A: 84.8점
#    실험군 B: 94.5점

# %% [markdown]
# ### 6.5 B+C등급 GPT 평가 실행

# %%
# B+C등급 GPT 평가 - 섹션 3에서 생성된 bc_grade_results 활용
bc_eval_results, bc_wins = evaluate_existing_results(
    bc_grade_results,  # 섹션 3에서 생성된 결과 사용
    "B+C등급 (공간 체험/교육 + 신뢰 기반 서비스)",
    sample_size=None  # 전체 평가
)
# Out:
# ====================================================================================================
# 📊 B+C등급 (공간 체험/교육 + 신뢰 기반 서비스) GPT 평가 (기존 A/B 결과 활용)
# ====================================================================================================
#
# 📌 전체 60개 평가
#
# [1/60] B-1
# --------------------------------------------------------------------------------
# 한글 입력: "입시학원 홍보, 소수정예 수학 클래스"
#
# 대조군 A: "A cozy and modern classroom setting designed for an exclusive small group of students engaged in a mathematics class. The room is filled with natural light streaming through large windows, casting sof..."
#
# 실험군 B: "A professional entrance exam tutoring academy classroom showcasing a small elite math class in session. The scene shows a focused tutor leaning slightly over a student’s desk explaining a concept whil..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문성과 신뢰감을 강조하며, 공간감을 잘 표현하여 입시학원의 특성을 잘 드러냄.
#
# [2/60] B-1
# --------------------------------------------------------------------------------
# 한글 입력: "외국어 학원, 원어민 영어 회화 수업"
#
# 대조군 A: "A vibrant and engaging scene inside a modern foreign language academy, showcasing a diverse group of students in a dynamic English conversation class. The setting is a bright, airy classroom adorned w..."
#
# 실험군 B: "A modern foreign language academy classroom during a native English conversation lesson, a native English-speaking teacher seated at the front guiding a small group of adult students in an engaged dis..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 공간의 넓고 쾌적한 분위기를 광각 렌즈와 전문적인 조명 설정을 통해 효과적으로 전달하며, 세부적인 텍스처와 색상 조합이 전문성을 강조합니다.
#
# [3/60] B-1
# --------------------------------------------------------------------------------
# 한글 입력: "코딩 학원, 어린이 프로그래밍 교육"
#
# 대조군 A: "A vibrant and engaging coding academy designed for children, showcasing a lively classroom filled with young students eagerly participating in programming lessons. The room is bright and colorful, wit..."
#
# 실험군 B: "A bright modern children's coding classroom featuring elementary-age students actively learning programming on laptops and tablets, with one teacher kneeling beside a child to offer guidance. Shot on ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 조명 설정을 구체적으로 설명하여 공간감과 전문성을 잘 전달하며, 학습 환경의 전문성을 강조함.
#
# [4/60] B-1
# --------------------------------------------------------------------------------
# 한글 입력: "스터디카페 홍보, 조용하고 쾌적한 학습 공간"
#
# 대조군 A: "A serene and comfortable study cafe designed for focused learning. The interior features soft, muted colors with warm wood accents, creating a cozy atmosphere. Large windows allow natural light to flo..."
#
# 실험군 B: "Study cafe interior showing a quiet, comfortable learning space with neatly organized individual desks and a few students working calmly with laptops and notebooks. Shot on a Canon EOS R5 with a 24mm ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 전문적인 조명 설정을 통해 공간감과 학습 환경의 전문성을 잘 표현하였으며, 업종 특화된 요소들이 잘 반영되어 있습니다.
#
# [5/60] B-1
# --------------------------------------------------------------------------------
# 한글 입력: "운전학원 안내, 친절한 1:1 운전 교육"
#
# 대조군 A: "Create an inviting scene inside a modern driving school, featuring a friendly driving instructor and a student engaged in a one-on-one driving lesson. The interior of the car should be well-lit, showc..."
#
# 실험군 B: "Driving school interior with a friendly one-to-one driving lesson between an instructor and a student in the foreground, the instructor leaning slightly toward the seated student pointing at a route m..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 76점
#    실험군 B 점수: 90점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 공간의 전반적인 구조를 잘 활용하여 학습 환경의 전문성과 신뢰성을 효과적으로 전달합니다.
#
# [6/60] B-1
# --------------------------------------------------------------------------------
# 한글 입력: "공무원 학원, 합격자 수기와 커리큘럼"
#
# 대조군 A: "A vibrant and dynamic scene inside a public service academy classroom, showcasing a diverse group of students deeply engaged in their studies. The room is filled with large windows that let in warm, n..."
#
# 실험군 B: "Public servant academy classroom showing a bright, organized study environment with success story displays and curriculum materials arranged for review. Shot on a full-frame camera with a wide 16mm le..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈를 활용하여 공간감을 잘 표현하고, 전문적이고 정돈된 학습 환경을 강조하여 신뢰성을 높였다.
#
# [7/60] B-1
# --------------------------------------------------------------------------------
# 한글 입력: "독서실 오픈, 24시간 개인 학습 부스"
#
# 대조군 A: "Visualize a modern, inviting study room designed for individual learning, featuring multiple personal study booths. The setting is a spacious, well-lit environment with large windows that allow natura..."
#
# 실험군 B: "A modern study room showcasing 24시간 개인 학습 부스 arranged in clean parallel rows, seen from a slightly elevated top-down angle that reveals the overall layout and individual booth intimacy. The foreground..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 고급스러운 촬영 기법과 세부적인 텍스처 묘사를 통해 공간의 깊이와 전문성을 잘 표현하고 있어, 광고 이미지 생성에 더 적합합니다.
#
# [8/60] B-1
# --------------------------------------------------------------------------------
# 한글 입력: "유학원 상담, 미국 대학 입학 컨설팅"
#
# 대조군 A: "A warm and inviting office environment designed for educational consulting, featuring a sleek modern desk with a laptop open, displaying a vibrant university website. In the background, a large world ..."
#
# 실험군 B: "Study abroad consultation for U.S. college admissions captured as an inviting overhead flat-lay of a counselor and prospective student actively reviewing application materials. The scene is shot like ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 촬영 기법과 디테일한 텍스처 표현을 통해 신뢰감과 전문성을 잘 전달하고 있으며, 업종 특화 키워드가 잘 반영되어 있습니다.
#
# [9/60] B-1
# --------------------------------------------------------------------------------
# 한글 입력: "취업 학원, 면접 스피치 특강"
#
# 대조군 A: "A dynamic scene set inside a modern classroom designed for professional development, filled with eager students participating in an interactive interview speech workshop. The room is well-lit with lar..."
#
# 실험군 B: "A career academy interview speech workshop in progress with a professional coach standing at the front demonstrating posture and hand gestures while a small group of adult students listens and practic..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈를 활용하여 공간감을 잘 표현하고, 조명과 색상 설정이 전문적이며 신뢰감을 줍니다. 이는 취업 학원의 학습 환경을 효과적으로 전달합니다.
#
# [10/60] B-1
# --------------------------------------------------------------------------------
# 한글 입력: "자격증 학원, 바리스타 자격증 과정"
#
# 대조군 A: "A vibrant and inviting coffee shop interior, showcasing a barista training academy environment. The scene is bustling with students engaged in a barista certification course. A diverse group of indivi..."
#
# 실험군 B: "Barista certification course in progress with an instructor demonstrating espresso extraction at the front while a small group of trainees practice at individual workstations. Shot on a Canon EOS R5 w..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 97점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 전문적인 조명 설정을 통해 학습 공간의 전문성과 신뢰성을 효과적으로 전달합니다. 또한, 텍스처와 디테일을 강조하여 교육 시설의 고급스러움을 잘 표현합니다.
#
# [11/60] B-2
# --------------------------------------------------------------------------------
# 한글 입력: "호텔 프로모션, 오션뷰 스위트룸 패키지"
#
# 대조군 A: "Create a captivating image of a luxurious oceanview suite in a high-end hotel. The suite features floor-to-ceiling windows that showcase a breathtaking view of the sparkling blue ocean, with gentle wa..."
#
# 실험군 B: "Ocean-view suite in a luxury hotel, photographed as a cinematic wide-angle interior to showcase the high ceiling and a panoramic ocean vista through floor-to-ceiling windows. Shot on a full-frame came..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 89점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 시네마틱 요소를 활용하여 공간감과 고급스러운 분위기를 잘 전달하며, 업종 특화된 요소들을 효과적으로 포함하고 있습니다.
#
# [12/60] B-2
# --------------------------------------------------------------------------------
# 한글 입력: "펜션 홍보, 가족 단위 바베큐 독채"
#
# 대조군 A: "A cozy, inviting vacation rental cabin surrounded by lush greenery, designed for family gatherings. The setting features a spacious outdoor barbecue area with a grill, picnic tables, and colorful stri..."
#
# 실험군 B: "A detached private vacation cottage prepared for a family barbecue, showing a wide cinematic view that includes the open-plan living room flowing directly onto a private wooden deck where a family of ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 시네마틱 조명, 고급스러운 인테리어를 통해 공간감과 럭셔리한 분위기를 잘 표현하여 업종의 특성을 더 잘 반영합니다.
#
# [13/60] B-2
# --------------------------------------------------------------------------------
# 한글 입력: "PC방 이벤트, 최신 사양 게이밍 좌석"
#
# 대조군 A: "Imagine a vibrant PC gaming lounge filled with the latest high-spec gaming seats. The setting is a modern, stylish room with sleek, illuminated gaming setups featuring powerful computers and large, ul..."
#
# 실험군 B: "Latest-spec gaming seats arranged in a premium PC bang event setting, each ergonomic chair paired with a high-end gaming PC tower and curved monitor, the seats slightly angled to invite a player and s..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 공간감과 신뢰성을 모두 잘 전달하며, 최신 사양의 게이밍 좌석과 고급스러운 환경을 세밀하게 묘사하여 업종 특화된 광고 이미지 생성에 더 적합합니다.
#
# [14/60] B-2
# --------------------------------------------------------------------------------
# 한글 입력: "노래방 시설, 프리미엄 코인 노래방"
#
# 대조군 A: "Imagine a luxurious karaoke room designed for an upscale experience. The setting is a modern, private karaoke lounge with plush velvet seating in deep shades of royal blue and gold accents. Soft, ambi..."
#
# 실험군 B: "Premium coin karaoke facility interior captured in an overhead flat-lay top-down composition, showing one private booth, the coin-operated kiosk, and a tidy tabletop with a microphone, headphones, and..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 현대적이고 전문적인 촬영 기법과 조명 설정을 통해 프리미엄 코인 노래방의 고급스러움과 청결함을 잘 표현하고 있습니다.
#
# [15/60] B-2
# --------------------------------------------------------------------------------
# 한글 입력: "글램핑장 오픈, 자연 속 럭셔리 캠핑"
#
# 대조군 A: "A luxurious glamping site nestled in the heart of nature, surrounded by lush greenery and towering trees. The scene captures elegantly furnished tents with large, cozy beds draped in soft linens, invi..."
#
# 실험군 B: "Luxury glamping suite revealed at golden hour, a spacious canvas-and-timber tent standing open to a panoramic woodland and lake view, inviting guests into a refined nature retreat. Shot on a Canon EOS..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 촬영 기법과 장비를 명확히 언급하며, 공간감과 럭셔리한 분위기를 효과적으로 전달한다. 이는 B-2 업종의 요구에 더 부합한다.
#
# [16/60] B-2
# --------------------------------------------------------------------------------
# 한글 입력: "여행사 패키지, 제주도 3박 4일 투어"
#
# 대조군 A: "A breathtaking landscape showcasing a 3-night, 4-day tour in Jeju Island, South Korea. The scene features a vibrant sunrise over the iconic Hallasan Mountain, with lush greenery and blooming wildflowe..."
#
# 실험군 B: "Jeju Island 3박 4일 투어 package portrayed as a cinematic luxury hotel suite scene with a panoramic ocean view. A well-dressed couple stands near floor-to-ceiling windows, one person pointing toward the d..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 시네마틱 인테리어와 럭셔리한 숙박 시설을 광각 렌즈로 잘 표현하여 고급스러운 여행 경험을 강조하고, 조명과 구도에서 전문성을 보여줌.
#
# [17/60] B-2
# --------------------------------------------------------------------------------
# 한글 입력: "찜질방 홍보, 힐링 스파 시설 안내"
#
# 대조군 A: "Imagine a serene and inviting jjimjilbang (Korean sauna) with a variety of cozy, softly-lit spaces designed for relaxation and healing. The interior features smooth wooden floors and warm stone walls,..."
#
# 실험군 B: "A luxurious Korean jjimjilbang healing spa interior presented as a cinematic wide shot from a slightly elevated, high-ceiling perspective that reveals a panoramic layout of multiple therapy zones. The..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 시네마틱한 조명을 활용하여 공간의 확장감과 럭셔리함을 잘 표현하며, 전문적인 디테일을 강조하여 찜질방의 고급스러운 이미지를 효과적으로 전달합니다.
#
# [18/60] B-2
# --------------------------------------------------------------------------------
# 한글 입력: "만화카페, 아늑한 독서 공간"
#
# 대조군 A: "Imagine a cozy comic cafe, designed to be a perfect reading space. The interior is adorned with warm wooden furniture, including plush armchairs and small tables for individual readers. Shelves lined ..."
#
# 실험군 B: "A cozy manga café reading nook captured in the soft glow of early morning light, a single low wooden table beside a plush beige armchair and a built-in shelf densely packed with colorful comic volumes..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 촬영 기법과 장비 사용을 강조하여 신뢰성과 전문성을 잘 전달합니다. 또한, 세부적인 질감과 분위기가 잘 표현되어 있어 광고 이미지 생성에 더 적합합니다.
#
# [19/60] B-2
# --------------------------------------------------------------------------------
# 한글 입력: "보드게임 카페, 친구들과 즐기는 게임"
#
# 대조군 A: "A cozy board game café filled with warm, inviting colors and soft lighting. The scene features a group of friends gathered around a large wooden table, deeply engaged in playing various board games. L..."
#
# 실험군 B: "A group of four friends gathered around a board game in a modern board game cafe, leaning in and laughing as hands reach to move colorful tokens and roll dice, captured from a clean top-down overhead ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 현대적이고 전문적인 느낌을 강조하며, 세부적인 질감과 조명 설정을 통해 프리미엄한 분위기를 잘 표현하여 보드게임 카페의 고급스러운 체험을 전달하는 데 더 적합합니다.
#
# [20/60] B-2
# --------------------------------------------------------------------------------
# 한글 입력: "리조트 워터파크, 신나는 물놀이 시설"
#
# 대조군 A: "Imagine a vibrant resort water park filled with excitement and joy. The scene is set under a bright blue sky with fluffy white clouds, casting playful shadows on the glistening water. In the foregroun..."
#
# 실험군 B: "Resort waterpark filled with guests enjoying exciting water-play attractions, captured as a cinematic wide-angle interior scene that emphasizes scale and motion. Shot on a full-frame camera with a 24m..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 79점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 시네마틱 조명을 사용하여 공간의 규모와 럭셔리함을 잘 표현하고, 전문성과 안전성을 강조하여 B-2 등급에 적합합니다.
#
# [21/60] B-3
# --------------------------------------------------------------------------------
# 한글 입력: "수영장 회원 모집, 성인 수영 강습"
#
# 대조군 A: "A vibrant and inviting scene at a modern swimming pool, showcasing a diverse group of adults engaged in a swimming lesson. The setting is a bright, sunny day with sunlight streaming through large glas..."
#
# 실험군 B: "Adult swimming lesson class with a diverse group of adults practicing technique under a focused instructor, captured mid-action as a swimmer executes a clean freestyle stroke and droplets arc from the..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 촬영 기법과 고급스러운 느낌을 주며, 텍스처와 디테일에 집중하여 신뢰성을 높인다. 이는 성인 수영 강습의 전문성과 고급스러움을 강조하는 데 적합하다.
#
# [22/60] B-3
# --------------------------------------------------------------------------------
# 한글 입력: "골프 연습장, 실내 스크린 골프 시설"
#
# 대조군 A: "A modern indoor golf practice facility, featuring state-of-the-art screen golf technology. The scene showcases a spacious, well-lit area with multiple golf simulators, where players are engaged in pra..."
#
# 실험군 B: "Indoor screen golf practice facility composed as a wide-angle interior scene showing three training bays receding into depth, one bay occupied by a single golfer mid-swing. Shot on a full-frame camera..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 전문적인 조명 설정을 통해 깊이감 있는 공간을 효과적으로 표현하며, 업종에 특화된 세부 사항을 잘 반영하고 있다.
#
# [23/60] B-3
# --------------------------------------------------------------------------------
# 한글 입력: "볼링장 이벤트, 단체 볼링 대회"
#
# 대조군 A: "A vibrant bowling alley filled with energy, showcasing a group bowling tournament. The scene is bustling with participants of various ages and backgrounds, all wearing colorful team shirts, cheering a..."
#
# 실험군 B: "A group bowling tournament event with multiple teams competing, captured as a wide, dynamic venue shot showing players in mid-action delivering shots down several lanes. Shot on a full-frame mirrorles..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 전문 장비를 활용하여 공간감과 전문성을 잘 표현하고 있으며, 청결하고 정돈된 이미지를 제공합니다. 이는 B-3 업종의 광고 이미지 생성에 더 적합합니다.
#
# [24/60] B-3
# --------------------------------------------------------------------------------
# 한글 입력: "당구장 홍보, 프로 당구 레슨"
#
# 대조군 A: "An inviting interior of a professional billiard hall, featuring several well-maintained pool tables with vibrant green felt. The setting is warmly lit with a mix of soft overhead lights and ambient li..."
#
# 실험군 B: "Professional billiards instructor giving a hands-on lesson to a focused student beside a single pool table in a spacious, immaculate billiards hall. Shot on a Canon EOS R5 with a 24-70mm f/2.8 lens at..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 공간감과 전문성을 강조하는 요소들이 잘 조화되어 있으며, 업종 특화된 디테일이 풍부하다. 이는 광고 이미지 생성에 있어 더 적합한 선택이다.
#
# [25/60] B-3
# --------------------------------------------------------------------------------
# 한글 입력: "테니스장 오픈, 실내 테니스 코트"
#
# 대조군 A: "A vibrant indoor tennis court, showcasing a fresh and inviting atmosphere. The court is surrounded by bright white walls with large windows allowing natural light to pour in, illuminating the polished..."
#
# 실험군 B: "Brand-new indoor tennis court at a grand opening, shown in a wide, dynamic overview with one court in the foreground and additional courts receding into the background. Shot like a professional sports..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 78점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 전문적인 조명을 통해 공간감과 깊이감을 잘 표현하고 있으며, 업종 특화된 전문성을 잘 드러내고 있다.
#
# [26/60] B-3
# --------------------------------------------------------------------------------
# 한글 입력: "탁구장 클럽, 동호인 리그전"
#
# 대조군 A: "Imagine a vibrant indoor table tennis club bustling with energy, where players of all ages and skill levels are engaged in a friendly league competition. The scene is filled with dynamic movement as p..."
#
# 실험군 B: "An indoor table tennis club hosting an amateur league match viewed from a high overhead angle, several tables arranged in neat rows with players engaged in mid-play. Shot like a professional sports ph..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 촬영 기법과 디테일한 질감 표현을 통해 공간의 특성을 더 잘 전달하며, 업종 특화 요소를 잘 반영하고 있음.
#
# [27/60] B-3
# --------------------------------------------------------------------------------
# 한글 입력: "풋살장 대관, 최신 인조잔디 구장"
#
# 대조군 A: "A vibrant futsal court set in an outdoor environment, showcasing the latest artificial turf technology. The scene depicts a well-maintained, bright green playing surface with realistic texture, surrou..."
#
# 실험군 B: "Modern futsal field with brand-new artificial turf seen from a slightly elevated wide-angle perspective, showcasing the full rectangular pitch, crisp white lines, goal areas and corner arcs, ready for..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 전문적인 촬영 설정을 통해 공간감과 세부 디테일을 탁월하게 표현하며, 최신 인조잔디와 시설의 청결함이 잘 강조되어 있습니다.
#
# [28/60] B-3
# --------------------------------------------------------------------------------
# 한글 입력: "배드민턴장, 동호회 대관 안내"
#
# 대조군 A: "A vibrant indoor badminton court bustling with energy, featuring bright fluorescent lighting that casts a clear glow over the polished wooden floor. In the foreground, a diverse group of enthusiastic ..."
#
# 실험군 B: "Badminton court prepared for a community club reservation, seen from a top-down overhead perspective showing two adjacent courts and a central aisle. Shot like a high-resolution commercial photograph ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 공간감과 시설의 디테일을 강조하여 전문적이고 신뢰할 수 있는 이미지를 생성하는 데 더 적합합니다.
#
# [29/60] B-3
# --------------------------------------------------------------------------------
# 한글 입력: "클라이밍 센터, 초보자 볼더링 체험"
#
# 대조군 A: "A vibrant indoor climbing center bustling with activity, featuring a variety of colorful bouldering walls designed for beginners. The setting is filled with bright, ambient lighting that highlights th..."
#
# 실험군 B: "A beginner bouldering class at an indoor climbing center, an instructor crouched on a crash pad demonstrating precise foot placement while a novice climber reaches for a brightly colored hold a few fe..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 조명을 활용하여 공간감을 잘 표현하고, 초보자 교육의 전문성을 강조하여 업종의 특성을 잘 반영함.
#
# [30/60] B-3
# --------------------------------------------------------------------------------
# 한글 입력: "스쿼시장 신규 오픈, 1:1 레슨"
#
# 대조군 A: "An inviting, modern squash court interior bustling with energy, showcasing a newly opened facility. The setting features sleek glass walls and polished wooden floors, reflecting bright overhead lights..."
#
# 실험군 B: "Newly opened squash court hosting a one-on-one coaching lesson, a coach instructs a player mid-lunge while demonstrating racket technique in the foreground. Shot on a Canon EOS R5 with a 24-70mm f/2.8..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적인 촬영 기술과 장비를 강조하며, 공간의 질감과 깊이를 세밀하게 표현하여 업종의 전문성을 잘 전달합니다.
#
# [31/60] C-1
# --------------------------------------------------------------------------------
# 한글 입력: "부동산 중개소, 역세권 신축 오피스텔 매물"
#
# 대조군 A: "A modern real estate office located in a bustling urban area, showcasing a newly constructed officetel in a prime location near a subway station. The scene is set during the late afternoon, with warm ..."
#
# 실험군 B: "Real estate agency presenting a newly built officetel near a subway station, a professional agent standing at a sleek reception counter gesturing toward a large tablet and a scale model of the buildin..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문성과 신뢰성을 강조하며, 업종에 특화된 요소를 잘 반영하여 부동산 중개소의 이미지를 효과적으로 전달합니다.
#
# [32/60] C-1
# --------------------------------------------------------------------------------
# 한글 입력: "법무법인 홍보, 기업 법률 자문 서비스"
#
# 대조군 A: "A professional and elegant office setting showcasing a modern law firm. The scene features a sleek conference room with a large oval wooden table surrounded by high-backed leather chairs. Sunlight str..."
#
# 실험군 B: "Corporate legal advisory consultation scene showing a lawyer and a corporate client seated across a neat oak conference table, captured in a slightly elevated three-quarter overhead view as they excha..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 90점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 법률 자문 서비스의 핵심 장면인 계약 체결을 강조하며, 텍스처와 디테일을 통해 신뢰감을 잘 전달하고 있다.
#
# [33/60] C-1
# --------------------------------------------------------------------------------
# 한글 입력: "세무사 사무소, 종합소득세 신고 대행"
#
# 대조군 A: "A modern tax office interior, showcasing a professional environment dedicated to comprehensive income tax filing services. The scene features a sleek reception area with a polished wooden desk, where ..."
#
# 실험군 B: "Tax accounting office assisting a client with comprehensive income tax filing, an experienced tax accountant in a navy suit seated across a polished white conference table while pointing at printed ta..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 세부적인 텍스처와 전문적인 업무 상황을 잘 표현하며, 조명과 색상 배치가 매우 전문적입니다. 이는 신뢰성을 강조하는 데 효과적입니다.
#
# [34/60] C-1
# --------------------------------------------------------------------------------
# 한글 입력: "회계사 상담, 스타트업 재무 컨설팅"
#
# 대조군 A: "A professional accountant's office setting, featuring a modern and sleek design with a large wooden desk and comfortable chairs. The room is filled with natural light streaming in through floor-to-cei..."
#
# 실험군 B: "An accountant consulting with a startup founder, seated across a wooden conference table while pointing at a laptop screen that displays financial charts and a spreadsheet interface. The accountant is..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문성과 신뢰성을 강조하는 요소가 더 강하며, 조명과 색상 배치가 업종 특성에 잘 맞아떨어진다.
#
# [35/60] C-1
# --------------------------------------------------------------------------------
# 한글 입력: "특허 사무소, 상표권 등록 안내"
#
# 대조군 A: "A modern patent office interior, showcasing sleek wooden desks and contemporary decor. The setting is bright and airy, illuminated by soft natural light streaming through large windows, creating a war..."
#
# 실험군 B: "Patent office consultant explaining trademark registration to a small group of clients at a polished conference table, standing and pointing to printed documents and a tablet while two clients listen ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 74점
#    실험군 B 점수: 88점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문성과 신뢰성을 강조하는 요소들이 잘 표현되어 있으며, 업종에 특화된 디테일한 묘사가 뛰어남. 또한, 조명과 구도가 매우 전문적으로 설정되어 있음.
#
# [36/60] C-1
# --------------------------------------------------------------------------------
# 한글 입력: "노무사 사무실, 근로계약서 검토 서비스"
#
# 대조군 A: "A modern labor consultancy office, featuring a sleek and professional interior design. The setting includes a large conference table made of polished wood surrounded by comfortable, ergonomic chairs. ..."
#
# 실험군 B: "A labor attorney in a tidy office reviewing an employment contract, shown as an intimate, professional close-up photograph. Shot on a Canon EOS R5 with a 50mm f/1.8 lens, wide aperture for shallow dep..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 89점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 세부적인 텍스처와 조명 설정을 통해 전문성과 신뢰성을 효과적으로 전달하며, 근접 촬영으로 인한 집중감이 강하여 광고 이미지에 적합합니다.
#
# [37/60] C-1
# --------------------------------------------------------------------------------
# 한글 입력: "광고 대행사, 브랜드 마케팅 캠페인"
#
# 대조군 A: "A vibrant and dynamic scene depicting a creative advertising agency at work, showcasing a collaborative environment. The setting is a modern office filled with large windows that let in natural light,..."
#
# 실험군 B: "A top-down overhead flat lay of an advertising agency's brand marketing campaign in active development, showing designers arranging mood boards, printed mockups, color swatches, prototype packaging an..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 세부적인 텍스처와 조명 설정을 통해 광고 대행사의 전문성과 신뢰성을 잘 전달합니다. 또한, 색조와 구도를 통해 현대적이고 정돈된 느낌을 효과적으로 표현합니다.
#
# [38/60] C-1
# --------------------------------------------------------------------------------
# 한글 입력: "경영 컨설팅, 중소기업 성장 전략"
#
# 대조군 A: "A dynamic office environment bustling with energy, showcasing a group of diverse business consultants engaged in a strategic meeting. The setting features a large, modern conference table surrounded b..."
#
# 실험군 B: "Business consulting session focused on small business growth strategy shown as a top-down, organized desk flat lay with a clear emphasis on charts and planning tools. Shot on a Canon EOS R5 with a 35m..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 정돈된 레이아웃과 세부적인 질감 표현으로 신뢰성과 전문성을 더 잘 전달한다. 또한, 업종 특화된 요소가 더 잘 반영되어 있다.
#
# [39/60] C-1
# --------------------------------------------------------------------------------
# 한글 입력: "행정사 사무소, 인허가 대행 서비스"
#
# 대조군 A: "A modern administrative office setting, featuring a sleek reception area with contemporary furniture. The walls are adorned with abstract art and inspirational quotes, creating a welcoming atmosphere...."
#
# 실험군 B: "Administrative services office providing licensing and permit application services, a professional consultation scene with an administrative officer in a navy suit explaining a stamped permit to a sea..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 전문적인 조명 설정을 통해 공간감과 신뢰성을 더욱 효과적으로 전달하며, 업종 특화된 요소들이 잘 반영되어 있다.
#
# [40/60] C-1
# --------------------------------------------------------------------------------
# 한글 입력: "번역 사무소, 법률 문서 번역 전문"
#
# 대조군 A: "An inviting and professional translation office interior, showcasing a sleek, modern workspace. The setting features a large wooden desk cluttered with legal documents, translation tools, and a high-e..."
#
# 실험군 B: "A professional translation office workspace specializing in legal document translation, presented as a top-down flat lay of a neatly organized wooden desk with one clear focal area showing active tran..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 텍스처와 조명, 구도에서 더 높은 점수를 받았으며, 법률 문서 번역의 전문성과 신뢰성을 더 잘 전달하고 있다.
#
# [41/60] C-2
# --------------------------------------------------------------------------------
# 한글 입력: "내과 의원, 건강검진 패키지 안내"
#
# 대조군 A: "An inviting interior of a modern internal medicine clinic, showcasing a warm and welcoming reception area. The walls are painted in soothing pastel colors, adorned with framed nature photographs that ..."
#
# 실험군 B: "A modern internal medicine clinic reception and examination area staged to present a health screening package, shot as a clean, trustworthy healthcare environment. The frame shows a neat reception des..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 공간감과 전문성을 강조하며, 청결하고 신뢰감을 주는 이미지를 잘 전달합니다. 이는 내과 의원의 광고 이미지에 적합합니다.
#
# [42/60] C-2
# --------------------------------------------------------------------------------
# 한글 입력: "치과 클리닉, 임플란트 상담 이벤트"
#
# 대조군 A: "A modern dental clinic interior, showcasing a clean and inviting atmosphere. The reception area features sleek, contemporary furniture with soft, neutral colors, accented by green plants that add a to..."
#
# 실험군 B: "A modern dental clinic hosting an implant consultation event, captured from a dynamic wide-angle perspective that shows a spacious consultation area with a dental chair, a consultation desk, and profe..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈를 활용한 공간감 표현과 전문적인 조명 설정이 돋보이며, 업종 특화된 요소들이 잘 반영되어 있어 치과 클리닉의 광고 이미지 생성에 더 적합하다.
#
# [43/60] C-2
# --------------------------------------------------------------------------------
# 한글 입력: "한의원 홍보, 비만 한방 다이어트"
#
# 대조군 A: "A serene and inviting traditional Korean medicine clinic, showcasing a cozy interior with wooden beams and soft, natural light filtering through paper lanterns. The room is adorned with herbal remedie..."
#
# 실험군 B: "A modern Korean medicine clinic consultation scene focused on a traditional herbal obesity diet program, showing a practitioner in a clean white medical coat gently explaining a personalized treatment..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 76점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 현대적이고 전문적인 의료 환경을 강조하여 신뢰성을 높이고, 업종 특화된 요소들을 잘 반영하여 광고 이미지 생성에 적합하다.
#
# [44/60] C-2
# --------------------------------------------------------------------------------
# 한글 입력: "정형외과, 척추 비수술 치료 프로그램"
#
# 대조군 A: "A serene and modern orthopedic clinic, showcasing a non-surgical spine treatment program. The setting features a clean, well-lit examination room with large windows allowing natural sunlight to stream..."
#
# 실험군 B: "An orthopedic clinic scene showing a non-surgical spine treatment program in action: a physiotherapist gently guiding a middle-aged patient through a spinal decompression session on a modern therapy t..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 공간감과 전문성을 잘 표현하며, 의료 장비와 치료 과정을 상세히 묘사하여 신뢰성을 높입니다. 또한, 촬영 장비와 설정에 대한 구체적인 설명이 있어 이미지 생성에 더 적합합니다.
#
# [45/60] C-2
# --------------------------------------------------------------------------------
# 한글 입력: "안과 라식 센터, 시력교정술 상담"
#
# 대조군 A: "A modern ophthalmology clinic specializing in LASIK eye surgery consultations. The setting is a sleek, well-lit waiting room featuring contemporary furniture with soft, inviting colors. Large windows ..."
#
# 실험군 B: "A patient seated across from an ophthalmologist during a LASIK vision correction consultation, the doctor calmly explaining corneal scan results while pointing to a digital 3D eye model on a tablet. S..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문성과 신뢰성을 강조하는 요소가 잘 반영되어 있으며, 텍스처와 조명 설정이 매우 정밀합니다. 업종 특화된 디테일이 잘 표현되어 있습니다.
#
# [46/60] C-2
# --------------------------------------------------------------------------------
# 한글 입력: "이비인후과, 수면무호흡 검사 안내"
#
# 대조군 A: "A serene and inviting ENT clinic waiting area, designed to evoke a sense of calm and assurance. The space is softly lit with warm, gentle lighting that casts a soothing glow across the room. Elegant w..."
#
# 실험군 B: "A modern ENT clinic examination room staged for a sleep apnea test, a trained technician in light blue scrubs carefully adjusts a portable polysomnography recorder and places disposable adhesive elect..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 74점
#    실험군 B 점수: 90점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 수면무호흡 검사에 필요한 장비와 환경을 구체적으로 설명하여 업종 특화성이 높고, 전문성과 신뢰성을 잘 전달합니다.
#
# [47/60] C-2
# --------------------------------------------------------------------------------
# 한글 입력: "소아과 의원, 영유아 예방접종"
#
# 대조군 A: "A cozy pediatric clinic interior designed for young children and infants, featuring soft pastel colors on the walls and playful animal-themed decorations. In the center, a friendly pediatrician, dress..."
#
# 실험군 B: "A pediatric clinic nurse gently administering a routine infant vaccination, captured as an intimate clinical portrait focusing on the moment of care. Shot on a Canon EOS R5 with an 85mm f/1.4 lens usi..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문적이고 위생적인 의료 환경을 강조하며, 세부적인 질감과 색상 정확도가 뛰어납니다. 이는 신뢰성을 중시하는 의료 업종에 적합합니다.
#
# [48/60] C-2
# --------------------------------------------------------------------------------
# 한글 입력: "산부인과, 임신 초기 검사 프로그램"
#
# 대조군 A: "A serene and inviting interior of a modern gynecology clinic, showcasing a comfortable examination room designed for early pregnancy check-ups. The room features soft pastel colors, with light beige w..."
#
# 실험군 B: "Obstetrics clinic scene showing a physician and a pregnant patient during an early pregnancy screening consultation, focused on the interaction and clinical environment. Shot on a Canon EOS R5 with a ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 임상 환경과 의사-환자 상호작용을 강조하여 전문성과 신뢰감을 잘 전달합니다. 또한, 세부적인 디테일이 뛰어나며, 업종 특화 요소가 잘 반영되어 있습니다.
#
# [49/60] C-2
# --------------------------------------------------------------------------------
# 한글 입력: "정신건강의학과, 스트레스 상담 클리닉"
#
# 대조군 A: "A serene and calming mental health clinic setting focused on stress counseling. The interior features soft, neutral colors, with light beige walls and natural wood accents. In one corner, a cozy seati..."
#
# 실험군 B: "A calm, welcoming stress counseling room in a mental health clinic shown in a clean overhead composition, an organized top-down view of a therapy setup prepared for a session. Shot on a full-frame cam..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 90점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 상단에서 내려다보는 구도를 통해 공간의 정돈된 느낌을 잘 전달하며, 섬세한 디테일과 전문적인 색조로 신뢰감을 줍니다. 이는 정신건강의학과 클리닉의 신뢰성과 전문성을 강조하는 데 적합합니다.
#
# [50/60] C-2
# --------------------------------------------------------------------------------
# 한글 입력: "요양원 안내, 어르신 전문 케어 시설"
#
# 대조군 A: "A serene nursing home environment designed specifically for elderly care. The scene is set in a beautifully landscaped garden, featuring blooming flowers and lush greenery that create a tranquil atmos..."
#
# 실험군 B: "Eldercare facility communal area with a friendly caregiver gently assisting two seated elderly residents as they share a light activity at a dining table, the caregiver smiling and leaning in to offer..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 실내의 세부적인 디테일과 따뜻한 분위기를 강조하여 신뢰성과 전문성을 잘 전달합니다. 이는 요양원 광고에 적합한 이미지 생성에 더 유리합니다.
#
# [51/60] C-3
# --------------------------------------------------------------------------------
# 한글 입력: "자동차 정비소, 엔진오일 교환 이벤트"
#
# 대조군 A: "A bustling automobile repair shop during a bright and sunny day, showcasing a vibrant scene of mechanics at work. In the foreground, a skilled mechanic is focused on changing the engine oil of a sleek..."
#
# 실험군 B: "A modern automotive repair shop hosting an engine oil change event, captured from a dynamic wide-angle viewpoint that emphasizes spaciousness and activity. Shot on a full-frame camera with a 24mm lens..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 76점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 광각 렌즈와 전문적인 조명 설정을 통해 공간의 넓이와 전문성을 효과적으로 전달하며, 청결하고 신뢰감 있는 분위기를 조성합니다.
#
# [52/60] C-3
# --------------------------------------------------------------------------------
# 한글 입력: "세차장 홍보, 프리미엄 손세차 서비스"
#
# 대조군 A: "A luxurious car wash setting showcasing a premium hand car wash service. The scene features a sleek, shiny sports car parked in the foreground, droplets of water glistening on its surface under bright..."
#
# 실험군 B: "Premium hand car wash service scene showing a uniformed technician performing a meticulous hand wash on a dark blue luxury sedan, captured in a three-quarter front view with a subtle split composition..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문성과 신뢰성을 강조하며, 세차 서비스의 디테일과 고급스러움을 잘 표현하고 있다. 조명과 구도가 전문적이며, 업종에 특화된 요소들이 잘 반영되어 있다.
#
# [53/60] C-3
# --------------------------------------------------------------------------------
# 한글 입력: "인테리어 업체, 아파트 리모델링 시공"
#
# 대조군 A: "A beautifully remodeled apartment interior showcasing modern design elements. The scene captures a spacious living room with large windows allowing natural light to flood in, highlighting the sleek, m..."
#
# 실험군 B: "Newly remodeled apartment living room and open kitchen staged by an interior renovation company, photographed to highlight craftsmanship and material quality. Shot on a full-frame camera with a wide 2..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 81점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문성과 신뢰성을 강조하며, 업종 특화된 키워드를 잘 활용하여 광고 이미지 생성에 더 적합합니다.
#
# [54/60] C-3
# --------------------------------------------------------------------------------
# 한글 입력: "이사업체 안내, 원룸 포장이사 서비스"
#
# 대조군 A: "A cozy, well-decorated one-room apartment in the process of being packed for a move. The room is filled with various moving boxes, some stacked neatly while others are partially open, revealing items ..."
#
# 실험군 B: "Studio one-room apartment packing and moving service in action, professional movers carefully packing and organizing a small urban apartment for relocation. Shot like a commercial documentary photogra..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 77점
#    실험군 B 점수: 89점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문성과 신뢰성을 강조하며, 업종 특화 요소가 잘 반영되어 있어 광고 이미지 생성에 더 적합합니다.
#
# [55/60] C-3
# --------------------------------------------------------------------------------
# 한글 입력: "에어컨 청소, 분해 완전 세척 서비스"
#
# 대조군 A: "An indoor scene showcasing a professional air conditioning cleaning service in action. The focus is on a technician wearing a clean uniform, carefully disassembling an air conditioning unit. The setti..."
#
# 실험군 B: "Disassembled air conditioner components for a professional complete-clean service, neatly arranged in a top-down flat lay on a bright white tiled countertop to emphasize cleanliness. Shot on a Canon E..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 청소 전후의 상태를 명확히 보여주고, 전문적인 디테일과 신뢰성을 강조하여 광고 이미지 생성에 더 적합합니다.
#
# [56/60] C-3
# --------------------------------------------------------------------------------
# 한글 입력: "방역 소독 업체, 바퀴벌레 퇴치 서비스"
#
# 대조군 A: "A professional pest control service in action, showcasing a technician in a clean, white uniform using a high-tech spray device to eliminate cockroaches in a modern kitchen. The setting is a bright, w..."
#
# 실험군 B: "A professional pest control technician in a white protective coverall and full-face respirator kneels at the baseboard of a modern residential kitchen, carefully applying cockroach treatment with a st..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 78점
#    실험군 B 점수: 90점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 질감, 조명, 색감에서 더 높은 점수를 받았으며, 전문성과 신뢰성을 잘 전달합니다.
#
# [57/60] C-3
# --------------------------------------------------------------------------------
# 한글 입력: "조경 관리, 아파트 단지 정원 가꾸기"
#
# 대조군 A: "A serene apartment complex garden meticulously maintained, showcasing a vibrant landscape filled with colorful flowers, lush green shrubs, and neatly manicured grass. The scene is set during a sunny d..."
#
# 실험군 B: "Apartment complex garden maintenance team tending and pruning raised flower beds and container gardens, workers in breathable workwear kneeling and using hand pruners and a wheelbarrow while one opera..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 전문적인 조경 관리의 세부적인 작업과 장비 사용을 강조하여 신뢰성과 전문성을 잘 전달합니다. 또한, 고해상도 촬영과 정돈된 레이아웃으로 업종 특화된 이미지를 생성하는 데 적합합니다.
#
# [58/60] C-3
# --------------------------------------------------------------------------------
# 한글 입력: "간판 제작소, LED 채널 간판 시공"
#
# 대조군 A: "A bustling sign-making workshop showcasing a variety of LED channel signs in various shapes and sizes. The setting is filled with bright, vibrant colors, with several signs glowing dynamically in the ..."
#
# 실험군 B: "A LED channel sign installation in progress inside a professional sign-making workshop, a skilled technician in protective gloves is fastening LED modules into an aluminum channel letter while a compl..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문성과 신뢰성을 강조하며, LED 채널 간판 시공의 기술적 세부사항을 잘 표현하여 업종에 적합한 광고 이미지를 생성할 수 있음.
#
# [59/60] C-3
# --------------------------------------------------------------------------------
# 한글 입력: "타일 시공 전문, 욕실 리모델링"
#
# 대조군 A: "A beautifully renovated bathroom showcasing expert tile installation. The scene features elegant, glossy ceramic tiles in shades of soft blue and white, creating a serene and modern atmosphere. Natura..."
#
# 실험군 B: "Bathroom remodeling showcasing professional tile installation in a freshly renovated bathroom, captured in a slightly elevated three-quarter view that emphasizes the newly laid wall and floor tiles. S..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: Prompt B provides a more detailed and professional portrayal of the tile installation process, which is crucial for establishing trust and expertise in the field of bathroom remodeling.
#
# [60/60] C-3
# --------------------------------------------------------------------------------
# 한글 입력: "도배/장판 업체, 벽지 시공 견적 안내"
#
# 대조군 A: "A modern interior scene showcasing a professional wallpaper and flooring installation company at work. The setting is a bright, well-lit living room featuring freshly painted walls adorned with elegan..."
#
# 실험군 B: "A professional wallpaper and flooring contractor arranging wallpaper sample boards and vinyl plank samples on a clean wooden workbench for a client estimate, hands positioning a textured wallpaper sam..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전문성과 신뢰성을 강조하는 요소가 잘 반영되어 있으며, 업종 특화된 키워드와 세부적인 텍스처 표현이 뛰어납니다.
#
#
# ====================================================================================================
# 📈 B+C등급 (공간 체험/교육 + 신뢰 기반 서비스) 평가 요약
# ====================================================================================================
# 평가 케이스 수: 60/60
#
# 🏆 승패 현황:
#    대조군 A 승: 0회 (0.0%)
#    실험군 B 승: 60회 (100.0%)
#    무승부: 0회 (0.0%)
#
# 📊 평균 점수:
#    대조군 A: 84.6점
#    실험군 B: 92.4점

# %% [markdown]
# ### 6.6 D+E등급 GPT 평가 실행

# %%
# D+E등급 GPT 평가 - 섹션 3에서 생성된 de_grade_results 활용
de_eval_results, de_wins = evaluate_existing_results(
    de_grade_results,  # 섹션 3에서 생성된 결과 사용
    "D+E등급 (목적형 소매 + 인프라)",
    sample_size=None  # 전체 평가
)
# Out:
# ====================================================================================================
# 📊 D+E등급 (목적형 소매 + 인프라) GPT 평가 (기존 A/B 결과 활용)
# ====================================================================================================
#
# 📌 전체 30개 평가
#
# [1/30] D-1
# --------------------------------------------------------------------------------
# 한글 입력: "타이어 전문점, 사계절 타이어 할인"
#
# 대조군 A: "A bustling tire specialty shop during a vibrant autumn day, showcasing a wide variety of all-season tires prominently displayed around the entrance. The shop is adorned with colorful banners indicatin..."
#
# 실험군 B: "All-season tires arranged on industrial steel racks and on a low display platform, a three-quarter view with one tire in the foreground turned slightly to show detailed tread pattern and sidewall curv..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 74점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 산업적 미학과 금속 질감을 강조하여 타이어의 견고함과 기능성을 효과적으로 전달합니다. 이는 D-1 등급의 핵심 원칙에 부합합니다.
#
# [2/30] D-1
# --------------------------------------------------------------------------------
# 한글 입력: "자동차 부품점, 순정 브레이크 패드"
#
# 대조군 A: "A bustling auto parts store filled with an array of automotive components, prominently featuring an organized display of genuine brake pads. The setting is well-lit with bright overhead lights that il..."
#
# 실험군 B: "OEM brake pads displayed in a tidy automotive parts store, top-down flat lay showing multiple sets neatly arranged in rows on a clean wooden workbench. The central composition features one open plain ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 제품의 질감과 세부 디테일을 강조하여 브레이크 패드의 기능성과 고급스러움을 잘 전달한다. 이는 자동차 부품점의 광고 이미지에 적합하다.
#
# [3/30] D-1
# --------------------------------------------------------------------------------
# 한글 입력: "철물점 홍보, 공구 세트 특가 판매"
#
# 대조군 A: "A vibrant hardware store interior showcasing a special sale on a wide variety of tool sets. The scene is bustling with customers exploring the aisles filled with bright and colorful tool displays. The..."
#
# 실험군 B: "A professional tool set displayed in an open foam-lined case on a sturdy wooden workbench, positioned front and center to showcase each piece clearly. Shot on a Canon EOS R5 with a 50mm macro lens at ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 78점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 금속 질감과 내구성을 강조하며, 산업적 미학을 잘 전달합니다. 조명과 구성이 제품의 기능성을 잘 보여주어 해당 업종의 광고 이미지 생성에 더 적합합니다.
#
# [4/30] D-1
# --------------------------------------------------------------------------------
# 한글 입력: "건축자재 판매, 시멘트/벽돌 도매"
#
# 대조군 A: "Imagine a bustling construction supply warehouse filled with various building materials. The scene includes towering stacks of bags of cement, neatly arranged bricks in vibrant colors, and a variety o..."
#
# 실험군 B: "Wholesale construction materials warehouse featuring stacked bags of cement and neatly palletized red clay bricks being inspected and loaded by workers, a sales representative gesturing toward product..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 76점
#    실험군 B 점수: 90점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 조명과 질감에 대한 구체적인 설명을 통해 제품의 내구성과 기능성을 잘 전달하며, 산업적 미학을 강조하는 데 효과적입니다.
#
# [5/30] D-1
# --------------------------------------------------------------------------------
# 한글 입력: "전기용품 가게, LED 조명 설치"
#
# 대조군 A: "A modern electric appliance store interior, showcasing a variety of LED lighting installations. The setting features sleek, contemporary shelves filled with different types of LED bulbs, strips, and f..."
#
# 실험군 B: "A store electrician on a ladder installing a slim rectangular LED panel in the ceiling of a well-organized electrical appliance shop, captured as a commercial documentation shot. Shot on a Canon EOS R..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 D-1 등급의 핵심 원칙인 산업적 미학과 금속 질감을 더 잘 표현하며, 전문적인 촬영 설정이 돋보입니다.
#
# [6/30] D-1
# --------------------------------------------------------------------------------
# 한글 입력: "중장비 대여, 굴삭기 렌탈 서비스"
#
# 대조군 A: "A vibrant construction site bustling with activity, showcasing a variety of heavy machinery for rent. In the foreground, a large, bright yellow excavator is digging into the earth, its arm raised high..."
#
# 실험군 B: "Aerial top-down view of multiple excavators neatly arranged in a rental equipment yard, each machine facing the same direction as if prepared for immediate dispatch, a technician in a high-visibility ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 정돈된 구성과 전문적인 사진 촬영 느낌으로 중장비의 견고함과 기능성을 잘 전달하여 광고 이미지 생성에 더 적합합니다.
#
# [7/30] D-1
# --------------------------------------------------------------------------------
# 한글 입력: "바닥재 전문, 마루/장판 시공"
#
# 대조군 A: "A cozy interior scene showcasing a beautifully finished wooden floor installation in a modern living room. The room is bathed in warm, natural light streaming through large windows, highlighting the r..."
#
# 실험군 B: "Flooring installation scene showing skilled craftsmen fitting engineered wood planks and luxury vinyl tiles across a clean commercial showroom floor, captured as a single composed product-focused shot..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 78점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 바닥재 시공의 산업적 미학과 내구성을 강조하며, 제품의 기능성을 명확하게 전달합니다. 이는 D-1 업종의 광고 이미지 생성에 더 적합합니다.
#
# [8/30] D-1
# --------------------------------------------------------------------------------
# 한글 입력: "의료기기 판매, 혈압계/체온계 세트"
#
# 대조군 A: "A modern medical device showroom featuring a sleek display of a blood pressure monitor and a digital thermometer set. The setting is well-lit, with bright, soft lighting that enhances the clean, clini..."
#
# 실험군 B: "Blood pressure monitor and digital thermometer set arranged as a professional product catalog composition, the blood pressure unit placed frontal three-quarter with cuff neatly coiled to the side and ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 제품의 질감과 기능성을 세밀하게 설명하고, 조명과 구성을 통해 제품의 실용성을 강조하여 의료기기 광고에 더 적합합니다.
#
# [9/30] D-1
# --------------------------------------------------------------------------------
# 한글 입력: "중고 물품점, 가전제품 매입/판매"
#
# 대조군 A: "An inviting second-hand store filled with a variety of used electronics. The scene is set inside a cozy, well-lit shop with warm wooden shelves displaying an array of appliances, including vintage rad..."
#
# 실험군 B: "A clean, professional product display of gently used household appliances arranged for buy-and-sell evaluation, front-facing and slightly staggered to show depth and different silhouettes. Shot on a C..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 80점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 산업적 미학과 금속 질감을 강조하여 D-1 등급의 특성을 잘 반영하고 있으며, 전문적인 조명과 구성을 통해 제품의 기능성과 실용성을 효과적으로 전달합니다.
#
# [10/30] D-1
# --------------------------------------------------------------------------------
# 한글 입력: "사료 전문점, 반려동물 사료 할인"
#
# 대조군 A: "A cozy pet food store interior, filled with colorful bags of various pet foods lining the wooden shelves. The setting is warmly lit with soft, ambient lights creating a welcoming atmosphere. In the fo..."
#
# 실험군 B: "A neatly organized display of pet food bags and cans on industrial metal shelving in a specialty pet food store, photographed as a commercial catalog-style shot to emphasize a promotional discount. Sh..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 64점
#    실험군 B 점수: 87점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 산업적 미학과 견고함을 강조하여 D-1 업종의 특성을 잘 반영하고 있습니다. 높은 대비와 금속 질감이 포함되어 있어 전문적이고 신뢰감을 주는 이미지를 생성할 수 있습니다.
#
# [11/30] D-2
# --------------------------------------------------------------------------------
# 한글 입력: "핸드폰 매장, 최신 스마트폰 개통"
#
# 대조군 A: "A modern mobile phone store interior, showcasing the latest smartphones on sleek display tables. The setting is vibrant and bustling with activity, featuring a diverse group of customers exploring var..."
#
# 실험군 B: "A mobile phone store salesperson handing a newly activated latest smartphone to a customer at a sleek service counter, front-facing product emphasis with the device slightly angled to reveal its thin ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 97점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 최신 스마트폰의 금속 질감과 세부 디테일을 강조하여 제품의 첨단성과 고급스러움을 잘 전달합니다. 이는 D-2 등급의 핵심 원칙에 부합합니다.
#
# [12/30] D-2
# --------------------------------------------------------------------------------
# 한글 입력: "컴퓨터 수리점, 노트북 SSD 업그레이드"
#
# 대조군 A: "A modern computer repair shop featuring a sleek, organized workspace. In the foreground, a technician is focused on upgrading a laptop's SSD, surrounded by an array of high-tech tools and components. ..."
#
# 실험군 B: "Laptop undergoing an SSD upgrade at a professional computer repair workstation, shown in a clean, front-facing close-up where a technician's gloved hands are gently sliding an M.2 NVMe SSD into the op..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 76점
#    실험군 B 점수: 90점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 고급 카메라 설정과 조명을 통해 제품의 세부 사항과 질감을 강조하며, 산업적 미학과 기능성을 잘 전달합니다. 이는 D-2 업종의 광고 이미지에 적합합니다.
#
# [13/30] D-2
# --------------------------------------------------------------------------------
# 한글 입력: "가전제품 매장, 에어컨 여름 특가"
#
# 대조군 A: "A bustling electronics store showcasing a summer promotion on air conditioning units. The scene is filled with various models of sleek, modern air conditioners displayed prominently on polished shelve..."
#
# 실험군 B: "Air conditioner displayed as the main subject in a clean appliance store showroom, presented in a front-facing, slightly three-quarter angle on a white glossy pedestal to emphasize its form and vents...."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 78점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 에어컨의 세부적인 질감과 기능성을 강조하며, 전문적인 조명과 촬영 기법을 통해 제품의 고급스러움과 첨단 느낌을 잘 전달합니다. 이는 가전제품 매장의 광고 이미지 생성에 더 적합합니다.
#
# [14/30] D-2
# --------------------------------------------------------------------------------
# 한글 입력: "복합기 임대, 사무실 프린터 렌탈"
#
# 대조군 A: "A modern office setting showcasing a sleek multifunction printer in a well-organized workspace. The printer, with its glossy black and silver finish, is placed on a light wooden desk surrounded by ess..."
#
# 실험군 B: "A front-facing multifunction office printer placed centrally on a seamless white backdrop, photographed as a clean commercial product shot. The device is shown upright with the paper tray slightly ope..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 제품의 세부적인 질감과 기능성을 강조하며, 고급스러운 조명과 구도로 전문적이고 첨단적인 이미지를 제공하여 D-2 업종의 광고 이미지 생성에 더 적합합니다.
#
# [15/30] D-2
# --------------------------------------------------------------------------------
# 한글 입력: "폰 수리 전문, 액정 교체 당일 수리"
#
# 대조군 A: "A modern smartphone repair shop bustling with activity, showcasing a technician working diligently on a sleek smartphone with a cracked screen. The setting is bright and welcoming, with large windows ..."
#
# 실험군 B: "Phone repair specialist replacing a cracked smartphone screen for same-day service, captured in a clean, professional repair workstation with the technician's hands carefully removing the broken glass..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 88점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 세밀한 질감과 전문적인 작업 환경을 강조하여 제품의 내구성과 기능성을 잘 전달합니다. 조명과 구도 또한 매우 정교하게 설정되어 있습니다.
#
# [16/30] D-2
# --------------------------------------------------------------------------------
# 한글 입력: "렌터카 업체, 장기 렌트 프로모션"
#
# 대조군 A: "A sleek, modern rental car parked in a picturesque setting, showcasing the concept of long-term car rental. The car, a shiny silver sedan, is positioned on a scenic coastal road with gentle waves lapp..."
#
# 실험군 B: "A premium car rental showroom scene focused on a long-term rental promotion, showing a lineup of three mid-size luxury SUVs angled toward the camera while a professional rental agent hands car keys to..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 72점
#    실험군 B 점수: 91점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 고급스러운 실내 환경과 차량의 디테일을 강조하여 렌터카의 품질과 신뢰성을 잘 전달합니다. 업종 특화 키워드를 잘 반영하여 장기 렌트 프로모션에 적합합니다.
#
# [17/30] D-2
# --------------------------------------------------------------------------------
# 한글 입력: "인력사무소, 단기 아르바이트 모집"
#
# 대조군 A: "A bustling urban scene depicting a modern job recruitment agency specializing in short-term part-time job placements. The setting features a sleek glass building with a bright, welcoming entrance ador..."
#
# 실험군 B: "An employment agency receptionist handing a clipboard with a short-term part-time job application form to a prospective applicant across a neat wooden desk, captured in a warm, welcoming moment. Shot ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 세부적인 질감과 조명, 그리고 실용성을 강조하는 면에서 더 뛰어나다. 이는 D-2 등급의 핵심 원칙에 부합한다.
#
# [18/30] D-2
# --------------------------------------------------------------------------------
# 한글 입력: "냉장고 수리, 컴프레서 교체 서비스"
#
# 대조군 A: "A close-up view of a modern kitchen featuring a refrigerator being repaired. The scene captures a technician, wearing a blue uniform and safety gloves, focused on replacing a compressor. The refrigera..."
#
# 실험군 B: "A refrigerator technician replacing a compressor in a clean commercial service scene, hands in blue nitrile gloves carefully aligning a new compact compressor into the rear compartment of a modern whi..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 산업적 미학과 기능성을 강조하는 조명과 구도를 통해 냉장고 수리의 전문성을 명확하게 전달합니다. 또한, 업종 특화 키워드를 잘 활용하여 광고 이미지 생성에 더 적합합니다.
#
# [19/30] D-2
# --------------------------------------------------------------------------------
# 한글 입력: "노트북 판매, 학생 할인 프로모션"
#
# 대조군 A: "A vibrant and modern electronics store showcasing a wide array of sleek laptops arranged neatly on wooden tables. The setting is bright and inviting, illuminated by warm overhead lights that highlight..."
#
# 실험군 B: "A modern slim laptop displayed in a commercial catalog-style product shot, placed at a three-quarter angle on a low matte-gray pedestal with the lid slightly open to reveal the keyboard and hinge deta..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 제품의 금속 질감과 견고함을 강조하며, 산업적 미학을 잘 전달합니다. 이는 D-2 등급의 핵심 원칙에 부합합니다.
#
# [20/30] D-2
# --------------------------------------------------------------------------------
# 한글 입력: "TV 수리점, 대형 TV 출장 서비스"
#
# 대조군 A: "A bustling TV repair shop filled with various models of televisions, both large and small, displayed on shelves and tables. The setting is bright and inviting, with warm ambient lighting that highligh..."
#
# 실험군 B: "A professional TV repair technician carrying a large 65‑inch flat‑screen TV during an on‑site service call in a modern, minimalist living room, captured mid‑step as he carefully aligns the TV to a wal..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 고급 카메라와 조명 설정을 통해 TV 수리의 전문성과 세부적인 질감을 잘 표현하여 첨단 기술과 실용성을 강조합니다.
#
# [21/30] E-1
# --------------------------------------------------------------------------------
# 한글 입력: "주유소 홍보, 리터당 할인 이벤트"
#
# 대조군 A: "A vibrant gas station scene during the golden hour, showcasing a bustling atmosphere with cars lining up to fuel up. The foreground features a modern gas pump, gleaming under the warm sunlight, with a..."
#
# 실험군 B: "A modern gas station forecourt photographed from a wide, slightly elevated perspective showing the full facility layout, pumps, canopy, convenience store entrance and parked car near a pump, composed ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 주유소의 인프라와 기능성을 강조하며, 산업적 미학을 잘 표현하여 광고 이미지 생성에 더 적합합니다.
#
# [22/30] E-1
# --------------------------------------------------------------------------------
# 한글 입력: "LPG 충전소, 자동차 가스 충전"
#
# 대조군 A: "A bustling LPG filling station set in an urban environment during golden hour, with the warm glow of the setting sun casting long shadows. The scene features a modern gas pump designed for LPG, with s..."
#
# 실험군 B: "LPG filling station with a passenger car actively refueling at a pump, the driver standing beside the vehicle while the nozzle is inserted into the car's LPG inlet. Shot on a Canon EOS R5 with a 24mm ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 75점
#    실험군 B 점수: 90점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 LPG 충전소의 기능성과 실용성을 강조하며, 인프라의 명확한 구성을 잘 보여줍니다. 또한, 조명과 색상이 실제 환경을 잘 반영하여 직관적입니다.
#
# [23/30] E-1
# --------------------------------------------------------------------------------
# 한글 입력: "셀프 주유소, 24시간 야간 운영"
#
# 대조군 A: "A bustling self-service gas station at night, illuminated by bright neon lights that reflect off the shiny surfaces of cars. The scene is lively, with a few vehicles parked at the fuel pumps, their dr..."
#
# 실험군 B: "Self-service gas station operating overnight under bright canopy lighting, captured in a wide-angle documentary photograph that clearly shows the full facility and pump layout. Shot on a Canon EOS R5 ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 80점
#    실험군 B 점수: 88점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 셀프 주유소의 기능성과 레이아웃을 명확하게 보여주며, 산업적 세부사항과 조명 설정이 뛰어납니다.
#
# [24/30] E-1
# --------------------------------------------------------------------------------
# 한글 입력: "세차장 겸 주유소, 셀프 세차 시설"
#
# 대조군 A: "Imagine a modern car wash and gas station hybrid, bustling with activity. The setting is bright and clean, showcasing a sleek, contemporary design. In the foreground, a row of shiny cars are lined up ..."
#
# 실험군 B: "A combined gas station and self-service car wash facility captured in a wide, documentary-style daytime photograph. Shot on a Canon EOS R5 with a 24mm lens, tripod-mounted for precise framing, apertur..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 84점
#    실험군 B 점수: 90점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 사진 촬영 기술과 장비를 구체적으로 언급하여 이미지의 명확성과 실용성을 높였으며, 시설의 기능적 레이아웃을 잘 전달합니다.
#
# [25/30] E-1
# --------------------------------------------------------------------------------
# 한글 입력: "전기차 충전소, 급속 충전 스테이션"
#
# 대조군 A: "A modern electric vehicle charging station set in a vibrant urban environment. The scene features sleek, futuristic charging units with glowing indicators, showcasing the latest in electric vehicle te..."
#
# 실험군 B: "A modern electric vehicle fast charging station photographed from a slightly elevated top-down angle, focusing on one active rapid charger in the foreground and a neat row of charging bays receding in..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 82점
#    실험군 B 점수: 92점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 전기차 충전소의 기능성과 산업적 디테일을 강조하여 실용성과 명확성을 잘 전달합니다. 또한, 조명과 색상 사용이 명확하고 실용적입니다.
#
# [26/30] E-2
# --------------------------------------------------------------------------------
# 한글 입력: "장례식장 안내, 엄숙한 추모 공간"
#
# 대조군 A: "A solemn funeral home setting, characterized by an atmosphere of deep reverence and tranquility. The interior features soft, muted colors, primarily shades of gray and white, with elegant wooden furni..."
#
# 실험군 B: "A funeral chapel interior where a funeral director in dark formal attire gently guides a small family down a central aisle toward a solemn memorial area, posed respectfully and composed to convey quie..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 94점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 장례식장의 엄숙한 분위기를 잘 전달하면서도, 구체적인 산업적 요소와 기능성을 강조하여 더 적합한 이미지를 생성할 수 있습니다.
#
# [27/30] E-2
# --------------------------------------------------------------------------------
# 한글 입력: "납골당 분양, 평화로운 영면 장소"
#
# 대조군 A: "Create a serene and peaceful scene of a modern columbarium, surrounded by a tranquil garden. The setting features elegant stone structures with intricate carvings and soft, natural colors that blend s..."
#
# 실험군 B: "A serene columbarium interior presented as a peaceful final resting place, photographed to showcase available niches and a dignified atmosphere. Shot on a full-frame camera with a 24mm lens at f/8 to ..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 86점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 실내의 세부적인 질감과 조명 설정을 통해 고급스럽고 품위 있는 분위기를 잘 전달하며, 업종 특화된 요소를 잘 반영하고 있습니다.
#
# [28/30] E-2
# --------------------------------------------------------------------------------
# 한글 입력: "상조 서비스, 장례 종합 패키지"
#
# 대조군 A: "Create a serene and respectful scene representing a comprehensive funeral service package. The setting is a tranquil funeral home with soft, warm lighting that creates a comforting atmosphere. In the ..."
#
# 실험군 B: "A dignified funeral service package presentation in an elegant funeral parlor arranged to convey a comprehensive 장례 종합 패키지. Shot as a professional interior photograph on a full-frame camera with a 35m..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 95점
#    🏆 승자: 실험군 B
#    📝 이유: B 프롬프트는 전문적인 사진 촬영 기법과 산업적 용어를 사용하여 장례 서비스의 고급스러움과 품위를 잘 전달합니다. 또한, 조명과 색상 선택이 매우 정교하여 광고 이미지로서의 완성도가 높습니다.
#
# [29/30] E-2
# --------------------------------------------------------------------------------
# 한글 입력: "수목장 안내, 자연과 함께하는 추모"
#
# 대조군 A: "A serene and tranquil woodland setting, showcasing a beautifully designed natural burial ground. The scene is bathed in soft, dappled sunlight filtering through the lush green leaves of tall trees, cr..."
#
# 실험군 B: "A serene woodland natural burial site photographed as a respectful informational scene: a small family stands quietly by a modest stone memorial and a biodegradable urn partially nestled into the fore..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 87점
#    실험군 B 점수: 93점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 인간과 자연의 연결을 강조하며, 따뜻한 조명과 세부적인 질감 표현으로 감성적이고 존중하는 분위기를 잘 전달합니다.
#
# [30/30] E-2
# --------------------------------------------------------------------------------
# 한글 입력: "추모관 홍보, 차분한 추모 시설"
#
# 대조군 A: "A serene memorial hall setting, designed for peaceful remembrance. The interior features soft, muted colors, with elegant wooden furnishings and gentle lighting that creates a calming atmosphere. Orna..."
#
# 실험군 B: "A calm, dignified memorial hall interior with a symmetrical central aisle leading the eye to a simple, respectfully designed altar, captured as a promotional photograph conveying quiet solace. Shot on..."
#
# 🔍 GPT 평가 중...
#
# 📊 평가 결과:
#    대조군 A 점수: 90점
#    실험군 B 점수: 96점
#    🏆 승자: 실험군 B
#    📝 이유: 프롬프트 B는 텍스처와 조명, 대칭적 구도를 통해 추모관의 품위와 정돈된 분위기를 잘 전달하며, 업종 특화 요소를 잘 반영하고 있음.
#
#
# ====================================================================================================
# 📈 D+E등급 (목적형 소매 + 인프라) 평가 요약
# ====================================================================================================
# 평가 케이스 수: 30/30
#
# 🏆 승패 현황:
#    대조군 A 승: 0회 (0.0%)
#    실험군 B 승: 30회 (100.0%)
#    무승부: 0회 (0.0%)
#
# 📊 평균 점수:
#    대조군 A: 82.0점
#    실험군 B: 93.0점

# %% [markdown]
# ### 6.7 전체 GPT 평가 종합 결과

# %%
# 전체 결과 종합
all_eval_results = s_eval_results + a_eval_results + bc_eval_results + de_eval_results
all_wins = {
    "A": s_wins["A"] + a_wins["A"] + bc_wins["A"] + de_wins["A"],
    "B": s_wins["B"] + a_wins["B"] + bc_wins["B"] + de_wins["B"],
    "TIE": s_wins["TIE"] + a_wins["TIE"] + bc_wins["TIE"] + de_wins["TIE"]
}

total_evaluated = len(all_eval_results)

print("\n" + "="*100)
print("🏆 전체 GPT 평가 종합 결과")
print("="*100)

print(f"\n총 평가 케이스: {total_evaluated}개")
print(f"\n📊 전체 승패 현황:")
print(f"   대조군 A 승: {all_wins['A']}회 ({all_wins['A']/total_evaluated*100:.1f}%)")
print(f"   실험군 B 승: {all_wins['B']}회 ({all_wins['B']/total_evaluated*100:.1f}%)")
print(f"   무승부: {all_wins['TIE']}회 ({all_wins['TIE']/total_evaluated*100:.1f}%)")

# 등급별 결과 테이블
print("\n" + "-"*50)
print("등급별 승패 현황")
print("-"*50)
grade_results = pd.DataFrame({
    "등급": ["S등급", "A등급", "B+C등급", "D+E등급", "전체"],
    "대조군 A 승": [s_wins["A"], a_wins["A"], bc_wins["A"], de_wins["A"], all_wins["A"]],
    "실험군 B 승": [s_wins["B"], a_wins["B"], bc_wins["B"], de_wins["B"], all_wins["B"]],
    "무승부": [s_wins["TIE"], a_wins["TIE"], bc_wins["TIE"], de_wins["TIE"], all_wins["TIE"]]
})
print(grade_results.to_string(index=False))

# 평균 점수 계산
all_scores_a = [r["score_a"] for r in all_eval_results if r.get("score_a")]
all_scores_b = [r["score_b"] for r in all_eval_results if r.get("score_b")]

if all_scores_a and all_scores_b:
    print(f"\n📈 전체 평균 점수:")
    print(f"   대조군 A: {sum(all_scores_a)/len(all_scores_a):.1f}점")
    print(f"   실험군 B: {sum(all_scores_b)/len(all_scores_b):.1f}점")
    print(f"   점수 차이: {sum(all_scores_b)/len(all_scores_b) - sum(all_scores_a)/len(all_scores_a):+.1f}점")

# 결과 저장
eval_df = pd.DataFrame([{
    "group": r["group"],
    "korean_input": r["korean_input"],
    "score_a": r["score_a"],
    "score_b": r["score_b"],
    "winner": r["winner"],
    "prompt_a": r["prompt_a"][:500],
    "prompt_b": r["prompt_b"][:500]
} for r in all_eval_results])

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
eval_output_path = f"ab_test_gpt_evaluation_{timestamp}.csv"
eval_df.to_csv(eval_output_path, index=False, encoding='utf-8-sig')
print(f"\n💾 GPT 평가 결과 저장 완료: {eval_output_path}")
# Out:
# ====================================================================================================
# 🏆 전체 GPT 평가 종합 결과
# ====================================================================================================
#
# 총 평가 케이스: 170개
#
# 📊 전체 승패 현황:
#    대조군 A 승: 0회 (0.0%)
#    실험군 B 승: 170회 (100.0%)
#    무승부: 0회 (0.0%)
#
# --------------------------------------------------
# 등급별 승패 현황
# --------------------------------------------------
#    등급  대조군 A 승  실험군 B 승  무승부
#   S등급        0       40    0
#   A등급        0       40    0
# B+C등급        0       60    0
# D+E등급        0       30    0
#    전체        0      170    0
#
# 📈 전체 평균 점수:
#    대조군 A: 84.8점
#    실험군 B: 94.0점
#    점수 차이: +9.2점
#
# 💾 GPT 평가 결과 저장 완료: ab_test_gpt_evaluation_20260122_121113.csv

# %% [markdown]
# ## 7. 상세 평가 분석 (샘플)

# %%
def display_detailed_evaluation(results, n_samples=2):
    """
    상세 평가 결과를 보기 좋게 출력
    """
    import random
    samples = random.sample(results, min(n_samples, len(results)))

    for i, sample in enumerate(samples, 1):
        evaluation = sample.get("evaluation", {})
        eval_a = evaluation.get("evaluation_a", {})
        eval_b = evaluation.get("evaluation_b", {})

        print(f"\n{'='*100}")
        print(f"📋 상세 평가 샘플 {i}: {sample['group']}")
        print(f"{'='*100}")

        print(f"\n📝 한글 입력: \"{sample['korean_input']}\"")

        print(f"\n{'─'*50}")
        print("🔵 대조군 A")
        print(f"{'─'*50}")
        print(f"프롬프트: \"{sample['prompt_a'][:300]}...\"" if len(sample['prompt_a']) > 300 else f"프롬프트: \"{sample['prompt_a']}\"")
        print(f"\n점수 상세:")
        print(f"  - 질감/주제 표현: {eval_a.get('texture_or_subject', 'N/A')}/20")
        print(f"  - 조명 설정: {eval_a.get('lighting', 'N/A')}/20")
        print(f"  - 색감/분위기: {eval_a.get('color_mood', 'N/A')}/20")
        print(f"  - 구도/앵글: {eval_a.get('composition', 'N/A')}/20")
        print(f"  - 업종 특화: {eval_a.get('industry_specific', 'N/A')}/20")
        print(f"  📊 총점: {eval_a.get('total', 'N/A')}/100")
        print(f"\n강점: {eval_a.get('strengths', 'N/A')}")
        print(f"약점: {eval_a.get('weaknesses', 'N/A')}")

        print(f"\n{'─'*50}")
        print("🟢 실험군 B")
        print(f"{'─'*50}")
        print(f"프롬프트: \"{sample['prompt_b'][:300]}...\"" if len(sample['prompt_b']) > 300 else f"프롬프트: \"{sample['prompt_b']}\"")
        print(f"\n점수 상세:")
        print(f"  - 질감/주제 표현: {eval_b.get('texture_or_subject', 'N/A')}/20")
        print(f"  - 조명 설정: {eval_b.get('lighting', 'N/A')}/20")
        print(f"  - 색감/분위기: {eval_b.get('color_mood', 'N/A')}/20")
        print(f"  - 구도/앵글: {eval_b.get('composition', 'N/A')}/20")
        print(f"  - 업종 특화: {eval_b.get('industry_specific', 'N/A')}/20")
        print(f"  📊 총점: {eval_b.get('total', 'N/A')}/100")
        print(f"\n강점: {eval_b.get('strengths', 'N/A')}")
        print(f"약점: {eval_b.get('weaknesses', 'N/A')}")

        print(f"\n{'─'*50}")
        print("🏆 평가 결론")
        print(f"{'─'*50}")
        winner = evaluation.get('winner', 'N/A')
        print(f"승자: {'대조군 A' if winner == 'A' else '실험군 B' if winner == 'B' else '무승부'}")
        print(f"이유: {evaluation.get('winner_reason', 'N/A')}")
        print(f"\n상세 비교: {evaluation.get('detailed_comparison', 'N/A')}")

# 전체 평가 결과에서 샘플 출력
if all_eval_results:
    print("\n" + "#"*100)
    print("# 상세 평가 분석 샘플")
    print("#"*100)
    display_detailed_evaluation(all_eval_results, 3)
# Out:
# ####################################################################################################
# # 상세 평가 분석 샘플
# ####################################################################################################
#
# ====================================================================================================
# 📋 상세 평가 샘플 1: S-1
# ====================================================================================================
#
# 📝 한글 입력: "마라탕 전문점, 얼얼하게 매운 국물과 재료들"
#
# ──────────────────────────────────────────────────
# 🔵 대조군 A
# ──────────────────────────────────────────────────
# 프롬프트: "A vibrant and enticing scene of a traditional mala tang restaurant, showcasing a steaming pot filled with a rich, spicy broth. The broth is a deep red color, bubbling energetically, with visible spices and herbs floating on the surface, creating an aromatic allure. Surrounding the hot pot, an array ..."
#
# 점수 상세:
#   - 질감/주제 표현: 18/20
#   - 조명 설정: 18/20
#   - 색감/분위기: 18/20
#   - 구도/앵글: 17/20
#   - 업종 특화: 18/20
#   📊 총점: 89/100
#
# 강점: 음식의 질감과 분위기를 잘 표현하고 있으며, 따뜻한 조명과 다양한 색감이 매력적이다.
# 약점: 구체적인 카메라 설정이나 촬영 기법에 대한 언급이 부족하다.
#
# ──────────────────────────────────────────────────
# 🟢 실험군 B
# ──────────────────────────────────────────────────
# 프롬프트: "Mala tang hot pot spread with a numbing, tongue-tingling spicy broth and neatly arranged fresh ingredients, presented in a top-down flat lay across a wooden dining table. Shot on a professional full-frame camera with a 35mm prime lens mounted overhead to capture the entire composition, aperture arou..."
#
# 점수 상세:
#   - 질감/주제 표현: 20/20
#   - 조명 설정: 19/20
#   - 색감/분위기: 19/20
#   - 구도/앵글: 20/20
#   - 업종 특화: 20/20
#   📊 총점: 98/100
#
# 강점: 세부적인 촬영 기법과 질감 표현이 뛰어나며, 업종에 특화된 전문 용어가 잘 사용되었다.
# 약점: 전반적으로 매우 뛰어나지만, 감성적인 묘사보다는 기술적인 설명이 강조되어 있다.
#
# ──────────────────────────────────────────────────
# 🏆 평가 결론
# ──────────────────────────────────────────────────
# 승자: 실험군 B
# 이유: 프롬프트 B는 촬영 기법과 질감 표현에서 더 높은 점수를 받았으며, 업종에 특화된 키워드 사용이 뛰어나다.
#
# 상세 비교: 프롬프트 A는 따뜻한 조명과 다양한 색감으로 감성적인 분위기를 잘 전달하지만, 구체적인 촬영 기법에 대한 언급이 부족하다. 반면, 프롬프트 B는 전문적인 촬영 기법과 질감 표현이 매우 뛰어나며, 업종에 특화된 용어 사용이 돋보인다. B 프롬프트는 특히 디테일한 질감 표현과 조명 설정에서 더 높은 점수를 받았다.
#
# ====================================================================================================
# 📋 상세 평가 샘플 2: C-3
# ====================================================================================================
#
# 📝 한글 입력: "이사업체 안내, 원룸 포장이사 서비스"
#
# ──────────────────────────────────────────────────
# 🔵 대조군 A
# ──────────────────────────────────────────────────
# 프롬프트: "A cozy, well-decorated one-room apartment in the process of being packed for a move. The room is filled with various moving boxes, some stacked neatly while others are partially open, revealing items like clothes, books, and kitchenware. A friendly moving team, dressed in uniforms, is carefully wrap..."
#
# 점수 상세:
#   - 질감/주제 표현: 16/20
#   - 조명 설정: 17/20
#   - 색감/분위기: 15/20
#   - 구도/앵글: 15/20
#   - 업종 특화: 14/20
#   📊 총점: 77/100
#
# 강점: 프롬프트 A는 따뜻하고 아늑한 분위기를 잘 전달하며, 이사 과정의 감정적인 측면을 강조합니다.
# 약점: 전문성과 신뢰성을 강조하기보다는 감정적인 요소에 치중하여 업종 특화 요소가 부족합니다.
#
# ──────────────────────────────────────────────────
# 🟢 실험군 B
# ──────────────────────────────────────────────────
# 프롬프트: "Studio one-room apartment packing and moving service in action, professional movers carefully packing and organizing a small urban apartment for relocation. Shot like a commercial documentary photograph on a Canon EOS R5 with a 35mm f/1.4 lens, slightly elevated three-quarter angle to show both peop..."
#
# 점수 상세:
#   - 질감/주제 표현: 18/20
#   - 조명 설정: 18/20
#   - 색감/분위기: 17/20
#   - 구도/앵글: 18/20
#   - 업종 특화: 18/20
#   📊 총점: 89/100
#
# 강점: 프롬프트 B는 전문적인 장비와 구도를 활용하여 신뢰성과 효율성을 강조하며, 업종 특화 요소가 잘 반영되어 있습니다.
# 약점: 약간의 감정적인 요소가 부족할 수 있지만, 전체적으로 전문성과 신뢰성을 잘 전달합니다.
#
# ──────────────────────────────────────────────────
# 🏆 평가 결론
# ──────────────────────────────────────────────────
# 승자: 실험군 B
# 이유: 프롬프트 B는 전문성과 신뢰성을 강조하며, 업종 특화 요소가 잘 반영되어 있어 광고 이미지 생성에 더 적합합니다.
#
# 상세 비교: 프롬프트 A는 따뜻하고 감정적인 분위기를 강조하지만, 업종 특화 요소가 부족합니다. 반면, 프롬프트 B는 전문적인 구도와 장비를 활용하여 신뢰성과 효율성을 강조하며, 업종 특화 요소가 잘 반영되어 있습니다. 따라서, 프롬프트 B가 광고 이미지 생성에 더 적합합니다.
#
# ====================================================================================================
# 📋 상세 평가 샘플 3: D-2
# ====================================================================================================
#
# 📝 한글 입력: "핸드폰 매장, 최신 스마트폰 개통"
#
# ──────────────────────────────────────────────────
# 🔵 대조군 A
# ──────────────────────────────────────────────────
# 프롬프트: "A modern mobile phone store interior, showcasing the latest smartphones on sleek display tables. The setting is vibrant and bustling with activity, featuring a diverse group of customers exploring various high-tech devices. Bright, overhead LED lights illuminate the space, casting a warm glow on the..."
#
# 점수 상세:
#   - 질감/주제 표현: 18/20
#   - 조명 설정: 18/20
#   - 색감/분위기: 16/20
#   - 구도/앵글: 17/20
#   - 업종 특화: 18/20
#   📊 총점: 87/100
#
# 강점: 활기찬 매장 분위기와 최신 스마트폰의 첨단 기능을 강조하며 다양한 고객 상호작용을 잘 표현함.
# 약점: 조금 더 명확한 제품 촬영과 금속 질감 강조가 부족할 수 있음.
#
# ──────────────────────────────────────────────────
# 🟢 실험군 B
# ──────────────────────────────────────────────────
# 프롬프트: "A mobile phone store salesperson handing a newly activated latest smartphone to a customer at a sleek service counter, front-facing product emphasis with the device slightly angled to reveal its thin metal frame and glass display. Shot as professional retail product photography on a Canon EOS R5 wit..."
#
# 점수 상세:
#   - 질감/주제 표현: 20/20
#   - 조명 설정: 20/20
#   - 색감/분위기: 18/20
#   - 구도/앵글: 19/20
#   - 업종 특화: 20/20
#   📊 총점: 97/100
#
# 강점: 최신 스마트폰의 금속 질감과 세부 디테일을 완벽하게 강조하며, 전문적인 제품 촬영 기술을 활용하여 고급스러운 느낌을 잘 전달함.
# 약점: 매장의 활기찬 분위기보다는 제품 자체에 집중되어 있어 매장 전체의 분위기를 전달하는 데는 한계가 있을 수 있음.
#
# ──────────────────────────────────────────────────
# 🏆 평가 결론
# ──────────────────────────────────────────────────
# 승자: 실험군 B
# 이유: B 프롬프트는 최신 스마트폰의 금속 질감과 세부 디테일을 강조하여 제품의 첨단성과 고급스러움을 잘 전달합니다. 이는 D-2 등급의 핵심 원칙에 부합합니다.
#
# 상세 비교: A 프롬프트는 매장의 활기찬 분위기와 고객 상호작용을 잘 표현하지만, 제품 자체의 금속 질감과 세부 디테일 강조가 부족합니다. 반면 B 프롬프트는 전문적인 촬영 기술을 활용하여 제품의 금속 질감과 세부 디테일을 강조하며, 첨단성과 고급스러움을 잘 전달합니다. 따라서 B 프롬프트가 D-2 등급의 광고 이미지 생성에 더 적합합니다.

# %% [markdown]
# ## 8. 결론
#
# ### 실험 설계
#
# | 항목 | 대조군 A | 실험군 B |
# |------|---------|----------|
# | 방식 | 일반 OpenAI API | 업종별 특화 시스템 |
# | 프롬프트 구조 | 단순 번역 + 일반 지시문 | 18개 하위 그룹별 최적화 |
# | 업종 키워드 | X | O (YAML 기반) |
# | 조명/색감 가이드 | X | O (업종별 특화) |
# | 구도/스타일 | 일반적 | 업종 맞춤형 |
#
# ### GPT 평가 기준 (업종별_분류_및_광고전략.md 기반)
#
# | 평가 항목 | 배점 | 설명 |
# |----------|------|------|
# | 질감/주제 표현 | 20점 | 업종별 핵심 비주얼 요소 표현 |
# | 조명 설정 | 20점 | 업종에 맞는 조명 명시 |
# | 색감/분위기 | 20점 | 적절한 색감과 무드 표현 |
# | 구도/앵글 | 20점 | 촬영 구도와 앵글 명시 |
# | 업종 특화 키워드 | 20점 | 업종별 전문 용어 포함 |
# | **총점** | **100점** | |
#
# ### 기대 효과
#
# 1. **업종별 최적화**: 실험군 B는 각 업종의 특성을 반영한 키워드, 조명, 구도를 자동 적용
# 2. **일관된 품질**: 동일 업종 내에서 일관된 비주얼 스타일 유지
# 3. **전문성**: 업종별 전문 용어와 비주얼 문법 활용
# 4. **객관적 검증**: GPT 기반 자동 평가로 품질 차이를 정량적으로 측정

# %% [markdown]
# ## 9. B 실험군 패배/무승부 케이스 분석
#
# 실험군 B(업종별 특화 시스템)가 대조군 A(일반 OpenAI API)에게 패배하거나 무승부인 케이스를 분석합니다.
# 이 케이스들은 `industries.yaml` 템플릿 개선의 핵심 데이터가 됩니다.

# %%
# ============================================
# B 실험군 패배/무승부 케이스 수집 및 분석
# ============================================

def collect_b_loss_or_tie_cases(all_eval_results: List[Dict]) -> List[Dict]:
    """
    B 실험군이 패배하거나 무승부인 케이스 수집
    
    Args:
        all_eval_results: 전체 GPT 평가 결과 리스트
    
    Returns:
        B가 지거나 비긴 케이스 리스트
    """
    b_loss_or_tie = []
    
    for result in all_eval_results:
        winner = result.get("winner")
        if winner in ["A", "TIE"]:  # A가 이기거나 무승부
            b_loss_or_tie.append(result)
    
    return b_loss_or_tie


def display_b_loss_cases(cases: List[Dict], title: str = "B 실험군 패배/무승부 케이스"):
    """
    B 실험군 패배/무승부 케이스를 상세히 출력
    """
    print(f"\n{'='*120}")
    print(f"📊 {title}")
    print(f"{'='*120}")
    print(f"총 {len(cases)}개 케이스 (A 승리 또는 무승부)\n")
    
    # 승패별 분류
    a_wins = [c for c in cases if c.get("winner") == "A"]
    ties = [c for c in cases if c.get("winner") == "TIE"]
    
    print(f"  - A 승리: {len(a_wins)}개")
    print(f"  - 무승부: {len(ties)}개")
    
    # 그룹별 분류
    group_counts = {}
    for case in cases:
        group = case.get("group", "Unknown")
        group_counts[group] = group_counts.get(group, 0) + 1
    
    print(f"\n📌 그룹별 분포:")
    for group, count in sorted(group_counts.items()):
        print(f"  - {group}: {count}개")
    
    print(f"\n{'='*120}")
    print("상세 케이스 분석")
    print(f"{'='*120}\n")
    
    for i, case in enumerate(cases, 1):
        group = case.get("group", "Unknown")
        korean_input = case.get("korean_input", "N/A")
        prompt_a = case.get("prompt_a", "N/A")
        prompt_b = case.get("prompt_b", "N/A")
        score_a = case.get("score_a", "N/A")
        score_b = case.get("score_b", "N/A")
        winner = case.get("winner", "N/A")
        evaluation = case.get("evaluation", {})
        
        winner_label = "🏆 A 승리" if winner == "A" else "🤝 무승부"
        
        print(f"\n[{i}/{len(cases)}] {group} - {winner_label}")
        print(f"-" * 100)
        
        # 입력 및 결과
        print(f"\n📝 한글 입력:")
        print(f"   \"{korean_input}\"")
        
        print(f"\n🅰️ 대조군 A 프롬프트 (점수: {score_a}점):")
        print(f"   \"{prompt_a[:300]}{'...' if len(str(prompt_a)) > 300 else ''}\"")
        
        print(f"\n🅱️ 실험군 B 프롬프트 (점수: {score_b}점):")
        print(f"   \"{prompt_b[:300]}{'...' if len(str(prompt_b)) > 300 else ''}\"")
        
        # GPT 평가 상세 내용
        if evaluation and "error" not in evaluation:
            eval_a = evaluation.get("evaluation_a", {})
            eval_b = evaluation.get("evaluation_b", {})
            
            print(f"\n📊 GPT 평가 상세:")
            print(f"   [대조군 A]")
            print(f"   - 질감/피사체: {eval_a.get('texture_or_subject', 'N/A')}점")
            print(f"   - 조명: {eval_a.get('lighting', 'N/A')}점")
            print(f"   - 색감/분위기: {eval_a.get('color_mood', 'N/A')}점")
            print(f"   - 구도: {eval_a.get('composition', 'N/A')}점")
            print(f"   - 업종 특화: {eval_a.get('industry_specific', 'N/A')}점")
            print(f"   - 강점: {eval_a.get('strengths', 'N/A')}")
            print(f"   - 약점: {eval_a.get('weaknesses', 'N/A')}")
            
            print(f"\n   [실험군 B]")
            print(f"   - 질감/피사체: {eval_b.get('texture_or_subject', 'N/A')}점")
            print(f"   - 조명: {eval_b.get('lighting', 'N/A')}점")
            print(f"   - 색감/분위기: {eval_b.get('color_mood', 'N/A')}점")
            print(f"   - 구도: {eval_b.get('composition', 'N/A')}점")
            print(f"   - 업종 특화: {eval_b.get('industry_specific', 'N/A')}점")
            print(f"   - 강점: {eval_b.get('strengths', 'N/A')}")
            print(f"   - 약점: {eval_b.get('weaknesses', 'N/A')}")
            
            print(f"\n   📝 승패 이유: {evaluation.get('winner_reason', 'N/A')}")
            print(f"   📝 상세 비교: {evaluation.get('detailed_comparison', 'N/A')}")
        
        print(f"\n{'─'*100}")
    
    return cases


# B 패배/무승부 케이스 수집
b_loss_or_tie_cases = collect_b_loss_or_tie_cases(all_eval_results)

# 상세 출력
display_b_loss_cases(b_loss_or_tie_cases, "이미지 프롬프트 B 실험군 패배/무승부 케이스")

# %% [markdown]
# ## 10. industries.yaml 개선사항 제안
#
# B 실험군 패배/무승부 케이스를 분석하여 `src/generation/image_generation/prompt/config/industries.yaml` 파일의 개선사항을 GPT를 활용해 구체적으로 제안합니다.

# %%
# ============================================
# industries.yaml 개선사항 제안 시스템
# ============================================

def generate_improvement_suggestions(
    b_loss_cases: List[Dict],
    yaml_file_path: str = "src/generation/image_generation/prompt/config/industries.yaml"
) -> Dict:
    """
    B 패배/무승부 케이스를 분석하여 industries.yaml 개선사항 제안
    
    Args:
        b_loss_cases: B가 지거나 비긴 케이스 리스트
        yaml_file_path: industries.yaml 파일 경로
    
    Returns:
        그룹별 개선사항 딕셔너리
    """
    if not b_loss_cases:
        print("분석할 B 패배/무승부 케이스가 없습니다.")
        return {}
    
    # 그룹별로 케이스 분류
    cases_by_group = {}
    for case in b_loss_cases:
        group = case.get("group", "Unknown")
        if group not in cases_by_group:
            cases_by_group[group] = []
        cases_by_group[group].append(case)
    
    print(f"\n{'='*120}")
    print(f"🔧 industries.yaml 개선사항 제안")
    print(f"{'='*120}")
    print(f"대상 파일: {yaml_file_path}")
    print(f"분석 대상: {len(b_loss_cases)}개 케이스 ({len(cases_by_group)}개 그룹)")
    print(f"{'='*120}\n")
    
    all_suggestions = {}
    
    for group, cases in cases_by_group.items():
        print(f"\n{'─'*100}")
        print(f"📌 {group} 그룹 분석 중... ({len(cases)}개 케이스)")
        print(f"{'─'*100}")
        
        # 케이스 요약 생성
        case_summaries = []
        for case in cases:
            summary = {
                "korean_input": case.get("korean_input", ""),
                "prompt_a": case.get("prompt_a", "")[:500],  # 너무 길면 자름
                "prompt_b": case.get("prompt_b", "")[:500],
                "score_a": case.get("score_a"),
                "score_b": case.get("score_b"),
                "winner": case.get("winner"),
                "evaluation": {
                    "a_strengths": case.get("evaluation", {}).get("evaluation_a", {}).get("strengths", ""),
                    "a_weaknesses": case.get("evaluation", {}).get("evaluation_a", {}).get("weaknesses", ""),
                    "b_strengths": case.get("evaluation", {}).get("evaluation_b", {}).get("strengths", ""),
                    "b_weaknesses": case.get("evaluation", {}).get("evaluation_b", {}).get("weaknesses", ""),
                    "winner_reason": case.get("evaluation", {}).get("winner_reason", ""),
                    "detailed_comparison": case.get("evaluation", {}).get("detailed_comparison", "")
                }
            }
            case_summaries.append(summary)
        
        # GPT에게 개선사항 요청
        system_prompt = """당신은 소상공인 광고 이미지 생성 시스템의 프롬프트 템플릿 전문가입니다.
A/B 테스트 결과를 분석하여 industries.yaml 파일의 개선사항을 제안합니다.

industries.yaml 파일은 다음과 같은 구조를 가집니다:
```yaml
industries:
  카테고리명:
    keywords: [키워드1, 키워드2, ...]
    lighting: "조명 설정"
    composition: "구도 설정"
    color_palette: [색상1, 색상2, ...]
    mood: "분위기"
    style: "스타일"
    prompt_template: "프롬프트 템플릿"
```

분석 결과를 바탕으로 다음을 제안해주세요:
1. 어떤 키워드를 추가/수정해야 하는지
2. 조명 설정을 어떻게 개선해야 하는지
3. 구도 설정을 어떻게 개선해야 하는지
4. 색상 팔레트를 어떻게 개선해야 하는지
5. 분위기와 스타일을 어떻게 개선해야 하는지
6. 프롬프트 템플릿을 어떻게 개선해야 하는지

반드시 JSON 형식으로 출력하세요."""

        user_prompt = f"""## 분석 대상 그룹
{group}

## A/B 테스트 결과 (B 실험군이 패배하거나 무승부인 케이스)
{json.dumps(case_summaries, ensure_ascii=False, indent=2)}

## 요청사항
위 케이스들을 분석하여 실험군 B(업종별 특화 시스템)가 대조군 A(일반 시스템)보다 성능이 떨어진 원인을 파악하고,
industries.yaml 파일의 해당 그룹 설정을 어떻게 개선해야 하는지 구체적으로 제안해주세요.

특히:
1. 대조군 A가 더 좋았던 이유 분석
2. 실험군 B의 약점 분석
3. industries.yaml에서 개선해야 할 구체적인 항목과 값

출력 형식:
{{
    "group": "{group}",
    "analysis": {{
        "why_a_won": "A가 더 좋았던 이유",
        "b_weaknesses": "B의 약점 분석",
        "common_patterns": "공통적으로 발견된 패턴"
    }},
    "improvements": {{
        "keywords": {{
            "add": ["추가할 키워드들"],
            "remove": ["제거할 키워드들"],
            "reason": "키워드 변경 이유"
        }},
        "lighting": {{
            "current_issue": "현재 조명 설정의 문제점",
            "suggestion": "개선된 조명 설정",
            "reason": "변경 이유"
        }},
        "composition": {{
            "current_issue": "현재 구도 설정의 문제점",
            "suggestion": "개선된 구도 설정",
            "reason": "변경 이유"
        }},
        "color_palette": {{
            "add": ["추가할 색상들"],
            "remove": ["제거할 색상들"],
            "reason": "색상 변경 이유"
        }},
        "mood_style": {{
            "current_issue": "현재 분위기/스타일 문제점",
            "suggestion": "개선된 분위기/스타일",
            "reason": "변경 이유"
        }},
        "prompt_template": {{
            "current_issue": "현재 템플릿 문제점",
            "suggestion": "개선된 템플릿 예시",
            "reason": "변경 이유"
        }}
    }},
    "priority": "높음/중간/낮음",
    "summary": "전체 개선사항 요약 (2-3문장)"
}}"""

        try:
            response = client.chat.completions.create(
                model="gpt-4o",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_prompt}
                ],
                temperature=0.5,
                response_format={"type": "json_object"}
            )
            
            suggestion = json.loads(response.choices[0].message.content)
            all_suggestions[group] = suggestion
            
            # 결과 출력
            print(f"\n✅ {group} 분석 완료")
            print(f"\n📊 분석 결과:")
            print(f"   - A 승리 이유: {suggestion.get('analysis', {}).get('why_a_won', 'N/A')}")
            print(f"   - B 약점: {suggestion.get('analysis', {}).get('b_weaknesses', 'N/A')}")
            print(f"\n🔧 주요 개선사항:")
            
            improvements = suggestion.get('improvements', {})
            
            if improvements.get('keywords', {}).get('add'):
                print(f"   - 키워드 추가: {improvements['keywords']['add']}")
            if improvements.get('lighting', {}).get('suggestion'):
                print(f"   - 조명 개선: {improvements['lighting']['suggestion']}")
            if improvements.get('composition', {}).get('suggestion'):
                print(f"   - 구도 개선: {improvements['composition']['suggestion']}")
            if improvements.get('prompt_template', {}).get('suggestion'):
                print(f"   - 템플릿 개선: {improvements['prompt_template']['suggestion'][:200]}...")
            
            print(f"\n   📌 우선순위: {suggestion.get('priority', 'N/A')}")
            print(f"   📝 요약: {suggestion.get('summary', 'N/A')}")
            
        except Exception as e:
            print(f"   ❌ 분석 오류: {str(e)}")
            all_suggestions[group] = {"error": str(e)}
        
        # API 레이트 리밋 방지
        import time
        time.sleep(1)
    
    return all_suggestions


# 개선사항 생성
improvement_suggestions = generate_improvement_suggestions(b_loss_or_tie_cases)

# %%
# ============================================
# 개선사항 종합 보고서 저장
# ============================================

def save_improvement_report(
    suggestions: Dict,
    b_loss_cases: List[Dict],
    output_path: str = "260122_이미지프롬프트_개선사항_보고서.json"
):
    """
    개선사항 보고서를 JSON 파일로 저장
    """
    report = {
        "report_type": "이미지 프롬프트 템플릿 개선사항",
        "target_file": "src/generation/image_generation/prompt/config/industries.yaml",
        "analysis_date": pd.Timestamp.now().strftime("%Y-%m-%d %H:%M:%S"),
        "total_b_loss_cases": len(b_loss_cases),
        "groups_analyzed": len(suggestions),
        "suggestions_by_group": suggestions,
        "b_loss_cases_detail": b_loss_cases
    }
    
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(report, f, ensure_ascii=False, indent=2)
    
    print(f"\n✅ 개선사항 보고서 저장 완료: {output_path}")
    return report


# 보고서 저장
improvement_report = save_improvement_report(
    improvement_suggestions,
    b_loss_or_tie_cases,
    "260122_이미지프롬프트_개선사항_보고서.json"
)

# 종합 요약 출력
print(f"\n{'='*120}")
print("📋 이미지 프롬프트 템플릿 개선사항 종합 요약")
print(f"{'='*120}")

priority_high = [g for g, s in improvement_suggestions.items() if s.get('priority') == '높음']
priority_medium = [g for g, s in improvement_suggestions.items() if s.get('priority') == '중간']
priority_low = [g for g, s in improvement_suggestions.items() if s.get('priority') == '낮음']

print(f"\n🔴 높은 우선순위 ({len(priority_high)}개 그룹): {priority_high}")
print(f"🟡 중간 우선순위 ({len(priority_medium)}개 그룹): {priority_medium}")
print(f"🟢 낮은 우선순위 ({len(priority_low)}개 그룹): {priority_low}")

print(f"\n📝 그룹별 핵심 개선사항:")
for group, suggestion in improvement_suggestions.items():
    if "error" not in suggestion:
        print(f"\n  [{group}]")
        print(f"  {suggestion.get('summary', 'N/A')}")
